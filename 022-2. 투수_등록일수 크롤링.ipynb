# %% [markdown]
# # Load Package

# %%
import time
import os
import warnings

import pandas as pd 

from selenium import webdriver
from selenium.webdriver.chrome.options import Options

warnings.filterwarnings(action='ignore')

options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")

# %% [markdown]
# # 내용 크롤링 함수화

# %%
def first_info_crawling(players): 
    
    ### 크롤링
    PLAYER = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[2]/a')[0].text for player in range(1, players+1)]
    ID = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[2]/a')[0].get_attribute('href').split('=')[1] for player in range(1, players+1)]
    TEAM = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[3]')[0].text for player in range(1, players+1)]
    ERA = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[4]')[0].text for player in range(1, players+1)]
    G = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[5]')[0].text for player in range(1, players+1)]
    W = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[6]')[0].text for player in range(1, players+1)]
    L = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[7]')[0].text for player in range(1, players+1)]
    SV = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[8]')[0].text for player in range(1, players+1)]
    HLD = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[9]')[0].text for player in range(1, players+1)]
    WPCT = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[10]')[0].text for player in range(1, players+1)]
    IP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[11]')[0].text for player in range(1, players+1)]
    H = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[12]')[0].text for player in range(1, players+1)]
    HR = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[13]')[0].text for player in range(1, players+1)]
    BB = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[14]')[0].text for player in range(1, players+1)]
    HBP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[15]')[0].text for player in range(1, players+1)]
    SO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[16]')[0].text for player in range(1, players+1)]
    R = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[17]')[0].text for player in range(1, players+1)]
    ER = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[18]')[0].text for player in range(1, players+1)]
    WHIP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[19]')[0].text for player in range(1, players+1)]
    

    # 데이터프레임 만들기
    df = pd.DataFrame({'선수명' : PLAYER,
                      'ID' : ID,
                      '팀명' : TEAM,
                      '평균자책점' : ERA,
                      '경기' : G,
                      '승리' : W,
                      '패배' : L,
                      '세이브' : SV,
                      '홀드' : HLD,
                      '승률' : WPCT,
                      '이닝' : IP,
                      '피안타' : H,
                      '홈런' : HR,
                      '볼넷' : BB,
                      '사구' : HBP,
                      '삼진' : SO,
                      '실점' : R,
                      '자책점' : ER,
                      '이닝당_출루허용률' : WHIP})

    return df

# %%
def second_info_crawling(players): 
    
    ### 크롤링
    CG = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[5]')[0].text for player in range(1, players+1)]
    SHO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[6]')[0].text for player in range(1, players+1)]
    QS = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[7]')[0].text for player in range(1, players+1)]
    BSV = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[8]')[0].text for player in range(1, players+1)]
    TBF = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[9]')[0].text for player in range(1, players+1)]
    NP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[10]')[0].text for player in range(1, players+1)]
    AVG = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[11]')[0].text for player in range(1, players+1)]
    SECOND_B = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[12]')[0].text for player in range(1, players+1)]
    THIRD_B = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[13]')[0].text for player in range(1, players+1)]
    SAC = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[14]')[0].text for player in range(1, players+1)]
    SF = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[15]')[0].text for player in range(1,players+1)]
    IBB = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[16]')[0].text for player in range(1,players+1)]
    WP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[17]')[0].text for player in range(1,players+1)]
    BK = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[18]')[0].text for player in range(1,players+1)]

    # 데이터프레임 만들기
    df = pd.DataFrame({'완투' : CG,
                      '완봉' : SHO,
                      '퀄리티스타트' : QS,
                      '블론세이브' : BSV,
                      '타자수' : TBF,
                      '투구수' : NP,
                      '피안타율' : AVG,
                      '2루타' : SECOND_B,
                      '3루타' : THIRD_B,
                      '희생번트' : SAC,
                      '희생플라이' : SF,
                      '고의4구' : IBB,
                      '폭투' : WP,
                      '보크' : BK})

    return df

# %%
def third_info_crawling(players): 
    
    ### 크롤링
    GS = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[5]')[0].text for player in range(1, players+1)]
    Wgs = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[6]')[0].text for player in range(1, players+1)]
    Wgr = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[7]')[0].text for player in range(1, players+1)]
    GF = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[8]')[0].text for player in range(1, players+1)]
    SVO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[9]')[0].text for player in range(1, players+1)]
    TS = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[10]')[0].text for player in range(1, players+1)]
    GDP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[11]')[0].text for player in range(1, players+1)]
    GO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[12]')[0].text for player in range(1, players+1)]
    AO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[13]')[0].text for player in range(1, players+1)]
    GO_AO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[14]')[0].text for player in range(1, players+1)]

    # 데이터프레임 만들기
    df = pd.DataFrame({'선발' : GS,
                      '선발승' : Wgs,
                      '구원승' : Wgr,
                      '종료' : GF,
                      '세이브기회' : SVO,
                      '터프세이브' : TS,
                      '병살타' : GDP,
                      '땅볼' : GO,
                      '뜬공' : AO,
                      '땅볼/뜬공' : GO_AO})

    return df

# %%
def fourth_info_crawling(players): 
    
    ### 크롤링
    BABIP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[5]')[0].text for player in range(1, players+1)]
    P_G = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[6]')[0].text for player in range(1, players+1)]
    P_IP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[7]')[0].text for player in range(1, players+1)]
    K_9 = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[8]')[0].text for player in range(1, players+1)]
    BB_9 = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[9]')[0].text for player in range(1, players+1)]
    K_BB = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[10]')[0].text for player in range(1, players+1)]
    OBP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[11]')[0].text for player in range(1, players+1)]
    SLG = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[12]')[0].text for player in range(1, players+1)]
    OPS = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[13]')[0].text for player in range(1, players+1)]

    # 데이터프레임 만들기
    df = pd.DataFrame({'인플레이타구타율' : BABIP,
                      '투구수/경기' : P_G,
                      '투구수/이닝' : P_IP,
                      '9이닝당 삼진' : K_9,
                      '9이닝당 볼넷' : BB_9,
                      '삼진/볼넷' : K_BB,
                      '피출루율' : OBP,
                      '피장타율' : SLG,
                      '피OPS' : OPS})

    return df

# %% [markdown]
# # 크롤링

# %%
INDEXLIST_OF_YEARS = [num for num in range(40,39,-1)] # (39,20,-1)
INDEXLIST_OF_YEARS
# Out:
# [40]

# %%
t1 = time.time()

########################## 접속과정 ##########################
# page에 접속
driver = webdriver.Chrome('chromedriver_96.exe', chrome_options=options) # 크롬 드라이버 다운로드후 본인 경로로 줍니다.
base_url = 'https://www.koreabaseball.com/Record/Player/PitcherBasic/Basic1.aspx'
driver.get(base_url)
time.sleep(2)
driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[2]')[0].click()
time.sleep(2)
driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[2]/select/option[1]')[0].click()
time.sleep(2)

########################## 연도 변경과정 ##########################
# 년도 바꾸기 (option[21] ~ option[39]) 2002~2020
for INDEX_YEAR in INDEXLIST_OF_YEARS: 
    
    ### 기본기록 클릭 (세부정보에서 년도 바꾸기가 먼저 눌리면 팀 개수 구할 때 반영이 안되는 이슈가 존재)
    try:
        driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[1]/ul/li[1]/a')[0].click()
    except:
        pass
    
    ### 년도 콤보박스 클릭
    driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[1]/select')[0].click()
    time.sleep(1)
    
    ### 세부년도 클릭
    BOX_YEAR = driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[1]/select/option[{INDEX_YEAR}]')[0]
    BOX_YEAR_PATH = BOX_YEAR.text
    BOX_YEAR.click() # 2020년이 options[39]
    time.sleep(1)
    
    ### 그 해 팀의 개수 파악
    INDEXLIST_OF_TEAMS = len(driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[3]/select/option')) - 1


    ########################## 팀 변경과정 ##########################
    # 팀바꾸기 (option[2] ~ 그 시즌 팀의 개수)
    for INDEX_TEAM in range(2,INDEXLIST_OF_TEAMS+2):
        
        ### 기본기록 클릭 (가장 첫 페이지부터 시작위함)
        try:
            driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[1]/ul/li[1]/a')[0].click()
        except:
            pass
        
        ### 팀 콤보박스 클릭
        driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[3]/select')[0].click()
        time.sleep(1)

        ### 세부 팀 클릭
        BOX_TEAM = driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[3]/select/option[{INDEX_TEAM}]')[0]
        BOX_TEAM_PATH = BOX_TEAM.text
        BOX_TEAM.click() # option[2]부터 팀이름 나옴(1은 팀선택)
        time.sleep(1)
        
        ### 기본기록 클릭
        try: # 첫 수집 시 페이지가 1로 안 바뀌는 것을 보정하기 위함
            driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/ul/li[1]/a')[0].click()
        except: # 첫 페이지 예외처리
            pass
        time.sleep(2)

        ########################## 1page 정보 수집과정 ##########################
        # 첫번째 정보 수집: 데이터 수집할 개수 정의 후 크롤링
        rows = len(driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr'))
        df1_1 = first_info_crawling(rows)

        # 두번째 정보 수집: 기록보기 화살표 클릭 후 크롤링
        driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[2]/a[2]')[0].click()
        df1_2 = second_info_crawling(rows)
        time.sleep(2)

        # 세번째 정보 수집: 세부기록 클릭 후 크롤링
        driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[1]/ul/li[2]/a')[0].click()
        df1_3 = third_info_crawling(rows)
        time.sleep(2)
        
        # 네번째 정보 수집: 기록보기 화살표 클릭 후 크롤링
        driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[2]/a[2]')[0].click()
        df1_4 = fourth_info_crawling(rows)
        time.sleep(2)

        # 1page 선수의 데이터 합치기
        df1 = pd.concat([df1_1, df1_2, df1_3, df1_4], axis=1)
        df1


        ########################## 2page 정보 수집과정 ##########################
        # 2page 유무 확인 후 있으면 수집
        if len(driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/div/a[4]/img')) != 0:

            # 첫번째 정보 수집: 기본기록 클릭 및 2page 클릭 및 데이터 수집할 개수 정의 후 크롤링
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[1]/ul/li[1]/a')[0].click()
            time.sleep(2)
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/div/a[4]/img')[0].click()
            time.sleep(2)
            rows = len(driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr'))
            df2_1 = first_info_crawling(rows)

            # 두번째 정보 수집: 기록보기 화살표 클릭 및 2page 클릭 후 크롤링
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[2]/a[2]')[0].click()
            time.sleep(2)
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/div/a[4]/img')[0].click()
            time.sleep(2)
            df2_2 = second_info_crawling(rows)

            # 세번째 정보 수집: 세부기록 클릭 후 2page 클릭 후 크롤링
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[1]/ul/li[2]/a')[0].click()
            time.sleep(2)
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/div/a[4]/img')[0].click()
            time.sleep(2)
            df2_3 = third_info_crawling(rows)
            
            # 네번째 정보 수집: 기록보기 화살표 후 2page 클릭 후 크롤링
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[2]/a[2]')[0].click()
            time.sleep(2)
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/div/a[4]/img')[0].click()
            time.sleep(2)
            df2_4 = fourth_info_crawling(rows)

            # 2page 선수의 데이터 합치기
            df2 = pd.concat([df2_1, df2_2, df2_3, df2_4], axis=1)

            # 1page, 2page 선수의 데이터 합치기
            df = pd.concat([df1, df2]).reset_index(drop=True)

        else:
            df = df1.copy()

        # 최종 저장
        if f'{BOX_TEAM_PATH}' not in os.listdir('선수데이터/투수/'):
            os.mkdir(f'선수데이터/투수/{BOX_TEAM_PATH}')

        df.to_csv(f'선수데이터/투수/{BOX_TEAM_PATH}/투수정보_{BOX_TEAM_PATH}({BOX_YEAR_PATH}).csv', index=False, encoding='utf-8-sig')
        print(f'=== {BOX_TEAM_PATH}({BOX_YEAR_PATH}) 저장완료 === 경과시간: {round(time.time()-t1)}초')
# Out:
# === 두산(2021) 저장완료 === 경과시간: 51초
# === 롯데(2021) 저장완료 === 경과시간: 118초
# === 삼성(2021) 저장완료 === 경과시간: 156초
# === 키움(2021) 저장완료 === 경과시간: 196초
# === 한화(2021) 저장완료 === 경과시간: 258초
# === KIA(2021) 저장완료 === 경과시간: 319초
# === KT(2021) 저장완료 === 경과시간: 352초
# === LG(2021) 저장완료 === 경과시간: 413초
# === NC(2021) 저장완료 === 경과시간: 453초
# === SSG(2021) 저장완료 === 경과시간: 513초
