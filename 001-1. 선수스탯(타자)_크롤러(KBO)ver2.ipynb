# %% [markdown]
# # Load Package

# %%
import time
import os
import warnings

import pandas as pd 

from selenium import webdriver
from selenium.webdriver.chrome.options import Options

warnings.filterwarnings(action='ignore')

options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")

# %% [markdown]
# # 내용 크롤링 함수화

# %%
def first_info_crawling(players): 
    
    ### 크롤링
    PLAYER = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[2]/a')[0].text for player in range(1, players+1)]
    ID = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[2]/a')[0].get_attribute('href').split('=')[1] for player in range(1, players+1)]
    TEAM = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[3]')[0].text for player in range(1, players+1)]
    AVG = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[4]')[0].text for player in range(1, players+1)]
    G = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[5]')[0].text for player in range(1, players+1)]
    PA = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[6]')[0].text for player in range(1, players+1)]
    AB = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[7]')[0].text for player in range(1, players+1)]
    R = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[8]')[0].text for player in range(1, players+1)]
    H = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[9]')[0].text for player in range(1, players+1)]
    SECOND_B = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[10]')[0].text for player in range(1, players+1)]
    THIRD_B = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[11]')[0].text for player in range(1, players+1)]
    HR = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[12]')[0].text for player in range(1, players+1)]
    TB = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[13]')[0].text for player in range(1, players+1)]
    RBI = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[14]')[0].text for player in range(1, players+1)]
    SAC = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[15]')[0].text for player in range(1, players+1)]
    SF = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[16]')[0].text for player in range(1, players+1)]

    # 데이터프레임 만들기
    df = pd.DataFrame({'선수명' : PLAYER,
                       'ID' : ID,
                      '팀명' : TEAM,
                      '타율' : AVG,
                      '경기' : G,
                      '타석' : PA,
                      '타수' : AB,
                      '득점' : R,
                      '안타' : H,
                      '2루타' : SECOND_B,
                      '3루타' : THIRD_B,
                      '홈런' : HR,
                      '루타' : TB,
                      '타점' : RBI,
                      '희생번트' : SAC,
                      '희생플라이' : SF})

    return df

# %%
def second_info_crawling(players): 
    
    ### 크롤링
    BB = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[5]')[0].text for player in range(1, players+1)]
    IBB = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[6]')[0].text for player in range(1, players+1)]
    HBP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[7]')[0].text for player in range(1, players+1)]
    SO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[8]')[0].text for player in range(1, players+1)]
    GDP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[9]')[0].text for player in range(1, players+1)]
    SLG = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[10]')[0].text for player in range(1, players+1)]
    OBP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[11]')[0].text for player in range(1, players+1)]
    OPS = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[12]')[0].text for player in range(1, players+1)]
    MH = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[13]')[0].text for player in range(1, players+1)]
    RISP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[14]')[0].text for player in range(1, players+1)]
    PH_BA = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[15]')[0].text for player in range(1,players+1)]

    # 데이터프레임 만들기
    df = pd.DataFrame({'볼넷' : BB,
                      '고의사구' : IBB,
                      '사구' : HBP,
                      '삼진' : SO,
                      '병살타' : GDP,
                      '장타율' : SLG,
                      '출루율' : OBP,
                      'OPS' : OPS,
                      '멀티히트' : MH,
                      '득점권타율' : RISP,
                      '대타타율' : PH_BA})

    return df

# %%
def third_info_crawling(players): 
    
    ### 크롤링
    XBH = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[5]')[0].text for player in range(1, players+1)]
    GO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[6]')[0].text for player in range(1, players+1)]
    AO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[7]')[0].text for player in range(1, players+1)]
    GO_AO = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[8]')[0].text for player in range(1, players+1)]
    GW_RBI = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[9]')[0].text for player in range(1, players+1)]
    BB_K = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[10]')[0].text for player in range(1, players+1)]
    P_PA = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[11]')[0].text for player in range(1, players+1)]
    ISOP = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[12]')[0].text for player in range(1, players+1)]
    XR = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[13]')[0].text for player in range(1, players+1)]
    GPA = [driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr[{player}]/td[14]')[0].text for player in range(1, players+1)]

    # 데이터프레임 만들기
    df = pd.DataFrame({'장타' : XBH,
                      '땅볼' : GO,
                      '뜬공' : AO,
                      '땅볼/뜬공' : GO_AO,
                      '결승타' : GW_RBI,
                      '볼넷/삼진' : BB_K,
                      '투구수/타석' : P_PA,
                      '순수장타율' : ISOP,
                      '추정득점' : XR,
                      'GPA' : GPA})

    return df

# %% [markdown]
# # 크롤링

# %%
INDEXLIST_OF_YEARS = [num for num in range(39,20,-1)] # (39,20,-1)
INDEXLIST_OF_YEARS
# Out:
# [39, 38, 37, 36, 35, 34, 33, 32, 31, 30, 29, 28, 27, 26, 25, 24, 23, 22, 21]

# %%
t1 = time.time()

########################## 접속과정 ##########################
# page에 접속
driver = webdriver.Chrome('chromedriver_93.exe', chrome_options=options) # 크롬 드라이버 다운로드후 본인 경로로 줍니다.
base_url = 'https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx'
driver.get(base_url)
time.sleep(2)


########################## 연도 변경과정 ##########################
# 년도 바꾸기 (option[21] ~ option[39]) 2002~2020
for INDEX_YEAR in INDEXLIST_OF_YEARS: 
    
    ### 기본기록 클릭 (세부정보에서 년도 바꾸기가 먼저 눌리면 팀 개수 구할 때 반영이 안되는 이슈가 존재)
    try:
        driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/ul/li[1]/a')[0].click()
    except:
        pass
    
    ### 년도 콤보박스 클릭
    driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[1]/select')[0].click()
    time.sleep(1)
    
    ### 세부년도 클릭
    BOX_YEAR = driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[1]/select/option[{INDEX_YEAR}]')[0]
    BOX_YEAR_PATH = BOX_YEAR.text
    BOX_YEAR.click() # 2020년이 options[39]
    time.sleep(1)
    
    ### 그 해 팀의 개수 파악
    INDEXLIST_OF_TEAMS = len(driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[3]/select/option')) - 1


    ########################## 팀 변경과정 ##########################
    # 팀바꾸기 (option[2] ~ 그 시즌 팀의 개수)
    for INDEX_TEAM in range(2,INDEXLIST_OF_TEAMS+2):
        
        ### 팀 콤보박스 클릭
        driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[3]/select')[0].click()
        time.sleep(1)

        ### 세부 팀 클릭
        BOX_TEAM = driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[1]/div[3]/select/option[{INDEX_TEAM}]')[0]
        BOX_TEAM_PATH = BOX_TEAM.text
        BOX_TEAM.click() # option[2]부터 팀이름 나옴(1은 팀선택)
        time.sleep(1)
        
        ### 기본기록 클릭
        try: # 첫 수집 시 페이지가 1로 안 바뀌는 것을 보정하기 위함
            driver.find_elements_by_xpath('/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/ul/li[1]/a')[0].click()
        except: # 첫 페이지 예외처리
            pass
        time.sleep(2)

        ########################## 1page 정보 수집과정 ##########################
        # 첫번째 정보 수집: 데이터 수집할 개수 정의 후 크롤링
        rows = len(driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr'))
        df1_1 = first_info_crawling(rows)

        # 두번째 정보 수집: 기록보기 화살표 클릭 후 크롤링
        driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[2]/a[2]')[0].click()
        df1_2 = second_info_crawling(rows)
        time.sleep(2)

        # 세번째 정보 수집: 세부기록 클릭 후 크롤링
        driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[1]/ul/li[2]/a')[0].click()
        df1_3 = third_info_crawling(rows)
        time.sleep(2)

        # 1page 선수의 데이터 합치기
        df1 = pd.concat([df1_1, df1_2, df1_3], axis=1)
        df1


        ########################## 2page 정보 수집과정 ##########################
        # 2page 유무 확인 후 있으면 수집
        if len(driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/div/a[4]/img')) != 0:

            # 첫번째 정보 수집: 기본기록 클릭 및 2page 클릭 및 데이터 수집할 개수 정의 후 크롤링
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/ul/li[1]/a')[0].click()
            time.sleep(2)
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/div/a[4]/img')[0].click()
            time.sleep(2)
            rows = len(driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/table/tbody/tr'))
            df2_1 = first_info_crawling(rows)

            # 두번째 정보 수집: 기록보기 화살표 클릭 및 2page 클릭 후 크롤링
            ### 기록보기 화살표 클릭
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[2]/a[2]')[0].click()
            time.sleep(2)
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/div/a[4]/img')[0].click()
            time.sleep(2)
            df2_2 = second_info_crawling(rows)

            # 세번째 정보 수집: 세부기록 클릭 후 2page 클릭 후 크롤링
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[2]/div[1]/ul/li[2]/a')[0].click()
            time.sleep(2)
            driver.find_elements_by_xpath(f'/html/body/form/div[3]/section/div/div/div[2]/div[3]/div[3]/div/a[4]/img')[0].click()
            time.sleep(2)
            df2_3 = third_info_crawling(rows)

            # 2page 선수의 데이터 합치기
            df2 = pd.concat([df2_1, df2_2, df2_3], axis=1)

            # 1page, 2page 선수의 데이터 합치기
            df = pd.concat([df1, df2]).reset_index(drop=True)

        else:
            df = df1.copy()

        # 최종 저장
        if f'{BOX_TEAM_PATH}' not in os.listdir('선수데이터/타자/'):
            os.mkdir(f'선수데이터/타자/{BOX_TEAM_PATH}')

        df.to_csv(f'선수데이터/타자/{BOX_TEAM_PATH}/타자정보_{BOX_TEAM_PATH}({BOX_YEAR_PATH}).csv', index=False, encoding='utf-8-sig')
        print(f'=== {BOX_TEAM_PATH}({BOX_YEAR_PATH}) 저장완료 === 경과시간: {round(time.time()-t1)}초')
# Out:
# === 두산(2020) 저장완료 === 경과시간: 99초
# === 롯데(2020) 저장완료 === 경과시간: 156초
# === 삼성(2020) 저장완료 === 경과시간: 215초
# === 키움(2020) 저장완료 === 경과시간: 279초
# === 한화(2020) 저장완료 === 경과시간: 342초
# === KIA(2020) 저장완료 === 경과시간: 400초
# === KT(2020) 저장완료 === 경과시간: 462초
# === LG(2020) 저장완료 === 경과시간: 525초
# === NC(2020) 저장완료 === 경과시간: 585초
# === SK(2020) 저장완료 === 경과시간: 655초
# === 두산(2019) 저장완료 === 경과시간: 715초
# === 롯데(2019) 저장완료 === 경과시간: 780초
# === 삼성(2019) 저장완료 === 경과시간: 836초
# === 키움(2019) 저장완료 === 경과시간: 869초
# === 한화(2019) 저장완료 === 경과시간: 931초
# === KIA(2019) 저장완료 === 경과시간: 998초
# === KT(2019) 저장완료 === 경과시간: 1055초
# === LG(2019) 저장완료 === 경과시간: 1114초
# === NC(2019) 저장완료 === 경과시간: 1182초
# === SK(2019) 저장완료 === 경과시간: 1239초
# === 넥센(2018) 저장완료 === 경과시간: 1278초
# === 두산(2018) 저장완료 === 경과시간: 1335초
# === 롯데(2018) 저장완료 === 경과시간: 1391초
# === 삼성(2018) 저장완료 === 경과시간: 1445초
# === 한화(2018) 저장완료 === 경과시간: 1500초
# === KIA(2018) 저장완료 === 경과시간: 1569초
# === KT(2018) 저장완료 === 경과시간: 1628초
# === LG(2018) 저장완료 === 경과시간: 1663초
# ...
