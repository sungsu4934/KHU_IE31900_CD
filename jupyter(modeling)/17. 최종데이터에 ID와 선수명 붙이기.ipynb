# %%
import pandas as pd

# %%
hitter_nonfa1 = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/단순가중/타자_단순가중_nonfa_test.csv', encoding='utf-8')
pitcher_fa1 = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/단순가중/투수_단순가중_fa_test.csv', encoding='utf-8')
pitcher_nonfa1 = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/단순가중/투수_단순가중_nonfa_test.csv', encoding='utf-8')

hitter_nonfa2 = pd.read_csv('../선수데이터(전처리완료)/최종결과/타자nonfa2020.csv', encoding='utf-8')
pitcher_fa2 = pd.read_csv('../선수데이터(전처리완료)/최종결과/투수fa2020.csv', encoding='utf-8')
pitcher_nonfa2 = pd.read_csv('../선수데이터(전처리완료)/최종결과/투수nonfa2020.csv', encoding='utf-8')

# %%
hitter_nonfa1 = hitter_nonfa1[['ID', '선수명']]
hitter_nonfa3 = pd.concat([hitter_nonfa1, hitter_nonfa2], axis=1)
hitter_nonfa3
# Out:
#         ID  선수명  데뷔년도    연도     타율   경기   타석   타수  득점  안타  ...  5년평균포일(수비)  \
# 0    69636  오선우  2019  2020  0.239   59   73   67  11  16  ...         0.0
# 1    65586  전병우  2015  2020  0.237  119  402  359  46  85  ...         0.0
# 2    67644  이정훈  2017  2020  0.000    3    4    4   0   0  ...         0.0
# 3    63559  백동훈  2013  2020  0.188   27   19   16   5   3  ...         0.0
# 4    65610  황대인  2015  2020  0.276   63  138  116  14  32  ...         0.0
# ..     ...  ...   ...   ...    ...  ...  ...  ...  ..  ..  ...         ...
# 218  65462  김기환  2015  2020  0.500    4    2    2   1   1  ...         0.0
# 219  63435  김성표  2013  2020  0.125   15    8    8   1   1  ...         0.0
# 220  65503  김지수  2015  2020  0.160   14   26   25   2   4  ...         0.0
# 221  65514  강태율  2015  2020  0.455   14   18   11   2   5  ...         0.0
# 222  65522  김강현  2015  2020  0.000    5    4    3   0   0  ...         0.0
#
# ...

# %%
pitcher_fa1 = pitcher_fa1[['ID', '선수명']]
pitcher_fa3 = pd.concat([pitcher_fa1, pitcher_fa2], axis=1)
pitcher_fa3
# Out:
#        ID  선수명  데뷔년도    연도  평균자책점  경기  승리  패배  세이브  홀드  ...  5년평균견제사(수비)  \
# 0   72447   권혁  2002  2020   9.39  15   2   2    0   2  ...     0.000000
# 1   73117  우규민  2003  2020   6.19  52   3   3    7  11  ...     1.099419
# 2   73211  노경은  2003  2020   4.87  25   5  10    0   0  ...     0.974886
# 3   73738  안영명  2003  2020   5.91  39   1   1    0   1  ...     0.207025
# 4   73750  윤규진  2003  2020   7.36   2   0   0    0   0  ...     0.000000
# 5   73801  송은범  2003  2020   4.50  56   4   2    2   6  ...     0.796918
# 6   74359  오주원  2004  2020   5.40  25   3   1    0   2  ...     0.000000
# 7   74454  윤성환  2004  2020   5.79   5   0   2    0   0  ...     0.259528
# 8   74513  장원준  2004  2020  12.71   2   0   1    0   0  ...     0.427933
# 9   74857  정우람  2004  2020   4.80  50   3   5   16   0  ...     0.000000
# 10  75258  금민철  2005  2020  15.43   3   0   0    0   0  ...     0.534514
# 11  75342  이보근  2005  2020   2.51  49   3   1    6   9  ...     0.000000
# ...

# %%
pitcher_nonfa1 = pitcher_nonfa1[['ID', '선수명']]
pitcher_nonfa3 = pd.concat([pitcher_nonfa1, pitcher_nonfa2], axis=1)
pitcher_nonfa3
# Out:
#         ID  선수명  데뷔년도    연도  평균자책점  경기  승리  패배  세이브  홀드  ...  5년평균견제사(수비)  \
# 0    69646  양승철  2019  2020   7.85  15   0   0    0   0  ...     0.000000
# 1    61457  임현준  2011  2020   1.78  51   1   1    0   5  ...     0.000000
# 2    67603  이승호  2017  2020   5.08  24   6   6    0   0  ...     1.666667
# 3    63512  박진형  2013  2020   5.70  53   1   4    0  17  ...     0.000000
# 4    63543  구승민  2013  2020   3.58  57   5   2    0  20  ...     0.250000
# ..     ...  ...   ...   ...    ...  ..  ..  ..  ...  ..  ...          ...
# 231  50992  김태경  2020  2020   0.00   1   0   0    0   0  ...     0.000000
# 232  63292  박종기  2013  2020   5.54   8   1   2    0   0  ...     0.000000
# 233  67391  김재웅  2017  2020   4.68  43   1   4    0   2  ...     0.000000
# 234  65411  김주온  2015  2020   7.55  29   0   3    0   0  ...     0.000000
# 235  63464  윤대경  2013  2020   1.59  55   5   0    0   7  ...     0.000000
#
#      5년평균자살(수비)  5년평균보살(수비)  5년평균병살(수비)  5년평균수비율(수비)   5년평균WAR  \
# ...

# %%
hitter_nonfa3.to_csv('../선수데이터(전처리완료)/최종결과2/타자nonfa2020.csv', encoding='utf-8-sig', index=False)
pitcher_fa3.to_csv('../선수데이터(전처리완료)/최종결과2/투수fa2020.csv', encoding='utf-8-sig', index=False)
pitcher_nonfa3.to_csv('../선수데이터(전처리완료)/최종결과2/투수nonfa2020.csv', encoding='utf-8-sig', index=False)
