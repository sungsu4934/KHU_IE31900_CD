# %%
'''
Catboost와 Lightgbm만 실험
'''

# %% [markdown]
# # 패키지 불러오기

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import xgboost as xgb

from catboost import Pool, CatBoostRegressor
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler


n_splits = 5

# %% [markdown]
# # 모델 정의
#  1. Lightgbm
#  2. Catboost

# %%
def Xy_split(dataset):
    
    X = dataset.drop('연봉', axis=1)
    column_dict = {f'variable{idx+1}':col for idx, col in enumerate(X.columns)}
    X = X.rename(columns = {col:f'variable{idx+1}' for idx, col in enumerate(X.columns)})
    y = dataset['연봉']
    
    return column_dict, X, y

# %%
def lgbm_model(data_x, data_y):

    # lgbm 모델링
    lgb_params = {"objective" : "rmse",
                 "verbosity" : -1}

    lgb_models={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        print(f'\n\n ============================ {step} ============================')    

        X_train = data_x.iloc[tr_idx, :].values
        y_train = data_y[tr_idx].values

        X_valid = data_x.iloc[val_idx, :].values
        y_valid = data_y[val_idx].values

        lgb_dtrain = lgb.Dataset(data = X_train, label = y_train) 
        lgb_dvalid = lgb.Dataset(data = X_valid, label = y_valid) 

        lgb_model = lgb.train(lgb_params, lgb_dtrain, 20000, valid_sets=[lgb_dvalid], early_stopping_rounds=100, verbose_eval=1000)
        lgb_models[step] = lgb_model

        step += 1
        
    # lgbm 성능종합
    performance = [lgb_models[step].best_score['valid_0']['rmse'] for step in range(1,6)]
    performance.append(np.mean(performance))

    output = pd.DataFrame({'lgbm':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %%
def cb_model(data_x, data_y):

    # cb 모델링
    cat_cols = []

    cb_models={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :]
        y_train = data_y[tr_idx]

        X_valid = data_x.iloc[val_idx, :]
        y_valid = data_y[val_idx]

        cb_dtrain = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        cb_dvalid = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        cb_model = CatBoostRegressor(iterations=20000, eval_metric='RMSE', loss_function='RMSE', verbose = 0)

        cb_model.fit(cb_dtrain, eval_set=cb_dvalid, early_stopping_rounds=100, verbose_eval=1000, use_best_model=True)
        cb_models[step] = cb_model

        step += 1
        
    # cb 성능종합
    performance = [cb_models[step].best_score_['validation']['RMSE'] for step in range(1,6)]
    performance.append(np.mean(performance))

    output = pd.DataFrame({'cb':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %% [markdown]
# # train, test분할 후 모델링

# %%
hitter = pd.read_csv('../선수데이터(전처리완료)/모델링용ver5/타자(모델링용_원핫인코딩)_train_ver5.csv')
pitcher = pd.read_csv('../선수데이터(전처리완료)/모델링용ver5/투수(모델링용_원핫인코딩)_train_ver5.csv')

hitter = hitter.drop(['ID', '선수명'], axis=1)
pitcher = pitcher.drop(['ID', '선수명'], axis=1)

# %% [markdown]
# #### 1. 타자

# %%
# train, test 분할
col_dict, X, y = Xy_split(hitter)

X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

# %%
# 타자데이터 도출
hitter_performance = pd.concat([lgbm_model(X, y),
                                cb_model(X, y)], axis=1)

round(hitter_performance, 1)
# Out:
#  ============================ 1 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [24]	valid_0's rmse: 11891.5
#
#
#  ============================ 2 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [57]	valid_0's rmse: 12566.1
#
#
#  ============================ 3 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [40]	valid_0's rmse: 14578.5
#
#
#  ============================ 4 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 11259.1
#
#
#  ============================ 5 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [29]	valid_0's rmse: 15509.6
# Learning rate set to 0.008484
# 0:	learn: 38425.6131657	test: 33933.8062890	best: 33933.8062890 (0)	total: 142ms	remaining: 47m 21s
# 1000:	learn: 7902.0155209	test: 12204.1522028	best: 12203.7443544 (998)	total: 5.4s	remaining: 1m 42s
# 2000:	learn: 5169.4797356	test: 11745.6975500	best: 11745.3104520 (1999)	total: 10.8s	remaining: 1m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11717.64758
# bestIteration = 2162
#
# Shrink model to first 2163 iterations.
# Learning rate set to 0.008484
# 0:	learn: 36845.9834925	test: 40382.4247967	best: 40382.4247967 (0)	total: 6.07ms	remaining: 2m 1s
# 1000:	learn: 8426.0259110	test: 12543.3497356	best: 12543.3497356 (1000)	total: 6.27s	remaining: 1m 59s
# 2000:	learn: 5731.7537822	test: 11644.9860670	best: 11643.4704086 (1995)	total: 11.9s	remaining: 1m 46s
# 3000:	learn: 4240.5643213	test: 11375.0691554	best: 11374.9764899 (2999)	total: 17.6s	remaining: 1m 39s
# 4000:	learn: 3152.1310830	test: 11176.3698206	best: 11176.1068646 (3975)	total: 23.8s	remaining: 1m 35s
# 5000:	learn: 2435.4455699	test: 11072.3791395	best: 11072.3791395 (5000)	total: 30.3s	remaining: 1m 31s
# 6000:	learn: 1884.9517209	test: 10997.5758780	best: 10997.5758780 (6000)	total: 37s	remaining: 1m 26s
# 7000:	learn: 1493.3217079	test: 10947.0921912	best: 10947.0921912 (7000)	total: 43.5s	remaining: 1m 20s
# 8000:	learn: 1231.3676690	test: 10925.6256194	best: 10925.5063968 (7987)	total: 50.4s	remaining: 1m 15s
# 9000:	learn: 1021.2806888	test: 10908.3887354	best: 10908.3049112 (8998)	total: 57.5s	remaining: 1m 10s
# 10000:	learn: 854.7664635	test: 10898.9231823	best: 10898.9231823 (10000)	total: 1m 4s	remaining: 1m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 10893.59652
# bestIteration = 10631
#
# Shrink model to first 10632 iterations.
# Learning rate set to 0.008484
# 0:	learn: 36843.5158260	test: 40390.0324373	best: 40390.0324373 (0)	total: 6.79ms	remaining: 2m 15s
# 1000:	learn: 7413.8798997	test: 14686.8950261	best: 14686.7052641 (997)	total: 7.01s	remaining: 2m 12s
# 2000:	learn: 5035.1421671	test: 14254.8731116	best: 14254.5806375 (1999)	total: 13.9s	remaining: 2m 4s
# 3000:	learn: 3667.5095381	test: 14025.7499984	best: 14025.2513095 (2995)	total: 20.8s	remaining: 1m 57s
# 4000:	learn: 2769.4007648	test: 13920.1800782	best: 13920.1800782 (4000)	total: 28s	remaining: 1m 51s
# 5000:	learn: 2164.9824852	test: 13865.3874983	best: 13865.3874983 (5000)	total: 35s	remaining: 1m 44s
# 6000:	learn: 1714.2434781	test: 13817.1922432	best: 13816.5003308 (5975)	total: 41.9s	remaining: 1m 37s
# 7000:	learn: 1389.8901376	test: 13790.1014985	best: 13790.1014985 (7000)	total: 48.5s	remaining: 1m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13778.46069
# bestIteration = 7809
#
# Shrink model to first 7810 iterations.
# Learning rate set to 0.008484
# 0:	learn: 38359.0658049	test: 34216.9930640	best: 34216.9930640 (0)	total: 7.17ms	remaining: 2m 23s
# 1000:	learn: 8010.5986053	test: 11405.1516033	best: 11405.1516033 (1000)	total: 8.24s	remaining: 2m 36s
# 2000:	learn: 5111.4565309	test: 10762.2346567	best: 10762.2346567 (2000)	total: 15.8s	remaining: 2m 22s
# 3000:	learn: 3611.1131010	test: 10513.2027546	best: 10512.8510724 (2999)	total: 22.7s	remaining: 2m 8s
# 4000:	learn: 2746.9983839	test: 10397.2391666	best: 10397.0113296 (3962)	total: 31s	remaining: 2m 3s
# 5000:	learn: 2190.4545266	test: 10351.4037689	best: 10351.0119423 (4995)	total: 37.8s	remaining: 1m 53s
# 6000:	learn: 1755.9858047	test: 10316.1822760	best: 10316.1822760 (6000)	total: 44.6s	remaining: 1m 44s
# 7000:	learn: 1431.8715253	test: 10295.7700039	best: 10295.5755192 (6996)	total: 51.5s	remaining: 1m 35s
# 8000:	learn: 1192.3077250	test: 10280.7360324	best: 10280.6424660 (7995)	total: 58.6s	remaining: 1m 27s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 10277.94622
# bestIteration = 8271
#
# Shrink model to first 8272 iterations.
# Learning rate set to 0.008484
# 0:	learn: 37336.8236858	test: 38490.5110434	best: 38490.5110434 (0)	total: 6.5ms	remaining: 2m 9s
# 1000:	learn: 7977.1018514	test: 14787.9632306	best: 14787.9632306 (1000)	total: 8.25s	remaining: 2m 36s
# 2000:	learn: 5371.0565998	test: 13885.7246824	best: 13884.5979018 (1997)	total: 15.5s	remaining: 2m 19s
# 3000:	learn: 3922.5789285	test: 13547.6373105	best: 13547.6373105 (3000)	total: 22.4s	remaining: 2m 7s
# 4000:	learn: 2902.1474840	test: 13330.5218764	best: 13330.5218764 (4000)	total: 29.3s	remaining: 1m 57s
# 5000:	learn: 2226.9744663	test: 13198.9744893	best: 13198.8407307 (4998)	total: 36.4s	remaining: 1m 49s
# 6000:	learn: 1771.3162259	test: 13128.9070712	best: 13128.3832393 (5966)	total: 43.3s	remaining: 1m 41s
# 7000:	learn: 1476.2101025	test: 13091.3363057	best: 13091.3363057 (7000)	total: 50.1s	remaining: 1m 33s
# 8000:	learn: 1220.0634386	test: 13067.9813803	best: 13067.9619928 (7999)	total: 57.2s	remaining: 1m 25s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13061.04197
# bestIteration = 8258
#
# Shrink model to first 8259 iterations.
#         lgbm       cb
# cv1  11891.5  11717.6
# cv2  12566.1  10893.6
# cv3  14578.5  13778.5
# cv4  11259.1  10277.9
# cv5  15509.6  13061.0
# 평균   13160.9  11945.7

# %% [markdown]
# #### 2. 투수

# %%
# train, test 분할
col_dict, X, y = Xy_split(pitcher)

X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

# %%
# 타자데이터 도출
pitcher_performance = pd.concat([lgbm_model(X, y),
                                 cb_model(X, y)], axis=1)

round(pitcher_performance, 1)
# Out:
#  ============================ 1 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [389]	valid_0's rmse: 9860.68
#
#
#  ============================ 2 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [54]	valid_0's rmse: 9779.54
#
#
#  ============================ 3 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [141]	valid_0's rmse: 10326.2
#
#
#  ============================ 4 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [711]	valid_0's rmse: 10457.9
#
#
#  ============================ 5 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [516]	valid_0's rmse: 10317.2
# Learning rate set to 0.008079
# 0:	learn: 28271.6737333	test: 28725.4965323	best: 28725.4965323 (0)	total: 18.5ms	remaining: 6m 10s
# 1000:	learn: 5772.7679748	test: 11105.5084493	best: 11105.5084493 (1000)	total: 6.56s	remaining: 2m 4s
# 2000:	learn: 3850.9959901	test: 10572.0459866	best: 10571.7288768 (1999)	total: 12.9s	remaining: 1m 55s
# 3000:	learn: 2805.7651641	test: 10375.4724842	best: 10375.4724842 (3000)	total: 19s	remaining: 1m 47s
# 4000:	learn: 2161.8702711	test: 10295.4298749	best: 10295.3398378 (3997)	total: 25.4s	remaining: 1m 41s
# 5000:	learn: 1708.3881176	test: 10267.5773443	best: 10267.3041802 (4929)	total: 31.5s	remaining: 1m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 10267.30418
# bestIteration = 4929
#
# Shrink model to first 4930 iterations.
# Learning rate set to 0.008079
# 0:	learn: 28658.9021745	test: 27192.3725101	best: 27192.3725101 (0)	total: 5.85ms	remaining: 1m 56s
# 1000:	learn: 5757.9449500	test: 9641.1737036	best: 9641.1627536 (999)	total: 6.14s	remaining: 1m 56s
# 2000:	learn: 3783.2735597	test: 9146.7308507	best: 9146.7308507 (2000)	total: 11.7s	remaining: 1m 45s
# 3000:	learn: 2733.1062166	test: 8958.8819638	best: 8958.7863655 (2998)	total: 17.5s	remaining: 1m 38s
# 4000:	learn: 2076.7150212	test: 8904.8507358	best: 8904.8337805 (3993)	total: 23.4s	remaining: 1m 33s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 8898.504462
# bestIteration = 4198
#
# Shrink model to first 4199 iterations.
# Learning rate set to 0.008079
# 0:	learn: 28749.3781873	test: 26790.1300114	best: 26790.1300114 (0)	total: 17.4ms	remaining: 5m 48s
# 1000:	learn: 5731.9376378	test: 10439.1432589	best: 10439.1432589 (1000)	total: 6.26s	remaining: 1m 58s
# 2000:	learn: 3716.2299138	test: 9700.7152851	best: 9700.7152851 (2000)	total: 12.4s	remaining: 1m 51s
# 3000:	learn: 2647.4519840	test: 9479.0333853	best: 9479.0333853 (3000)	total: 19.1s	remaining: 1m 48s
# 4000:	learn: 2060.1321368	test: 9437.7295876	best: 9437.7295876 (4000)	total: 26s	remaining: 1m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 9403.420075
# bestIteration = 4874
#
# Shrink model to first 4875 iterations.
# Learning rate set to 0.008079
# 0:	learn: 27986.3257270	test: 29894.8998560	best: 29894.8998560 (0)	total: 6.23ms	remaining: 2m 4s
# 1000:	learn: 5846.5576621	test: 9650.0827455	best: 9649.6358051 (999)	total: 6.12s	remaining: 1m 56s
# 2000:	learn: 3824.2976306	test: 9004.6315046	best: 9004.3180693 (1999)	total: 12.6s	remaining: 1m 52s
# 3000:	learn: 2818.9823445	test: 8789.3074458	best: 8789.3074458 (3000)	total: 18.9s	remaining: 1m 46s
# 4000:	learn: 2141.3304263	test: 8745.0807304	best: 8743.5650555 (3930)	total: 25.9s	remaining: 1m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 8743.565056
# bestIteration = 3930
#
# Shrink model to first 3931 iterations.
# Learning rate set to 0.008079
# 0:	learn: 28168.2089199	test: 29199.5061986	best: 29199.5061986 (0)	total: 6.3ms	remaining: 2m 5s
# 1000:	learn: 5995.5365726	test: 10845.8052188	best: 10845.8052188 (1000)	total: 7.22s	remaining: 2m 17s
# 2000:	learn: 3893.7807682	test: 9922.0491517	best: 9922.0491517 (2000)	total: 13.5s	remaining: 2m 1s
# 3000:	learn: 2843.8653234	test: 9688.8035222	best: 9688.8035222 (3000)	total: 19.9s	remaining: 1m 52s
# 4000:	learn: 2175.4389510	test: 9611.5887804	best: 9611.0407871 (3988)	total: 26.2s	remaining: 1m 44s
# 5000:	learn: 1732.0260126	test: 9555.6833736	best: 9554.7925412 (4986)	total: 32.6s	remaining: 1m 37s
# 6000:	learn: 1404.3779316	test: 9535.9755554	best: 9535.4292344 (5954)	total: 39.2s	remaining: 1m 31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 9535.232146
# bestIteration = 6034
#
# Shrink model to first 6035 iterations.
#         lgbm       cb
# cv1   9860.7  10267.3
# cv2   9779.5   8898.5
# cv3  10326.2   9403.4
# cv4  10457.9   8743.6
# cv5  10317.2   9535.2
# 평균   10148.3   9369.6
