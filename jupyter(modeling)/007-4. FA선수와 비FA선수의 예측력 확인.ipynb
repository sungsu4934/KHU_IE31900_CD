# %%
'''
Catboost와 Lightgbm만 실험
'''

# %% [markdown]
# # 패키지 불러오기

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import xgboost as xgb

from catboost import Pool, CatBoostRegressor
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler


n_splits = 5

# %% [markdown]
# # 모델 정의
#  1. Lightgbm
#  2. Catboost

# %%
def Xy_split(dataset):
    
    X = dataset.drop('연봉', axis=1)
    column_dict = {f'variable{idx+1}':col for idx, col in enumerate(X.columns)}
    X = X.rename(columns = {col:f'variable{idx+1}' for idx, col in enumerate(X.columns)})
    y = dataset['연봉']
    
    return column_dict, X, y

# %%
def lgbm_model(data_x, data_y):

    # lgbm 모델링
    lgb_params = {"objective" : "rmse",
                 "verbosity" : -1}

    lgb_models={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        print(f'\n\n ============================ {step} ============================')    

        X_train = data_x.iloc[tr_idx, :].values
        y_train = data_y[tr_idx].values

        X_valid = data_x.iloc[val_idx, :].values
        y_valid = data_y[val_idx].values

        lgb_dtrain = lgb.Dataset(data = X_train, label = y_train) 
        lgb_dvalid = lgb.Dataset(data = X_valid, label = y_valid) 

        lgb_model = lgb.train(lgb_params, lgb_dtrain, 20000, valid_sets=[lgb_dvalid], early_stopping_rounds=100, verbose_eval=1000)
        lgb_models[step] = lgb_model

        step += 1
        
    # lgbm 성능종합
    performance = [lgb_models[step].best_score['valid_0']['rmse'] for step in range(1,6)]
    performance.append(np.mean(performance))

    output = pd.DataFrame({'lgbm':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %%
def cb_model(data_x, data_y):

    # cb 모델링
    cat_cols = []

    cb_models={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :]
        y_train = data_y[tr_idx]

        X_valid = data_x.iloc[val_idx, :]
        y_valid = data_y[val_idx]

        cb_dtrain = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        cb_dvalid = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        cb_model = CatBoostRegressor(iterations=20000, eval_metric='RMSE', loss_function='RMSE', verbose = 0)

        cb_model.fit(cb_dtrain, eval_set=cb_dvalid, early_stopping_rounds=100, verbose_eval=1000, use_best_model=True)
        cb_models[step] = cb_model

        step += 1
        
    # cb 성능종합
    performance = [cb_models[step].best_score_['validation']['RMSE'] for step in range(1,6)]
    performance.append(np.mean(performance))

    output = pd.DataFrame({'cb':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %% [markdown]
# # train, test분할 후 모델링

# %%
hitter = pd.read_csv('../선수데이터(전처리완료)/모델링용ver3/타자(모델링용_원핫인코딩)_train_ver3.csv')
pitcher = pd.read_csv('../선수데이터(전처리완료)/모델링용ver3/투수(모델링용_원핫인코딩)_train_ver3.csv')

# %%
fa_ids = hitter.loc[hitter['FA여부'] == 1, 'ID'].unique()
fa_hitter = hitter[hitter['ID'].isin(list(fa_ids))].drop(['ID','선수명'], axis=1).reset_index(drop=True)
nonfa_hitter = hitter[~hitter['ID'].isin(list(fa_ids))].drop(['ID','선수명'], axis=1).reset_index(drop=True)

fa_ids = pitcher.loc[pitcher['FA여부'] == 1, 'ID'].unique()
fa_pitcher = pitcher[pitcher['ID'].isin(list(fa_ids))].drop(['ID','선수명'], axis=1).reset_index(drop=True)
nonfa_pitcher = pitcher[~pitcher['ID'].isin(list(fa_ids))].drop(['ID','선수명'], axis=1).reset_index(drop=True)

# %% [markdown]
# #### 1. 타자

# %%
# train, test 분할
col_dict, X, y = Xy_split(fa_hitter)

X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

pd.concat([lgbm_model(X, y),
           cb_model(X, y)], axis=1)
# Out:
#  ============================ 1 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 25603.2
#
#
#  ============================ 2 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [62]	valid_0's rmse: 28754.7
#
#
#  ============================ 3 ============================
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's rmse: 29710.3
# Early stopping, best iteration is:
# [1884]	valid_0's rmse: 29702.9
#
#
#  ============================ 4 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [127]	valid_0's rmse: 27343.5
#
#
#  ============================ 5 ============================
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's rmse: 31153.5
# Early stopping, best iteration is:
# [1345]	valid_0's rmse: 31146.5
# Learning rate set to 0.006969
# 0:	learn: 55049.8889677	test: 50603.3773949	best: 50603.3773949 (0)	total: 20.7ms	remaining: 6m 54s
# 1000:	learn: 18675.2293728	test: 27541.3922055	best: 27541.3922055 (1000)	total: 5.12s	remaining: 1m 37s
# 2000:	learn: 12001.1570007	test: 26660.9683757	best: 26660.7161472 (1998)	total: 9.31s	remaining: 1m 23s
# 3000:	learn: 8065.9033556	test: 26217.9939254	best: 26214.0718794 (2985)	total: 13.3s	remaining: 1m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 26096.54299
# bestIteration = 3488
#
# Shrink model to first 3489 iterations.
# Learning rate set to 0.006971
# 0:	learn: 55555.5126419	test: 48350.9481012	best: 48350.9481012 (0)	total: 6.54ms	remaining: 2m 10s
# 1000:	learn: 18344.2064927	test: 28536.3566940	best: 28536.3566940 (1000)	total: 4.14s	remaining: 1m 18s
# 2000:	learn: 12522.9191666	test: 27293.7381967	best: 27293.7381967 (2000)	total: 8.3s	remaining: 1m 14s
# 3000:	learn: 8736.3787443	test: 26830.5922524	best: 26830.4735095 (2990)	total: 12.6s	remaining: 1m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 26747.23081
# bestIteration = 3516
#
# Shrink model to first 3517 iterations.
# Learning rate set to 0.006971
# 0:	learn: 52372.7262084	test: 61017.8210220	best: 61017.8210220 (0)	total: 7.83ms	remaining: 2m 36s
# 1000:	learn: 17974.4901465	test: 29961.4624849	best: 29961.0431518 (999)	total: 4.22s	remaining: 1m 20s
# 2000:	learn: 12016.5117580	test: 28917.3942503	best: 28917.1751021 (1999)	total: 8.37s	remaining: 1m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 28690.02301
# bestIteration = 2635
#
# Shrink model to first 2636 iterations.
# Learning rate set to 0.006971
# 0:	learn: 54636.4726412	test: 52441.8621124	best: 52441.8621124 (0)	total: 8.39ms	remaining: 2m 47s
# 1000:	learn: 18176.2987622	test: 28152.0248036	best: 28152.0248036 (1000)	total: 4.63s	remaining: 1m 27s
# 2000:	learn: 12519.3362524	test: 26919.5734057	best: 26919.5734057 (2000)	total: 9.34s	remaining: 1m 23s
# 3000:	learn: 8810.1479415	test: 26431.7927069	best: 26431.7927069 (3000)	total: 13.9s	remaining: 1m 18s
# 4000:	learn: 6225.8598547	test: 26204.1822843	best: 26201.4241500 (3981)	total: 18.5s	remaining: 1m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 26159.41255
# bestIteration = 4305
#
# Shrink model to first 4306 iterations.
# Learning rate set to 0.006971
# 0:	learn: 53238.5750342	test: 57853.3035295	best: 57853.3035295 (0)	total: 4.98ms	remaining: 1m 39s
# 1000:	learn: 18196.2430334	test: 31643.8112683	best: 31643.8112683 (1000)	total: 4.71s	remaining: 1m 29s
# 2000:	learn: 12226.4982725	test: 29916.5230423	best: 29916.5230423 (2000)	total: 9.4s	remaining: 1m 24s
# 3000:	learn: 8437.3403116	test: 29458.3076670	best: 29458.3076670 (3000)	total: 14.2s	remaining: 1m 20s
# 4000:	learn: 6114.4286659	test: 29251.1508426	best: 29251.1508426 (4000)	total: 19s	remaining: 1m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 29235.94931
# bestIteration = 4161
#
# Shrink model to first 4162 iterations.
#              lgbm            cb
# cv1  25603.200796  26096.542987
# cv2  28754.678604  26747.230806
# cv3  29702.861914  28690.023013
# cv4  27343.525095  26159.412551
# cv5  31146.450186  29235.949312
# 평균   28510.143319  27385.831734

# %%
# train, test 분할
col_dict, X, y = Xy_split(nonfa_hitter)

X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

pd.concat([lgbm_model(X, y),
           cb_model(X, y)], axis=1)
# Out:
#  ============================ 1 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	valid_0's rmse: 5144
#
#
#  ============================ 2 ============================
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's rmse: 4968.9
# Early stopping, best iteration is:
# [1430]	valid_0's rmse: 4953.56
#
#
#  ============================ 3 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	valid_0's rmse: 3299.81
#
#
#  ============================ 4 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [179]	valid_0's rmse: 7658.27
#
#
#  ============================ 5 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's rmse: 4346.83
# Learning rate set to 0.007731
# 0:	learn: 9990.5115004	test: 9523.5120046	best: 9523.5120046 (0)	total: 7.54ms	remaining: 2m 30s
# 1000:	learn: 2169.0556987	test: 5107.8360036	best: 5107.6137167 (986)	total: 5.44s	remaining: 1m 43s
# 2000:	learn: 1394.6714996	test: 5000.0793991	best: 5000.0190297 (1997)	total: 10.9s	remaining: 1m 38s
# 3000:	learn: 1004.2770783	test: 4973.1798768	best: 4972.6811022 (2992)	total: 16.6s	remaining: 1m 33s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4972.681102
# bestIteration = 2992
#
# Shrink model to first 2993 iterations.
# Learning rate set to 0.007731
# 0:	learn: 9922.6676388	test: 9826.1825432	best: 9826.1825432 (0)	total: 5.89ms	remaining: 1m 57s
# 1000:	learn: 2505.3765539	test: 5396.6767393	best: 5396.6767393 (1000)	total: 5.7s	remaining: 1m 48s
# 2000:	learn: 1560.3902051	test: 5182.3771653	best: 5182.3771653 (2000)	total: 11.4s	remaining: 1m 42s
# 3000:	learn: 1089.7009821	test: 5106.1433420	best: 5104.3683361 (2947)	total: 17.5s	remaining: 1m 39s
# 4000:	learn: 807.4991057	test: 5081.5261457	best: 5081.5072362 (3999)	total: 24.6s	remaining: 1m 38s
# 5000:	learn: 622.6980628	test: 5069.0799590	best: 5069.0799590 (5000)	total: 32.5s	remaining: 1m 37s
# 6000:	learn: 492.0916233	test: 5065.0222731	best: 5064.6834906 (5941)	total: 38.8s	remaining: 1m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 5064.683491
# bestIteration = 5941
#
# Shrink model to first 5942 iterations.
# Learning rate set to 0.007732
# 0:	learn: 10611.3648419	test: 6342.9993878	best: 6342.9993878 (0)	total: 8.78ms	remaining: 2m 55s
# 1000:	learn: 2414.0314974	test: 3062.0703596	best: 3062.0703596 (1000)	total: 6.42s	remaining: 2m 1s
# 2000:	learn: 1535.6793337	test: 2877.4443755	best: 2877.4443755 (2000)	total: 12.6s	remaining: 1m 53s
# 3000:	learn: 1053.3907032	test: 2767.1884782	best: 2766.9459147 (2998)	total: 18.7s	remaining: 1m 46s
# 4000:	learn: 790.1194179	test: 2721.4109734	best: 2721.2523817 (3998)	total: 24.5s	remaining: 1m 37s
# 5000:	learn: 605.1480129	test: 2708.1982564	best: 2708.1982564 (5000)	total: 30.4s	remaining: 1m 31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2702.952935
# bestIteration = 5453
#
# Shrink model to first 5454 iterations.
# Learning rate set to 0.007732
# 0:	learn: 8756.2016248	test: 13588.9784425	best: 13588.9784425 (0)	total: 5.72ms	remaining: 1m 54s
# 1000:	learn: 2613.6725630	test: 8037.0993360	best: 8036.3993421 (999)	total: 6.59s	remaining: 2m 5s
# 2000:	learn: 1655.8708583	test: 7606.6378017	best: 7606.6378017 (2000)	total: 12.8s	remaining: 1m 54s
# 3000:	learn: 1150.9079976	test: 7486.7780196	best: 7486.7126654 (2999)	total: 18.8s	remaining: 1m 46s
# 4000:	learn: 864.6916088	test: 7450.4985527	best: 7450.3836814 (3999)	total: 24.4s	remaining: 1m 37s
# 5000:	learn: 663.0141146	test: 7436.8063364	best: 7436.8029982 (4998)	total: 30.6s	remaining: 1m 31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7431.652447
# bestIteration = 5297
#
# Shrink model to first 5298 iterations.
# Learning rate set to 0.007732
# 0:	learn: 10139.1500103	test: 8901.7953798	best: 8901.7953798 (0)	total: 7.92ms	remaining: 2m 38s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4764.979161
# bestIteration = 502
#
# Shrink model to first 503 iterations.
#             lgbm           cb
# cv1  5144.004903  4972.681102
# cv2  4953.562543  5064.683491
# cv3  3299.811318  2702.952935
# cv4  7658.269677  7431.652447
# cv5  4346.834502  4764.979161
# 평균   5080.496589  4987.389827

# %% [markdown]
# #### 2. 투수

# %%
# train, test 분할
col_dict, X, y = Xy_split(fa_pitcher)

X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

pd.concat([lgbm_model(X, y),
           cb_model(X, y)], axis=1)
# Out:
#  ============================ 1 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [538]	valid_0's rmse: 28597.8
#
#
#  ============================ 2 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [415]	valid_0's rmse: 24110.1
#
#
#  ============================ 3 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [321]	valid_0's rmse: 25294
#
#
#  ============================ 4 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [68]	valid_0's rmse: 25259.8
#
#
#  ============================ 5 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [751]	valid_0's rmse: 21186
# Learning rate set to 0.006132
# 0:	learn: 46614.4599141	test: 56680.4976973	best: 56680.4976973 (0)	total: 5.4ms	remaining: 1m 47s
# 1000:	learn: 13619.4187805	test: 30123.1572478	best: 30123.1572478 (1000)	total: 4.32s	remaining: 1m 22s
# 2000:	learn: 7485.1100189	test: 29154.4972460	best: 29151.1616796 (1945)	total: 8.99s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 29141.46889
# bestIteration = 2033
#
# Shrink model to first 2034 iterations.
# Learning rate set to 0.006132
# 0:	learn: 49409.7735038	test: 46236.6810500	best: 46236.6810500 (0)	total: 5.25ms	remaining: 1m 44s
# 1000:	learn: 13804.0556519	test: 27034.0038069	best: 27034.0038069 (1000)	total: 4.69s	remaining: 1m 28s
# 2000:	learn: 7969.1087895	test: 26049.0346199	best: 26045.7956509 (1986)	total: 9.34s	remaining: 1m 23s
# 3000:	learn: 4450.9743126	test: 25465.0631596	best: 25464.0592993 (2998)	total: 14s	remaining: 1m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 25373.59153
# bestIteration = 3576
#
# Shrink model to first 3577 iterations.
# Learning rate set to 0.006132
# 0:	learn: 50891.9098806	test: 39415.2478332	best: 39415.2478332 (0)	total: 6.04ms	remaining: 2m
# 1000:	learn: 14115.1792180	test: 25013.4594734	best: 25012.6310580 (999)	total: 4.86s	remaining: 1m 32s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 24262.68995
# bestIteration = 1883
#
# Shrink model to first 1884 iterations.
# Learning rate set to 0.006132
# 0:	learn: 47181.9931932	test: 54740.6665820	best: 54740.6665820 (0)	total: 6.57ms	remaining: 2m 11s
# 1000:	learn: 13842.9790595	test: 25059.3573862	best: 25058.9926128 (998)	total: 4.67s	remaining: 1m 28s
# 2000:	learn: 7246.3891927	test: 23435.0434649	best: 23427.6842410 (1964)	total: 9.46s	remaining: 1m 25s
# 3000:	learn: 4158.2383016	test: 23238.8615211	best: 23234.1660271 (2955)	total: 14.3s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 23231.23714
# bestIteration = 3072
#
# Shrink model to first 3073 iterations.
# Learning rate set to 0.006134
# 0:	learn: 49562.8759311	test: 45513.2162753	best: 45513.2162753 (0)	total: 5.27ms	remaining: 1m 45s
# 1000:	learn: 14224.4877905	test: 23915.5089495	best: 23915.5089495 (1000)	total: 4.7s	remaining: 1m 29s
# 2000:	learn: 8565.4723003	test: 22655.8008130	best: 22654.1350869 (1995)	total: 9.01s	remaining: 1m 21s
# 3000:	learn: 4948.9360194	test: 22219.6164982	best: 22219.6164982 (3000)	total: 13.2s	remaining: 1m 14s
# 4000:	learn: 3087.2902473	test: 22085.2180691	best: 22081.4517674 (3953)	total: 17.8s	remaining: 1m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 22074.04838
# bestIteration = 4136
#
# Shrink model to first 4137 iterations.
#              lgbm            cb
# cv1  28597.839275  29141.468889
# cv2  24110.139264  25373.591532
# cv3  25293.953093  24262.689950
# cv4  25259.772296  23231.237139
# cv5  21185.967394  22074.048383
# 평균   24889.534264  24816.607179

# %%
# train, test 분할
col_dict, X, y = Xy_split(nonfa_pitcher)

X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

pd.concat([lgbm_model(X, y),
           cb_model(X, y)], axis=1)
# Out:
#  ============================ 1 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	valid_0's rmse: 5045.75
#
#
#  ============================ 2 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [92]	valid_0's rmse: 10359.9
#
#
#  ============================ 3 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [69]	valid_0's rmse: 8497.33
#
#
#  ============================ 4 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [91]	valid_0's rmse: 6673.67
#
#
#  ============================ 5 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [37]	valid_0's rmse: 6187
# Learning rate set to 0.00762
# 0:	learn: 12091.6837535	test: 8564.8943011	best: 8564.8943011 (0)	total: 6.23ms	remaining: 2m 4s
# 1000:	learn: 3647.0813424	test: 4586.9198487	best: 4586.2796268 (989)	total: 5.26s	remaining: 1m 39s
# 2000:	learn: 2390.0432454	test: 4425.9792631	best: 4425.5248396 (1996)	total: 10.7s	remaining: 1m 35s
# 3000:	learn: 1666.0886548	test: 4366.5963616	best: 4366.5963616 (3000)	total: 15.9s	remaining: 1m 30s
# 4000:	learn: 1197.8754915	test: 4318.4102255	best: 4318.3721267 (3999)	total: 21.2s	remaining: 1m 24s
# 5000:	learn: 880.4537427	test: 4299.5477623	best: 4299.4889378 (4998)	total: 26.5s	remaining: 1m 19s
# 6000:	learn: 665.7225950	test: 4290.3180651	best: 4290.2456010 (5999)	total: 31.6s	remaining: 1m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4290.245601
# bestIteration = 5999
#
# Shrink model to first 6000 iterations.
# Learning rate set to 0.007621
# 0:	learn: 10792.7811281	test: 13886.4686959	best: 13886.4686959 (0)	total: 4.9ms	remaining: 1m 37s
# 1000:	learn: 3794.4225872	test: 10627.3345634	best: 10627.3345634 (1000)	total: 4.9s	remaining: 1m 32s
# 2000:	learn: 2443.6513579	test: 10257.5283525	best: 10256.9093794 (1998)	total: 9.97s	remaining: 1m 29s
# 3000:	learn: 1782.6863468	test: 10200.3155882	best: 10200.3155882 (3000)	total: 14.9s	remaining: 1m 24s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 10198.5492
# bestIteration = 3080
#
# Shrink model to first 3081 iterations.
# Learning rate set to 0.007621
# 0:	learn: 11075.1037649	test: 12944.4110156	best: 12944.4110156 (0)	total: 4.94ms	remaining: 1m 38s
# 1000:	learn: 3715.3523999	test: 8712.0892496	best: 8712.0892496 (1000)	total: 4.98s	remaining: 1m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 8537.733295
# bestIteration = 1414
#
# Shrink model to first 1415 iterations.
# Learning rate set to 0.007621
# 0:	learn: 11507.0231002	test: 11397.3667392	best: 11397.3667392 (0)	total: 5.18ms	remaining: 1m 43s
# 1000:	learn: 3719.6220881	test: 6312.9910985	best: 6312.9910985 (1000)	total: 5.11s	remaining: 1m 36s
# 2000:	learn: 2488.0356198	test: 5931.0817688	best: 5931.0817688 (2000)	total: 10s	remaining: 1m 29s
# 3000:	learn: 1733.8209176	test: 5776.8572215	best: 5776.8572215 (3000)	total: 15s	remaining: 1m 24s
# 4000:	learn: 1260.6002203	test: 5715.8860254	best: 5715.8860254 (4000)	total: 20.2s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 5692.411241
# bestIteration = 4829
#
# Shrink model to first 4830 iterations.
# Learning rate set to 0.007621
# 0:	learn: 11856.5658528	test: 9801.9738309	best: 9801.9738309 (0)	total: 5.26ms	remaining: 1m 45s
# 1000:	learn: 3770.7355587	test: 5629.1719507	best: 5629.1719507 (1000)	total: 5.32s	remaining: 1m 40s
# 2000:	learn: 2539.1140653	test: 5348.7679232	best: 5348.6232196 (1969)	total: 10.4s	remaining: 1m 33s
# 3000:	learn: 1790.2758107	test: 5259.3819158	best: 5257.1220050 (2943)	total: 15.4s	remaining: 1m 27s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 5257.122005
# bestIteration = 2943
#
# Shrink model to first 2944 iterations.
#              lgbm            cb
# cv1   5045.745964   4290.245601
# cv2  10359.903365  10198.549202
# cv3   8497.331948   8537.733295
# cv4   6673.666704   5692.411241
# cv5   6186.995144   5257.122005
# 평균    7352.728625   6795.212269
