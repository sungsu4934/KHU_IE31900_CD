# %% [markdown]
# # 패키지 불러오기

# %%
import math
import pandas as pd
import numpy as np

import lightgbm as lgb
from catboost import Pool, CatBoostRegressor

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression

n_splits = 5

# %% [markdown]
# # 데이터 불러오기

# %%
hitter_simple_fa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/단순가중/타자_단순가중_fa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
hitter_simple_nonfa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/단순가중/타자_단순가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
pitcher_simple_fa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/단순가중/투수_단순가중_fa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
pitcher_simple_nonfa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/단순가중/투수_단순가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)

hitter_time_weighted_fa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간가중/타자_시간가중_fa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
hitter_time_weighted_nonfa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간가중/타자_시간가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
pitcher_time_weighted_fa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간가중/투수_시간가중_fa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
pitcher_time_weighted_nonfa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간가중/투수_시간가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)

hitter_play_weighted_fa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/경기가중/타자_경기가중_fa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
hitter_play_weighted_nonfa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/경기가중/타자_경기가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
pitcher_play_weighted_fa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/경기가중/투수_경기가중_fa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
pitcher_play_weighted_nonfa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/경기가중/투수_경기가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)

hitter_time_and_play_weighted_fa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간경기가중/타자_시간경기가중_fa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
hitter_time_and_play_weighted_nonfa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간경기가중/타자_시간경기가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
pitcher_time_and_play_weighted_fa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간경기가중/투수_시간경기가중_fa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)
pitcher_time_and_play_weighted_nonfa = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간경기가중/투수_시간경기가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)

# %% [markdown]
# # 모델 정의

# %%
def Xy_split(dataset):
    
    dataset_X = dataset.drop('연봉', axis=1)
    dataset_y = dataset['연봉']
    
    return dataset_X, dataset_y

# %%
def lgbm_model(data_x, data_y):

    # lgbm 모델링
    lgb_params = {"objective" : "rmse",
                 "verbosity" : -1}

    lgb_models={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        print(f'\n\n ============================ {step} ============================')    

        X_train = data_x.iloc[tr_idx, :].values
        y_train = data_y[tr_idx].values

        X_valid = data_x.iloc[val_idx, :].values
        y_valid = data_y[val_idx].values

        lgb_dtrain = lgb.Dataset(data = X_train, label = y_train) 
        lgb_dvalid = lgb.Dataset(data = X_valid, label = y_valid) 

        lgb_model = lgb.train(lgb_params, lgb_dtrain, 20000, valid_sets=[lgb_dvalid], early_stopping_rounds=100, verbose_eval=1000)
        lgb_models[step] = lgb_model

        step += 1
        
    # lgbm 성능종합
    performance = [lgb_models[step].best_score['valid_0']['rmse'] for step in range(1,6)]
    cv_performance = round(np.mean(performance),1)

    return cv_performance

# %%
def cb_model(data_x, data_y):

    # cb 모델링
    cat_cols = []

    cb_models={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :]
        y_train = data_y[tr_idx]

        X_valid = data_x.iloc[val_idx, :]
        y_valid = data_y[val_idx]

        cb_dtrain = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        cb_dvalid = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        cb_model = CatBoostRegressor(iterations=20000, eval_metric='RMSE', loss_function='RMSE', verbose = 0)

        cb_model.fit(cb_dtrain, eval_set=cb_dvalid, early_stopping_rounds=100, verbose_eval=1000, use_best_model=True)
        cb_models[step] = cb_model

        step += 1
        
    # cb 성능종합
    performance = [cb_models[step].best_score_['validation']['RMSE'] for step in range(1,6)]
    cv_performance = round(np.mean(performance),1)

    return cv_performance

# %%
def lgbm_log_model(data_x, data_y):

    # lgbm 모델링
    lgb_params = {"objective" : "rmse",
                 "verbosity" : -1}

    performance = []

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :].values
        y_train = data_y[tr_idx].values

        X_valid = data_x.iloc[val_idx, :].values
        y_valid = data_y[val_idx].values

        lgb_dtrain = lgb.Dataset(data = X_train, label = y_train) 
        lgb_dvalid = lgb.Dataset(data = X_valid, label = y_valid) 

        lgb_model = lgb.train(lgb_params, lgb_dtrain, 20000, valid_sets=[lgb_dvalid], early_stopping_rounds=100, verbose_eval=1000)
        pred_valid = list(map(lambda x: 10 ** x, lgb_model.predict(X_valid)))
        rmse = mean_squared_error(list(map(lambda x: 10 ** x, y_valid)), pred_valid, squared=False)

        performance.append(rmse)

    # lgbm 성능종합
    cv_performance = round(np.mean(performance),1)

    return cv_performance

# %%
def cb_log_model(data_x, data_y):

    # cb 모델링
    cat_cols = []
    performance = []

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :]
        y_train = data_y[tr_idx]

        X_valid = data_x.iloc[val_idx, :]
        y_valid = data_y[val_idx]

        cb_dtrain = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        cb_dvalid = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        cb_model = CatBoostRegressor(iterations=20000, eval_metric='RMSE', loss_function='RMSE', verbose = 0)

        cb_model.fit(cb_dtrain, eval_set=cb_dvalid, early_stopping_rounds=100, verbose_eval=1000, use_best_model=True)
        pred_valid = list(map(lambda x: 10 ** x, cb_model.predict(X_valid)))
        rmse = mean_squared_error(list(map(lambda x: 10 ** x, y_valid)), pred_valid, squared=False)

        performance.append(rmse)
        
    # cb 성능종합
    cv_performance = round(np.mean(performance),1)

    return cv_performance

# %% [markdown]
# # 변수선택법 방법론 정의

# %%
def get_lgbm_RFE_rank(X, y):

    X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

    X = X.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y = y.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)
    
    original_feature_num = X.shape[1]

    # RFE 적용
    lgb_params = {"objective" : "rmse",
                 "verbosity" : -1}

    remove_cols = []

    while True:

        # 변수명 정의
        column_names = list(X.columns)
        print(f'남은변수개수: {len(column_names)}')

        # lgbm 모델링
        lgb_dtrain = lgb.Dataset(data = X, label = y) 
        lgb_dvalid = lgb.Dataset(data = X_test, label = y_test) 

        lgb_model = lgb.train(lgb_params, lgb_dtrain, 20000, valid_sets=[lgb_dvalid], early_stopping_rounds=100, verbose_eval=1000)

        # 가장 낮은 변수들 중 1개 삭제
        remove_col = [col for col, importance in zip(column_names, lgb_model.feature_importance()) if importance == min(lgb_model.feature_importance())][-1]
        remove_cols.append(remove_col)
        X.drop(remove_col, axis=1, inplace=True)
        X_test.drop(remove_col, axis=1, inplace=True)

        # while문 종료조건
        if X.shape[1] == 1:
            remove_cols.append(X.columns[0])
            break

    # 데이터프레임으로 생성
    result = pd.DataFrame({'변수명':remove_cols,
                           'RFE순위':[i for i in range(original_feature_num, 0, -1)]})

    return result

# %%
def get_cb_RFE_rank(X, y):

    X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

    X = X.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y = y.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    original_feature_num = X.shape[1]
        
    # RFE 적용
    remove_cols = []

    while True:

        # 변수명 정의
        column_names = list(X.columns)
        print(f'남은변수개수: {len(column_names)}')

        # cb 모델링
        cat_cols = []
        cb_dtrain = Pool(data=X, label=y, cat_features=cat_cols)
        cb_dvalid = Pool(data=X_test, label=y_test, cat_features=cat_cols)

        cb_model = CatBoostRegressor(iterations=20000, eval_metric='RMSE', loss_function='RMSE', verbose = 0)
        cb_model.fit(cb_dtrain, eval_set=cb_dvalid, early_stopping_rounds=100, verbose_eval=1000, use_best_model=True)

        # 가장 낮은 변수들 중 1개 삭제
        remove_col = [col for col, importance in zip(column_names, cb_model.feature_importances_) if importance == min(cb_model.feature_importances_)][-1]
        remove_cols.append(remove_col)
        X.drop(remove_col, axis=1, inplace=True)
        X_test.drop(remove_col, axis=1, inplace=True)

        # while문 종료조건
        if X.shape[1] == 1:
            remove_cols.append(X.columns[0])
            break

    # 데이터프레임으로 생성
    result = pd.DataFrame({'변수명':remove_cols,
                           'RFE순위':[i for i in range(original_feature_num, 0, -1)]})
    
    return result

# %%
def lgbm_RFE_modeling(data_x, data_y, score_dataframe, log_transformation):

    # 성능을 담을 변수 초기화
    performances = []

    # 변수개수별 성능파악
    for n_features in range(0, data_x.shape[1]+1, 5):

        # 변수가 0개일때는 실행x
        if n_features == 0:
            continue

        ### 변수목록 선정
        features = list(score_dataframe.loc[score_dataframe['RFE순위'].isin([i for i in range(1, n_features+1)]), '변수명'])

        # 모델링 후 데이터프레임 생성
        data_x_tmp = data_x[features]
        
        if log_transformation == True:
            performances.append(lgbm_log_model(data_x_tmp, data_y))
        else:
            performances.append(lgbm_model(data_x_tmp, data_y))

    result = pd.DataFrame({'RMSE':performances}, index = [i for i in range(5, data_x.shape[1]+1, 5)])
    
    return result

# %%
def cb_RFE_modeling(data_x, data_y, score_dataframe, log_transformation):

    # 성능을 담을 변수 초기화
    performances = []

    # 변수개수별 성능파악
    for n_features in range(0, data_x.shape[1]+1, 5):

        # 변수가 0개일때는 실행x
        if n_features == 0:
            continue

        ### 변수목록 선정
        features = list(score_dataframe.loc[score_dataframe['RFE순위'].isin([i for i in range(1, n_features+1)]), '변수명'])

        # 모델링 후 데이터프레임 생성
        data_x_tmp = data_x[features]
        
        if log_transformation == True:
            performances.append(cb_log_model(data_x_tmp, data_y))
        else:
            performances.append(cb_model(data_x_tmp, data_y))

    result = pd.DataFrame({'RMSE':performances}, index = [i for i in range(5, data_x.shape[1]+1, 5)])
    
    return result

# %%
def get_mi_rank(X, y):

    # score 산정
    mutual_info = SelectKBest(mutual_info_regression, k=1).fit(X, y)
    mutual_info_importance = pd.Series(mutual_info.scores_).rank(ascending=False)

    # 데이터프레임 생성
    mi_score = pd.DataFrame({'변수명':list(X.columns),
                        'mi순위':list(mutual_info_importance)})

    return mi_score

# %%
def lgbm_mi_modeling(data_x, data_y, score_dataframe, log_transformation):
    
    # 성능을 담을 변수 초기화
    performances = []
    
    # 변수개수별 성능파악
    for n_features in range(0, data_x.shape[1]+1, 5):
        
        # 변수가 0개일때는 실행x
        if n_features == 0:
            continue

        ### 변수목록 선정
        features = list(score_dataframe.loc[score_dataframe['mi순위'].isin([i for i in range(1, n_features+1)]), '변수명'])
        
        # 모델링 후 데이터프레임 생성
        data_x_tmp = data_x[features]
        
        if log_transformation == True:
            performances.append(lgbm_log_model(data_x_tmp, data_y))
        else:
            performances.append(lgbm_model(data_x_tmp, data_y))
    
    result = pd.DataFrame({'RMSE':performances}, index = [i for i in range(5, data_x.shape[1]+1, 5)])
    
    return result

# %%
def cb_mi_modeling(data_x, data_y, score_dataframe, log_transformation):
    
    # 성능을 담을 변수 초기화
    performances = []
    
    # 변수개수별 성능파악
    for n_features in range(0, data_x.shape[1]+1, 5):
        
        # 변수가 0개일때는 실행x
        if n_features == 0:
            continue

        ### 변수목록 선정
        features = list(score_dataframe.loc[score_dataframe['mi순위'].isin([i for i in range(1, n_features+1)]), '변수명'])
        
        # 모델링 후 데이터프레임 생성
        data_x_tmp = data_x[features]
        
        if log_transformation == True:
            performances.append(cb_log_model(data_x_tmp, data_y))
        else:
            performances.append(cb_model(data_x_tmp, data_y))    
    
    result = pd.DataFrame({'RMSE':performances}, index = [i for i in range(5, data_x.shape[1]+1, 5)])
    
    return result

# %%
def feature_seleciton_modeling(model_type, selection_method, log_transformation):
    
    if (model_type == 'lightgbm') & (selection_method == 'RFE'):
        score = get_lgbm_RFE_rank(dataset)
        performance = lgbm_RFE_modeling(data_x, data_y, score, log_transformation)
        
    elif (model_type == 'catboost') & (selection_method == 'RFE'):
        score = get_cb_RFE_rank(dataset)
        performance = cb_RFE_modeling(data_x, data_y, score, log_transformation)
        
    elif (model_type == 'lgbm') & (selection_method == 'mi'):
        score = get_mi_rank(dataset)
        performance = lgbm_mi_modeling(data_x, data_y, score, log_transformation)
        
    elif (model_type == 'catboost') & (selection_method == 'mi'):
        score = get_mi_rank(dataset)
        performance = cb_mi_modeling(data_x, data_y, score, log_transformation)
        
    return performance

# %% [markdown]
# # util 정의

# %%
def load_dataset(player_type, weight_type, fa_type):
    
    #### 단순가중 ####
    if (player_type == '타자') & (weight_type == 'simple') & (fa_type == 'fa'):
        return hitter_simple_fa
    
    elif (player_type == '타자') & (weight_type == 'simple') & (fa_type == 'nonfa'):
        return hitter_simple_nonfa
    
    elif (player_type == '투수') & (weight_type == 'simple') & (fa_type == 'fa'):
        return pitcher_simple_fa
    
    elif (player_type == '투수') & (weight_type == 'simple') & (fa_type == 'nonfa'):
        return pitcher_simple_nonfa
    
    #### 시간가중 ####
    elif (player_type == '타자') & (weight_type == 'time') & (fa_type == 'fa'):
        return hitter_time_weighted_fa
    
    elif (player_type == '타자') & (weight_type == 'time') & (fa_type == 'nonfa'):
        return hitter_time_weighted_nonfa
    
    elif (player_type == '투수') & (weight_type == 'time') & (fa_type == 'fa'):
        return pitcher_time_weighted_fa
    
    elif (player_type == '투수') & (weight_type == 'time') & (fa_type == 'nonfa'):
        return pitcher_time_weighted_nonfa
    
    #### 경기가중 ####
    elif (player_type == '타자') & (weight_type == 'play') & (fa_type == 'fa'):
        return hitter_play_weighted_fa
    
    elif (player_type == '타자') & (weight_type == 'play') & (fa_type == 'nonfa'):
        return hitter_play_weighted_nonfa
    
    elif (player_type == '투수') & (weight_type == 'play') & (fa_type == 'fa'):
        return pitcher_play_weighted_fa
    
    elif (player_type == '투수') & (weight_type == 'play') & (fa_type == 'nonfa'):
        return pitcher_play_weighted_nonfa
    
    #### 시간경기가중 ####
    elif (player_type == '타자') & (weight_type == 'time_and_play') & (fa_type == 'fa'):
        return hitter_time_and_play_weighted_fa
    
    elif (player_type == '타자') & (weight_type == 'time_and_play') & (fa_type == 'nonfa'):
        return hitter_time_and_play_weighted_nonfa
    
    elif (player_type == '투수') & (weight_type == 'time_and_play') & (fa_type == 'fa'):
        return pitcher_time_and_play_weighted_fa
    
    elif (player_type == '투수') & (weight_type == 'time_and_play') & (fa_type == 'nonfa'):
        return pitcher_time_and_play_weighted_nonfa

# %%
def scaler_transformation(dataset, scaler_type):
    
    # Z-score scaler
    if scaler_type == 'standardized_scaler':
        scaler = StandardScaler()
        dataset_scaled = scaler.fit_transform(dataset)
        dataset_scaled = pd.DataFrame(dataset_scaled)
    
    # Minmax scaler
    elif scaler_type == 'minmax_scaler':
        scaler = MinMaxScaler()
        dataset_scaled = scaler.fit_transform(dataset)
        dataset_scaled = pd.DataFrame(dataset_scaled)
        
    return dataset_scaled

# %%
def log_transformation(dataset):
    
    dataset_log = pd.Series(list(map(lambda x: math.log10(x), dataset)))
    return dataset_log

# %% [markdown]
# # 종합함수

# %%
def modeling(data_x, data_y, model_type, selection_method, log_transformation):
    
    if (model_type == 'lightgbm') & (selection_method == 'RFE'):
        score = get_lgbm_RFE_rank(data_x, data_y)
        performance = lgbm_RFE_modeling(data_x, data_y, score, log_transformation)
        return score, performance
        
    elif (model_type == 'catboost') & (selection_method == 'RFE'):
        score = get_cb_RFE_rank(data_x, data_y)
        performance = cb_RFE_modeling(data_x, data_y, score, log_transformation)
        return score, performance
        
    elif (model_type == 'lightgbm') & (selection_method == 'mi'):
        score = get_mi_rank(data_x, data_y)
        performance = lgbm_mi_modeling(data_x, data_y, score, log_transformation)
        return score, performance
        
    elif (model_type == 'catboost') & (selection_method == 'mi'):
        score = get_mi_rank(data_x, data_y)
        performance = cb_mi_modeling(data_x, data_y, score, log_transformation)
        return score, performance
        
    elif (model_type == 'lightgbm') & (log_transformation == True) & (selection_method == 'no_use'):
        performance = lgbm_log_model(data_x, data_y)
        return performance
        
    elif (model_type == 'lightgbm') & (log_transformation == False) & (selection_method == 'no_use'):
        performance = lgbm_model(data_x, data_y)
        return performance
        
    elif (model_type == 'catboost') & (log_transformation == True) & (selection_method == 'no_use'):
        performance = cb_log_model(data_x, data_y)
        return performance
        
    elif (model_type == 'catboost') & (log_transformation == False) & (selection_method == 'no_use'):
        performance = cb_model(data_x, data_y)
        return performance

# %%
def get_performance(player_type, weight_type, fa_type, scaler_type, log_transform, model_type, selection_method):
    
    # 데이터 불러오기
    df = load_dataset(player_type, weight_type, fa_type)
    
    # X, y 분할
    X_data, y_data = Xy_split(df)
    
    # 스케일링여부 체크
    if scaler_type in ['standardized_scaler', 'minmax_scaler']:
        X_data = scaler_transformation(X_data, scaler_type)
    
    # 로그변환 여부 체크
    if log_transform == True:
        y_data = log_transformation(y_data)
        
    if selection_method == 'no_use':
        performance = modeling(X_data, y_data, model_type, selection_method, log_transform)
        
    elif selection_method in ['RFE', 'mi']:
        score_df, performance = modeling(X_data, y_data, model_type, selection_method, log_transform)
    
    print(f'\n\n===== {model_type} === {player_type} {fa_type} =====')
    print(f'===== {weight_type} == 스케일링: {scaler_type} == log변환: {log_transform} == 변수선택법: {selection_method} =====')
    
    if selection_method == 'no_use':
        print(f'===== RMSE: {performance} =====')    
        return performance
        
    elif selection_method in ['RFE', 'mi']:
        display(performance)
        return score_df, performance

# %% [markdown]
# # 최종실험

# %%
def cb_final_model(data_x, data_y):

    # cb 모델링
    cat_cols = []

    cb_models={}
    r2_scores={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :]
        y_train = data_y[tr_idx]

        X_valid = data_x.iloc[val_idx, :]
        y_valid = data_y[val_idx]

        cb_dtrain = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        cb_dvalid = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        cb_model = CatBoostRegressor(iterations=20000, eval_metric='RMSE', loss_function='RMSE', verbose = 0)

        cb_model.fit(cb_dtrain, eval_set=cb_dvalid, early_stopping_rounds=100, verbose_eval=1000, use_best_model=True)
        r2 = r2_score(y_valid, cb_model.predict(X_valid))
        
        cb_models[step] = cb_model
        r2_scores[step] = r2
        
        step += 1
        
    return cb_models, r2_scores

# %% [markdown]
# #### (1) 투수FA
#  - 시간경기가중 // Z-scoring + Feature selection(RFE)

# %%
# 데이터 load
train = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간경기가중/투수_시간경기가중_fa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)

# Xy split
train_x, train_y = Xy_split(train)

# 스케일링
train_x = scaler_transformation(dataset = train_x, 
                                scaler_type = 'standardized_scaler')

# RFE 변수 순위 도출
ranking = get_cb_RFE_rank(train_x, train_y)
ranking
# Out:
# 남은변수개수: 143
# Learning rate set to 0.006278
# 0:	learn: 48273.8152265	test: 39428.9240563	best: 39428.9240563 (0)	total: 171ms	remaining: 57m 2s
# 1000:	learn: 7008.0480110	test: 14039.0031596	best: 14039.0031596 (1000)	total: 5.53s	remaining: 1m 45s
# 2000:	learn: 3742.5687661	test: 13153.8802287	best: 13153.8802287 (2000)	total: 11.1s	remaining: 1m 39s
# 3000:	learn: 2126.3724595	test: 12958.0678529	best: 12957.7203966 (2994)	total: 16.9s	remaining: 1m 35s
# 4000:	learn: 1284.0760268	test: 12893.1872847	best: 12892.8698430 (3974)	total: 22.5s	remaining: 1m 29s
# 5000:	learn: 817.4530858	test: 12868.8443529	best: 12868.7059655 (4998)	total: 27.9s	remaining: 1m 23s
# 6000:	learn: 528.4267291	test: 12855.0395703	best: 12854.4532713 (5923)	total: 33.6s	remaining: 1m 18s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 
	remaining: 1m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12742.99359
# bestIteration = 5540
#
# Shrink model to first 5541 iterations.
# 남은변수개수: 127
# Learning rate set to 0.006278
# 0:	learn: 48262.4509020	test: 39397.4019652	best: 39397.4019652 (0)	total: 8.72ms	remaining: 2m 54s
# 1000:	learn: 7130.5867871	test: 14080.0408258	best: 14080.0408258 (1000)	total: 5.05s	remaining: 1m 35s
# 2000:	learn: 3791.3529907	test: 13234.6359452	best: 13234.5443080 (1999)	total: 10.1s	remaining: 1m 30s
# 3000:	learn: 2153.3202344	test: 12990.8173876	best: 12990.5722209 (2962)	total: 15.1s	remaining: 1m 25s
# 4000:	learn: 1311.5956403	test: 12908.1906486	best: 12908.0023375 (3998)	total: 20.2s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12880.08159
# bestIteration = 4599
#
# Shrink model to first 4600 iterations.
# 남은변수개수: 126
# Learning rate set to 0.006278
# 0:	learn: 48266.8632683	test: 39416.7615050	best: 39416.7615050 (0)	total: 14.4ms	remaining: 4m 48s
# 1000:	learn: 7131.3940638	test: 13832.5749913	best: 13832.5749913 (1000)	total: 5.1s	remaining: 1m 36s
# 2000:	learn: 3809.2015574	test: 13046.9467853	best: 13046.9467853 (2000)	total: 10.2s	remaining: 1m 31s
# 3000:	learn: 2188.3739070	test: 12816.1719624	best: 12816.1719624 (3000)	total: 15.3s	remaining: 1m 26s
# 4000:	learn: 1333.7147461	test: 12726.0769596	best: 12725.9280914 (3998)	total: 20.4s	remaining: 1m 21s
# 5000:	learn: 843.6500695	test: 12681.7008708	best: 12681.1576007 (4992)	total: 25.4s	remaining: 1m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12666.84725
# bestIteration = 5681
#
# Shrink model to first 5682 iterations.
# 남은변수개수: 125
# Learning rate set to 0.006278
# 0:	learn: 48253.6277416	test: 39407.9827995	best: 39407.9827995 (0)	total: 8.09ms	remaining: 2m 41s
# 1000:	learn: 7040.6372589	test: 13800.4709065	best: 13800.4709065 (1000)	total: 5.07s	remaining: 1m 36s
# 2000:	learn: 3661.1793448	test: 12915.8458650	best: 12915.8458650 (2000)	total: 10.2s	remaining: 1m 31s
# 3000:	learn: 2120.7290252	test: 12721.0708755	best: 12720.6303000 (2989)	total: 15.3s	remaining: 1m 26s
# 4000:	learn: 1275.6852602	test: 12644.2325363	best: 12643.1822674 (3977)	total: 20.4s	remaining: 1m 21s
# 5000:	learn: 782.1816936	test: 12608.4902576	best: 12608.1074435 (4969)	total: 25.5s	remaining: 1m 16s
# 6000:	learn: 494.8030603	test: 12592.2103903	best: 12591.8470051 (5986)	total: 30.6s	remaining: 1m 11s
# 7000:	learn: 315.7574224	test: 12580.1874507	best: 12580.1477972 (6998)	total: 35.7s	remaining: 1m 6s
# 8000:	learn: 201.1041324	test: 12576.2267685	best: 12576.2267685 (8000)	total: 40.8s	remaining: 1m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12574.82848
# bestIteration = 8425
#
# Shrink model to first 8426 iterations.
# 남은변수개수: 124
# Learning rate set to 0.006278
# 0:	learn: 48286.1198749	test: 39447.7542053	best: 39447.7542053 (0)	total: 6.4ms	remaining: 2m 7s
# 1000:	learn: 6984.1623851	test: 14002.7953216	best: 14002.7953216 (1000)	total: 5.09s	remaining: 1m 36s
# 2000:	learn: 3697.8708794	test: 13186.2555014	best: 13185.9769167 (1998)	total: 10.2s	remaining: 1m 31s
# 3000:	learn:

# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12554.66433
# bestIteration = 8823
#
# Shrink model to first 8824 iterations.
# 남은변수개수: 120
# Learning rate set to 0.006278
# 0:	learn: 48273.6705872	test: 39449.3858755	best: 39449.3858755 (0)	total: 23.6ms	remaining: 7m 51s
# 1000:	learn: 7007.5075352	test: 13695.3645819	best: 13695.3645819 (1000)	total: 5.1s	remaining: 1m 36s
# 2000:	learn: 3761.8795924	test: 12781.8944618	best: 12781.8944618 (2000)	total: 10.2s	remaining: 1m 31s
# 3000:	learn: 2107.2955435	test: 12559.1271688	best: 12559.0878227 (2998)	total: 15.3s	remaining: 1m 26s
# 4000:	learn: 1315.0105435	test: 12487.0422997	best: 12486.6736416 (3933)	total: 20.5s	remaining: 1m 21s
# 5000:	learn: 858.0783033	test: 12459.4810817	best: 12459.1249783 (4940)	total: 25.6s	remaining: 1m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12448.46698
# bestIteration = 5519
#
# Shrink model to first 5520 iterations.
# 남은변수개수: 119
# Learning rate set to 0.006278
# 0:	learn: 48258.9844912	test: 39421.0979362	best: 39421.0979362 (0)	total: 7.89ms	remaining: 2m 37s
# 1000:	learn: 6991.1543790	test: 13640.7513082	best: 13640.7513082 (1000)	total: 5.03s	remaining: 1m 35s
# 2000:	learn: 3677.8539576	test: 12734.4214109	best: 12734.2333857 (1999)	total: 10s	remaining: 1m 30s
# 3000:	learn: 2052.2148195	test: 12562.3579128	best: 12562.3579128 (3000)	total: 15.1s	remaining: 1m 25s
# 4000:	learn: 1247.3109323	test: 12481.3730029	best: 12481.2887145 (3996)	total: 20.2s	remaining: 1m 20s
# 5000:	learn: 811.3420650	test: 12454.0874744	best: 12454.0844456 (4998)	total: 25.2s	remaining: 1m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12436.05132
# bestIteration = 5849
#
# Shrink model to first 5850 iterations.
# 남은변수개수: 118
# Learning rate set to 0.006278
# 0:	learn: 48261.5076459	test: 39421.6840507	best: 39421.6840507 (0)	total: 7.5ms	remaining: 2m 29s
# 1000:	learn: 7086.2874623	test: 14031.2550006	best: 14031.2550006 (1000)	total: 5.06s	remaining: 1m 36s
# 2000:	learn: 3669.8821848	test: 13073.5887593	best: 13073.5887593 (2000)	total: 10.2s	remaining: 1m 31s
# 3000:	learn: 2082.8405709	test: 12864.0974415	best: 12864.0974415 (3000)	total: 15.2s	remaining: 1m 26s
# 4000:	learn: 1287.8431507	test: 12797.0366018	best: 12795.7326336 (3961)	total: 20.3s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12785.17486
# bestIteration = 4258
#
# Shrink model to first 4259 iterations.
# 남은변수개수: 117
# Learning rate set to 0.006278
# 0:	learn: 48248.2732959	test: 39429.4476347	best: 39429.4476347 (0)	total: 9.99ms	remaining: 3m 19s
# 1000:	learn: 7062.1256698	test: 13826.2080658	best: 13826.2080658 (1000)	total: 5.02s	remaining: 1m 35s
# 2000:	learn: 3723.1575816	test: 12944.3534747	best: 12940.9503582 (1990)	total: 10s	remaining: 1m 30s
	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12639.32747
# bestIteration = 3272
#
# Shrink model to first 3273 iterations.
# 남은변수개수: 105
# Learning rate set to 0.006278
# 0:	learn: 48266.6408362	test: 39386.7742040	best: 39386.7742040 (0)	total: 17.3ms	remaining: 5m 45s
# 1000:	learn: 6931.8017774	test: 13585.4174765	best: 13585.4174765 (1000)	total: 4.75s	remaining: 1m 30s
# 2000:	learn: 3598.4949755	test: 12717.5973355	best: 12717.5973355 (2000)	total: 9.42s	remaining: 1m 24s
# 3000:	learn: 2050.3712578	test: 12514.0070819	best: 12513.8971523 (2999)	total: 14.1s	remaining: 1m 20s
# 4000:	learn: 1282.7692728	test: 12423.7815666	best: 12423.7815666 (4000)	total: 18.8s	remaining: 1m 15s
# 5000:	learn: 832.5014505	test: 12377.3469381	best: 12377.3469381 (5000)	total: 23.5s	remaining: 1m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12355.41388
# bestIteration = 5662
#
# Shrink model to first 5663 iterations.
# 남은변수개수: 104
# Learning rate set to 0.006278
# 0:	learn: 48276.2399997	test: 39395.7137130	best: 39395.7137130 (0)	total: 26.9ms	remaining: 8m 56s
# 1000:	learn: 6924.7007501	test: 13482.6591167	best: 13482.6591167 (1000)	total: 4.71s	remaining: 1m 29s
# 2000:	learn: 3603.0263261	test: 12610.6238729	best: 12608.5803320 (1997)	total: 9.43s	remaining: 1m 24s
# 3000:	learn: 2015.4305447	test: 12435.2390312	best: 12435.2390312 (3000)	total: 14.1s	remaining: 1m 20s
# 4000:	learn: 1239.3559366	test: 12336.0971716	best: 12336.0971716 (4000)	total: 18.9s	remaining: 1m 15s
# 5000:	learn: 808.4720512	test: 12298.6566273	best: 12298.5066322 (4997)	total: 23.6s	remaining: 1m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12289.75919
# bestIteration = 5434
#
# Shrink model to first 5435 iterations.
# 남은변수개수: 103
# Learning rate set to 0.006278
# 0:	learn: 48296.4113402	test: 39442.6747096	best: 39442.6747096 (0)	total: 31.1ms	remaining: 10m 21s
# 1000:	learn: 6910.7883331	test: 13802.4652485	best: 13802.4652485 (1000)	total: 4.71s	remaining: 1m 29s
# 2000:	learn: 3736.9549673	test: 12955.1137465	best: 12955.1137465 (2000)	total: 9.37s	remaining: 1m 24s
# 3000:	learn: 2150.6491771	test: 12697.2334463	best: 12697.2334463 (3000)	total: 14.1s	remaining: 1m 19s
# 4000:	learn: 1345.2910120	test: 12602.0487439	best: 12602.0151446 (3988)	total: 18.8s	remaining: 1m 15s
# 5000:	learn: 859.9515999	test: 12549.0972861	best: 12549.0972861 (5000)	total: 23.5s	remaining: 1m 10s
# 6000:	learn: 555.2165471	test: 12525.2266407	best: 12525.2025766 (5998)	total: 28.2s	remaining: 1m 5s
# 7000:	learn: 360.8732840	test: 12511.9951643	best: 12511.9951643 (7000)	total: 32.9s	remaining: 1m 1s
# 8000:	learn: 235.0875085	test: 12504.7635934	best: 12504.6845206 (7990)	total: 37.6s	remaining: 56.3s
# 9000:	learn: 156.8386771	test: 12501.1496319	best: 12501.1496319 (9000)	total: 42.3s	remaining: 51.7s
# 10000:	learn: 105.2566149	test: 12498.3740201	best: 12498.3517273 (9960)	total: 47s	remaining: 47s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 
6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12490.90034
# bestIteration = 7502
#
# Shrink model to first 7503 iterations.
# 남은변수개수: 99
# Learning rate set to 0.006278
# 0:	learn: 48260.2369609	test: 39399.4772349	best: 39399.4772349 (0)	total: 17.9ms	remaining: 5m 57s
# 1000:	learn: 6883.1091861	test: 13670.3433477	best: 13670.3433477 (1000)	total: 4.59s	remaining: 1m 27s
# 2000:	learn: 3692.5409860	test: 12806.0681851	best: 12806.0681851 (2000)	total: 9.1s	remaining: 1m 21s
# 3000:	learn: 2087.1973602	test: 12609.9890654	best: 12609.7010804 (2997)	total: 13.6s	remaining: 1m 17s
# 4000:	learn: 1321.7342205	test: 12526.5998184	best: 12526.3879900 (3995)	total: 18.2s	remaining: 1m 12s
# 5000:	learn: 860.3611274	test: 12482.7830781	best: 12482.7830781 (5000)	total: 22.7s	remaining: 1m 8s
# 6000:	learn: 563.4037952	test: 12455.7087182	best: 12455.7087182 (6000)	total: 27.3s	remaining: 1m 3s
# 7000:	learn: 368.8564538	test: 12439.5474093	best: 12439.4424207 (6990)	total: 31.8s	remaining: 59s
# 8000:	learn: 241.4111434	test: 12430.4918985	best: 12430.4918985 (8000)	total: 36.3s	remaining: 54.4s
# 9000:	learn: 160.2229435	test: 12424.7561601	best: 12424.6504429 (8988)	total: 40.8s	remaining: 49.9s
# 10000:	learn: 107.2160065	test: 12421.7264577	best: 12421.7141905 (9993)	total: 45.3s	remaining: 45.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12420.1002
# bestIteration = 10851
#
# Shrink model to first 10852 iterations.
# 남은변수개수: 98
# Learning rate set to 0.006278
# 0:	learn: 48267.8582549	test: 39411.4431940	best: 39411.4431940 (0)	total: 5.95ms	remaining: 1m 59s
# 1000:	learn: 6860.0392146	test: 13620.4788631	best: 13620.4788631 (1000)	total: 4.5s	remaining: 1m 25s
# 2000:	learn: 3656.5850564	test: 12779.8446528	best: 12779.8262630 (1999)	total: 8.96s	remaining: 1m 20s
# 3000:	learn: 2054.9084472	test: 12572.6803180	best: 12572.6803180 (3000)	total: 13.5s	remaining: 1m 16s
# 4000:	learn: 1295.5145305	test: 12482.4482006	best: 12482.4482006 (4000)	total: 18s	remaining: 1m 11s
# 5000:	learn: 850.6305170	test: 12445.9169168	best: 12445.8016221 (4997)	total: 22.4s	remaining: 1m 7s
# 6000:	learn: 562.4416499	test: 12427.8956286	best: 12427.8956286 (6000)	total: 27s	remaining: 1m 2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12424.90835
# bestIteration = 6129
#
# Shrink model to first 6130 iterations.
# 남은변수개수: 97
# Learning rate set to 0.006278
# 0:	learn: 48271.9364229	test: 39437.0216992	best: 39437.0216992 (0)	total: 5.31ms	remaining: 1m 46s
# 1000:	learn: 6903.2273470	test: 13689.1386597	best: 13689.1386597 (1000)	total: 4.43s	remaining: 1m 24s
# 2000:	learn: 3588.7556228	test: 12821.9821923	best: 12821.5156376 (1992)	total: 8.88s	remaining: 1m 19s
# 3000:	learn: 2025.4048126	test: 12645.6122856	best: 12645.5563044 (2996)	total: 13.4s	remaining: 1m 15s
# 4000:	learn: 1277.9310165	test: 12564.4639737	best: 12564.4639737 (4000)	total: 17.9s	remaining: 1m 11s
# 5000:	learn: 822.4502973	test: 12531.1511517	best: 12531.0671297 (4994)	total: 22.3s	remaining: 1m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 
7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11485.56177
# bestIteration = 5472
#
# Shrink model to first 5473 iterations.
# 남은변수개수: 24
# Learning rate set to 0.006278
# 0:	learn: 48265.5899699	test: 39429.9174762	best: 39429.9174762 (0)	total: 16.3ms	remaining: 5m 25s
# 1000:	learn: 6765.3127879	test: 12891.5456488	best: 12891.5456488 (1000)	total: 1.43s	remaining: 27s
# 2000:	learn: 3938.3109031	test: 12036.3724252	best: 12034.6728266 (1986)	total: 2.81s	remaining: 25.3s
# 3000:	learn: 2616.5314404	test: 11885.8556977	best: 11885.8471936 (2999)	total: 4.22s	remaining: 23.9s
# 4000:	learn: 1706.5494580	test: 11798.5750661	best: 11798.5750661 (4000)	total: 5.61s	remaining: 22.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11774.57106
# bestIteration = 4527
#
# Shrink model to first 4528 iterations.
# 남은변수개수: 23
# Learning rate set to 0.006278
# 0:	learn: 48247.8083350	test: 39382.1784969	best: 39382.1784969 (0)	total: 9.57ms	remaining: 3m 11s
# 1000:	learn: 6833.3677841	test: 12817.9183067	best: 12817.9183067 (1000)	total: 1.38s	remaining: 26.2s
# 2000:	learn: 3927.9183103	test: 11960.0312248	best: 11960.0312248 (2000)	total: 2.78s	remaining: 25s
# 3000:	learn: 2512.9523869	test: 11797.9123367	best: 11795.9435290 (2985)	total: 4.17s	remaining: 23.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11790.67642
# bestIteration = 3198
#
# Shrink model to first 3199 iterations.
# 남은변수개수: 22
# Learning rate set to 0.006278
# 0:	learn: 48240.4167489	test: 39386.3090151	best: 39386.3090151 (0)	total: 14.7ms	remaining: 4m 54s
# 1000:	learn: 6864.8354453	test: 12748.3730692	best: 12748.3730692 (1000)	total: 1.39s	remaining: 26.4s
# 2000:	learn: 4091.2416573	test: 11956.5725756	best: 11955.7510922 (1994)	total: 2.77s	remaining: 24.9s
# 3000:	learn: 2546.4141407	test: 11774.2355155	best: 11774.2317637 (2999)	total: 4.16s	remaining: 23.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11744.08855
# bestIteration = 3370
#
# Shrink model to first 3371 iterations.
# 남은변수개수: 21
# Learning rate set to 0.006278
# 0:	learn: 48248.0123732	test: 39432.0896561	best: 39432.0896561 (0)	total: 15.5ms	remaining: 5m 9s
# 1000:	learn: 6810.3174346	test: 12704.2190957	best: 12704.2190957 (1000)	total: 1.37s	remaining: 26s
# 2000:	learn: 4137.2102157	test: 11924.7429330	best: 11924.7429330 (2000)	total: 2.72s	remaining: 24.5s
# 3000:	learn: 2634.5581634	test: 11652.0859349	best: 11652.0859349 (3000)	total: 4.07s	remaining: 23.1s
# 4000:	learn: 1764.0704529	test: 11548.6111744	best: 11548.5190521 (3996)	total: 5.44s	remaining: 21.8s
# 5000:	learn: 1234.4562866	test: 11506.8965547	best: 11506.8965547 (5000)	total: 6.8s	remaining: 20.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 
7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11870.00106
# bestIteration = 5502
#
# Shrink model to first 5503 iterations.
# 남은변수개수: 13
# Learning rate set to 0.006278
# 0:	learn: 48238.7028477	test: 39413.4782641	best: 39413.4782641 (0)	total: 16.6ms	remaining: 5m 31s
# 1000:	learn: 7362.0684357	test: 13840.8990535	best: 13840.8990535 (1000)	total: 896ms	remaining: 17s
# 2000:	learn: 4717.8355006	test: 13015.8961550	best: 13012.6911749 (1986)	total: 1.8s	remaining: 16.2s
# 3000:	learn: 3247.8936245	test: 12602.9913880	best: 12600.9678505 (2954)	total: 2.67s	remaining: 15.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12525.13938
# bestIteration = 3753
#
# Shrink model to first 3754 iterations.
# 남은변수개수: 12
# Learning rate set to 0.006278
# 0:	learn: 48237.9378759	test: 39426.2979928	best: 39426.2979928 (0)	total: 8.87ms	remaining: 2m 57s
# 1000:	learn: 7387.5404473	test: 13970.3067731	best: 13970.3067731 (1000)	total: 908ms	remaining: 17.2s
# 2000:	learn: 4795.8596186	test: 13259.7369644	best: 13259.2536397 (1998)	total: 1.8s	remaining: 16.2s
# 3000:	learn: 3333.6396766	test: 12958.9762827	best: 12958.7440198 (2993)	total: 2.7s	remaining: 15.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12925.92375
# bestIteration = 3396
#
# Shrink model to first 3397 iterations.
# 남은변수개수: 11
# Learning rate set to 0.006278
# 0:	learn: 48244.4665260	test: 39400.8885146	best: 39400.8885146 (0)	total: 9.88ms	remaining: 3m 17s
# 1000:	learn: 7675.3164411	test: 14428.6268917	best: 14428.6268917 (1000)	total: 844ms	remaining: 16s
# 2000:	learn: 4997.3680267	test: 13754.1568870	best: 13754.1436436 (1999)	total: 1.68s	remaining: 15.1s
# 3000:	learn: 3636.4006412	test: 13491.8447709	best: 13490.9578734 (2982)	total: 2.53s	remaining: 14.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13419.3319
# bestIteration = 3809
#
# Shrink model to first 3810 iterations.
# 남은변수개수: 10
# Learning rate set to 0.006278
# 0:	learn: 48229.8408613	test: 39376.5637621	best: 39376.5637621 (0)	total: 10ms	remaining: 3m 20s
# 1000:	learn: 7769.7759304	test: 14313.5351456	best: 14313.5351456 (1000)	total: 843ms	remaining: 16s
# 2000:	learn: 5134.6362812	test: 13523.8822270	best: 13523.8822270 (2000)	total: 1.72s	remaining: 15.4s
# 3000:	learn: 3632.2633213	test: 13250.4576723	best: 13250.4576723 (3000)	total: 2.55s	remaining: 14.4s
# 4000:	learn: 2777.1035831	test: 13151.2193979	best: 13151.1709979 (3999)	total: 3.36s	remaining: 13.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13134.80909
# bestIteration = 4204
#
# Shrink model to first 4205 iterations.
# 남은변수개수: 9
# Learning rate set to 0.006278
# 0:	learn: 48241.6925783	test: 39425.4237604	best: 39425.4237604 (0)	total: 14.8ms	remaining: 4m 55s
# 1000:	learn: 7773.5543624	test: 14414.2841749	best: 14411.7916539 (995)	total: 837ms	remaining: 15.9s
# 2000:	learn: 5206.0992710	test: 13713.9949717	best: 13713.9949717 (2000)	total: 1.65s	remaining: 14.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13526.05875
# bestIteration = 2849
#
# Shrink model to first 2850 iterations.
# 남은변수개수: 8
# Learning rate set to 0.006278
# 0:	learn: 48251.2206308	test: 39399.0913140	best: 39399.0913140 (0)	total: 1.34ms	remaining: 26.7s
# 1000:	learn: 8462.8599336	test: 14639.1222170	best: 14639.1222170 (1000)	total: 825ms	remaining: 15.7s
# 2000:	learn: 6001.1939701	test: 13958.1629535	best: 13957.0188137 (1999)	total: 1.69s	remaining: 15.2s
# 3000:	learn: 4551.3338981	test: 13787.5697814	best: 13785.0889853 (2989)	total: 2.6s	remaining: 14.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13784.17301
# bestIteration = 3035
#
# Shrink model to first 3036 iterations.
# 남은변수개수: 7
# Learning rate set to 0.006278
# 0:	learn: 48230.3478579	test: 39402.3896837	best: 39402.3896837 (0)	total: 7.25ms	remaining: 2m 24s
# 1000:	learn: 8730.9767733	test: 16180.6267408	best: 16180.6267408 (1000)	total: 831ms	remaining: 15.8s
# 2000:	learn: 6071.5962260	test: 15556.2890947	best: 15555.3101242 (1999)	total: 1.64s	remaining: 14.8s
# 3000:	learn: 4676.9224755	test: 15337.3679282	best: 15337.1806393 (2991)	total: 2.52s	remaining: 14.3s
# 4000:	learn: 3787.7632568	test: 15259.7438929	best: 15258.6058695 (3996)	total: 3.36s	remaining: 13.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 15226.56648
# bestIteration = 4511
#
# Shrink model to first 4512 iterations.
# 남은변수개수: 6
# Learning rate set to 0.006278
# 0:	learn: 48238.6043485	test: 39367.5650865	best: 39367.5650865 (0)	total: 1.47ms	remaining: 29.3s
# 1000:	learn: 9030.5727225	test: 16415.8607602	best: 16415.8607602 (1000)	total: 798ms	remaining: 15.1s
# 2000:	learn: 6555.4871355	test: 15935.6735475	best: 15933.1633511 (1997)	total: 1.59s	remaining: 14.3s
# 3000:	learn: 5028.3408147	test: 15699.7803490	best: 15699.7803490 (3000)	total: 2.38s	remaining: 13.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 15666.22505
# bestIteration = 3388
#
# Shrink model to first 3389 iterations.
# 남은변수개수: 5
# Learning rate set to 0.006278
# 0:	learn: 48246.8564078	test: 39416.4937224	best: 39416.4937224 (0)	total: 1.26ms	remaining: 25.2s
# 1000:	learn: 8981.0216277	test: 15905.9607235	best: 15905.4553562 (998)	total: 729ms	remaining: 13.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 15723.90717
# bestIteration = 1701
#
# Shrink model to first 1702 iterations.
# 남은변수개수: 4
# Learning rate set to 0.006278
# 0:	learn: 48250.4581176	test: 39431.1013446	best: 39431.1013446 (0)	total: 1.2ms	remaining: 24.1s
# 1000:	learn: 9699.1708636	test: 16911.5700426	best: 16910.4215430 (999)	total: 702ms	remaining: 13.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 16897.12127
# bestIteration = 1018
#
# Shrink model to first 1019 iterations.
# 남은변수개수: 3
# Learning rate set to 0.006278
# 0:	learn: 48242.8040052	test: 39394.0554657	best: 39394.0554657 (0)	total: 11.4ms	remaining: 3m 48s
# 1000:	learn: 14375.4262476	test: 21626.4144140	best: 21625.9327373 (997)	total: 641ms	remaining: 12.2s
# 2000:	learn: 11948.5735795	test: 20564.0005255	best: 20562.5584769 (1997)	total: 1.35s	remaining: 12.2s
# 3000:	learn: 10674.1579574	test: 19926.6424529	best: 19926.6424529 (3000)	total: 2.05s	remaining: 11.6s
# 4000:	learn: 9999.2704839	test: 19674.7688969	best: 19674.7688969 (4000)	total: 2.76s	remaining: 11s
# 5000:	learn: 9535.1253842	test: 19570.4053014	best: 19570.4053014 (5000)	total: 3.46s	remaining: 10.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 19535.99041
# bestIteration = 5783
#
# Shrink model to first 5784 iterations.
# 남은변수개수: 2
# Learning rate set to 0.006278
# 0:	learn: 48247.6479708	test: 39407.8429905	best: 39407.8429905 (0)	total: 646us	remaining: 12.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 25403.93754
# bestIteration = 347
#
# Shrink model to first 348 iterations.
#      변수명  RFE순위
# 0    141    143
# 1     64    142
# 2     77    141
# 3     70    140
# 4     72    139
# ..   ...    ...
# 138   60      5
# 139  142      4
# 140    0      3
# 141  139      2
# 142   80      1
#
# [143 rows x 2 columns]

# %%
# RFE 최적변수만큼 할당
optimal_rank = 15
modeling_columns = list(ranking.loc[ranking['RFE순위'].isin([i for i in range(1, optimal_rank+1)]), '변수명'])
print(modeling_columns)
train_x2 = train_x[modeling_columns]

# 훈련
final_models, r2scores = cb_final_model(train_x2, train_y)
round(np.mean(list(r2scores.values())),4)
# Out:
# [116, 88, 14, 58, 63, 94, 1, 138, 65, 61, 60, 142, 0, 139, 80]
# Learning rate set to 0.006355
# 0:	learn: 48024.3307522	test: 38018.9613400	best: 38018.9613400 (0)	total: 3.63ms	remaining: 1m 12s
# 1000:	learn: 7095.7890450	test: 13209.8992010	best: 13209.8992010 (1000)	total: 970ms	remaining: 18.4s
# 2000:	learn: 4699.1354015	test: 12747.2029438	best: 12747.2029438 (2000)	total: 1.94s	remaining: 17.5s
# 3000:	learn: 3091.5424109	test: 12442.6336194	best: 12442.6336194 (3000)	total: 2.94s	remaining: 16.7s
# 4000:	learn: 2236.0975951	test: 12366.4810820	best: 12365.7487751 (3971)	total: 3.92s	remaining: 15.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12359.86252
# bestIteration = 4204
#
# Shrink model to first 4205 iterations.
# Learning rate set to 0.006355
# 0:	learn: 47307.9196771	test: 41392.3083571	best: 41392.3083571 (0)	total: 4.74ms	remaining: 1m 34s
# 1000:	learn: 7214.6499651	test: 13937.4379881	best: 13937.4379881 (1000)	total: 1.06s	remaining: 20.2s
# 2000:	learn: 4810.5641234	test: 13224.5504187	best: 13224.5504187 (2000)	total: 2.02s	remaining: 18.2s
# 3000:	learn: 3230.9720796	test: 12826.9223995	best: 12825.9435567 (2996)	total: 2.98s	remaining: 16.9s
# 4000:	learn: 2222.3806168	test: 12634.8833921	best: 12634.8527336 (3999)	total: 3.98s	remaining: 15.9s
# 5000:	learn: 1584.0186675	test: 12544.2928869	best: 12543.8761453 (4992)	total: 5.04s	remaining: 15.1s
# 6000:	learn: 1169.8250012	test: 12505.2726763	best: 12505.1208274 (5982)	total: 5.98s	remaining: 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12494.28165
# bestIteration = 6360
#
# Shrink model to first 6361 iterations.
# Learning rate set to 0.006357
# 0:	learn: 42690.0945627	test: 58273.9695390	best: 58273.9695390 (0)	total: 1.69ms	remaining: 33.8s
# 1000:	learn: 7195.3171626	test: 13269.5302250	best: 13269.5302250 (1000)	total: 1.05s	remaining: 19.9s
# 2000:	learn: 4841.8845756	test: 12135.8539268	best: 12135.8539268 (2000)	total: 2.03s	remaining: 18.3s
# 3000:	learn: 3262.3596192	test: 11915.0543913	best: 11914.5512143 (2981)	total: 3.04s	remaining: 17.2s
# 4000:	learn: 2297.9281089	test: 11757.2046989	best: 11755.9716691 (3956)	total: 3.97s	remaining: 15.9s
# 5000:	learn: 1655.5073619	test: 11673.9122270	best: 11673.9122270 (5000)	total: 4.9s	remaining: 14.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11653.47308
# bestIteration = 5484
#
# Shrink model to first 5485 iterations.
# Learning rate set to 0.006357
# 0:	learn: 47156.1132346	test: 42064.7202399	best: 42064.7202399 (0)	total: 3.5ms	remaining: 1m 9s
# 1000:	learn: 7292.2269039	test: 10808.9178935	best: 10808.9178935 (1000)	total: 920ms	remaining: 17.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 10569.36128
# bestIteration = 1633
#
# Shrink model to first 1634 iterations.
# Learning rate set to 0.006357
# 0:	learn: 45475.3287216	test: 48908.6270849	best: 48908.6270849 (0)	total: 7.75ms	remaining: 2m 34s
# 1000:	learn: 6920.0143144	test: 13832.5839736	best: 13832.5839736 (1000)	total: 916ms	remaining: 17.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13619.21387
# bestIteration = 1506
#
# Shrink model to first 1507 iterations.
# 0.9245

# %% [markdown]
# #### (2) 타자 nonFA
#  - 시간경기가중 // Z-scoring + Feature selection(RFE)

# %%
# 데이터 load
train = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/시간경기가중/타자_시간경기가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)

# Xy split
train_x, train_y = Xy_split(train)

# 스케일링
train_x = scaler_transformation(dataset = train_x, 
                                scaler_type = 'standardized_scaler')

# RFE 변수 순위 도출
ranking = get_cb_RFE_rank(train_x, train_y)
ranking
# Out:
# 남은변수개수: 145
# Learning rate set to 0.007498
# 0:	learn: 8619.6493114	test: 6447.2252572	best: 6447.2252572 (0)	total: 22.1ms	remaining: 7m 22s
# 1000:	learn: 1724.8132729	test: 2769.3123306	best: 2769.3123306 (1000)	total: 5.56s	remaining: 1m 45s
# 2000:	learn: 1035.9936853	test: 2667.4877340	best: 2667.4877340 (2000)	total: 11.7s	remaining: 1m 45s
# 3000:	learn: 729.7803309	test: 2636.2553001	best: 2636.2553001 (3000)	total: 17.5s	remaining: 1m 39s
# 4000:	learn: 516.5489678	test: 2621.7854811	best: 2621.7854811 (4000)	total: 23.2s	remaining: 1m 32s
# 5000:	learn: 373.9175500	test: 2613.9181757	best: 2613.8311792 (4990)	total: 28.7s	remaining: 1m 26s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2613.626442
# bestIteration = 5165
#
# Shrink model to first 5166 iterations.
# 남은변수개수: 144
# Learning rate set to 0.007498
# 0:	learn: 8619.6493114	test: 6447.2252572	best: 6447.2252572 (0)	total: 15.5ms	remaining: 5m 10s
# 1000:	learn: 1724.8132729	test: 2769.3123306	best: 2769.3123306 (1000)	total: 5.43s	remaining: 1m 43s
# 2000:	learn: 1035.9936853	test: 2667.4877340	best: 2667.4877340 (2000)	total: 10.8s	remaining: 1m 37s
# 3000:	learn: 729.7803309	test: 2636.2553001	best: 2636.2553001 (3000)	total: 16.3s	remaining: 1m 32s
# 4000:	learn: 516.5489678	test: 2621.7854811	best: 2621.7854811 (4000)	total: 21.7s	remaining: 1m 26s
# 5000:	learn: 373.9175500	test: 2613.9181757	best: 2613.8311792 (4990)	total: 27.2s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2613.626442
# bestIteration = 5165
#
# Shrink model to first 5166 iterations.
# 남은변수개수: 143
# Learning rate set to 0.007498
# 0:	learn: 8619.6493114	test: 6447.2252572	best: 6447.2252572 (0)	total: 15.4ms	remaining: 5m 8s
# 1000:	learn: 1724.8132729	test: 2769.3123306	best: 2769.3123306 (1000)	total: 5.41s	remaining: 1m 42s
# 2000:	learn: 1035.9936853	test: 2667.4877340	best: 2667.4877340 (2000)	total: 10.8s	remaining: 1m 37s
# 3000:	learn: 729.7803309	test: 2636.2553001	best: 2636.2553001 (3000)	total: 16.2s	remaining: 1m 31s
# 4000:	learn: 516.5489678	test: 2621.7854811	best: 2621.7854811 (4000)	total: 21.7s	remaining: 1m 26s
# 5000:	learn: 373.9175500	test: 2613.9181757	best: 2613.8311792 (4990)	total: 27.2s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2613.626442
# bestIteration = 5165
#
# Shrink model to first 5166 iterations.
# 남은변수개수: 142
# Learning rate set to 0.007498
# 0:	learn: 8619.6493114	test: 6447.2252572	best: 6447.2252572 (0)	total: 15.4ms	remaining: 5m 8s
# 1000:	learn: 1724.8132729	test: 2769.3123306	best: 2769.3123306 (1000)	total: 5.38s	remaining: 1m 42s
# 2000:	learn: 1035.9936853	test: 2667.4877340	best: 2667.4877340 (2000)	total: 10.8s	remaining: 1m 36s
# 3000:	learn: 729.7803309	test: 2636.2553001	best: 2636.2553001 (3000)	total: 16.2s	remaining: 1m 31s
# 4000:	learn: 516.5489678	test: 2621.7854811	best: 2621.7854811 (4000)	total: 21.6s	remaining: 1m 26s
# 5000:	learn: 373.9175500	test: 2613.9181757	best: 2613.8311792 (4990)	total: 27s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2613.626442
# bestIteration = 5165
#
# Shrink model to first 5166 iterations.
# 남은변수개수: 141
# Learning rate set to 0.007498
# 0:	learn: 8619.6493114	test: 6447.2252572	best: 6447.2252572 (0)	total: 20.6ms	remaining: 6m 52s
# 1000:	learn: 1724.8132729	test: 2769.3123306	best: 2769.3123306 (1000)	total: 5.37s	remaining: 1m 41s
# 2000:	learn: 1035.9936853	test: 2667.4877340	best: 2667.4877340 (2000)	total: 10.8s	remaining: 1m 37s
# 3000:	learn: 729.7803309	test: 2636.2553001	best: 2636.2553001 (3000)	total: 16.2s	remaining: 1m 31s
# 4000:	learn: 516.5489678	test: 2621.7854811	best: 2621.7854811 (4000)	total: 21.7s	remaining: 1m 26s
# 5000:	learn: 373.9175500	test: 2613.9181757	best: 2613.8311792 (4990)	total: 27.1s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2613.626442
# bestIteration = 5165
#
# Shrink model to first 5166 iterations.
# 남은변수개수: 140
# Learning rate set to 0.007498
# 0:	learn: 8618.5530433	test: 6447.7622521	best: 6447.7622521 (0)	total: 21.7ms	remaining: 7m 13s
# 1000:	learn: 1728.4733647	test: 2728.1685810	best: 2728.0683780 (999)	total: 5.43s	remaining: 1m 43s
# 2000:	learn: 1046.5211069	test: 2614.8948641	best: 2614.8948641 (2000)	total: 10.9s	remaining: 1m 37s
# 3000:	learn: 748.1483626	test: 2586.2663478	best: 2586.0490162 (2997)	total: 16.3s	remaining: 1m 32s
# 4000:	learn: 524.9490166	test: 2575.0817596	best: 2575.0817596 (4000)	total: 21.8s	remaining: 1m 27s
# 5000:	learn: 378.1269065	test: 2565.4739498	best: 2565.4536183 (4999)	total: 27.3s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2562.310195
# bestIteration = 5666
#
# Shrink model to first 5667 iterations.
# 남은변수개수: 139
# Learning rate set to 0.007498
# 0:	learn: 8623.4019898	test: 6454.5907460	best: 6454.5907460 (0)	total: 15.6ms	remaining: 5m 11s
# 1000:	learn: 1725.5921463	test: 2782.4491785	best: 2782.4491785 (1000)	total: 5.51s	remaining: 1m 44s
# 2000:	learn: 1033.3892362	test: 2685.3504807	best: 2685.3504807 (2000)	total: 11s	remaining: 1m 38s
# 3000:	learn: 718.0101073	test: 2656.9580856	best: 2656.9523580 (2999)	total: 16.4s	remaining: 1m 32s
# 4000:	learn: 510.4247910	test: 2641.4773656	best: 2641.4398654 (3996)	total: 21.8s	remaining: 1m 27s
# 5000:	learn: 364.3493300	test: 2630.9703489	best: 2630.9443978 (4992)	total: 27.4s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2627.132492
# bestIteration = 5794
#
# Shrink model to first 5795 iterations.
# 남은변수개수: 138
# Learning rate set to 0.007498
# 0:	learn: 8621.0424315	test: 6446.7412132	best: 6446.7412132 (0)	total: 21.7ms	remaining: 7m 13s
# 1000:	learn: 1726.3921849	test: 2754.7856961	best: 2754.7856961 (1000)	total: 5.43s	remaining: 1m 43s
# 2000:	learn: 1036.7514739	test: 2654.7288897	best: 2654.7083979 (1997)	total: 10.9s	remaining: 1m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2632.432354
# bestIteration = 2822
#
# Shrink model to first 2823 iterations.
# 남은변수개수: 137
# Learning rate set to 0.007498
# 0:	learn: 8619.3146812	test: 6448.1561164	best: 6448.1561164 (0)	total: 12.7ms	remaining: 4m 13s
# 1000:	learn: 1721.4616722	test: 2764.2305826	best: 2764.2191501 (997)	total: 5.43s	remaining: 1m 43s
# 2000:	learn: 1052.5925962	test: 2659.5556103	best: 2659.5556103 (2000)	total: 10.9s	remaining: 1m 38s
# 3000:	learn: 740.1792192	test: 2626.9040260	best: 2626.8271326 (2987)	total: 16.4s	remaining: 1m 32s
# 4000:	learn: 525.0615475	test: 2609.7818329	best: 2609.7818329 (4000)	total: 21.9s	remaining: 1m 27s
# 5000:	learn: 378.1914440	test: 2602.2900452	best: 2602.2900452 (5000)	total: 27.4s	remaining: 1m 22s
# 6000:	learn: 280.9843604	test: 2598.1145849	best: 2598.0013192 (5966)	total: 32.9s	remaining: 1m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2596.585995
# bestIteration = 6470
#
# Shrink model to first 6471 iterations.
# 남은변수개수: 136
# Learning rate set to 0.007498
# 0:	learn: 8618.6935485	test: 6448.5592224	best: 6448.5592224 (0)	total: 13ms	remaining: 4m 19s
# 1000:	learn: 1721.5251382	test: 2755.5586509	best: 2755.4809859 (999)	total: 5.42s	remaining: 1m 42s
# 2000:	learn: 1040.7872738	test: 2647.7761095	best: 2647.7761095 (2000)	total: 10.9s	remaining: 1m 38s
# 3000:	learn: 738.1639891	test: 2619.5268623	best: 2619.4270429 (2999)	total: 16.3s	remaining: 1m 32s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2615.09012
# bestIteration = 3304
#
# Shrink model to first 3305 iterations.
# 남은변수개수: 135
# Learning rate set to 0.007498
# 0:	learn: 8619.2905344	test: 6446.4668751	best: 6446.4668751 (0)	total: 12.8ms	remaining: 4m 16s
# 1000:	learn: 1713.8927709	test: 2747.6085668	best: 2747.6085668 (1000)	total: 5.45s	remaining: 1m 43s
# 2000:	learn: 1029.5028994	test: 2638.2918812	best: 2638.2918812 (2000)	total: 10.9s	remaining: 1m 37s
# 3000:	learn: 721.2434396	test: 2605.8370017	best: 2605.8370017 (3000)	total: 16.3s	remaining: 1m 32s
# 4000:	learn: 509.8410892	test: 2592.0833997	best: 2592.0354066 (3995)	total: 21.7s	remaining: 1m 26s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2586.367129
# bestIteration = 4581
#
# Shrink model to first 4582 iterations.
# 남은변수개수: 134
# Learning rate set to 0.007498
# 0:	learn: 8619.2570230	test: 6447.7845978	best: 6447.7845978 (0)	total: 13.9ms	remaining: 4m 37s
# 1000:	learn: 1720.1705017	test: 2757.7055884	best: 2757.7055884 (1000)	total: 5.41s	remaining: 1m 42s
# 2000:	learn: 1029.5046513	test: 2651.1675450	best: 2651.1675450 (2000)	total: 10.8s	remaining: 1m 37s
# 3000:	learn: 726.1374303	test: 2616.8237267	best: 2616.7363333 (2999)	total: 16.3s	remaining: 1m 32s
# 4000:	learn: 522.0749992	test: 2603.7331816	best: 2603.4216156 (3956)	total: 21.7s	remaining: 1m 26s
# 5000:	learn: 372.4945740	test: 2595.3399291	best: 2595.3366786 (4999)	total: 27.1s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2594.651349
# bestIteration = 5057
#
# Shrink model to first 5058 iterations.
# 남은변수개수: 133
# Learning rate set to 0.007498
# 0:	learn: 8618.7914267	test: 6448.0677029	best: 6448.0677029 (0)	total: 16.7ms	remaining: 5m 33s
# 1000:	learn: 1723.0835623	test: 2801.9875731	best: 2801.9875731 (1000)	total: 5.42s	remaining: 1m 42s
# 2000:	learn: 1043.8045001	test: 2689.7339539	best: 2689.7339539 (2000)	total: 10.9s	remaining: 1m 38s
# 3000:	learn: 726.0886660	test: 2657.7540848	best: 2657.5824698 (2990)	total: 16.3s	remaining: 1m 32s
# 4000:	learn: 508.2655947	test: 2638.6460936	best: 2638.6440948 (3998)	total: 21.8s	remaining: 1m 27s
# 5000:	learn: 370.4554254	test: 2629.0245465	best: 2629.0245465 (5000)	total: 27.3s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2622.841687
# bestIteration = 5899
#
# Shrink model to first 5900 iterations.
# 남은변수개수: 132
# Learning rate set to 0.007498
# 0:	learn: 8620.2537656	test: 6450.8973980	best: 6450.8973980 (0)	total: 8.02ms	remaining: 2m 40s
# 1000:	learn: 1727.1841472	test: 2752.3425990	best: 2752.3425990 (1000)	total: 5.42s	remaining: 1m 42s
# 2000:	learn: 1039.0440761	test: 2638.1219244	best: 2637.9021632 (1997)	total: 10.9s	remaining: 1m 37s
# 3000:	learn: 737.0812675	test: 2612.1952626	best: 2612.1952626 (3000)	total: 16.4s	remaining: 1m 32s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2602.464344
# bestIteration = 3514
#
# Shrink model to first 3515 iterations.
# 남은변수개수: 131
# Learning rate set to 0.007498
# 0:	learn: 8619.1418929	test: 6442.7228818	best: 6442.7228818 (0)	total: 23.2ms	remaining: 7m 44s
# 1000:	learn: 1724.4718938	test: 2781.4063339	best: 2781.2654593 (995)	total: 5.41s	remaining: 1m 42s
# 2000:	learn: 1047.8402539	test: 2680.3598355	best: 2680.3598355 (2000)	total: 10.9s	remaining: 1m 37s
# 3000:	learn: 737.7223142	test: 2647.2378688	best: 2647.1954403 (2999)	total: 16.3s	remaining: 1m 32s
# 4000:	learn: 523.6922652	test: 2629.5051905	best: 2629.4579551 (3992)	total: 21.8s	remaining: 1m 27s
# 5000:	learn: 372.2235284	test: 2619.0658762	best: 2619.0376816 (4987)	total: 27.3s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2616.062179
# bestIteration = 5565
#
# Shrink model to first 5566 iterations.
# 남은변수개수: 130
# Learning rate set to 0.007498
# 0:	learn: 8621.5507074	test: 6446.2974433	best: 6446.2974433 (0)	total: 6.35ms	remaining: 2m 6s
# 1000:	learn: 1731.0381222	test: 2755.6543271	best: 2755.4997719 (999)	total: 5.39s	remaining: 1m 42s
# 2000:	learn: 1044.5414460	test: 2649.5998168	best: 2649.5998168 (2000)	total: 10.8s	remaining: 1m 37s
# 3000:	learn: 725.8808252	test: 2615.9711907	best: 2615.9681232 (2999)	total: 16.2s	remaining: 1m 31s
# 4000:	learn: 509.3545599	test: 2601.0531011	best: 2601.0531011 (4000)	total: 21.7s	remaining: 1m 26s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2594.676886
# bestIteration = 4738
#
# Shrink model to first 4739 iterations.
# 남은변수개수: 129
# Learning rate set to 0.007498
# 0:	learn: 8617.8873105	test: 6446.4341536	best: 6446.4341536 (0)	total: 23.8ms	remaining: 7m 55s
# 1000:	learn: 1725.5498467	test: 2792.7191151	best: 2792.6493887 (999)	total: 5.41s	remaining: 1m 42s
# 2000:	learn: 1034.6075156	test: 2682.8566867	best: 2682.8566867 (2000)	total: 10.8s	remaining: 1m 37s
# 3000:	learn: 741.3030246	test: 2649.6664640	best: 2649.5876391 (2998)	total: 16.2s	remaining: 1m 31s
# 4000:	learn: 511.3328368	test: 2632.7354395	best: 2632.6581971 (3983)	total: 21.8s	remaining: 1m 26s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2627.565189
# bestIteration = 4550
#
# Shrink model to first 4551 iterations.
# 남은변수개수: 128
# Learning rate set to 0.007498
# 0:	learn: 8622.1176160	test: 6449.6813470	best: 6449.6813470 (0)	total: 9.52ms	remaining: 3m 10s
# 1000:	learn: 1727.1388325	test: 2778.5925865	best: 2778.2704937 (999)	total: 5.36s	remaining: 1m 41s
# 2000:	learn: 1039.6501009	test: 2679.8102707	best: 2679.8102707 (2000)	total: 10.7s	remaining: 1m 36s
# 3000:	learn: 756.7755452	test: 2660.9510271	best: 2660.9510271 (3000)	total: 16.1s	remaining: 1m 31s
# 4000:	learn: 533.6038934	test: 2640.7212790	best: 2640.5866158 (3995)	total: 21.5s	remaining: 1m 25s
# 5000:	learn: 388.4098910	test: 2632.4939606	best: 2632.3800227 (4964)	total: 26.9s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 
 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2595.575891
# bestIteration = 5818
#
# Shrink model to first 5819 iterations.
# 남은변수개수: 123
# Learning rate set to 0.007498
# 0:	learn: 8618.0023466	test: 6444.8616405	best: 6444.8616405 (0)	total: 6.02ms	remaining: 2m
# 1000:	learn: 1721.1993873	test: 2773.9922136	best: 2773.9922136 (1000)	total: 5.25s	remaining: 1m 39s
# 2000:	learn: 1032.0090834	test: 2669.7124627	best: 2669.7124627 (2000)	total: 10.5s	remaining: 1m 34s
# 3000:	learn: 731.2793936	test: 2631.2839977	best: 2631.2483859 (2999)	total: 15.8s	remaining: 1m 29s
# 4000:	learn: 514.2346098	test: 2612.5254477	best: 2612.3225079 (3997)	total: 21.1s	remaining: 1m 24s
# 5000:	learn: 368.7620140	test: 2604.5599217	best: 2604.5599217 (5000)	total: 26.4s	remaining: 1m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2603.844404
# bestIteration = 5142
#
# Shrink model to first 5143 iterations.
# 남은변수개수: 122
# Learning rate set to 0.007498
# 0:	learn: 8620.0901034	test: 6444.7307309	best: 6444.7307309 (0)	total: 22.2ms	remaining: 7m 24s
# 1000:	learn: 1715.0502052	test: 2792.8515572	best: 2792.8515572 (1000)	total: 5.28s	remaining: 1m 40s
# 2000:	learn: 1035.9459107	test: 2678.5950026	best: 2678.5950026 (2000)	total: 10.5s	remaining: 1m 34s
# 3000:	learn: 710.0595240	test: 2652.2102475	best: 2652.2102475 (3000)	total: 15.8s	remaining: 1m 29s
# 4000:	learn: 503.2812041	test: 2636.6895583	best: 2636.6895583 (4000)	total: 21.1s	remaining: 1m 24s
# 5000:	learn: 358.8666253	test: 2628.7628559	best: 2628.5484966 (4937)	total: 26.5s	remaining: 1m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2628.373455
# bestIteration = 5041
#
# Shrink model to first 5042 iterations.
# 남은변수개수: 121
# Learning rate set to 0.007498
# 0:	learn: 8619.2367720	test: 6445.0554124	best: 6445.0554124 (0)	total: 6.27ms	remaining: 2m 5s
# 1000:	learn: 1711.0316207	test: 2771.8487160	best: 2771.8173768 (999)	total: 5.29s	remaining: 1m 40s
# 2000:	learn: 1022.6795085	test: 2657.6296044	best: 2657.6138101 (1999)	total: 10.6s	remaining: 1m 35s
# 3000:	learn: 717.7236587	test: 2626.1525099	best: 2626.1525099 (3000)	total: 15.9s	remaining: 1m 30s
# 4000:	learn: 501.3795062	test: 2607.7380055	best: 2607.5761263 (3997)	total: 21.3s	remaining: 1m 25s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2607.576126
# bestIteration = 3997
#
# Shrink model to first 3998 iterations.
# 남은변수개수: 120
# Learning rate set to 0.007498
# 0:	learn: 8620.3051374	test: 6446.1695029	best: 6446.1695029 (0)	total: 6.98ms	remaining: 2m 19s
# 1000:	learn: 1720.8314551	test: 2743.1048837	best: 2743.1048837 (1000)	total: 5.28s	remaining: 1m 40s
# 2000:	learn: 1038.7879958	test: 2641.4268354	best: 2641.4268354 (2000)	total: 10.6s	remaining: 1m 35s
# 3000:	learn: 723.7536951	test: 2613.2411972	best: 2613.2225972 (2998)	total: 15.9s	remaining: 1m 29s
# 4000:	learn: 509.6156400	test: 2598.4798675	best: 2598.3131893 (3951)	total: 21.2s	remaining: 1m 24s
# 5000:	learn: 362.4396926	test: 2589.6103669	best: 2589.5791481 (4997)	total: 26.5s	remaining: 1m 19s
# 6000:	learn: 267.9561854	test: 2583.4258187	best: 2583.3669054 (5982)	total: 31.9s	remaining: 1m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2581.801183
# bestIteration = 6328
#
# Shrink model to first 6329 iterations.
# 남은변수개수: 119
# Learning rate set to 0.007498
# 0:	learn: 8622.8115346	test: 6451.6459742	best: 6451.6459742 (0)	total: 24.9ms	remaining: 8m 17s
# 1000:	learn: 1728.7564164	test: 2764.3748890	best: 2764.3748890 (1000)	total: 5.23s	remaining: 1m 39s
# 2000:	learn: 1032.5966738	test: 2648.5643468	best: 2648.5643468 (2000)	total: 10.5s	remaining: 1m 34s
# 3000:	learn: 714.1657755	test: 2618.4346774	best: 2618.4009237 (2998)	total: 15.7s	remaining: 1m 29s
# 4000:	learn: 502.6044045	test: 2601.2451136	best: 2601.2451136 (4000)	total: 21s	remaining: 1m 23s
# 5000:	learn: 360.8563651	test: 2590.2277808	best: 2590.2277808 (5000)	total: 26.3s	remaining: 1m 18s
# 6000:	learn: 269.4160409	test: 2584.6960635	best: 2584.6551377 (5942)	total: 31.5s	remaining: 1m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2582.305099
# bestIteration = 6793
#
# Shrink model to first 6794 iterations.
# 남은변수개수: 118
# Learning rate set to 0.007498
# 0:	learn: 8617.7981886	test: 6443.2082970	best: 6443.2082970 (0)	total: 9.84ms	remaining: 3m 16s
# 1000:	learn: 1728.0769019	test: 2769.2888396	best: 2769.2888396 (1000)	total: 5.18s	remaining: 1m 38s
# 2000:	learn: 1034.7630326	test: 2644.4578178	best: 2644.4578178 (2000)	total: 10.3s	remaining: 1m 32s
# 3000:	learn: 718.2515733	test: 2613.0406063	best: 2613.0292455 (2999)	total: 15.5s	remaining: 1m 27s
# 4000:	learn: 504.8236781	test: 2595.1890247	best: 2594.6144822 (3938)	total: 20.7s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2589.966539
# bestIteration = 4382
#
# Shrink model to first 4383 iterations.
# 남은변수개수: 117
# Learning rate set to 0.007498
# 0:	learn: 8621.7686035	test: 6450.4345132	best: 6450.4345132 (0)	total: 19.6ms	remaining: 6m 31s
# 1000:	learn: 1714.5706529	test: 2782.7857681	best: 2782.7789672 (999)	total: 5.18s	remaining: 1m 38s
# 2000:	learn: 1030.9792183	test: 2668.7004047	best: 2668.7004047 (2000)	total: 10.4s	remaining: 1m 33s
# 3000:	learn: 713.3597056	test: 2639.8560524	best: 2639.7679674 (2995)	total: 15.6s	remaining: 1m 28s
# 4000:	learn: 504.5503414	test: 2616.9233082	best: 2616.9112174 (3999)	total: 20.8s	remaining: 1m 23s
# 5000:	learn: 357.5412921	test: 2602.5393723	best: 2602.5085975 (4998)	total: 26.1s	remaining: 1m 18s
# 6000:	learn: 266.3111770	test: 2597.6027355	best: 2597.6027355 (6000)	total: 31.4s	remaining: 1m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2595.911326
# bestIteration = 6868
#
# Shrink model to first 6869 iterations.
# 남은변수개수: 116
# Learning rate set to 0.007498
# 0:	learn: 8620.1330319	test: 6448.5189926	best: 6448.5189926 (0)	total: 14.7ms	remaining: 4m 54s
# 1000:	learn: 1715.4745818	test: 2767.2075623	best: 2766.5693282 (998)	total: 5.18s	remaining: 1m 38s
	remaining: 1m 8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2566.642247
# bestIteration = 5904
#
# Shrink model to first 5905 iterations.
# 남은변수개수: 102
# Learning rate set to 0.007498
# 0:	learn: 8619.7808463	test: 6448.1754051	best: 6448.1754051 (0)	total: 5.6ms	remaining: 1m 52s
# 1000:	learn: 1716.3091245	test: 2761.0770641	best: 2761.0770641 (1000)	total: 4.85s	remaining: 1m 32s
# 2000:	learn: 1033.3665721	test: 2636.9314514	best: 2636.8959852 (1999)	total: 9.72s	remaining: 1m 27s
# 3000:	learn: 720.3411430	test: 2608.7515468	best: 2608.7515468 (3000)	total: 14.6s	remaining: 1m 22s
# 4000:	learn: 499.1996382	test: 2589.2063071	best: 2589.0734877 (3987)	total: 19.5s	remaining: 1m 17s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2581.086369
# bestIteration = 4615
#
# Shrink model to first 4616 iterations.
# 남은변수개수: 101
# Learning rate set to 0.007498
# 0:	learn: 8618.6131749	test: 6444.7851235	best: 6444.7851235 (0)	total: 13.7ms	remaining: 4m 33s
# 1000:	learn: 1726.1823282	test: 2781.0558927	best: 2781.0558927 (1000)	total: 4.85s	remaining: 1m 32s
# 2000:	learn: 1053.8802172	test: 2663.5485012	best: 2663.5485012 (2000)	total: 9.75s	remaining: 1m 27s
# 3000:	learn: 719.7219720	test: 2628.7555575	best: 2628.7555575 (3000)	total: 14.6s	remaining: 1m 22s
# 4000:	learn: 506.4534110	test: 2605.0698272	best: 2605.0698272 (4000)	total: 19.5s	remaining: 1m 18s
# 5000:	learn: 364.4261007	test: 2594.1398024	best: 2594.1376751 (4999)	total: 24.4s	remaining: 1m 13s
# 6000:	learn: 272.4813213	test: 2587.5458535	best: 2587.5458535 (6000)	total: 29.3s	remaining: 1m 8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2586.330246
# bestIteration = 6297
#
# Shrink model to first 6298 iterations.
# 남은변수개수: 100
# Learning rate set to 0.007498
# 0:	learn: 8621.4757768	test: 6447.8056288	best: 6447.8056288 (0)	total: 10.8ms	remaining: 3m 35s
# 1000:	learn: 1721.1438980	test: 2745.0241214	best: 2745.0241214 (1000)	total: 4.79s	remaining: 1m 31s
# 2000:	learn: 1054.9278425	test: 2633.6103508	best: 2633.6103508 (2000)	total: 9.6s	remaining: 1m 26s
# 3000:	learn: 737.9444961	test: 2602.3931192	best: 2602.3931192 (3000)	total: 14.4s	remaining: 1m 21s
# 4000:	learn: 505.5589711	test: 2583.3362921	best: 2583.3362921 (4000)	total: 19.3s	remaining: 1m 17s
# 5000:	learn: 361.4384974	test: 2574.8659492	best: 2574.7087568 (4973)	total: 24.1s	remaining: 1m 12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2571.95896
# bestIteration = 5530
#
# Shrink model to first 5531 iterations.
# 남은변수개수: 99
# Learning rate set to 0.007498
# 0:	learn: 8620.2727801	test: 6448.3827986	best: 6448.3827986 (0)	total: 23.6ms	remaining: 7m 51s
# 1000:	learn: 1718.4021030	test: 2738.7356549	best: 2738.7356549 (1000)	total: 4.79s	remaining: 1m 31s
# 2000:	learn: 1055.6493662	test: 2625.0214381	best: 2625.0214381 (2000)	total: 9.59s	remaining: 1m 26s
# 3000:	learn: 742.0447177	test: 2591.4335405	best: 2591.3867085 (2990)	total: 14.4s	remaining: 1m 21s
# 4000:	learn: 512.7015034	test: 2574.1593204	best: 2573.9593791 (3973)	total: 19.2s	remaining: 1m 16s
# 5000:	learn: 364.7019066	test: 2561.3571252	best: 2561.3088018 (4996)	total: 24s	remaining: 1m 12s
# 6000:	learn: 269.3542714	test: 2554.9888382	best: 2554.9888382 (6000)	total: 28.9s	remaining: 1m 7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 
	remaining: 1m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2567.756077
# bestIteration = 5080
#
# Shrink model to first 5081 iterations.
# 남은변수개수: 91
# Learning rate set to 0.007498
# 0:	learn: 8623.8840813	test: 6452.8340749	best: 6452.8340749 (0)	total: 5.39ms	remaining: 1m 47s
# 1000:	learn: 1734.0324714	test: 2774.8735249	best: 2774.8735249 (1000)	total: 4.37s	remaining: 1m 22s
# 2000:	learn: 1067.9183860	test: 2672.5284464	best: 2672.2193428 (1993)	total: 8.74s	remaining: 1m 18s
# 3000:	learn: 734.7213801	test: 2633.8899373	best: 2633.7874223 (2999)	total: 13.1s	remaining: 1m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2630.760189
# bestIteration = 3190
#
# Shrink model to first 3191 iterations.
# 남은변수개수: 90
# Learning rate set to 0.007498
# 0:	learn: 8619.9446256	test: 6445.5829164	best: 6445.5829164 (0)	total: 20.3ms	remaining: 6m 45s
# 1000:	learn: 1728.4581313	test: 2770.4227442	best: 2769.9523257 (998)	total: 4.29s	remaining: 1m 21s
# 2000:	learn: 1071.9072567	test: 2653.7796916	best: 2653.7407557 (1999)	total: 8.63s	remaining: 1m 17s
# 3000:	learn: 744.1363384	test: 2614.0959811	best: 2614.0959811 (3000)	total: 13s	remaining: 1m 13s
# 4000:	learn: 530.9331507	test: 2599.4663783	best: 2599.3566355 (3995)	total: 17.3s	remaining: 1m 9s
# 5000:	learn: 381.6108695	test: 2593.0041849	best: 2592.9234594 (4978)	total: 21.6s	remaining: 1m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2590.798555
# bestIteration = 5451
#
# Shrink model to first 5452 iterations.
# 남은변수개수: 89
# Learning rate set to 0.007498
# 0:	learn: 8620.1368191	test: 6444.5418408	best: 6444.5418408 (0)	total: 21.2ms	remaining: 7m 3s
# 1000:	learn: 1732.5386301	test: 2767.5449510	best: 2766.9050469 (999)	total: 4.34s	remaining: 1m 22s
# 2000:	learn: 1061.0371760	test: 2655.0572107	best: 2654.9933858 (1998)	total: 8.68s	remaining: 1m 18s
# 3000:	learn: 740.8895476	test: 2621.6375341	best: 2621.6101808 (2999)	total: 13.1s	remaining: 1m 13s
# 4000:	learn: 531.8289075	test: 2607.6139562	best: 2607.5992483 (3999)	total: 17.4s	remaining: 1m 9s
# 5000:	learn: 382.8842682	test: 2598.8219959	best: 2598.7648145 (4996)	total: 21.8s	remaining: 1m 5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2597.282839
# bestIteration = 5341
#
# Shrink model to first 5342 iterations.
# 남은변수개수: 88
# Learning rate set to 0.007498
# 0:	learn: 8617.8826612	test: 6442.3074532	best: 6442.3074532 (0)	total: 5.05ms	remaining: 1m 41s
# 1000:	learn: 1726.3286918	test: 2781.2694929	best: 2781.2694929 (1000)	total: 4.31s	remaining: 1m 21s
# 2000:	learn: 1054.6824342	test: 2672.2457686	best: 2672.1531846 (1987)	total: 8.58s	remaining: 1m 17s
# 3000:	learn: 737.1511152	test: 2641.3697812	best: 2641.3268263 (2999)	total: 12.9s	remaining: 1m 13s
# 4000:	learn: 550.4126778	test: 2628.6160559	best: 2628.4246999 (3996)	total: 17.2s	remaining: 1m 8s
# 5000:	learn: 398.6376530	test: 2622.0171407	best: 2622.0171407 (5000)	total: 21.5s	remaining: 1m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2619.138484
# bestIteration = 5425
#
# Shrink model to first 5426 iterations.
# 남은변수개수: 87
# Learning rate set to 0.007498
# 0:	learn: 8618.2017369	test: 6449.5673052	best: 6449.5673052 (0)	total: 13.6ms	remaining: 4m 32s
# 1000:	learn: 1729.6325462	test: 2755.0629009	best: 2755.0629009 (1000)	total: 4.26s	remaining: 1m 20s
# 2000:	learn: 1057.4100050	test: 2642.9839119	best: 2642.9839119 (2000)	total: 8.5s	remaining: 1m 16s
# 3000:	learn: 749.0017133	test: 2612.3653771	best: 2611.8117001 (2947)	total: 12.8s	remaining: 1m 12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2611.8117
# bestIteration = 2947
#
# Shrink model to first 2948 iterations.
# 남은변수개수: 86
# Learning rate set to 0.007498
# 0:	learn: 8621.0103687	test: 6447.2873304	best: 6447.2873304 (0)	total: 5.06ms	remaining: 1m 41s
# 1000:	learn: 1726.9425156	test: 2760.5320138	best: 2760.5320138 (1000)	total: 4.17s	remaining: 1m 19s
# 2000:	learn: 1054.5873797	test: 2651.1921406	best: 2651.1921406 (2000)	total: 8.36s	remaining: 1m 15s
# 3000:	learn: 731.3660756	test: 2622.7940437	best: 2622.7940437 (3000)	total: 12.6s	remaining: 1m 11s
# 4000:	learn: 523.1668804	test: 2606.2010671	best: 2606.2010671 (4000)	total: 16.7s	remaining: 1m 6s
# 5000:	learn: 381.8281913	test: 2598.3418310	best: 2598.0028396 (4944)	total: 21s	remaining: 1m 2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2598.00284
# bestIteration = 4944
#
# Shrink model to first 4945 iterations.
# 남은변수개수: 85
# Learning rate set to 0.007498
# 0:	learn: 8620.9033958	test: 6446.7331311	best: 6446.7331311 (0)	total: 9.24ms	remaining: 3m 4s
# 1000:	learn: 1723.3258486	test: 2751.0148719	best: 2751.0148719 (1000)	total: 4.08s	remaining: 1m 17s
# 2000:	learn: 1064.0211219	test: 2633.3907468	best: 2633.1084139 (1995)	total: 8.18s	remaining: 1m 13s
# 3000:	learn: 735.6070788	test: 2608.2703613	best: 2608.2189959 (2997)	total: 12.3s	remaining: 1m 9s
# 4000:	learn: 539.9581596	test: 2597.3577045	best: 2597.3499941 (3999)	total: 16.4s	remaining: 1m 5s
# 5000:	learn: 394.6013498	test: 2592.0501681	best: 2591.8262105 (4983)	total: 20.5s	remaining: 1m 1s
# 6000:	learn: 295.2902634	test: 2587.9448718	best: 2587.8729313 (5954)	total: 24.7s	remaining: 57.5s
# 7000:	learn: 225.2017076	test: 2585.2914537	best: 2585.1743374 (6991)	total: 28.9s	remaining: 53.6s
# ...
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2554.68066
# bestIteration = 3016
#
# Shrink model to first 3017 iterations.
# 남은변수개수: 38
# Learning rate set to 0.007498
# 0:	learn: 8620.0489537	test: 6449.0846940	best: 6449.0846940 (0)	total: 12.1ms	remaining: 4m 2s
# 1000:	learn: 1746.0132006	test: 2663.8112582	best: 2663.8112582 (1000)	total: 2.2s	remaining: 41.8s
# 2000:	learn: 1103.8784844	test: 2591.8126980	best: 2591.7807159 (1988)	total: 4.41s	remaining: 39.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2588.607088
# bestIteration = 2099
#
# Shrink model to first 2100 iterations.
# 남은변수개수: 37
# Learning rate set to 0.007498
# 0:	learn: 8617.8477646	test: 6447.5205841	best: 6447.5205841 (0)	total: 2.71ms	remaining: 54.3s
# 1000:	learn: 1745.9416875	test: 2688.5716838	best: 2688.3270044 (999)	total: 2.14s	remaining: 40.6s
# 2000:	learn: 1117.2655955	test: 2605.7395816	best: 2605.6657926 (1997)	total: 4.33s	remaining: 39s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2601.783294
# bestIteration = 2365
#
# Shrink model to first 2366 iterations.
# 남은변수개수: 36
# Learning rate set to 0.007498
# 0:	learn: 8617.9858093	test: 6445.0868765	best: 6445.0868765 (0)	total: 2.66ms	remaining: 53.2s
# 1000:	learn: 1758.4378795	test: 2698.7394853	best: 2698.6965467 (999)	total: 2.15s	remaining: 40.7s
# 2000:	learn: 1121.7331667	test: 2628.3359012	best: 2628.2296032 (1923)	total: 4.26s	remaining: 38.3s
# 3000:	learn: 790.7001433	test: 2608.1701867	best: 2608.0454222 (2991)	total: 6.4s	remaining: 36.2s
# 4000:	learn: 591.3893632	test: 2598.2650426	best: 2598.0982760 (3971)	total: 8.58s	remaining: 34.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2597.565751
# bestIteration = 4040
#
# Shrink model to first 4041 iterations.
# 남은변수개수: 35
# Learning rate set to 0.007498
# 0:	learn: 8618.4416794	test: 6443.5839388	best: 6443.5839388 (0)	total: 2.68ms	remaining: 53.6s
# 1000:	learn: 1748.4025966	test: 2703.3801397	best: 2703.3801397 (1000)	total: 2.07s	remaining: 39.3s
# 2000:	learn: 1121.9841176	test: 2624.0768520	best: 2623.9371147 (1993)	total: 4.15s	remaining: 37.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2611.829893
# bestIteration = 2734
#
# Shrink model to first 2735 iterations.
# 남은변수개수: 34
# Learning rate set to 0.007498
# 0:	learn: 8618.4496597	test: 6444.4715408	best: 6444.4715408 (0)	total: 2.62ms	remaining: 52.5s
# 1000:	learn: 1746.5301303	test: 2707.3372778	best: 2707.3372778 (1000)	total: 2.06s	remaining: 39.1s
# 2000:	learn: 1106.2183273	test: 2635.5762936	best: 2635.5748052 (1998)	total: 4.16s	remaining: 37.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2632.039413
# bestIteration = 2164
#
# Shrink model to first 2165 iterations.
# 남은변수개수: 33
# Learning rate set to 0.007498
# 0:	learn: 8620.1329392	test: 6444.9490770	best: 6444.9490770 (0)	total: 2.62ms	remaining: 52.4s
# 1000:	learn: 1755.7398260	test: 2713.0850174	best: 2713.0850174 (1000)	total: 1.97s	remaining: 37.5s
# 2000:	learn: 1114.9292537	test: 2634.0348073	best: 2633.1398637 (1954)	total: 3.98s	remaining: 35.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2615.599669
# bestIteration = 2695
#
# Shrink model to first 2696 iterations.
# 남은변수개수: 32
# Learning rate set to 0.007498
# 0:	learn: 8617.8536545	test: 6446.5576638	best: 6446.5576638 (0)	total: 2.5ms	remaining: 50.1s
# 1000:	learn: 1757.2391049	test: 2681.3960323	best: 2681.3960323 (1000)	total: 1.81s	remaining: 34.3s
# 2000:	learn: 1138.9826486	test: 2592.6835496	best: 2592.2733663 (1983)	total: 3.68s	remaining: 33.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2592.273366
# bestIteration = 1983
#
# Shrink model to first 1984 iterations.
# 남은변수개수: 31
# Learning rate set to 0.007498
# 0:	learn: 8616.6483680	test: 6444.5419797	best: 6444.5419797 (0)	total: 12.4ms	remaining: 4m 8s
# 1000:	learn: 1755.8209635	test: 2688.9698237	best: 2688.9698237 (1000)	total: 1.82s	remaining: 34.6s
# 2000:	learn: 1135.2337117	test: 2612.6249686	best: 2612.3923149 (1994)	total: 3.64s	remaining: 32.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2597.525534
# bestIteration = 2595
#
# Shrink model to first 2596 iterations.
# 남은변수개수: 30
# Learning rate set to 0.007498
# 0:	learn: 8617.9401740	test: 6443.7931339	best: 6443.7931339 (0)	total: 15.8ms	remaining: 5m 15s
# 1000:	learn: 1771.7967992	test: 2712.4420692	best: 2712.3606288 (998)	total: 1.79s	remaining: 34s
# 2000:	learn: 1145.2950803	test: 2628.7434119	best: 2628.7434119 (2000)	total: 3.58s	remaining: 32.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2627.945035
# bestIteration = 2006
#
# Shrink model to first 2007 iterations.
# 남은변수개수: 29
# Learning rate set to 0.007498
# 0:	learn: 8619.0097324	test: 6446.1444458	best: 6446.1444458 (0)	total: 2.44ms	remaining: 48.9s
# 1000:	learn: 1761.6041435	test: 2694.8618694	best: 2694.8618694 (1000)	total: 1.71s	remaining: 32.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2623.239521
# bestIteration = 1765
#
# Shrink model to first 1766 iterations.
# 남은변수개수: 28
# Learning rate set to 0.007498
# 0:	learn: 8620.4988333	test: 6447.7169958	best: 6447.7169958 (0)	total: 2.4ms	remaining: 48.1s
# 1000:	learn: 1760.1925028	test: 2695.5502466	best: 2695.4280296 (999)	total: 1.67s	remaining: 31.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2615.728697
# bestIteration = 1738
#
# Shrink model to first 1739 iterations.
# 남은변수개수: 27
# Learning rate set to 0.007498
# 0:	learn: 8618.2752341	test: 6447.3152564	best: 6447.3152564 (0)	total: 2.3ms	remaining: 46s
# 1000:	learn: 1758.5929561	test: 2712.2345568	best: 2712.2345568 (1000)	total: 1.65s	remaining: 31.4s
# 2000:	learn: 1135.9470555	test: 2629.5767687	best: 2629.5767687 (2000)	total: 3.35s	remaining: 30.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2612.801641
# bestIteration = 2719
#
# Shrink model to first 2720 iterations.
# 남은변수개수: 26
# Learning rate set to 0.007498
# 0:	learn: 8621.1543109	test: 6445.0126567	best: 6445.0126567 (0)	total: 3.2ms	remaining: 1m 3s
# 1000:	learn: 1775.3724997	test: 2682.8777538	best: 2682.8777538 (1000)	total: 1.68s	remaining: 31.9s
# 2000:	learn: 1169.4084472	test: 2604.9265166	best: 2604.3685116 (1932)	total: 3.34s	remaining: 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2604.368512
# bestIteration = 1932
#
# Shrink model to first 1933 iterations.
# 남은변수개수: 25
# Learning rate set to 0.007498
# 0:	learn: 8619.0979520	test: 6443.3953112	best: 6443.3953112 (0)	total: 4.5ms	remaining: 1m 30s
# 1000:	learn: 1773.3582923	test: 2691.6295021	best: 2691.5585257 (999)	total: 1.59s	remaining: 30.2s
# 2000:	learn: 1164.9735930	test: 2608.3068156	best: 2606.4220009 (1953)	total: 3.23s	remaining: 29.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2606.422001
# bestIteration = 1953
#
# Shrink model to first 1954 iterations.
# 남은변수개수: 24
# Learning rate set to 0.007498
# 0:	learn: 8619.4845455	test: 6447.1770815	best: 6447.1770815 (0)	total: 2.38ms	remaining: 47.6s
# 1000:	learn: 1785.1193750	test: 2678.7010512	best: 2678.7010512 (1000)	total: 1.58s	remaining: 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2622.032124
# bestIteration = 1699
#
# Shrink model to first 1700 iterations.
# 남은변수개수: 23
# Learning rate set to 0.007498
# 0:	learn: 8618.1760609	test: 6441.2992683	best: 6441.2992683 (0)	total: 2.33ms	remaining: 46.6s
# 1000:	learn: 1776.2854309	test: 2718.4580983	best: 2718.4580983 (1000)	total: 1.59s	remaining: 30.2s
# 2000:	learn: 1189.2310995	test: 2643.0512179	best: 2641.9009647 (1964)	total: 3.19s	remaining: 28.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2641.900965
# bestIteration = 1964
#
# Shrink model to first 1965 iterations.
# 남은변수개수: 22
# Learning rate set to 0.007498
# 0:	learn: 8618.5515429	test: 6443.2596604	best: 6443.2596604 (0)	total: 17ms	remaining: 5m 40s
# 1000:	learn: 1781.2854503	test: 2699.3013556	best: 2698.9077671 (999)	total: 1.57s	remaining: 29.8s
# 2000:	learn: 1200.8328768	test: 2617.7284713	best: 2617.0955747 (1976)	total: 3.17s	remaining: 28.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2613.207588
# bestIteration = 2230
#
# Shrink model to first 2231 iterations.
# 남은변수개수: 21
# Learning rate set to 0.007498
# 0:	learn: 8618.8199066	test: 6445.7721462	best: 6445.7721462 (0)	total: 2.2ms	remaining: 44s
# 1000:	learn: 1787.3592758	test: 2672.9126072	best: 2672.9126072 (1000)	total: 1.53s	remaining: 29.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2621.829968
# bestIteration = 1769
#
# Shrink model to first 1770 iterations.
# 남은변수개수: 20
# Learning rate set to 0.007498
# 0:	learn: 8616.8061168	test: 6442.1274775	best: 6442.1274775 (0)	total: 16.5ms	remaining: 5m 30s
# 1000:	learn: 1793.4429650	test: 2724.7287873	best: 2724.7287873 (1000)	total: 1.53s	remaining: 29s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2656.292147
# bestIteration = 1708
#
# Shrink model to first 1709 iterations.
# 남은변수개수: 19
# Learning rate set to 0.007498
# 0:	learn: 8617.9193528	test: 6447.3234557	best: 6447.3234557 (0)	total: 1.94ms	remaining: 38.9s
# 1000:	learn: 1780.1890994	test: 2748.7849787	best: 2748.7849787 (1000)	total: 1.49s	remaining: 28.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2693.398313
# bestIteration = 1757
#
# Shrink model to first 1758 iterations.
# 남은변수개수: 18
# Learning rate set to 0.007498
# 0:	learn: 8617.4804366	test: 6444.1972455	best: 6444.1972455 (0)	total: 4.17ms	remaining: 1m 23s
# 1000:	learn: 1781.9749980	test: 2711.1019531	best: 2711.0316165 (998)	total: 1.45s	remaining: 27.6s
# 2000:	learn: 1216.9029957	test: 2652.0705258	best: 2651.9106925 (1992)	total: 2.93s	remaining: 26.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2648.878866
# bestIteration = 2211
#
# Shrink model to first 2212 iterations.
# 남은변수개수: 17
# Learning rate set to 0.007498
# 0:	learn: 8617.7087452	test: 6444.3823538	best: 6444.3823538 (0)	total: 11.4ms	remaining: 3m 47s
# 1000:	learn: 1815.7854263	test: 2731.1103015	best: 2731.1103015 (1000)	total: 1.4s	remaining: 26.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2703.178985
# bestIteration = 1587
#
# Shrink model to first 1588 iterations.
# 남은변수개수: 16
# Learning rate set to 0.007498
# 0:	learn: 8615.9317102	test: 6442.9941921	best: 6442.9941921 (0)	total: 1.8ms	remaining: 36.1s
# 1000:	learn: 1812.5084625	test: 2735.5600423	best: 2735.4924742 (998)	total: 1.3s	remaining: 24.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2685.283263
# bestIteration = 1742
#
# Shrink model to first 1743 iterations.
# 남은변수개수: 15
# Learning rate set to 0.007498
# 0:	learn: 8617.4381529	test: 6446.4531871	best: 6446.4531871 (0)	total: 1.81ms	remaining: 36.3s
# 1000:	learn: 1818.6792978	test: 2735.9252724	best: 2735.4830950 (998)	total: 1.15s	remaining: 21.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2689.433505
# bestIteration = 1842
#
# Shrink model to first 1843 iterations.
# 남은변수개수: 14
# Learning rate set to 0.007498
# 0:	learn: 8621.1342435	test: 6448.7020777	best: 6448.7020777 (0)	total: 8.76ms	remaining: 2m 55s
# 1000:	learn: 1851.2619758	test: 2796.8932901	best: 2796.5652076 (997)	total: 1.09s	remaining: 20.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2761.932334
# bestIteration = 1512
#
# Shrink model to first 1513 iterations.
# 남은변수개수: 13
# Learning rate set to 0.007498
# 0:	learn: 8616.7165392	test: 6443.0228485	best: 6443.0228485 (0)	total: 13.3ms	remaining: 4m 26s
# 1000:	learn: 1904.7669285	test: 2811.4782988	best: 2811.2636203 (997)	total: 1.06s	remaining: 20.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2788.74692
# bestIteration = 1345
#
# Shrink model to first 1346 iterations.
# 남은변수개수: 12
# Learning rate set to 0.007498
# 0:	learn: 8618.2028005	test: 6442.7502216	best: 6442.7502216 (0)	total: 1.68ms	remaining: 33.7s
# 1000:	learn: 1899.6626611	test: 2848.2450688	best: 2848.1047533 (999)	total: 1.06s	remaining: 20.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2819.428374
# bestIteration = 1440
#
# Shrink model to first 1441 iterations.
# 남은변수개수: 11
# Learning rate set to 0.007498
# 0:	learn: 8618.1768513	test: 6446.0317970	best: 6446.0317970 (0)	total: 1.64ms	remaining: 32.9s
# 1000:	learn: 1906.4229851	test: 2817.8436586	best: 2817.8436586 (1000)	total: 995ms	remaining: 18.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2799.706804
# bestIteration = 1316
#
# Shrink model to first 1317 iterations.
# 남은변수개수: 10
# Learning rate set to 0.007498
# 0:	learn: 8619.7141975	test: 6447.2917873	best: 6447.2917873 (0)	total: 1.56ms	remaining: 31.2s
# 1000:	learn: 1924.8021488	test: 2835.0430035	best: 2835.0178775 (999)	total: 982ms	remaining: 18.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2829.425479
# bestIteration = 1152
#
# Shrink model to first 1153 iterations.
# 남은변수개수: 9
# Learning rate set to 0.007498
# 0:	learn: 8618.7793478	test: 6448.9578353	best: 6448.9578353 (0)	total: 1.56ms	remaining: 31.3s
# 1000:	learn: 1915.9843519	test: 2776.4122875	best: 2776.4122875 (1000)	total: 980ms	remaining: 18.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2768.533244
# bestIteration = 1158
#
# Shrink model to first 1159 iterations.
# 남은변수개수: 8
# Learning rate set to 0.007498
# 0:	learn: 8619.4315079	test: 6452.1432757	best: 6452.1432757 (0)	total: 1.56ms	remaining: 31.2s
# 1000:	learn: 2009.3415218	test: 2906.4591579	best: 2906.4463457 (997)	total: 954ms	remaining: 18.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2890.315831
# bestIteration = 1189
#
# Shrink model to first 1190 iterations.
# 남은변수개수: 7
# Learning rate set to 0.007498
# 0:	learn: 8617.9104035	test: 6443.1029611	best: 6443.1029611 (0)	total: 1.56ms	remaining: 31.3s
# 1000:	learn: 2023.2847138	test: 2918.7558118	best: 2918.7558118 (1000)	total: 934ms	remaining: 17.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2864.63844
# bestIteration = 1651
#
# Shrink model to first 1652 iterations.
# 남은변수개수: 6
# Learning rate set to 0.007498
# 0:	learn: 8616.7346780	test: 6440.3281632	best: 6440.3281632 (0)	total: 1.52ms	remaining: 30.3s
# 1000:	learn: 2032.4320748	test: 2954.4195413	best: 2954.2961325 (996)	total: 907ms	remaining: 17.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2914.050537
# bestIteration = 1426
#
# Shrink model to first 1427 iterations.
# 남은변수개수: 5
# Learning rate set to 0.007498
# 0:	learn: 8619.0411807	test: 6447.0922152	best: 6447.0922152 (0)	total: 1.43ms	remaining: 28.6s
# 1000:	learn: 2014.8356339	test: 2985.7577913	best: 2985.6376737 (994)	total: 892ms	remaining: 16.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2956.429551
# bestIteration = 1475
#
# Shrink model to first 1476 iterations.
# 남은변수개수: 4
# Learning rate set to 0.007498
# 0:	learn: 8621.6813609	test: 6446.2993090	best: 6446.2993090 (0)	total: 1.41ms	remaining: 28.2s
# 1000:	learn: 2230.9575778	test: 3190.2984020	best: 3190.2484055 (999)	total: 892ms	remaining: 16.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 3109.747732
# bestIteration = 1414
#
# Shrink model to first 1415 iterations.
# 남은변수개수: 3
# Learning rate set to 0.007498
# 0:	learn: 8617.4500058	test: 6441.2522705	best: 6441.2522705 (0)	total: 1.37ms	remaining: 27.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 3256.828207
# bestIteration = 495
#
# Shrink model to first 496 iterations.
# 남은변수개수: 2
# Learning rate set to 0.007498
# 0:	learn: 8619.8010633	test: 6447.9614622	best: 6447.9614622 (0)	total: 1.38ms	remaining: 27.6s
# 1000:	learn: 2923.7562498	test: 3633.2794063	best: 3633.2794063 (1000)	total: 838ms	remaining: 15.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 3592.086952
# bestIteration = 1368
#
# Shrink model to first 1369 iterations.
#      변수명  RFE순위
# 0     87    145
# 1     86    144
# 2     85    143
# 3     55    142
# 4     81    141
# ..   ...    ...
# 140    7      5
# 141  134      4
# 142  118      3
# 143   57      2
# 144  144      1
#
# [145 rows x 2 columns]

# %%
# RFE 최적변수만큼 할당
optimal_rank = 10
modeling_columns = list(ranking.loc[ranking['RFE순위'].isin([i for i in range(1, optimal_rank+1)]), '변수명'])
print(modeling_columns)
train_x2 = train_x[modeling_columns]

# 훈련
final_models, r2scores = cb_final_model(train_x2, train_y)
round(np.mean(list(r2scores.values())),4)
# Out:
# [59, 64, 140, 96, 101, 7, 134, 118, 57, 144]
# Learning rate set to 0.007589
# 0:	learn: 8554.9873643	test: 6125.7340471	best: 6125.7340471 (0)	total: 1.65ms	remaining: 33s
# 1000:	learn: 1904.8448560	test: 2769.0729618	best: 2769.0729618 (1000)	total: 994ms	remaining: 18.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2752.487436
# bestIteration = 1305
#
# Shrink model to first 1306 iterations.
# Learning rate set to 0.007589
# 0:	learn: 8510.1157526	test: 6389.8642469	best: 6389.8642469 (0)	total: 6.91ms	remaining: 2m 18s
# 1000:	learn: 1823.9870227	test: 2851.4641462	best: 2851.2277320 (998)	total: 1.01s	remaining: 19.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2810.752039
# bestIteration = 1490
#
# Shrink model to first 1491 iterations.
# Learning rate set to 0.007589
# 0:	learn: 7307.0896993	test: 10817.0398543	best: 10817.0398543 (0)	total: 1.58ms	remaining: 31.7s
# 1000:	learn: 2090.4419608	test: 2961.6026550	best: 2961.6026550 (1000)	total: 986ms	remaining: 18.7s
# 2000:	learn: 1453.4439531	test: 2533.2023173	best: 2533.2023173 (2000)	total: 1.98s	remaining: 17.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2474.120585
# bestIteration = 2635
#
# Shrink model to first 2636 iterations.
# Learning rate set to 0.00759
# 0:	learn: 8398.4684108	test: 6947.8412321	best: 6947.8412321 (0)	total: 1.62ms	remaining: 32.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2620.245109
# bestIteration = 727
#
# Shrink model to first 728 iterations.
# Learning rate set to 0.00759
# 0:	learn: 7794.3962674	test: 9351.0119223	best: 9351.0119223 (0)	total: 1.63ms	remaining: 32.6s
# 1000:	learn: 2200.5883765	test: 2864.8346076	best: 2864.8346076 (1000)	total: 978ms	remaining: 18.6s
# 2000:	learn: 1520.9745727	test: 2439.0745282	best: 2439.0745282 (2000)	total: 1.98s	remaining: 17.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2402.414482
# bestIteration = 2727
#
# Shrink model to first 2728 iterations.
# 0.8694

# %% [markdown]
# #### (3) 투수 nonFA
#  - 단순가중 // Feature selection(RFE)

# %%
# 데이터 load
train = pd.read_csv('../선수데이터(전처리완료)/모델링용ver8/단순가중/투수_단순가중_nonfa_train.csv', encoding='cp949').drop(['ID','선수명'], axis=1)

# Xy split
train_x, train_y = Xy_split(train)

# 스케일링
train_x = scaler_transformation(dataset = train_x, 
                                scaler_type = 'standardized_scaler')

# RFE 변수 순위 도출
ranking = get_cb_RFE_rank(train_x, train_y)
ranking
# Out:
# 남은변수개수: 143
# Learning rate set to 0.007431
# 0:	learn: 8587.8944283	test: 8914.9664910	best: 8914.9664910 (0)	total: 21.7ms	remaining: 7m 13s
# 1000:	learn: 2433.9402635	test: 4781.1656188	best: 4781.1656188 (1000)	total: 4.39s	remaining: 1m 23s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4726.899024
# bestIteration = 1525
#
# Shrink model to first 1526 iterations.
# 남은변수개수: 142
# Learning rate set to 0.007431
# 0:	learn: 8589.7942075	test: 8912.8590394	best: 8912.8590394 (0)	total: 21.2ms	remaining: 7m 4s
# 1000:	learn: 2423.4626002	test: 4777.0283285	best: 4775.8495957 (996)	total: 4.39s	remaining: 1m 23s
# 2000:	learn: 1493.2781946	test: 4715.9126994	best: 4715.8240446 (1996)	total: 8.79s	remaining: 1m 19s
# 3000:	learn: 1029.8805295	test: 4661.5283629	best: 4661.4592943 (2992)	total: 13.2s	remaining: 1m 14s
# 4000:	learn: 746.1756591	test: 4641.5796339	best: 4641.3864630 (3970)	total: 17.6s	remaining: 1m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4637.894209
# bestIteration = 4272
#
# Shrink model to first 4273 iterations.
# 남은변수개수: 141
# Learning rate set to 0.007431
# 0:	learn: 8589.7942075	test: 8912.8590394	best: 8912.8590394 (0)	total: 5.38ms	remaining: 1m 47s
# 1000:	learn: 2423.4626002	test: 4777.0283285	best: 4775.8495957 (996)	total: 4.4s	remaining: 1m 23s
# 2000:	learn: 1493.2781946	test: 4715.9126994	best: 4715.8240446 (1996)	total: 8.8s	remaining: 1m 19s
# 3000:	learn: 1029.8805295	test: 4661.5283629	best: 4661.4592943 (2992)	total: 13.3s	remaining: 1m 15s
# 4000:	learn: 746.1756591	test: 4641.5796339	best: 4641.3864630 (3970)	total: 17.7s	remaining: 1m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4637.894209
# bestIteration = 4272
#
# Shrink model to first 4273 iterations.
# 남은변수개수: 140
# Learning rate set to 0.007431
# 0:	learn: 8589.7942075	test: 8912.8590394	best: 8912.8590394 (0)	total: 5.23ms	remaining: 1m 44s
# 1000:	learn: 2423.4626002	test: 4777.0283285	best: 4775.8495957 (996)	total: 4.36s	remaining: 1m 22s
# 2000:	learn: 1493.2781946	test: 4715.9126994	best: 4715.8240446 (1996)	total: 8.76s	remaining: 1m 18s
# 3000:	learn: 1029.8805295	test: 4661.5283629	best: 4661.4592943 (2992)	total: 13.1s	remaining: 1m 14s
# 4000:	learn: 746.1756591	test: 4641.5796339	best: 4641.3864630 (3970)	total: 17.6s	remaining: 1m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4637.894209
# bestIteration = 4272
#
# Shrink model to first 4273 iterations.
# 남은변수개수: 139
# Learning rate set to 0.007431
# 0:	learn: 8589.7942075	test: 8912.8590394	best: 8912.8590394 (0)	total: 17.7ms	remaining: 5m 53s
# 1000:	learn: 2423.4626002	test: 4777.0283285	best: 4775.8495957 (996)	total: 4.38s	remaining: 1m 23s
# 2000:	learn: 1493.2781946	test: 4715.9126994	best: 4715.8240446 (1996)	total: 8.78s	remaining: 1m 18s
# 3000:	learn: 1029.8805295	test: 4661.5283629	best: 4661.4592943 (2992)	total: 13.2s	remaining: 1m 14s
# 4000:	learn: 746.1756591	test: 4641.5796339	best: 4641.3864630 (3970)	total: 17.6s	remaining: 1m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4637.894209
# bestIteration = 4272
#
# Shrink model to first 4273 iterations.
# 남은변수개수: 138
# Learning rate set to 0.007431
# 0:	learn: 8589.7942075	test: 8912.8590394	best: 8912.8590394 (0)	total: 5.29ms	remaining: 1m 45s
# 1000:	learn: 2423.4626002	test: 4777.0283285	best: 4775.8495957 (996)	total: 4.38s	remaining: 1m 23s
# 2000:	learn: 1493.2781946	test: 4715.9126994	best: 4715.8240446 (1996)	total: 8.76s	remaining: 1m 18s
# 3000:	learn: 1029.8805295	test: 4661.5283629	best: 4661.4592943 (2992)	total: 13.2s	remaining: 1m 14s
# 4000:	learn: 746.1756591	test: 4641.5796339	best: 4641.3864630 (3970)	total: 17.6s	remaining: 1m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4637.894209
# bestIteration = 4272
#
# Shrink model to first 4273 iterations.
# 남은변수개수: 137
# Learning rate set to 0.007431
# 0:	learn: 8589.1749736	test: 8913.3349113	best: 8913.3349113 (0)	total: 13.4ms	remaining: 4m 27s
# 1000:	learn: 2438.4513645	test: 4819.8789715	best: 4819.8789715 (1000)	total: 4.36s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4771.475013
# bestIteration = 1330
#
# Shrink model to first 1331 iterations.
# 남은변수개수: 136
# Learning rate set to 0.007431
# 0:	learn: 8590.3359410	test: 8909.2302841	best: 8909.2302841 (0)	total: 18.4ms	remaining: 6m 8s
# 1000:	learn: 2429.5090789	test: 4840.4470447	best: 4839.9888474 (982)	total: 4.39s	remaining: 1m 23s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4796.661634
# bestIteration = 1394
#
# Shrink model to first 1395 iterations.
# 남은변수개수: 135
# Learning rate set to 0.007431
# 0:	learn: 8591.9300758	test: 8915.1224744	best: 8915.1224744 (0)	total: 18.4ms	remaining: 6m 7s
# 1000:	learn: 2422.3528985	test: 4769.5171963	best: 4769.2278873 (995)	total: 4.37s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4731.491861
# bestIteration = 1337
#
# Shrink model to first 1338 iterations.
# 남은변수개수: 134
# Learning rate set to 0.007431
# 0:	learn: 8590.0985240	test: 8915.6715207	best: 8915.6715207 (0)	total: 5.19ms	remaining: 1m 43s
# 1000:	learn: 2426.4921479	test: 4808.9993882	best: 4808.5216106 (999)	total: 4.43s	remaining: 1m 24s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4754.936583
# bestIteration = 1405
#
# Shrink model to first 1406 iterations.
# 남은변수개수: 133
# Learning rate set to 0.007431
# 0:	learn: 8593.3046540	test: 8918.6989743	best: 8918.6989743 (0)	total: 5.25ms	remaining: 1m 45s
# 1000:	learn: 2467.8625047	test: 4810.1482261	best: 4810.1482261 (1000)	total: 4.36s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4762.127096
# bestIteration = 1395
#
# Shrink model to first 1396 iterations.
# 남은변수개수: 132
# Learning rate set to 0.007431
# 0:	learn: 8588.8861708	test: 8912.1509619	best: 8912.1509619 (0)	total: 5.19ms	remaining: 1m 43s
# 1000:	learn: 2445.0183509	test: 4797.6665605	best: 4797.6665605 (1000)	total: 4.37s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4749.041448
# bestIteration = 1427
#
# Shrink model to first 1428 iterations.
# 남은변수개수: 131
# Learning rate set to 0.007431
# 0:	learn: 8593.3232010	test: 8913.5868216	best: 8913.5868216 (0)	total: 5.37ms	remaining: 1m 47s
# 1000:	learn: 2438.4103014	test: 4856.7098394	best: 4856.1990395 (998)	total: 4.38s	remaining: 1m 23s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4796.167295
# bestIteration = 1483
#
# Shrink model to first 1484 iterations.
# 남은변수개수: 130
# Learning rate set to 0.007431
# 0:	learn: 8592.2351733	test: 8919.2310898	best: 8919.2310898 (0)	total: 19.9ms	remaining: 6m 37s
# 1000:	learn: 2436.8412533	test: 4820.6811750	best: 4820.6811750 (1000)	total: 4.33s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4772.565591
# bestIteration = 1339
#
# Shrink model to first 1340 iterations.
# 남은변수개수: 129
# Learning rate set to 0.007431
# 0:	learn: 8591.7405672	test: 8911.1149560	best: 8911.1149560 (0)	total: 11ms	remaining: 3m 39s
# 1000:	learn: 2431.4325707	test: 4757.6882348	best: 4757.2095299 (997)	total: 4.32s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4723.101081
# bestIteration = 1441
#
# Shrink model to first 1442 iterations.
# 남은변수개수: 128
# Learning rate set to 0.007431
# 0:	learn: 8593.1026995	test: 8912.0498460	best: 8912.0498460 (0)	total: 5.19ms	remaining: 1m 43s
# 1000:	learn: 2419.7593350	test: 4779.5849429	best: 4779.5849429 (1000)	total: 4.34s	remaining: 1m 22s
# 2000:	learn: 1508.6782409	test: 4683.9110695	best: 4683.6091243 (1988)	total: 8.65s	remaining: 1m 17s
# 3000:	learn: 1041.7545186	test: 4633.2086175	best: 4633.0437385 (2995)	total: 13s	remaining: 1m 13s
# 4000:	learn: 734.9683476	test: 4610.7840333	best: 4610.7323012 (3986)	total: 17.3s	remaining: 1m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4604.354593
# bestIteration = 4628
#
# Shrink model to first 4629 iterations.
# 남은변수개수: 127
# Learning rate set to 0.007431
# 0:	learn: 8591.9474245	test: 8910.4739965	best: 8910.4739965 (0)	total: 23.2ms	remaining: 7m 44s
# 1000:	learn: 2441.2626602	test: 4838.4588722	best: 4837.9653286 (999)	total: 4.32s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4786.703728
# bestIteration = 1390
#
# Shrink model to first 1391 iterations.
# 남은변수개수: 126
# Learning rate set to 0.007431
# 0:	learn: 8592.5726948	test: 8910.3332862	best: 8910.3332862 (0)	total: 10.2ms	remaining: 3m 24s
# 1000:	learn: 2448.0829101	test: 4792.6009442	best: 4792.0179065 (998)	total: 4.33s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4739.761047
# bestIteration = 1353
#
# Shrink model to first 1354 iterations.
# 남은변수개수: 125
# Learning rate set to 0.007431
# 0:	learn: 8589.3091792	test: 8913.3701391	best: 8913.3701391 (0)	total: 19.5ms	remaining: 6m 30s
# 1000:	learn: 2424.8260044	test: 4813.2563068	best: 4813.2563068 (1000)	total: 4.27s	remaining: 1m 21s
# 2000:	learn: 1517.4811552	test: 4731.0793780	best: 4731.0793780 (2000)	total: 8.56s	remaining: 1m 16s
# 3000:	learn: 1025.5511912	test: 4675.1658978	best: 4675.1246892 (2970)	total: 12.9s	remaining: 1m 12s
# 4000:	learn: 753.7189714	test: 4658.3095520	best: 4658.2277945 (3991)	total: 17.2s	remaining: 1m 8s
# 5000:	learn: 560.5945376	test: 4648.6197604	best: 4648.5616319 (4998)	total: 21.5s	remaining: 1m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4642.283097
# bestIteration = 5841
#
# Shrink model to first 5842 iterations.
# 남은변수개수: 124
# Learning rate set to 0.007431
# 0:	learn: 8590.5682553	test: 8914.7918840	best: 8914.7918840 (0)	total: 5.45ms	remaining: 1m 49s
# 1000:	learn: 2451.2859540	test: 4814.4609416	best: 4813.7535634 (996)	total: 4.27s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4756.665254
# bestIteration = 1378
#
# Shrink model to first 1379 iterations.
# 남은변수개수: 123
# Learning rate set to 0.007431
# 0:	learn: 8593.6604815	test: 8913.0650210	best: 8913.0650210 (0)	total: 5.34ms	remaining: 1m 46s
# 1000:	learn: 2422.0107268	test: 4752.6327329	best: 4752.3637873 (999)	total: 4.25s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4698.24592
# bestIteration = 1403
#
# Shrink model to first 1404 iterations.
# 남은변수개수: 122
# Learning rate set to 0.007431
# 0:	learn: 8593.2596353	test: 8917.1005323	best: 8917.1005323 (0)	total: 13.9ms	remaining: 4m 38s
# 1000:	learn: 2426.2092970	test: 4757.1344737	best: 4756.9160546 (999)	total: 4.21s	remaining: 1m 19s
# 2000:	learn: 1508.5796184	test: 4668.2008364	best: 4668.2008364 (2000)	total: 8.48s	remaining: 1m 16s
# 3000:	learn: 1053.5892050	test: 4618.2683426	best: 4618.2458485 (2999)	total: 12.7s	remaining: 1m 12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4609.417938
# bestIteration = 3407
#
# Shrink model to first 3408 iterations.
# 남은변수개수: 121
# Learning rate set to 0.007431
# 0:	learn: 8593.7965575	test: 8913.9933861	best: 8913.9933861 (0)	total: 5.34ms	remaining: 1m 46s
# 1000:	learn: 2430.9160496	test: 4809.6359306	best: 4809.6359306 (1000)	total: 4.26s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4760.421414
# bestIteration = 1375
#
# Shrink model to first 1376 iterations.
# 남은변수개수: 120
# Learning rate set to 0.007431
# 0:	learn: 8591.8593182	test: 8916.7811458	best: 8916.7811458 (0)	total: 5.28ms	remaining: 1m 45s
# 1000:	learn: 2457.9896124	test: 4806.1942597	best: 4806.1322416 (990)	total: 4.22s	remaining: 1m 20s
# 2000:	learn: 1456.9673376	test: 4694.6546494	best: 4694.6428304 (1999)	total: 8.48s	remaining: 1m 16s
# 3000:	learn: 1013.5493117	test: 4648.6161960	best: 4648.6161960 (3000)	total: 12.8s	remaining: 1m 12s
# 4000:	learn: 722.6731570	test: 4628.8679952	best: 4628.8679952 (4000)	total: 17.1s	remaining: 1m 8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4620.583472
# bestIteration = 4761
#
# Shrink model to first 4762 iterations.
# 남은변수개수: 119
# Learning rate set to 0.007431
# 0:	learn: 8593.8076837	test: 8910.1374646	best: 8910.1374646 (0)	total: 19ms	remaining: 6m 20s
# 1000:	learn: 2435.8273714	test: 4793.1838054	best: 4793.1346385 (997)	total: 4.21s	remaining: 1m 19s
# 2000:	learn: 1497.6850902	test: 4690.0391744	best: 4690.0133334 (1998)	total: 8.43s	remaining: 1m 15s
# 3000:	learn: 1027.3431111	test: 4639.3637554	best: 4638.8784374 (2996)	total: 12.7s	remaining: 1m 11s
# 4000:	learn: 725.6473559	test: 4619.2729085	best: 4619.2729085 (4000)	total: 16.9s	remaining: 1m 7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4617.623058
# bestIteration = 4282
#
# Shrink model to first 4283 iterations.
# 남은변수개수: 118
# Learning rate set to 0.007431
# 0:	learn: 8594.2642813	test: 8910.4924981	best: 8910.4924981 (0)	total: 20.2ms	remaining: 6m 43s
# 1000:	learn: 2434.0716872	test: 4795.1919058	best: 4795.1762817 (999)	total: 4.16s	remaining: 1m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4748.472733
# bestIteration = 1522
#
# Shrink model to first 1523 iterations.
# 남은변수개수: 117
# Learning rate set to 0.007431
# 0:	learn: 8589.5433980	test: 8912.5952209	best: 8912.5952209 (0)	total: 5.09ms	remaining: 1m 41s
# 1000:	learn: 2445.5979714	test: 4787.7759451	best: 4787.7759451 (1000)	total: 4.16s	remaining: 1m 18s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4745.50673
# bestIteration = 1525
#
# Shrink model to first 1526 iterations.
# 남은변수개수: 116
# Learning rate set to 0.007431
# 0:	learn: 8592.8895948	test: 8910.1850010	best: 8910.1850010 (0)	total: 5.1ms	remaining: 1m 42s
# 1000:	learn: 2425.8060436	test: 4788.4457515	best: 4788.0309138 (997)	total: 4.15s	remaining: 1m 18s
# 2000:	learn: 1489.0799335	test: 4716.5986684	best: 4716.5986684 (2000)	total: 8.34s	remaining: 1m 15s
# 3000:	learn: 1020.2124798	test: 4678.0901126	best: 4677.7000672 (2994)	total: 12.6s	remaining: 1m 11s
# 4000:	learn: 735.3616068	test: 4652.5104678	best: 4652.4922436 (3999)	total: 16.8s	remaining: 1m 7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4646.52589
# bestIteration = 4772
#
# Shrink model to first 4773 iterations.
# 남은변수개수: 115
# Learning rate set to 0.007431
# 0:	learn: 8592.2992794	test: 8912.1280091	best: 8912.1280091 (0)	total: 19.6ms	remaining: 6m 32s
# 1000:	learn: 2444.5545760	test: 4835.9296770	best: 4835.0974737 (991)	total: 4.17s	remaining: 1m 19s
# 2000:	learn: 1500.1830931	test: 4753.3529252	best: 4753.3529252 (2000)	total: 8.37s	remaining: 1m 15s
# 3000:	learn: 1026.2885458	test: 4707.7273649	best: 4707.6449581 (2998)	total: 12.6s	remaining: 1m 11s
# 4000:	learn: 741.4852417	test: 4686.2290804	best: 4686.1708757 (3984)	total: 16.9s	remaining: 1m 7s
# 5000:	learn: 555.4777708	test: 4677.3687629	best: 4677.2820254 (4986)	total: 21.1s	remaining: 1m 3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4676.982764
# bestIteration = 5030
#
# Shrink model to first 5031 iterations.
# 남은변수개수: 114
# Learning rate set to 0.007431
# 0:	learn: 8593.1844600	test: 8907.3257030	best: 8907.3257030 (0)	total: 5.15ms	remaining: 1m 43s
# 1000:	learn: 2441.5094609	test: 4808.0070997	best: 4807.8580230 (986)	total: 4.09s	remaining: 1m 17s
# 2000:	learn: 1523.2223933	test: 4749.9448020	best: 4749.9448020 (2000)	total: 8.22s	remaining: 1m 13s
# 3000:	learn: 1038.3328439	test: 4720.8150748	best: 4720.6564926 (2994)	total: 12.4s	remaining: 1m 10s
# 4000:	learn: 747.0342225	test: 4695.1829885	best: 4694.8356630 (3993)	total: 16.5s	remaining: 1m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4689.77003
# bestIteration = 4805
#
# Shrink model to first 4806 iterations.
# 남은변수개수: 113
# Learning rate set to 0.007431
# 0:	learn: 8587.2881215	test: 8907.7160772	best: 8907.7160772 (0)	total: 5.26ms	remaining: 1m 45s
# 1000:	learn: 2423.5701823	test: 4776.7132350	best: 4776.7132350 (1000)	total: 4.14s	remaining: 1m 18s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4725.956096
# bestIteration = 1421
#
# Shrink model to first 1422 iterations.
# 남은변수개수: 112
# Learning rate set to 0.007431
# 0:	learn: 8590.1340856	test: 8915.8927790	best: 8915.8927790 (0)	total: 17.8ms	remaining: 5m 56s
# 1000:	learn: 2431.3080020	test: 4759.7387977	best: 4759.4961328 (997)	total: 4.16s	remaining: 1m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4718.567986
# bestIteration = 1725
#
# Shrink model to first 1726 iterations.
# 남은변수개수: 111
# Learning rate set to 0.007431
# 0:	learn: 8595.9304468	test: 8919.2382941	best: 8919.2382941 (0)	total: 5ms	remaining: 1m 40s
# 1000:	learn: 2414.5924941	test: 4780.3272329	best: 4780.0480092 (998)	total: 4.07s	remaining: 1m 17s
# 2000:	learn: 1497.7179270	test: 4685.6782202	best: 4685.2296846 (1926)	total: 8.17s	remaining: 1m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4685.229685
# bestIteration = 1926
#
# Shrink model to first 1927 iterations.
# 남은변수개수: 110
# Learning rate set to 0.007431
# 0:	learn: 8589.5650109	test: 8908.4753177	best: 8908.4753177 (0)	total: 17.7ms	remaining: 5m 54s
# 1000:	learn: 2430.5074935	test: 4787.1818193	best: 4786.8368241 (998)	total: 4.12s	remaining: 1m 18s
# 2000:	learn: 1528.8817173	test: 4708.1316984	best: 4708.1316984 (2000)	total: 8.2s	remaining: 1m 13s
# 3000:	learn: 1024.4284157	test: 4657.3156065	best: 4657.3156065 (3000)	total: 12.3s	remaining: 1m 9s
# 4000:	learn: 740.9432525	test: 4635.0164951	best: 4635.0164951 (4000)	total: 16.4s	remaining: 1m 5s
# 5000:	learn: 550.8310434	test: 4624.6621906	best: 4624.2708688 (4978)	total: 20.6s	remaining: 1m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4622.080973
# bestIteration = 5441
#
# Shrink model to first 5442 iterations.
# 남은변수개수: 109
# Learning rate set to 0.007431
# 0:	learn: 8592.0996657	test: 8915.5074227	best: 8915.5074227 (0)	total: 4.93ms	remaining: 1m 38s
# 1000:	learn: 2439.3391142	test: 4828.9422110	best: 4828.9422110 (1000)	total: 3.98s	remaining: 1m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4778.205096
# bestIteration = 1507
#
# Shrink model to first 1508 iterations.
# 남은변수개수: 108
# Learning rate set to 0.007431
# 0:	learn: 8592.1769001	test: 8915.3788814	best: 8915.3788814 (0)	total: 4.74ms	remaining: 1m 34s
# 1000:	learn: 2439.5517629	test: 4792.4863635	best: 4792.3961627 (996)	total: 3.96s	remaining: 1m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4777.019019
# bestIteration = 1091
#
# Shrink model to first 1092 iterations.
# 남은변수개수: 107
# Learning rate set to 0.007431
# 0:	learn: 8592.1588848	test: 8921.2763995	best: 8921.2763995 (0)	total: 10.9ms	remaining: 3m 37s
# 1000:	learn: 2449.5997271	test: 4760.9373677	best: 4760.5655734 (993)	total: 4.01s	remaining: 1m 16s
# 2000:	learn: 1539.3685781	test: 4678.3619845	best: 4678.3619845 (2000)	total: 8.04s	remaining: 1m 12s
# 3000:	learn: 1061.3973496	test: 4625.6787754	best: 4625.5867488 (2989)	total: 12.1s	remaining: 1m 8s
# 4000:	learn: 765.7088660	test: 4606.7986525	best: 4606.7019059 (3991)	total: 16.2s	remaining: 1m 4s
# 5000:	learn: 589.9767166	test: 4597.4077847	best: 4597.3689349 (4997)	total: 20.2s	remaining: 1m
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4594.901041
# bestIteration = 5268
#
# Shrink model to first 5269 iterations.
# 남은변수개수: 106
# Learning rate set to 0.007431
# 0:	learn: 8594.1817726	test: 8922.1032271	best: 8922.1032271 (0)	total: 4.97ms	remaining: 1m 39s
# 1000:	learn: 2428.9731596	test: 4826.2827621	best: 4825.9500501 (994)	total: 3.97s	remaining: 1m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4771.871914
# bestIteration = 1468
#
# Shrink model to first 1469 iterations.
# 남은변수개수: 105
# Learning rate set to 0.007431
# 0:	learn: 8593.2346712	test: 8918.7226330	best: 8918.7226330 (0)	total: 4.74ms	remaining: 1m 34s
# 1000:	learn: 2425.4046447	test: 4788.2520505	best: 4788.2520505 (1000)	total: 3.9s	remaining: 1m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4751.204247
# bestIteration = 1558
#
# Shrink model to first 1559 iterations.
# 남은변수개수: 104
# Learning rate set to 0.007431
# 0:	learn: 8593.4014942	test: 8918.3465065	best: 8918.3465065 (0)	total: 20.2ms	remaining: 6m 43s
# 1000:	learn: 2423.2301358	test: 4784.0628736	best: 4783.7568758 (992)	total: 3.93s	remaining: 1m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4746.885657
# bestIteration = 1481
#
# Shrink model to first 1482 iterations.
# 남은변수개수: 103
# Learning rate set to 0.007431
# 0:	learn: 8597.5789623	test: 8916.5319800	best: 8916.5319800 (0)	total: 4.72ms	remaining: 1m 34s
# 1000:	learn: 2453.8501908	test: 4837.4173364	best: 4836.9584918 (998)	total: 3.86s	remaining: 1m 13s
# 2000:	learn: 1511.4980316	test: 4754.1003702	best: 4754.1003702 (2000)	total: 7.78s	remaining: 1m 10s
# 3000:	learn: 1040.0960065	test: 4699.4854564	best: 4699.4854564 (3000)	total: 11.7s	remaining: 1m 6s
# 4000:	learn: 747.6042387	test: 4673.6492402	best: 4673.6492402 (4000)	total: 15.6s	remaining: 1m 2s
# 5000:	learn: 566.0697448	test: 4663.3633611	best: 4663.3633611 (5000)	total: 19.5s	remaining: 58.6s
# 6000:	learn: 427.7555843	test: 4657.3801682	best: 4657.2793612 (5974)	total: 23.5s	remaining: 54.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4657.128675
# bestIteration = 6007
#
# Shrink model to first 6008 iterations.
# 남은변수개수: 102
# Learning rate set to 0.007431
# 0:	learn: 8595.3301855	test: 8907.4701886	best: 8907.4701886 (0)	total: 4.8ms	remaining: 1m 36s
# 1000:	learn: 2451.2190564	test: 4797.9189385	best: 4797.4376807 (995)	total: 3.91s	remaining: 1m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4749.240474
# bestIteration = 1484
#
# Shrink model to first 1485 iterations.
# 남은변수개수: 101
# Learning rate set to 0.007431
# 0:	learn: 8589.5918028	test: 8915.1684630	best: 8915.1684630 (0)	total: 4.52ms	remaining: 1m 30s
# 1000:	learn: 2468.9099260	test: 4810.1944809	best: 4810.1944809 (1000)	total: 3.73s	remaining: 1m 10s
# 2000:	learn: 1540.5809868	test: 4742.3984502	best: 4742.3112325 (1999)	total: 7.53s	remaining: 1m 7s
# 3000:	learn: 1059.5350578	test: 4701.1327604	best: 4700.8825495 (2995)	total: 11.3s	remaining: 1m 4s
# 4000:	learn: 762.4960118	test: 4673.0068538	best: 4673.0068538 (4000)	total: 15.1s	remaining: 1m
# 5000:	learn: 567.9050631	test: 4662.4767481	best: 4662.3768234 (4992)	total: 18.9s	remaining: 56.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4661.602977
# bestIteration = 5074
#
# Shrink model to first 5075 iterations.
# 남은변수개수: 100
# Learning rate set to 0.007431
# 0:	learn: 8592.4488189	test: 8913.7395718	best: 8913.7395718 (0)	total: 22.9ms	remaining: 7m 37s
# 1000:	learn: 2422.9799080	test: 4788.7792816	best: 4787.8774206 (994)	total: 3.78s	remaining: 1m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4751.914259
# bestIteration = 1364
#
# Shrink model to first 1365 iterations.
# 남은변수개수: 99
# Learning rate set to 0.007431
# 0:	learn: 8590.5886121	test: 8916.0266999	best: 8916.0266999 (0)	total: 6.31ms	remaining: 2m 6s
# 1000:	learn: 2433.1002696	test: 4796.9447466	best: 4796.9447466 (1000)	total: 3.71s	remaining: 1m 10s
# 2000:	learn: 1516.6289538	test: 4720.1684435	best: 4720.1684435 (2000)	total: 7.44s	remaining: 1m 6s
# 3000:	learn: 1053.5179130	test: 4665.1201593	best: 4665.1201593 (3000)	total: 11.2s	remaining: 1m 3s
# 4000:	learn: 754.1835254	test: 4643.3966961	best: 4643.3817523 (3999)	total: 15s	remaining: 1m
# 5000:	learn: 559.1175409	test: 4632.3007609	best: 4632.1319259 (4936)	total: 18.8s	remaining: 56.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4629.935328
# bestIteration = 5436
#
# Shrink model to first 5437 iterations.
# 남은변수개수: 98
# Learning rate set to 0.007431
# 0:	learn: 8592.3503989	test: 8915.8381166	best: 8915.8381166 (0)	total: 19.8ms	remaining: 6m 36s
# 1000:	learn: 2409.6703810	test: 4797.6534828	best: 4797.6534828 (1000)	total: 3.66s	remaining: 1m 9s
# 2000:	learn: 1504.7695707	test: 4702.1247066	best: 4702.1247066 (2000)	total: 7.37s	remaining: 1m 6s
# 3000:	learn: 1038.0489785	test: 4655.6158812	best: 4655.6158812 (3000)	total: 11.1s	remaining: 1m 2s
# 4000:	learn: 732.8230872	test: 4632.9896131	best: 4632.9820660 (3999)	total: 14.8s	remaining: 59.2s
# 5000:	learn: 544.0755745	test: 4622.0219117	best: 4621.8817077 (4983)	total: 18.6s	remaining: 55.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4620.684123
# bestIteration = 5297
#
# Shrink model to first 5298 iterations.
# 남은변수개수: 97
# Learning rate set to 0.007431
# 0:	learn: 8592.1328142	test: 8920.8732274	best: 8920.8732274 (0)	total: 4.49ms	remaining: 1m 29s
# 1000:	learn: 2457.6497211	test: 4785.5569320	best: 4785.5569320 (1000)	total: 3.66s	remaining: 1m 9s
# 2000:	learn: 1542.7859736	test: 4706.9834336	best: 4706.9834336 (2000)	total: 7.36s	remaining: 1m 6s
# 3000:	learn: 1102.6488576	test: 4665.9616192	best: 4665.8798118 (2999)	total: 11.1s	remaining: 1m 2s
# 4000:	learn: 776.5900954	test: 4645.9199822	best: 4645.8779025 (3999)	total: 14.8s	remaining: 59.3s
# 5000:	learn: 567.5474207	test: 4630.7936902	best: 4630.7567154 (4999)	total: 18.6s	remaining: 55.7s
# 6000:	learn: 422.1161521	test: 4624.6860536	best: 4624.6779914 (5972)	total: 22.3s	remaining: 52.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4622.654203
# bestIteration = 6284
#
# Shrink model to first 6285 iterations.
# 남은변수개수: 96
# Learning rate set to 0.007431
# 0:	learn: 8590.9136902	test: 8913.5565383	best: 8913.5565383 (0)	total: 4.65ms	remaining: 1m 33s
# 1000:	learn: 2429.2104583	test: 4797.0950723	best: 4797.0950723 (1000)	total: 3.64s	remaining: 1m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4746.913207
# bestIteration = 1521
#
# Shrink model to first 1522 iterations.
# 남은변수개수: 95
# Learning rate set to 0.007431
# 0:	learn: 8594.9737971	test: 8912.7336076	best: 8912.7336076 (0)	total: 8.28ms	remaining: 2m 45s
# 1000:	learn: 2408.3630915	test: 4740.1473439	best: 4739.0302713 (995)	total: 3.67s	remaining: 1m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4698.328742
# bestIteration = 1406
#
# Shrink model to first 1407 iterations.
# 남은변수개수: 94
# Learning rate set to 0.007431
# 0:	learn: 8592.6054708	test: 8911.9187241	best: 8911.9187241 (0)	total: 8.06ms	remaining: 2m 41s
# 1000:	learn: 2438.2787024	test: 4844.2091668	best: 4844.2091668 (1000)	total: 3.63s	remaining: 1m 8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4793.028196
# bestIteration = 1338
#
# Shrink model to first 1339 iterations.
# 남은변수개수: 93
# Learning rate set to 0.007431
# 0:	learn: 8591.4784736	test: 8911.9315752	best: 8911.9315752 (0)	total: 5.32ms	remaining: 1m 46s
# 1000:	learn: 2444.1973493	test: 4795.3955475	best: 4795.3955475 (1000)	total: 3.61s	remaining: 1m 8s
# 2000:	learn: 1544.7524974	test: 4717.8623540	best: 4717.8623540 (2000)	total: 7.23s	remaining: 1m 5s
# 3000:	learn: 1064.5565890	test: 4662.5680492	best: 4662.3747878 (2992)	total: 10.8s	remaining: 1m 1s
# 4000:	learn: 763.9714288	test: 4637.0353485	best: 4636.8356060 (3992)	total: 14.5s	remaining: 57.9s
# 5000:	learn: 566.3999245	test: 4624.1420881	best: 4624.0725122 (4999)	total: 18.1s	remaining: 54.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4620.202838
# bestIteration = 5614
#
# Shrink model to first 5615 iterations.
# 남은변수개수: 92
# Learning rate set to 0.007431
# 0:	learn: 8593.3035394	test: 8915.4942514	best: 8915.4942514 (0)	total: 20.9ms	remaining: 6m 57s
# 1000:	learn: 2411.2725523	test: 4790.0680287	best: 4788.1643632 (984)	total: 3.54s	remaining: 1m 7s
# 2000:	learn: 1508.4830518	test: 4701.7865617	best: 4701.6224649 (1993)	total: 7.06s	remaining: 1m 3s
# 3000:	learn: 1035.7704468	test: 4655.7950715	best: 4655.6742769 (2999)	total: 10.6s	remaining: 1m
# 4000:	learn: 748.6805353	test: 4631.9027519	best: 4631.8890431 (3991)	total: 14.2s	remaining: 56.7s
# 5000:	learn: 558.8244933	test: 4621.4929511	best: 4621.4929511 (5000)	total: 17.7s	remaining: 53.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4620.017693
# bestIteration = 5198
#
# Shrink model to first 5199 iterations.
# 남은변수개수: 91
# Learning rate set to 0.007431
# 0:	learn: 8596.6173124	test: 8915.3671090	best: 8915.3671090 (0)	total: 19ms	remaining: 6m 19s
# 1000:	learn: 2428.6168338	test: 4801.2421421	best: 4801.0153322 (999)	total: 3.5s	remaining: 1m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4764.382722
# bestIteration = 1457
#
# Shrink model to first 1458 iterations.
# 남은변수개수: 90
# Learning rate set to 0.007431
# 0:	learn: 8590.7919151	test: 8915.2099928	best: 8915.2099928 (0)	total: 4.34ms	remaining: 1m 26s
# 1000:	learn: 2415.2828172	test: 4767.9330963	best: 4765.2784962 (990)	total: 3.45s	remaining: 1m 5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4746.230237
# bestIteration = 1223
#
# Shrink model to first 1224 iterations.
# 남은변수개수: 89
# Learning rate set to 0.007431
# 0:	learn: 8591.3084057	test: 8914.6002524	best: 8914.6002524 (0)	total: 4.35ms	remaining: 1m 26s
# 1000:	learn: 2441.7766885	test: 4783.6756379	best: 4783.1585272 (998)	total: 3.44s	remaining: 1m 5s
# 2000:	learn: 1548.5595040	test: 4713.8972229	best: 4713.8436867 (1999)	total: 6.84s	remaining: 1m 1s
# 3000:	learn: 1080.5813936	test: 4664.0329921	best: 4663.9449909 (2982)	total: 10.3s	remaining: 58.4s
# 4000:	learn: 789.9561292	test: 4639.7036559	best: 4639.6691604 (3999)	total: 13.8s	remaining: 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4630.680221
# bestIteration = 4444
#
# Shrink model to first 4445 iterations.
# 남은변수개수: 88
# Learning rate set to 0.007431
# 0:	learn: 8588.6079748	test: 8913.0022249	best: 8913.0022249 (0)	total: 7.24ms	remaining: 2m 24s
# 1000:	learn: 2417.6373024	test: 4786.8978884	best: 4786.5045051 (994)	total: 3.41s	remaining: 1m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4739.791889
# bestIteration = 1483
#
# Shrink model to first 1484 iterations.
# 남은변수개수: 87
# Learning rate set to 0.007431
# 0:	learn: 8593.9704977	test: 8918.9872703	best: 8918.9872703 (0)	total: 4.07ms	remaining: 1m 21s
# 1000:	learn: 2440.5117308	test: 4795.0508435	best: 4795.0508435 (1000)	total: 3.35s	remaining: 1m 3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4751.122608
# bestIteration = 1332
#
# Shrink model to first 1333 iterations.
# 남은변수개수: 86
# Learning rate set to 0.007431
# 0:	learn: 8592.4943228	test: 8917.5452329	best: 8917.5452329 (0)	total: 4.13ms	remaining: 1m 22s
# 1000:	learn: 2424.5830568	test: 4739.9304297	best: 4739.5894750 (997)	total: 3.31s	remaining: 1m 2s
# 2000:	learn: 1514.8394202	test: 4661.1239141	best: 4661.1239141 (2000)	total: 6.64s	remaining: 59.7s
# 3000:	learn: 1040.0001065	test: 4610.4000194	best: 4610.3439221 (2999)	total: 9.99s	remaining: 56.6s
# 4000:	learn: 745.1614044	test: 4585.7632745	best: 4585.5535854 (3963)	total: 13.3s	remaining: 53.4s
# 5000:	learn: 551.2974001	test: 4576.0639106	best: 4575.9146385 (4937)	total: 16.7s	remaining: 50.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4573.083079
# bestIteration = 5428
#
# Shrink model to first 5429 iterations.
# 남은변수개수: 85
# Learning rate set to 0.007431
# 0:	learn: 8592.0074863	test: 8915.3047236	best: 8915.3047236 (0)	total: 4.04ms	remaining: 1m 20s
# 1000:	learn: 2389.0045050	test: 4775.1211904	best: 4775.1211904 (1000)	total: 3.28s	remaining: 1m 2s
# 2000:	learn: 1520.0467019	test: 4693.9037169	best: 4693.5853206 (1999)	total: 6.59s	remaining: 59.3s
# 3000:	learn: 1046.9980132	test: 4633.3303431	best: 4633.2854659 (2998)	total: 9.96s	remaining: 56.4s
# 4000:	learn: 766.4061463	test: 4604.9472347	best: 4604.9472347 (4000)	total: 13.3s	remaining: 53.3s
# 5000:	learn: 559.1083482	test: 4592.4647197	best: 4592.4647197 (5000)	total: 16.7s	remaining: 50s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4589.40546
# bestIteration = 5382
#
# Shrink model to first 5383 iterations.
# 남은변수개수: 84
# Learning rate set to 0.007431
# 0:	learn: 8593.2950056	test: 8910.8000536	best: 8910.8000536 (0)	total: 4.22ms	remaining: 1m 24s
# 1000:	learn: 2408.1252068	test: 4781.4672815	best: 4781.4672815 (1000)	total: 3.32s	remaining: 1m 2s
# 2000:	learn: 1537.4144813	test: 4708.0984923	best: 4707.9967653 (1998)	total: 6.68s	remaining: 1m
# 3000:	learn: 1055.5155790	test: 4643.4977474	best: 4643.4977474 (3000)	total: 10.1s	remaining: 57s
# 4000:	learn: 745.9703833	test: 4613.5363912	best: 4613.5363912 (4000)	total: 13.4s	remaining: 53.7s
# 5000:	learn: 559.6692532	test: 4598.5641564	best: 4598.5641564 (5000)	total: 16.8s	remaining: 50.4s
# 6000:	learn: 425.5855102	test: 4591.5551222	best: 4591.5421442 (5999)	total: 20.2s	remaining: 47.1s
# 7000:	learn: 329.1859948	test: 4585.2044782	best: 4585.1761998 (6997)	total: 23.6s	remaining: 43.7s
# 8000:	learn: 259.1686519	test: 4580.3745225	best: 4580.3645330 (7972)	total: 26.9s	remaining: 40.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4579.626038
# bestIteration = 8243
#
# Shrink model to first 8244 iterations.
# 남은변수개수: 83
# Learning rate set to 0.007431
# 0:	learn: 8594.9222419	test: 8915.5769291	best: 8915.5769291 (0)	total: 5.7ms	remaining: 1m 53s
# 1000:	learn: 2392.6848424	test: 4789.0659422	best: 4789.0659422 (1000)	total: 3.27s	remaining: 1m 2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4754.329114
# bestIteration = 1486
#
# Shrink model to first 1487 iterations.
# 남은변수개수: 82
# Learning rate set to 0.007431
# 0:	learn: 8590.0374700	test: 8906.4677699	best: 8906.4677699 (0)	total: 7.56ms	remaining: 2m 31s
# 1000:	learn: 2397.1204093	test: 4818.9556518	best: 4818.5534244 (997)	total: 3.26s	remaining: 1m 1s
# 2000:	learn: 1508.9090077	test: 4740.0801861	best: 4739.9230331 (1998)	total: 6.51s	remaining: 58.6s
# 3000:	learn: 1056.8480841	test: 4682.1285715	best: 4682.1285715 (3000)	total: 9.79s	remaining: 55.5s
# 4000:	learn: 753.7763061	test: 4657.3037396	best: 4656.8346440 (3928)	total: 13.1s	remaining: 52.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4651.022527
# bestIteration = 4506
#
# Shrink model to first 4507 iterations.
# 남은변수개수: 81
# Learning rate set to 0.007431
# 0:	learn: 8595.7824785	test: 8912.4994874	best: 8912.4994874 (0)	total: 21.3ms	remaining: 7m 6s
# 1000:	learn: 2377.3724894	test: 4720.2992675	best: 4720.0278467 (997)	total: 3.27s	remaining: 1m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4685.386001
# bestIteration = 1373
#
# Shrink model to first 1374 iterations.
# 남은변수개수: 80
# Learning rate set to 0.007431
# 0:	learn: 8593.6357074	test: 8918.8453220	best: 8918.8453220 (0)	total: 19.5ms	remaining: 6m 29s
# 1000:	learn: 2408.6040703	test: 4750.6888168	best: 4750.6888168 (1000)	total: 3.22s	remaining: 1m 1s
# 2000:	learn: 1493.2024312	test: 4673.1599185	best: 4673.1599185 (2000)	total: 6.44s	remaining: 57.9s
# 3000:	learn: 1032.4853400	test: 4614.7441607	best: 4614.7214477 (2998)	total: 9.74s	remaining: 55.2s
# 4000:	learn: 740.3277780	test: 4590.7507516	best: 4590.7246829 (3993)	total: 13s	remaining: 52s
# 5000:	learn: 547.3441097	test: 4579.0273206	best: 4578.7752736 (4927)	total: 16.2s	remaining: 48.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4578.775274
# bestIteration = 4927
#
# Shrink model to first 4928 iterations.
# 남은변수개수: 79
# Learning rate set to 0.007431
# 0:	learn: 8595.1398198	test: 8912.6368587	best: 8912.6368587 (0)	total: 2.02ms	remaining: 40.3s
# 1000:	learn: 2402.9727664	test: 4764.2829321	best: 4764.2829321 (1000)	total: 3.2s	remaining: 1m
# 2000:	learn: 1512.8811320	test: 4673.8753201	best: 4673.8753201 (2000)	total: 6.4s	remaining: 57.6s
# 3000:	learn: 1066.7957732	test: 4610.9139435	best: 4610.9013651 (2999)	total: 9.64s	remaining: 54.6s
# 4000:	learn: 756.2511190	test: 4581.7222460	best: 4581.7222460 (4000)	total: 12.9s	remaining: 51.5s
# 5000:	learn: 565.2692231	test: 4572.8320592	best: 4572.7874898 (4992)	total: 16.1s	remaining: 48.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4568.813709
# bestIteration = 5876
#
# Shrink model to first 5877 iterations.
# 남은변수개수: 78
# Learning rate set to 0.007431
# 0:	learn: 8595.3794967	test: 8918.2329132	best: 8918.2329132 (0)	total: 3.88ms	remaining: 1m 17s
# 1000:	learn: 2406.0642652	test: 4768.8041838	best: 4768.1577263 (995)	total: 3.2s	remaining: 1m
# 2000:	learn: 1512.2074801	test: 4680.8486877	best: 4680.8486877 (2000)	total: 6.43s	remaining: 57.8s
# 3000:	learn: 1046.4727316	test: 4616.8036842	best: 4616.8036842 (3000)	total: 9.66s	remaining: 54.7s
# 4000:	learn: 758.0061181	test: 4588.1754784	best: 4588.1320726 (3999)	total: 12.9s	remaining: 51.6s
# 5000:	learn: 552.6557381	test: 4574.7184285	best: 4574.7184285 (5000)	total: 16.2s	remaining: 48.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4572.896085
# bestIteration = 5404
#
# Shrink model to first 5405 iterations.
# 남은변수개수: 77
# Learning rate set to 0.007431
# 0:	learn: 8594.1848410	test: 8912.9525481	best: 8912.9525481 (0)	total: 5.38ms	remaining: 1m 47s
# 1000:	learn: 2385.5880935	test: 4703.7398368	best: 4703.7398368 (1000)	total: 3.13s	remaining: 59.5s
# 2000:	learn: 1509.2629994	test: 4610.7548078	best: 4610.6254929 (1996)	total: 6.28s	remaining: 56.5s
# 3000:	learn: 1043.0542540	test: 4555.5489346	best: 4555.5489346 (3000)	total: 9.48s	remaining: 53.7s
# 4000:	learn: 731.3337500	test: 4526.9067218	best: 4526.7852907 (3991)	total: 12.7s	remaining: 50.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4518.844086
# bestIteration = 4668
#
# Shrink model to first 4669 iterations.
# 남은변수개수: 76
# Learning rate set to 0.007431
# 0:	learn: 8591.9711012	test: 8917.0175606	best: 8917.0175606 (0)	total: 19.1ms	remaining: 6m 22s
# 1000:	learn: 2413.1188678	test: 4740.1003155	best: 4740.1003155 (1000)	total: 3.13s	remaining: 59.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4702.48964
# bestIteration = 1408
#
# Shrink model to first 1409 iterations.
# 남은변수개수: 75
# Learning rate set to 0.007431
# 0:	learn: 8595.2648434	test: 8914.9168467	best: 8914.9168467 (0)	total: 13.5ms	remaining: 4m 29s
# 1000:	learn: 2403.2524776	test: 4749.6156286	best: 4749.6156286 (1000)	total: 3.11s	remaining: 59s
# 2000:	learn: 1505.2339521	test: 4668.0146947	best: 4667.8456902 (1983)	total: 6.23s	remaining: 56s
# 3000:	learn: 1038.5082405	test: 4616.0464099	best: 4615.5880050 (2983)	total: 9.34s	remaining: 52.9s
# 4000:	learn: 734.6354378	test: 4590.8888685	best: 4590.5568426 (3932)	total: 12.5s	remaining: 49.9s
# 5000:	learn: 539.2181900	test: 4579.4818333	best: 4579.4224520 (4997)	total: 15.6s	remaining: 46.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4573.825485
# bestIteration = 5678
#
# Shrink model to first 5679 iterations.
# 남은변수개수: 74
# Learning rate set to 0.007431
# 0:	learn: 8589.8176466	test: 8911.7044074	best: 8911.7044074 (0)	total: 5.69ms	remaining: 1m 53s
# 1000:	learn: 2423.2192505	test: 4743.9164426	best: 4743.9164426 (1000)	total: 3.08s	remaining: 58.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4708.587213
# bestIteration = 1342
#
# Shrink model to first 1343 iterations.
# 남은변수개수: 73
# Learning rate set to 0.007431
# 0:	learn: 8590.7081106	test: 8918.6056029	best: 8918.6056029 (0)	total: 16.9ms	remaining: 5m 38s
# 1000:	learn: 2394.2784976	test: 4728.2930176	best: 4728.2930176 (1000)	total: 3.02s	remaining: 57.3s
# 2000:	learn: 1524.0577357	test: 4652.4913426	best: 4652.4913426 (2000)	total: 6.03s	remaining: 54.3s
# 3000:	learn: 1048.5120389	test: 4579.2936330	best: 4579.2456994 (2999)	total: 9.07s	remaining: 51.4s
# 4000:	learn: 749.2281992	test: 4552.3650293	best: 4552.1242947 (3992)	total: 12.1s	remaining: 48.5s
# 5000:	learn: 554.3741275	test: 4536.8797544	best: 4536.8052029 (4997)	total: 15.2s	remaining: 45.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4533.436686
# bestIteration = 5287
#
# Shrink model to first 5288 iterations.
# 남은변수개수: 72
# Learning rate set to 0.007431
# 0:	learn: 8590.4393796	test: 8916.0477412	best: 8916.0477412 (0)	total: 18.3ms	remaining: 6m 5s
# 1000:	learn: 2411.4084625	test: 4762.8141616	best: 4762.8141616 (1000)	total: 2.99s	remaining: 56.7s
# 2000:	learn: 1531.5378026	test: 4695.7267007	best: 4695.6668885 (1998)	total: 5.95s	remaining: 53.5s
# 3000:	learn: 1054.6451387	test: 4645.6999091	best: 4645.5385567 (2985)	total: 8.93s	remaining: 50.6s
# 4000:	learn: 747.0221599	test: 4613.0498486	best: 4613.0498486 (4000)	total: 11.9s	remaining: 47.8s
# 5000:	learn: 554.0456311	test: 4601.7941506	best: 4601.7941506 (5000)	total: 14.9s	remaining: 44.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 
9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4608.359441
# bestIteration = 4370
#
# Shrink model to first 4371 iterations.
# 남은변수개수: 68
# Learning rate set to 0.007431
# 0:	learn: 8594.7271342	test: 8919.0487743	best: 8919.0487743 (0)	total: 6.08ms	remaining: 2m 1s
# 1000:	learn: 2347.2914746	test: 4754.5508347	best: 4754.0290653 (999)	total: 2.91s	remaining: 55.2s
# 2000:	learn: 1503.2981814	test: 4694.8022840	best: 4694.5372715 (1998)	total: 5.84s	remaining: 52.5s
# 3000:	learn: 1038.8724677	test: 4626.2051488	best: 4626.1906198 (2999)	total: 8.76s	remaining: 49.6s
# 4000:	learn: 737.8287528	test: 4594.5026219	best: 4594.5026219 (4000)	total: 11.7s	remaining: 46.9s
# 5000:	learn: 542.5760326	test: 4580.8157486	best: 4580.6605107 (4984)	total: 14.7s	remaining: 44s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4578.817288
# bestIteration = 5337
#
# Shrink model to first 5338 iterations.
# 남은변수개수: 67
# Learning rate set to 0.007431
# 0:	learn: 8593.3998300	test: 8910.2618375	best: 8910.2618375 (0)	total: 3.76ms	remaining: 1m 15s
# 1000:	learn: 2331.8664758	test: 4716.5823131	best: 4716.5823131 (1000)	total: 2.84s	remaining: 53.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4685.430721
# bestIteration = 1547
#
# Shrink model to first 1548 iterations.
# 남은변수개수: 66
# Learning rate set to 0.007431
# 0:	learn: 8598.8643073	test: 8924.4080826	best: 8924.4080826 (0)	total: 3.82ms	remaining: 1m 16s
# 1000:	learn: 2355.2668608	test: 4721.8714295	best: 4721.8714295 (1000)	total: 2.86s	remaining: 54.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4678.005802
# bestIteration = 1570
#
# Shrink model to first 1571 iterations.
# 남은변수개수: 65
# Learning rate set to 0.007431
# 0:	learn: 8586.6598802	test: 8908.2417207	best: 8908.2417207 (0)	total: 3.63ms	remaining: 1m 12s
# 1000:	learn: 2347.5498055	test: 4734.6028251	best: 4732.6771109 (995)	total: 2.77s	remaining: 52.6s
# 2000:	learn: 1475.6794779	test: 4667.1069808	best: 4667.0732741 (1999)	total: 5.56s	remaining: 50s
# 3000:	learn: 1020.2070988	test: 4597.9502907	best: 4597.9502907 (3000)	total: 8.35s	remaining: 47.3s
# 4000:	learn: 727.7426876	test: 4573.2256901	best: 4573.0864420 (3995)	total: 11.2s	remaining: 44.8s
# 5000:	learn: 533.4276868	test: 4561.2262985	best: 4561.2262985 (5000)	total: 14s	remaining: 42.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4558.516982
# bestIteration = 5593
#
# Shrink model to first 5594 iterations.
# 남은변수개수: 64
# Learning rate set to 0.007431
# 0:	learn: 8593.0402388	test: 8916.8366951	best: 8916.8366951 (0)	total: 20.5ms	remaining: 6m 50s
# 1000:	learn: 2344.9786624	test: 4761.1396449	best: 4760.8851065 (996)	total: 2.75s	remaining: 52.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4717.482677
# bestIteration = 1357
#
# Shrink model to first 1358 iterations.
# 남은변수개수: 63
# Learning rate set to 0.007431
# 0:	learn: 8594.3705164	test: 8915.4096896	best: 8915.4096896 (0)	total: 3.54ms	remaining: 1m 10s
# 1000:	learn: 2336.7522815	test: 4744.4303489	best: 4743.8453314 (998)	total: 2.73s	remaining: 51.8s
# 2000:	learn: 1485.5850368	test: 4649.1850425	best: 4649.1838065 (1999)	total: 5.47s	remaining: 49.2s
# 3000:	learn: 1032.5905548	test: 4581.8763573	best: 4581.8763573 (3000)	total: 8.23s	remaining: 46.6s
# 4000:	learn: 745.6241452	test: 4550.8995712	best: 4550.8995712 (4000)	total: 11s	remaining: 44s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4542.845356
# bestIteration = 4676
#
# Shrink model to first 4677 iterations.
# 남은변수개수: 62
# Learning rate set to 0.007431
# 0:	learn: 8591.9170129	test: 8908.2382100	best: 8908.2382100 (0)	total: 3.51ms	remaining: 1m 10s
# 1000:	learn: 2336.5282896	test: 4753.1206978	best: 4752.8330945 (983)	total: 2.71s	remaining: 51.4s
# 2000:	learn: 1492.2994763	test: 4681.0907454	best: 4681.0907454 (2000)	total: 5.42s	remaining: 48.7s
# 3000:	learn: 1024.9276350	test: 4611.0226819	best: 4611.0226819 (3000)	total: 8.16s	remaining: 46.3s
# 4000:	learn: 732.4714032	test: 4587.6992886	best: 4587.6537050 (3997)	total: 10.9s	remaining: 43.6s
# 5000:	learn: 532.7267537	test: 4574.9460893	best: 4574.8287267 (4991)	total: 13.6s	remaining: 40.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4572.896298
# bestIteration = 5375
#
# Shrink model to first 5376 iterations.
# 남은변수개수: 61
# Learning rate set to 0.007431
# 0:	learn: 8592.8463913	test: 8908.2412795	best: 8908.2412795 (0)	total: 14.9ms	remaining: 4m 57s
# 1000:	learn: 2375.1047281	test: 4784.1506743	best: 4784.1506743 (1000)	total: 2.66s	remaining: 50.6s
# 2000:	learn: 1516.6225032	test: 4704.5343093	best: 4704.5343093 (2000)	total: 5.34s	remaining: 48s
# 3000:	learn: 1033.8946284	test: 4646.1319714	best: 4646.0347214 (2998)	total: 7.99s	remaining: 45.3s
# 4000:	learn: 730.6545689	test: 4616.2070478	best: 4616.2070478 (4000)	total: 10.6s	remaining: 42.6s
# 5000:	learn: 531.6334486	test: 4600.4160140	best: 4600.2937661 (4990)	total: 13.3s	remaining: 39.9s
# 6000:	learn: 412.1047787	test: 4592.3381981	best: 4592.2214874 (5985)	total: 16s	remaining: 37.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4587.852115
# bestIteration = 6639
#
# Shrink model to first 6640 iterations.
# 남은변수개수: 60
# Learning rate set to 0.007431
# 0:	learn: 8591.3608677	test: 8914.7615366	best: 8914.7615366 (0)	total: 3.33ms	remaining: 1m 6s
# 1000:	learn: 2370.8927287	test: 4726.8110296	best: 4726.8110296 (1000)	total: 2.62s	remaining: 49.7s
# 2000:	learn: 1513.1701995	test: 4656.8532547	best: 4656.8499439 (1983)	total: 5.26s	remaining: 47.3s
# 3000:	learn: 1024.1732830	test: 4606.8919596	best: 4606.8565070 (2996)	total: 7.93s	remaining: 44.9s
# 4000:	learn: 757.7243660	test: 4585.8058906	best: 4585.8058906 (4000)	total: 10.6s	remaining: 42.3s
# ...
# 4000:	learn: 860.1056365	test: 4536.8541616	best: 4536.8541616 (4000)	total: 5.39s	remaining: 21.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4536.854162
# bestIteration = 4000
#
# Shrink model to first 4001 iterations.
# 남은변수개수: 25
# Learning rate set to 0.007431
# 0:	learn: 8591.8268409	test: 8914.5898503	best: 8914.5898503 (0)	total: 2.07ms	remaining: 41.4s
# 1000:	learn: 2360.8572080	test: 4711.3939298	best: 4711.3939298 (1000)	total: 1.31s	remaining: 24.9s
2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4441.440029
# bestIteration = 5607
#
# Shrink model to first 5608 iterations.
# 남은변수개수: 21
# Learning rate set to 0.007431
# 0:	learn: 8590.0867808	test: 8917.3945951	best: 8917.3945951 (0)	total: 1.98ms	remaining: 39.6s
# 1000:	learn: 2336.5144283	test: 4656.9312811	best: 4656.8749247 (999)	total: 1.21s	remaining: 22.9s
# 2000:	learn: 1609.3671243	test: 4569.4436196	best: 4569.3698106 (1998)	total: 2.39s	remaining: 21.5s
# 3000:	learn: 1196.2725319	test: 4538.2258536	best: 4538.2258536 (3000)	total: 3.59s	remaining: 20.3s
# 4000:	learn: 915.6802123	test: 4499.3942428	best: 4499.3942428 (4000)	total: 4.8s	remaining: 19.2s
# 5000:	learn: 738.0314905	test: 4482.4140632	best: 4482.2776161 (4986)	total: 6.01s	remaining: 18s
# 6000:	learn: 607.9396143	test: 4471.4971037	best: 4471.4971037 (6000)	total: 7.24s	remaining: 16.9s
# 7000:	learn: 502.0672293	test: 4465.0322112	best: 4465.0182196 (6999)	total: 8.47s	remaining: 15.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4464.8508
# bestIteration = 7008
#
# Shrink model to first 7009 iterations.
# 남은변수개수: 20
# Learning rate set to 0.007431
# 0:	learn: 8589.2140382	test: 8911.8604517	best: 8911.8604517 (0)	total: 1.8ms	remaining: 36s
# 1000:	learn: 2378.4274682	test: 4663.6507341	best: 4663.5443333 (995)	total: 1.13s	remaining: 21.5s
# 2000:	learn: 1656.7295307	test: 4558.4036788	best: 4558.4036788 (2000)	total: 2.27s	remaining: 20.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4543.314684
# bestIteration = 2218
#
# Shrink model to first 2219 iterations.
# 남은변수개수: 19
# Learning rate set to 0.007431
# 0:	learn: 8590.2673067	test: 8911.4286766	best: 8911.4286766 (0)	total: 1.77ms	remaining: 35.5s
# 1000:	learn: 2367.8764805	test: 4656.3627628	best: 4656.3450929 (999)	total: 1.14s	remaining: 21.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4637.724595
# bestIteration = 1244
#
# Shrink model to first 1245 iterations.
# 남은변수개수: 18
# Learning rate set to 0.007431
# 0:	learn: 8591.7967255	test: 8914.3060868	best: 8914.3060868 (0)	total: 1.84ms	remaining: 36.7s
# 1000:	learn: 2409.7139414	test: 4633.5516917	best: 4633.5516917 (1000)	total: 1.14s	remaining: 21.7s
# 2000:	learn: 1746.2567556	test: 4540.6105508	best: 4540.6105508 (2000)	total: 2.29s	remaining: 20.6s
# 3000:	learn: 1324.9608921	test: 4490.2279308	best: 4490.1112945 (2992)	total: 3.45s	remaining: 19.5s
# 4000:	learn: 1058.6028910	test: 4459.6081181	best: 4459.5317597 (3999)	total: 4.6s	remaining: 18.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4456.745194
# bestIteration = 4181
#
# Shrink model to first 4182 iterations.
# 남은변수개수: 17
# Learning rate set to 0.007431
# 0:	learn: 8591.4279184	test: 8917.9144710	best: 8917.9144710 (0)	total: 1.84ms	remaining: 36.8s
# 1000:	learn: 2365.7629099	test: 4582.3120920	best: 4582.3120920 (1000)	total: 1.11s	remaining: 21.2s
# 2000:	learn: 1725.2540250	test: 4435.9998468	best: 4435.8731456 (1992)	total: 2.24s	remaining: 20.2s
# 3000:	learn: 1337.6096416	test: 4384.5929866	best: 4384.4385074 (2997)	total: 3.37s	remaining: 19.1s
# 4000:	learn: 1072.8353106	test: 4359.4188446	best: 4359.0482480 (3960)	total: 4.49s	remaining: 18s
# 5000:	learn: 879.3576848	test: 4348.2241987	best: 4347.7207570 (4926)	total: 5.64s	remaining: 16.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 
5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4263.39495
# bestIteration = 9404
#
# Shrink model to first 9405 iterations.
# 남은변수개수: 13
# Learning rate set to 0.007431
# 0:	learn: 8590.5761654	test: 8909.0990926	best: 8909.0990926 (0)	total: 1.66ms	remaining: 33.2s
# 1000:	learn: 2344.0022473	test: 4495.6464965	best: 4494.9317400 (994)	total: 1.01s	remaining: 19.2s
# 2000:	learn: 1826.1866172	test: 4372.6200367	best: 4372.6200367 (2000)	total: 2.02s	remaining: 18.1s
# 3000:	learn: 1446.5252012	test: 4326.0147778	best: 4326.0147778 (3000)	total: 3.05s	remaining: 17.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4303.775587
# bestIteration = 3689
#
# Shrink model to first 3690 iterations.
# 남은변수개수: 12
# Learning rate set to 0.007431
# 0:	learn: 8587.8027281	test: 8912.0588249	best: 8912.0588249 (0)	total: 1.65ms	remaining: 33s
# 1000:	learn: 2367.8456708	test: 4566.4725659	best: 4566.3007018 (999)	total: 996ms	remaining: 18.9s
# 2000:	learn: 1842.5150915	test: 4416.5806555	best: 4416.5806555 (2000)	total: 1.97s	remaining: 17.7s
# 3000:	learn: 1452.1972914	test: 4348.8820630	best: 4348.8581922 (2999)	total: 2.99s	remaining: 17s
# 4000:	learn: 1173.5793371	test: 4316.7164691	best: 4316.3359594 (3994)	total: 4.02s	remaining: 16.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4307.75779
# bestIteration = 4524
#
# Shrink model to first 4525 iterations.
# 남은변수개수: 11
# Learning rate set to 0.007431
# 0:	learn: 8589.7926291	test: 8907.6145069	best: 8907.6145069 (0)	total: 1.62ms	remaining: 32.3s
# 1000:	learn: 2356.8505682	test: 4479.7183657	best: 4479.4282735 (995)	total: 994ms	remaining: 18.9s
# 2000:	learn: 1849.6821892	test: 4348.5302395	best: 4348.5302395 (2000)	total: 1.98s	remaining: 17.8s
# 3000:	learn: 1467.6955733	test: 4266.8428057	best: 4266.7249588 (2999)	total: 2.98s	remaining: 16.9s
# 4000:	learn: 1220.4054062	test: 4225.5212484	best: 4225.5212484 (4000)	total: 3.98s	remaining: 15.9s
# 5000:	learn: 1031.5079727	test: 4204.7891521	best: 4204.6254934 (4940)	total: 4.98s	remaining: 14.9s
# 6000:	learn: 889.0340262	test: 4192.0181525	best: 4191.6872610 (5965)	total: 6.02s	remaining: 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4191.687261
# bestIteration = 5965
#
# Shrink model to first 5966 iterations.
# 남은변수개수: 10
# Learning rate set to 0.007431
# 0:	learn: 8589.8176940	test: 8911.5155483	best: 8911.5155483 (0)	total: 1.67ms	remaining: 33.4s
# 1000:	learn: 2375.7321692	test: 4434.6178312	best: 4434.6178312 (1000)	total: 967ms	remaining: 18.4s
# 2000:	learn: 1858.7823396	test: 4294.3021349	best: 4294.3021349 (2000)	total: 1.92s	remaining: 17.3s
# 3000:	learn: 1476.4147241	test: 4230.1100635	best: 4229.7880746 (2993)	total: 2.89s	remaining: 16.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4229.297063
# bestIteration = 3033
#
# Shrink model to first 3034 iterations.
# 남은변수개수: 9
# Learning rate set to 0.007431
# 0:	learn: 8590.0880158	test: 8915.0715602	best: 8915.0715602 (0)	total: 1.45ms	remaining: 29.1s
# 1000:	learn: 2439.3937475	test: 4533.6953929	best: 4533.6953929 (1000)	total: 943ms	remaining: 17.9s
# 2000:	learn: 1899.6100740	test: 4369.3373818	best: 4369.2217912 (1996)	total: 1.9s	remaining: 17.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4328.823814
# bestIteration = 2378
#
# Shrink model to first 2379 iterations.
# 남은변수개수: 8
# Learning rate set to 0.007431
# 0:	learn: 8589.5022144	test: 8910.5389747	best: 8910.5389747 (0)	total: 1.49ms	remaining: 29.7s
# 1000:	learn: 2473.1805548	test: 4685.4392580	best: 4685.4392580 (1000)	total: 949ms	remaining: 18s
# 2000:	learn: 1936.6146092	test: 4599.5558169	best: 4599.5461710 (1998)	total: 1.89s	remaining: 17s
# 3000:	learn: 1597.3505576	test: 4529.8432479	best: 4529.6349012 (2998)	total: 2.85s	remaining: 16.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4517.125554
# bestIteration = 3378
#
# Shrink model to first 3379 iterations.
# 남은변수개수: 7
# Learning rate set to 0.007431
# 0:	learn: 8592.9090982	test: 8917.9816653	best: 8917.9816653 (0)	total: 1.49ms	remaining: 29.7s
# 1000:	learn: 2511.1267589	test: 4707.4057182	best: 4707.0773366 (999)	total: 983ms	remaining: 18.6s
# 2000:	learn: 2055.7646163	test: 4639.4932816	best: 4639.2260167 (1961)	total: 1.91s	remaining: 17.2s
# 3000:	learn: 1734.6335638	test: 4585.9726309	best: 4585.4666346 (2989)	total: 2.86s	remaining: 16.2s
# 4000:	learn: 1504.7960393	test: 4555.0968735	best: 4555.0742392 (3999)	total: 3.79s	remaining: 15.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4547.125078
# bestIteration = 4626
#
# Shrink model to first 4627 iterations.
# 남은변수개수: 6
# Learning rate set to 0.007431
# 0:	learn: 8590.6136406	test: 8916.7953611	best: 8916.7953611 (0)	total: 1.48ms	remaining: 29.6s
# 1000:	learn: 2599.7447495	test: 4736.3313543	best: 4736.2734614 (999)	total: 933ms	remaining: 17.7s
# 2000:	learn: 2126.8702128	test: 4606.2626575	best: 4606.2626575 (2000)	total: 1.86s	remaining: 16.7s
# 3000:	learn: 1831.4098662	test: 4541.2310963	best: 4541.2310963 (3000)	total: 2.79s	remaining: 15.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4526.298176
# bestIteration = 3802
#
# Shrink model to first 3803 iterations.
# 남은변수개수: 5
# Learning rate set to 0.007431
# 0:	learn: 8589.9963810	test: 8909.7280105	best: 8909.7280105 (0)	total: 1.46ms	remaining: 29.1s
# 1000:	learn: 2598.0484012	test: 4929.3999867	best: 4929.3999867 (1000)	total: 921ms	remaining: 17.5s
# 2000:	learn: 2123.0769418	test: 4838.8062028	best: 4838.8062028 (2000)	total: 1.83s	remaining: 16.5s
# 3000:	learn: 1823.5397434	test: 4774.0729677	best: 4773.8702717 (2999)	total: 2.76s	remaining: 15.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4754.965302
# bestIteration = 3834
#
# Shrink model to first 3835 iterations.
# 남은변수개수: 4
# Learning rate set to 0.007431
# 0:	learn: 8592.5236804	test: 8915.7575699	best: 8915.7575699 (0)	total: 1.44ms	remaining: 28.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 5264.156403
# bestIteration = 758
#
# Shrink model to first 759 iterations.
# 남은변수개수: 3
# Learning rate set to 0.007431
# 0:	learn: 8587.3218043	test: 8905.7596450	best: 8905.7596450 (0)	total: 1.39ms	remaining: 27.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 5648.672897
# bestIteration = 460
#
# Shrink model to first 461 iterations.
# 남은변수개수: 2
# Learning rate set to 0.007431
# 0:	learn: 8589.7781981	test: 8905.8589985	best: 8905.8589985 (0)	total: 1.39ms	remaining: 27.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 5759.657497
# bestIteration = 896
#
# Shrink model to first 897 iterations.
#      변수명  RFE순위
# 0    141    143
# 1     81    142
# 2     80    141
# 3     64    140
# 4     59    139
# ..   ...    ...
# 138   58      5
# 139  139      4
# 140    0      3
# 141  138      2
# 142  142      1
#
# [143 rows x 2 columns]

# %%
# RFE 최적변수만큼 할당
optimal_rank = 10
modeling_columns = list(ranking.loc[ranking['RFE순위'].isin([i for i in range(1, optimal_rank+1)]), '변수명'])
print(modeling_columns)
train_x2 = train_x[modeling_columns]

# 훈련
final_models, r2scores = cb_final_model(train_x2, train_y)
round(np.mean(list(r2scores.values())),4)
# Out:
# [14, 68, 60, 87, 65, 58, 139, 0, 138, 142]
# Learning rate set to 0.007522
# 0:	learn: 8598.6996538	test: 8952.3038353	best: 8952.3038353 (0)	total: 1.55ms	remaining: 31.1s
# 1000:	learn: 2433.3308726	test: 3616.7465184	best: 3616.6502537 (999)	total: 976ms	remaining: 18.5s
# 2000:	learn: 1849.7734115	test: 3424.4667928	best: 3423.8269290 (1998)	total: 1.93s	remaining: 17.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 3387.442465
# bestIteration = 2514
#
# Shrink model to first 2515 iterations.
# Learning rate set to 0.007522
# 0:	learn: 8585.3035747	test: 8993.1114917	best: 8993.1114917 (0)	total: 1.49ms	remaining: 29.9s
# 1000:	learn: 2299.7004406	test: 4343.0656144	best: 4343.0656144 (1000)	total: 979ms	remaining: 18.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4253.98811
# bestIteration = 1899
#
# Shrink model to first 1900 iterations.
# Learning rate set to 0.007522
# 0:	learn: 9134.7491342	test: 6477.4887916	best: 6477.4887916 (0)	total: 1.57ms	remaining: 31.5s
# 1000:	learn: 2376.5157210	test: 3098.5444170	best: 3097.9755596 (994)	total: 983ms	remaining: 18.6s
# 2000:	learn: 1840.6059239	test: 3067.6741837	best: 3065.1268404 (1920)	total: 1.95s	remaining: 17.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 3065.12684
# bestIteration = 1920
#
# Shrink model to first 1921 iterations.
# Learning rate set to 0.007523
# 0:	learn: 8838.7359718	test: 7952.9810993	best: 7952.9810993 (0)	total: 1.51ms	remaining: 30.3s
# 1000:	learn: 2376.7511021	test: 4098.9622050	best: 4098.9622050 (1000)	total: 996ms	remaining: 18.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 4062.507905
# bestIteration = 1377
#
# Shrink model to first 1378 iterations.
# Learning rate set to 0.007523
# 0:	learn: 8139.7079499	test: 10532.6895293	best: 10532.6895293 (0)	total: 1.58ms	remaining: 31.6s
# 1000:	learn: 2324.4644243	test: 5294.1402783	best: 5294.1402783 (1000)	total: 982ms	remaining: 18.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 5181.2465
# bestIteration = 1415
#
# Shrink model to first 1416 iterations.
# 0.7807
