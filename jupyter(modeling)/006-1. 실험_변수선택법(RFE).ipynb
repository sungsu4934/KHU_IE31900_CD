# %% [markdown]
# # 패키지 불러오기

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import xgboost as xgb

from catboost import Pool, CatBoostRegressor
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE


n_splits = 5

# %% [markdown]
# # 모델 정의
#  1. Random Forest
#  2. Lightgbm
#  3. Xgboost
#  4. Catboost
#  5. Knn
#  6. Linear regression

# %%
def Xy_split(dataset):
    
    X = dataset.drop('연봉', axis=1)
    column_dict = {f'variable{idx+1}':col for idx, col in enumerate(X.columns)}
    X = X.rename(columns = {col:f'variable{idx+1}' for idx, col in enumerate(X.columns)})
    y = dataset['연봉']
    
    return column_dict, X, y

# %% [markdown]
# # train, test분할 후 모델링

# %%
hitter = pd.read_csv('../선수데이터(전처리완료)/모델링용ver1/타자(모델링용).csv')
pitcher = pd.read_csv('../선수데이터(전처리완료)/모델링용ver1/투수(모델링용).csv')

# %% [markdown]
# #### 1. 타자

# %%
# train, test 분할
col_dict, X, y = Xy_split(hitter)

# 변수의 순위도출
model = RandomForestRegressor(random_state = 42)
selector = RFE(model, n_features_to_select = 1, step = 1)
selector = selector.fit(X, y)

# 데이터프레임으로 생성
hitter_rf = pd.DataFrame({'변수명':list(col_dict.keys()),
                  '실제변수명':list(col_dict.values()),
                  'rf순위':list(selector.ranking_)})

# %%
# train, test 분할
col_dict, X, y = Xy_split(hitter)
X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

X = X.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y = y.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

col_dict_origin = col_dict.copy()

# RFE 적용
lgb_params = {"objective" : "rmse",
             "verbosity" : -1}

remove_cols = []

while True:

    # lgbm 모델링
    lgb_dtrain = lgb.Dataset(data = X, label = y) 
    lgb_dvalid = lgb.Dataset(data = X_test, label = y_test) 

    lgb_model = lgb.train(lgb_params, lgb_dtrain, 20000, valid_sets=[lgb_dvalid], early_stopping_rounds=100, verbose_eval=1000)

    # 가장 낮은 변수들 중 1개 삭제
    remove_col = [col for col, importance in zip(list(col_dict.keys()), lgb_model.feature_importance()) if importance == min(lgb_model.feature_importance())][-1]
    remove_cols.append(remove_col)
    X.drop(remove_col, axis=1, inplace=True)
    X_test.drop(remove_col, axis=1, inplace=True)
    del col_dict[remove_col]
    
    # while문 종료조건
    if X.shape[1] == 1:
        remove_cols.append(X.columns[0])
        break

# 데이터프레임으로 생성
hitter_lgbm = pd.DataFrame({'변수명':remove_cols,
                            '실제변수명':[col_dict_origin[key] for key in remove_cols],
                            'lgbm순위':[i for i in range(len(col_dict_origin), 0, -1)]})
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's rmse: 16069.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 16099.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 16099.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 16099.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 16099.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [64]	valid_0's rmse: 16145.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [183]	valid_0's rmse: 15972.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [102]	valid_0's rmse: 16136.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	valid_0's rmse: 16111.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	valid_0's rmse: 16111.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [56]	valid_0's rmse: 16446
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [56]	valid_0's rmse: 16343.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [247]	valid_0's rmse: 16063
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [199]	valid_0's rmse: 16023.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [55]	valid_0's rmse: 16218.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [204]	valid_0's rmse: 16115.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [148]	valid_0's rmse: 15962.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [227]	valid_0's rmse: 15972.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [324]	valid_0's rmse: 16359.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [280]	valid_0's rmse: 15870.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [347]	valid_0's rmse: 16249.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [71]	valid_0's rmse: 15921
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [221]	valid_0's rmse: 15985
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [274]	valid_0's rmse: 16243.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	valid_0's rmse: 15939.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [276]	valid_0's rmse: 15859.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [210]	valid_0's rmse: 16778.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [221]	valid_0's rmse: 16369.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [60]	valid_0's rmse: 16628
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 16728.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [185]	valid_0's rmse: 16617.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [192]	valid_0's rmse: 17013.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [43]	valid_0's rmse: 16926.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [207]	valid_0's rmse: 16748.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's rmse: 17231.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [52]	valid_0's rmse: 17069.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [192]	valid_0's rmse: 16607.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [45]	valid_0's rmse: 16974.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [266]	valid_0's rmse: 16598.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [210]	valid_0's rmse: 16359.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [237]	valid_0's rmse: 16457
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [143]	valid_0's rmse: 16699.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [244]	valid_0's rmse: 16562.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's rmse: 17283.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [247]	valid_0's rmse: 17022.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [111]	valid_0's rmse: 16666.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [190]	valid_0's rmse: 16706.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [147]	valid_0's rmse: 17170.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [80]	valid_0's rmse: 17165.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [178]	valid_0's rmse: 16815.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [164]	valid_0's rmse: 16376.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [151]	valid_0's rmse: 16666.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [159]	valid_0's rmse: 16594.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [158]	valid_0's rmse: 16034
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [149]	valid_0's rmse: 16525.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [149]	valid_0's rmse: 16358
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [337]	valid_0's rmse: 16235.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [423]	valid_0's rmse: 16514.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [277]	valid_0's rmse: 16963
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [49]	valid_0's rmse: 17573.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [221]	valid_0's rmse: 16981.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [137]	valid_0's rmse: 18128.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [46]	valid_0's rmse: 18358.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	valid_0's rmse: 18671.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	valid_0's rmse: 18534.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [29]	valid_0's rmse: 18372.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [30]	valid_0's rmse: 18595.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	valid_0's rmse: 18528.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [27]	valid_0's rmse: 18613.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [22]	valid_0's rmse: 20446.4

# %%
# train, test 분할
col_dict, X, y = Xy_split(hitter)
X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

X = X.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y = y.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

col_dict_origin = col_dict.copy()

# RFE 적용
xgb_final_param = {
          "objective" : 'reg:squarederror',
          "random_state" : 42,
          "verbosity" : 0
          }

remove_cols = []

while True:
    
    print(X.shape[1])

    # xgb 모델링
    xgb_dtrain = xgb.DMatrix(data = X, label = y) 
    xgb_dvalid = xgb.DMatrix(data = X_test, label = y_test) 

    xgb_model = xgb.train(params = xgb_final_param, dtrain = xgb_dtrain, num_boost_round = 20000, early_stopping_rounds = 100, verbose_eval = 1000, evals=[(xgb_dtrain, 'train'), (xgb_dvalid,'eval')])

    # 가장 낮은 변수들 중 1개 삭제
    remove_col = sorted(xgb_model.get_score().items(),  key = lambda item: item[1])[0][0]
    remove_cols.append(remove_col)
    X.drop(remove_col, axis=1, inplace=True)
    X_test.drop(remove_col, axis=1, inplace=True)
    del col_dict[remove_col]
    
    # while문 종료조건
    if X.shape[1] == 1:
        remove_cols.append(X.columns[0])
        break

# 데이터프레임으로 생성
hitter_xgb = pd.DataFrame({'변수명':remove_cols,
                            '실제변수명':[col_dict_origin[key] for key in remove_cols],
                            'xgb순위':[i for i in range(len(col_dict_origin), 0, -1)]})
# Out:
# 85
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [116]	train-rmse:340.26849	eval-rmse:16826.00977
# 84
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [116]	train-rmse:341.34064	eval-rmse:16832.26562
# 83
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [141]	train-rmse:218.37823	eval-rmse:16831.61133
# 82
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [142]	train-rmse:214.87942	eval-rmse:16833.35938
# 81
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [233]	train-rmse:59.84266	eval-rmse:16661.29102
# 80
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [186]	train-rmse:103.28033	eval-rmse:16630.18945
# 79
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [205]	train-rmse:77.08006	eval-rmse:16638.30273
# 78
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [121]	train-rmse:327.47858	eval-rmse:16798.95312
# 77
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [143]	train-rmse:238.16538	eval-rmse:16591.86914
# 76
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [204]	train-rmse:82.33493	eval-rmse:16821.26758
# 75
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [236]	train-rmse:53.13566	eval-rmse:16725.01367
# 74
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [134]	train-rmse:244.97412	eval-rmse:16667.61914
# 73
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [133]	train-rmse:266.29828	eval-rmse:16660.75000
# 72
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [151]	train-rmse:184.22908	eval-rmse:16693.52539
# 71
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [111]	train-rmse:365.35483	eval-rmse:16920.66602
# 70
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [132]	train-rmse:253.04803	eval-rmse:16939.90820
# 69
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [178]	train-rmse:111.45666	eval-rmse:16596.95703
# 68
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [111]	train-rmse:368.47244	eval-rmse:16826.25195
# 67
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [112]	train-rmse:374.14542	eval-rmse:16887.51367
# 66
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [111]	train-rmse:407.32599	eval-rmse:16826.91406
# 65
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [112]	train-rmse:390.38983	eval-rmse:16899.34375
# 64
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [108]	train-rmse:406.19852	eval-rmse:17014.50781
# 63
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [117]	train-rmse:331.18625	eval-rmse:16713.63867
# 62
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [117]	train-rmse:369.36493	eval-rmse:16703.35547
# 61
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [147]	train-rmse:209.39841	eval-rmse:16826.37109
# 60
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [115]	train-rmse:338.25574	eval-rmse:16765.91797
# 59
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [112]	train-rmse:364.15414	eval-rmse:16847.41797
# 58
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [113]	train-rmse:397.82947	eval-rmse:16850.81445
# 57
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [109]	train-rmse:396.77948	eval-rmse:16904.86719
# 56
# [0]	train-rmse:27527.58594	eval-rmse:28039.86719
# [109]	train-rmse:387.99676	eval-rmse:16850.98047
# 55
# [0]	train-rmse:27534.69336	eval-rmse:28049.35938
# [107]	train-rmse:403.79895	eval-rmse:17107.54297
# 54
# [0]	train-rmse:27534.69336	eval-rmse:28049.35938
# [109]	train-rmse:391.58057	eval-rmse:16671.16797
# 53
# [0]	train-rmse:27535.66406	eval-rmse:28119.13477
# [107]	train-rmse:445.67047	eval-rmse:17191.34180
# 52
# [0]	train-rmse:27535.66406	eval-rmse:28119.13477
# [106]	train-rmse:412.58578	eval-rmse:17232.93164
# 51
# [0]	train-rmse:27535.66406	eval-rmse:28119.13477
# [107]	train-rmse:444.23264	eval-rmse:17321.84570
# 50
# [0]	train-rmse:27535.66406	eval-rmse:28119.13477
# [199]	train-rmse:92.64634	eval-rmse:15898.34375
# 49
# [0]	train-rmse:27536.77344	eval-rmse:28178.67773
# [148]	train-rmse:245.12369	eval-rmse:16115.27246
# 48
# [0]	train-rmse:27539.57031	eval-rmse:28185.32422
# [138]	train-rmse:263.48569	eval-rmse:16273.32227
# 47
# [0]	train-rmse:27543.47266	eval-rmse:28175.72266
# [166]	train-rmse:151.37058	eval-rmse:16165.31641
# 46
# [0]	train-rmse:27557.71484	eval-rmse:28195.87891
# [133]	train-rmse:325.32068	eval-rmse:15277.38281
# 45
# [0]	train-rmse:27557.71484	eval-rmse:28195.87891
# [128]	train-rmse:284.06378	eval-rmse:15303.07812
# 44
# [0]	train-rmse:27557.71484	eval-rmse:28195.87891
# [110]	train-rmse:374.65002	eval-rmse:15536.48340
# 43
# [0]	train-rmse:27557.71484	eval-rmse:28195.87891
# [163]	train-rmse:147.24675	eval-rmse:15111.22754
# 42
# [0]	train-rmse:27557.71484	eval-rmse:28195.87891
# [147]	train-rmse:213.20897	eval-rmse:15580.88965
# 41
# [0]	train-rmse:27557.71484	eval-rmse:28195.87891
# [180]	train-rmse:125.65493	eval-rmse:15113.08496
# 40
# [0]	train-rmse:27557.71484	eval-rmse:28195.87891
# [117]	train-rmse:340.43225	eval-rmse:15607.54785
# 39
# [0]	train-rmse:27557.71484	eval-rmse:28195.87891
# [576]	train-rmse:0.43090	eval-rmse:15260.64062
# 38
# [0]	train-rmse:27559.64453	eval-rmse:28089.55469
# [108]	train-rmse:427.77988	eval-rmse:15573.25488
# 37
# [0]	train-rmse:27562.20508	eval-rmse:28028.41211
# [132]	train-rmse:269.23413	eval-rmse:15046.76562
# 36
# [0]	train-rmse:27562.20508	eval-rmse:28028.41211
# [113]	train-rmse:375.35016	eval-rmse:15219.34668
# 35
# [0]	train-rmse:27562.20508	eval-rmse:28028.41211
# [116]	train-rmse:406.20233	eval-rmse:15280.26562
# 34
# [0]	train-rmse:27562.20508	eval-rmse:28028.41211
# [257]	train-rmse:44.71551	eval-rmse:15059.22949
# 33
# [0]	train-rmse:27562.20508	eval-rmse:28028.41211
# [166]	train-rmse:176.29657	eval-rmse:15450.93555
# 32
# [0]	train-rmse:27564.57812	eval-rmse:28042.20508
# [107]	train-rmse:435.29352	eval-rmse:15518.88379
# 31
# [0]	train-rmse:27564.57812	eval-rmse:27979.93945
# [110]	train-rmse:458.58551	eval-rmse:15055.85742
# 30
# [0]	train-rmse:27567.36719	eval-rmse:27978.13281
# [121]	train-rmse:368.03027	eval-rmse:15429.41699
# 29
# [0]	train-rmse:27590.80273	eval-rmse:28188.12891
# [124]	train-rmse:361.94135	eval-rmse:16057.30273
# 28
# [0]	train-rmse:27590.80273	eval-rmse:28188.12891
# [118]	train-rmse:402.49756	eval-rmse:15771.06250
# 27
# [0]	train-rmse:27590.85352	eval-rmse:28188.42383
# [112]	train-rmse:414.28705	eval-rmse:15545.71094
# 26
# [0]	train-rmse:27592.55273	eval-rmse:28193.50977
# [110]	train-rmse:510.93192	eval-rmse:15612.29297
# 25
# [0]	train-rmse:27592.63086	eval-rmse:28193.03516
# [108]	train-rmse:483.30649	eval-rmse:15991.98828
# 24
# [0]	train-rmse:27594.37695	eval-rmse:28207.52930
# [109]	train-rmse:473.42270	eval-rmse:15951.38965
# 23
# [0]	train-rmse:27594.37695	eval-rmse:28207.52930
# [128]	train-rmse:344.78104	eval-rmse:15492.97559
# 22
# [0]	train-rmse:27594.37695	eval-rmse:28207.52930
# [133]	train-rmse:330.82794	eval-rmse:15506.75293
# 21
# [0]	train-rmse:27642.31055	eval-rmse:28132.55078
# [122]	train-rmse:414.00116	eval-rmse:15258.77246
# 20
# [0]	train-rmse:27646.09375	eval-rmse:28100.31250
# [113]	train-rmse:472.27255	eval-rmse:16229.97461
# 19
# [0]	train-rmse:27650.79492	eval-rmse:28096.51172
# [109]	train-rmse:515.32538	eval-rmse:15956.91992
# 18
# [0]	train-rmse:27650.79492	eval-rmse:28096.51172
# [109]	train-rmse:585.95013	eval-rmse:15995.50391
# 17
# [0]	train-rmse:27651.81445	eval-rmse:28087.95312
# [126]	train-rmse:460.78104	eval-rmse:15804.84570
# 16
# [0]	train-rmse:27764.78516	eval-rmse:28630.61914
# [116]	train-rmse:563.69873	eval-rmse:15184.59180
# 15
# [0]	train-rmse:27764.78516	eval-rmse:28630.61914
# [115]	train-rmse:586.32233	eval-rmse:15663.32910
# 14
# [0]	train-rmse:27752.02148	eval-rmse:28294.84766
# [114]	train-rmse:616.70984	eval-rmse:15680.80176
# 13
# [0]	train-rmse:27752.02148	eval-rmse:28294.84766
# [110]	train-rmse:701.47199	eval-rmse:14988.66699
# 12
# [0]	train-rmse:27753.37695	eval-rmse:28348.18164
# [114]	train-rmse:736.84009	eval-rmse:14497.15723
# 11
# [0]	train-rmse:27735.94727	eval-rmse:28336.04883
# [113]	train-rmse:725.83472	eval-rmse:14990.02832
# 10
# [0]	train-rmse:27786.33984	eval-rmse:28193.32617
# [112]	train-rmse:957.87000	eval-rmse:14838.00684
# 9
# [0]	train-rmse:27848.16016	eval-rmse:28529.80078
# [109]	train-rmse:1024.46692	eval-rmse:16846.19141
# 8
# [0]	train-rmse:27848.16016	eval-rmse:28529.80078
# [110]	train-rmse:1003.32288	eval-rmse:16849.62305
# 7
# [0]	train-rmse:27903.87305	eval-rmse:28528.53125
# [110]	train-rmse:1144.42310	eval-rmse:16351.72266
# 6
# [0]	train-rmse:27961.00000	eval-rmse:28292.18555
# [109]	train-rmse:1266.46643	eval-rmse:15864.62500
# 5
# [0]	train-rmse:27968.47852	eval-rmse:28284.93945
# [110]	train-rmse:1435.46472	eval-rmse:15609.70215
# 4
# [0]	train-rmse:27929.95312	eval-rmse:28366.35156
# [111]	train-rmse:1776.58862	eval-rmse:15908.44141
# 3
# [0]	train-rmse:28031.76562	eval-rmse:28224.58789
# [128]	train-rmse:2119.26221	eval-rmse:14853.97461
# 2
# [0]	train-rmse:28336.88477	eval-rmse:28727.57031
# [110]	train-rmse:3841.89648	eval-rmse:19776.70703

# %%
# train, test 분할
col_dict, X, y = Xy_split(hitter)
X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

X = X.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y = y.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

col_dict_origin = col_dict.copy()

# RFE 적용
remove_cols = []

while True:
    
    print(X.shape[1])

    # cb 모델링
    cat_cols = []
    cb_dtrain = Pool(data=X, label=y, cat_features=cat_cols)
    cb_dvalid = Pool(data=X_test, label=y_test, cat_features=cat_cols)

    cb_model = CatBoostRegressor(iterations=20000, eval_metric='RMSE', loss_function='RMSE', verbose = 0)
    cb_model.fit(cb_dtrain, eval_set=cb_dvalid, early_stopping_rounds=100, verbose_eval=1000, use_best_model=True)
    
    # 가장 낮은 변수들 중 1개 삭제
    remove_col = [col for col, importance in zip(list(col_dict.keys()), cb_model.feature_importances_) if importance == min(cb_model.feature_importances_)][-1]
    remove_cols.append(remove_col)
    X.drop(remove_col, axis=1, inplace=True)
    X_test.drop(remove_col, axis=1, inplace=True)
    del col_dict[remove_col]
    
    # while문 종료조건
    if X.shape[1] == 1:
        remove_cols.append(X.columns[0])
        break

# 데이터프레임으로 생성
hitter_cb = pd.DataFrame({'변수명':remove_cols,
                            '실제변수명':[col_dict_origin[key] for key in remove_cols],
                            'cb순위':[i for i in range(len(col_dict_origin), 0, -1)]})
# Out:
# 85
# Learning rate set to 0.009788
# 0:	learn: 33144.2942830	test: 32448.7293867	best: 32448.7293867 (0)	total: 162ms	remaining: 53m 57s
# 1000:	learn: 8200.1371800	test: 14417.8767489	best: 14417.8767489 (1000)	total: 7.08s	remaining: 2m 14s
# 2000:	learn: 5183.7493040	test: 13834.7590057	best: 13834.7590057 (2000)	total: 14s	remaining: 2m 5s
# 3000:	learn: 3680.4705635	test: 13603.3988834	best: 13603.3988834 (3000)	total: 21s	remaining: 1m 58s
# 4000:	learn: 2691.8876817	test: 13504.4838907	best: 13503.2596307 (3954)	total: 28.1s	remaining: 1m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13503.25963
# bestIteration = 3954
#
# Shrink model to first 3955 iterations.
# 84
# Learning rate set to 0.009788
# 0:	learn: 33104.5931387	test: 32357.9473044	best: 32357.9473044 (0)	total: 31.2ms	remaining: 10m 23s
# 1000:	learn: 8303.2371684	test: 14216.8675655	best: 14213.3078089 (995)	total: 7.07s	remaining: 2m 14s
# 2000:	learn: 5277.6373078	test: 13615.8258086	best: 13615.8258086 (2000)	total: 14s	remaining: 2m 5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13474.18395
# bestIteration = 2740
#
# Shrink model to first 2741 iterations.
# 83
# Learning rate set to 0.009788
# 0:	learn: 33138.7297454	test: 32395.1554381	best: 32395.1554381 (0)	total: 28.9ms	remaining: 9m 38s
# 1000:	learn: 8217.1321836	test: 14310.5479516	best: 14310.5479516 (1000)	total: 7.06s	remaining: 2m 14s
# 2000:	learn: 5243.8802685	test: 13846.7652434	best: 13845.8694213 (1997)	total: 14s	remaining: 2m 5s
# 3000:	learn: 3641.4597523	test: 13576.8003564	best: 13576.8003564 (3000)	total: 20.9s	remaining: 1m 58s
# 4000:	learn: 2716.6863089	test: 13466.2065295	best: 13465.9200414 (3998)	total: 27.9s	remaining: 1m 51s
# 5000:	learn: 2094.8918560	test: 13417.8717048	best: 13417.2824849 (4992)	total: 34.9s	remaining: 1m 44s
# 6000:	learn: 1637.8754732	test: 13377.4545839	best: 13377.3028939 (5966)	total: 41.9s	remaining: 1m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13371.93263
# bestIteration = 6246
#
# Shrink model to first 6247 iterations.
# 82
# Learning rate set to 0.009788
# 0:	learn: 33109.3155481	test: 32383.4621062	best: 32383.4621062 (0)	total: 23.7ms	remaining: 7m 54s
# 1000:	learn: 8257.8661849	test: 14157.3933701	best: 14157.3933701 (1000)	total: 7.01s	remaining: 2m 13s
# 2000:	learn: 5254.1999459	test: 13600.4470533	best: 13600.1901279 (1995)	total: 14s	remaining: 2m 5s
# 3000:	learn: 3703.1892127	test: 13381.1691673	best: 13379.2884171 (2988)	total: 21s	remaining: 1m 58s
# 4000:	learn: 2666.6576884	test: 13284.2016490	best: 13283.5222080 (3929)	total: 27.9s	remaining: 1m 51s
# 5000:	learn: 2079.7775668	test: 13204.6737485	best: 13204.6737485 (5000)	total: 35.4s	remaining: 1m 46s
# 6000:	learn: 1637.2680765	test: 13179.0087449	best: 13178.5764663 (5986)	total: 43.6s	remaining: 1m 41s
# 7000:	learn: 1311.6193670	test: 13159.1427295	best: 13158.9697772 (6996)	total: 52s	remaining: 1m 36s
# 8000:	learn: 1061.5613474	test: 13150.5525790	best: 13150.3061370 (7939)	total: 59.3s	remaining: 1m 28s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13149.59372
# bestIteration = 8043
#
# Shrink model to first 8044 iterations.
# 81
# Learning rate set to 0.009788
# 0:	learn: 33105.4692267	test: 32356.7059000	best: 32356.7059000 (0)	total: 38.8ms	remaining: 12m 55s
# 1000:	learn: 8329.8949484	test: 14212.8174753	best: 14211.9265536 (999)	total: 7.01s	remaining: 2m 12s
# 2000:	learn: 5354.4989185	test: 13598.8135679	best: 13598.1228489 (1997)	total: 14s	remaining: 2m 5s
# 3000:	learn: 3685.3505885	test: 13336.1072132	best: 13335.2734052 (2977)	total: 21.1s	remaining: 1m 59s
# 4000:	learn: 2769.3282599	test: 13252.1351348	best: 13250.6047979 (3985)	total: 28.8s	remaining: 1m 55s
# 5000:	learn: 2109.5970003	test: 13190.9182765	best: 13190.0946718 (4942)	total: 36.2s	remaining: 1m 48s
# 6000:	learn: 1664.9875508	test: 13151.7043241	best: 13151.7043241 (6000)	total: 43.2s	remaining: 1m 40s
# 7000:	learn: 1345.4917394	test: 13126.2589805	best: 13126.2589805 (7000)	total: 50.2s	remaining: 1m 33s
# 8000:	learn: 1090.7685732	test: 13114.6129606	best: 13114.5087303 (7998)	total: 57.2s	remaining: 1m 25s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13111.467
# bestIteration = 8230
#
# Shrink model to first 8231 iterations.
# 80
# Learning rate set to 0.009788
# 0:	learn: 33106.9116647	test: 32400.6680121	best: 32400.6680121 (0)	total: 25ms	remaining: 8m 19s
# 1000:	learn: 8222.8308710	test: 14240.1231122	best: 14237.9027287 (997)	total: 7.17s	remaining: 2m 16s
# 2000:	learn: 5225.3507880	test: 13657.2588679	best: 13657.2588679 (2000)	total: 14.4s	remaining: 2m 9s
# 3000:	learn: 3691.1348223	test: 13465.1885481	best: 13465.1885481 (3000)	total: 21.8s	remaining: 2m 3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13462.41854
# bestIteration = 3040
#
# Shrink model to first 3041 iterations.
# 79
# Learning rate set to 0.009788
# 0:	learn: 33108.2157061	test: 32389.5604121	best: 32389.5604121 (0)	total: 37.5ms	remaining: 12m 29s
# 1000:	learn: 8189.7972484	test: 14192.4994633	best: 14192.4994633 (1000)	total: 7.11s	remaining: 2m 14s
# 2000:	learn: 5195.2636339	test: 13622.5378752	best: 13622.5378752 (2000)	total: 14s	remaining: 2m 6s
# 3000:	learn: 3699.4261084	test: 13413.2142826	best: 13413.2142826 (3000)	total: 21s	remaining: 1m 59s
# 4000:	learn: 2746.1034598	test: 13312.7323204	best: 13312.1909324 (3979)	total: 28.1s	remaining: 1m 52s
# 5000:	learn: 2120.7513377	test: 13257.5993734	best: 13257.3974287 (4995)	total: 35s	remaining: 1m 45s
# 6000:	learn: 1684.2761952	test: 13220.4045853	best: 13220.3994728 (5980)	total: 42.3s	remaining: 1m 38s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13218.73769
# bestIteration = 6092
#
# Shrink model to first 6093 iterations.
# 78
# Learning rate set to 0.009788
# 0:	learn: 33107.4685504	test: 32412.9862796	best: 32412.9862796 (0)	total: 32ms	remaining: 10m 39s
# 1000:	learn: 8233.5001067	test: 14250.6009664	best: 14250.6009664 (1000)	total: 7.66s	remaining: 2m 25s
# 2000:	learn: 5258.1759587	test: 13483.5205925	best: 13482.8354876 (1999)	total: 14.8s	remaining: 2m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13307.06178
# bestIteration = 2840
#
# Shrink model to first 2841 iterations.
# 77
# Learning rate set to 0.009788
# 0:	learn: 33118.1019645	test: 32403.2462382	best: 32403.2462382 (0)	total: 39.5ms	remaining: 13m 10s
# 1000:	learn: 8228.6225971	test: 14266.8297012	best: 14266.8297012 (1000)	total: 9.01s	remaining: 2m 51s
# 2000:	learn: 5257.3165772	test: 13707.3849742	best: 13707.2901887 (1999)	total: 18.1s	remaining: 2m 42s
# 3000:	learn: 3702.4028612	test: 13553.3228657	best: 13552.3068923 (2997)	total: 25.4s	remaining: 2m 24s
# 4000:	learn: 2705.3822260	test: 13468.2988635	best: 13468.2988635 (4000)	total: 33s	remaining: 2m 11s
# 5000:	learn: 2161.3469827	test: 13422.9847074	best: 13422.7406396 (4997)	total: 40.1s	remaining: 2m
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13410.67961
# bestIteration = 5264
#
# Shrink model to first 5265 iterations.
# 76
# Learning rate set to 0.009788
# 0:	learn: 33114.6023321	test: 32402.0636143	best: 32402.0636143 (0)	total: 32.4ms	remaining: 10m 47s
# 1000:	learn: 8282.1672915	test: 14223.6618040	best: 14223.6618040 (1000)	total: 6.95s	remaining: 2m 11s
# 2000:	learn: 5184.8192954	test: 13604.3862217	best: 13602.1584940 (1995)	total: 14.1s	remaining: 2m 6s
# 3000:	learn: 3673.0598692	test: 13427.6994028	best: 13427.4217324 (2997)	total: 21.6s	remaining: 2m 2s
# 4000:	learn: 2736.9347389	test: 13329.8727165	best: 13329.8727165 (4000)	total: 29.4s	remaining: 1m 57s
# 5000:	learn: 2162.3202984	test: 13285.8526940	best: 13285.8526940 (5000)	total: 36.2s	remaining: 1m 48s
# 6000:	learn: 1723.9541358	test: 13253.4831527	best: 13253.4831527 (6000)	total: 43.2s	remaining: 1m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13246.34556
# bestIteration = 6183
#
# Shrink model to first 6184 iterations.
# 75
# Learning rate set to 0.009788
# 0:	learn: 33117.6764369	test: 32418.8636163	best: 32418.8636163 (0)	total: 39.7ms	remaining: 13m 14s
# 1000:	learn: 8249.8972138	test: 14441.7352197	best: 14441.7352197 (1000)	total: 8.58s	remaining: 2m 42s
# 2000:	learn: 5125.7727965	test: 13883.2495755	best: 13883.2495755 (2000)	total: 16.3s	remaining: 2m 26s
# 3000:	learn: 3629.9291062	test: 13685.5283350	best: 13685.5283350 (3000)	total: 23.9s	remaining: 2m 15s
# 4000:	learn: 2737.5750223	test: 13574.5060609	best: 13574.5060609 (4000)	total: 31.8s	remaining: 2m 7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13562.43166
# bestIteration = 4291
#
# Shrink model to first 4292 iterations.
# 74
# Learning rate set to 0.009788
# 0:	learn: 33120.4250300	test: 32413.9475056	best: 32413.9475056 (0)	total: 38.7ms	remaining: 12m 54s
# 1000:	learn: 8253.3911501	test: 14387.4589338	best: 14387.4589338 (1000)	total: 7.6s	remaining: 2m 24s
# 2000:	learn: 5260.3092049	test: 13841.7248330	best: 13841.6440785 (1996)	total: 15.3s	remaining: 2m 17s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13672.58394
# bestIteration = 2735
#
# Shrink model to first 2736 iterations.
# 73
# Learning rate set to 0.009788
# 0:	learn: 33121.0200567	test: 32407.0489957	best: 32407.0489957 (0)	total: 26.4ms	remaining: 8m 47s
# 1000:	learn: 8180.4309552	test: 14330.8422481	best: 14329.2128343 (997)	total: 8.27s	remaining: 2m 36s
# 2000:	learn: 5253.8329180	test: 13745.4455137	best: 13745.1886620 (1998)	total: 16.7s	remaining: 2m 29s
# 3000:	learn: 3808.1895615	test: 13563.2176296	best: 13561.8999979 (2996)	total: 25s	remaining: 2m 21s
# 4000:	learn: 2839.0872633	test: 13459.5997217	best: 13459.5622640 (3998)	total: 33.5s	remaining: 2m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13446.88602
# bestIteration = 4442
#
# Shrink model to first 4443 iterations.
# 72
# Learning rate set to 0.009788
# 0:	learn: 33109.1172696	test: 32359.9306260	best: 32359.9306260 (0)	total: 27.7ms	remaining: 9m 14s
# 1000:	learn: 8288.0130936	test: 14394.2720820	best: 14394.2720820 (1000)	total: 8.48s	remaining: 2m 41s
# 2000:	learn: 5358.6013044	test: 13826.9330642	best: 13826.8732871 (1999)	total: 16.7s	remaining: 2m 30s
# 3000:	learn: 3867.7703629	test: 13651.3169819	best: 13650.8575327 (2976)	total: 25.2s	remaining: 2m 22s
# 4000:	learn: 2909.8641163	test: 13543.5333791	best: 13543.1006026 (3985)	total: 33.2s	remaining: 2m 12s
# 5000:	learn: 2284.0116696	test: 13487.8871337	best: 13487.7819686 (4996)	total: 40.7s	remaining: 2m 2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13465.79079
# bestIteration = 5636
#
# Shrink model to first 5637 iterations.
# 71
# Learning rate set to 0.009788
# 0:	learn: 33130.2833056	test: 32426.0018406	best: 32426.0018406 (0)	total: 28.5ms	remaining: 9m 30s
# 1000:	learn: 8295.7177469	test: 14361.5632559	best: 14361.5632559 (1000)	total: 6.93s	remaining: 2m 11s
# 2000:	learn: 5269.7446881	test: 13755.8624522	best: 13755.4478935 (1995)	total: 13.7s	remaining: 2m 2s
# 3000:	learn: 3704.0474230	test: 13562.4560019	best: 13561.1247087 (2997)	total: 20.5s	remaining: 1m 55s
# 4000:	learn: 2770.8294063	test: 13443.3518628	best: 13443.3223027 (3999)	total: 27.4s	remaining: 1m 49s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13413.93315
# bestIteration = 4594
#
# Shrink model to first 4595 iterations.
# 70
# Learning rate set to 0.009788
# 0:	learn: 33123.5421810	test: 32418.5474067	best: 32418.5474067 (0)	total: 25.3ms	remaining: 8m 26s
# 1000:	learn: 8295.2792476	test: 14242.6285045	best: 14242.6285045 (1000)	total: 6.93s	remaining: 2m 11s
# 2000:	learn: 5165.2599842	test: 13685.3493917	best: 13685.3493917 (2000)	total: 13.7s	remaining: 2m 3s
# 3000:	learn: 3702.7813720	test: 13479.6038512	best: 13479.2570400 (2997)	total: 20.5s	remaining: 1m 55s
# 4000:	learn: 2756.0624948	test: 13399.1836510	best: 13399.1836510 (4000)	total: 27.4s	remaining: 1m 49s
# 5000:	learn: 2143.5152722	test: 13341.5076750	best: 13341.1442502 (4961)	total: 34.3s	remaining: 1m 42s
# 6000:	learn: 1702.9885404	test: 13320.6541005	best: 13319.2625052 (5956)	total: 41.1s	remaining: 1m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13319.26251
# bestIteration = 5956
#
# Shrink model to first 5957 iterations.
# 69
# Learning rate set to 0.009788
# 0:	learn: 33138.2700085	test: 32441.1602871	best: 32441.1602871 (0)	total: 31.4ms	remaining: 10m 28s
# 1000:	learn: 8212.2913604	test: 14410.9496353	best: 14410.9496353 (1000)	total: 6.85s	remaining: 2m 9s
# 2000:	learn: 5225.5573219	test: 13855.7365582	best: 13855.3327861 (1998)	total: 13.7s	remaining: 2m 2s
# 3000:	learn: 3750.0035985	test: 13680.8067005	best: 13680.8067005 (3000)	total: 20.6s	remaining: 1m 56s
# 4000:	learn: 2829.6980788	test: 13608.9511052	best: 13608.5927981 (3998)	total: 27.5s	remaining: 1m 49s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13577.07316
# bestIteration = 4684
#
# Shrink model to first 4685 iterations.
# 68
# Learning rate set to 0.009788
# 0:	learn: 33132.1855102	test: 32415.8003922	best: 32415.8003922 (0)	total: 31.4ms	remaining: 10m 28s
# 1000:	learn: 8335.1952319	test: 14463.4534935	best: 14463.3185563 (999)	total: 6.81s	remaining: 2m 9s
# 2000:	learn: 5315.4887242	test: 13857.4915558	best: 13856.6560415 (1998)	total: 13.6s	remaining: 2m 2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13765.34125
# bestIteration = 2410
#
# Shrink model to first 2411 iterations.
# 67
# Learning rate set to 0.009788
# 0:	learn: 33107.5140133	test: 32401.5064682	best: 32401.5064682 (0)	total: 23.8ms	remaining: 7m 56s
# 1000:	learn: 8304.4339693	test: 14322.9131817	best: 14322.9131817 (1000)	total: 6.8s	remaining: 2m 9s
# 2000:	learn: 5241.1762529	test: 13730.7884536	best: 13730.7884536 (2000)	total: 13.6s	remaining: 2m 2s
# 3000:	learn: 3770.5694498	test: 13506.9176443	best: 13506.2575028 (2997)	total: 21.2s	remaining: 2m
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13422.88214
# bestIteration = 3721
#
# Shrink model to first 3722 iterations.
# 66
# Learning rate set to 0.009788
# 0:	learn: 33144.8778745	test: 32453.0400736	best: 32453.0400736 (0)	total: 29.6ms	remaining: 9m 51s
# 1000:	learn: 8204.0314231	test: 14302.5495824	best: 14302.5495824 (1000)	total: 7.12s	remaining: 2m 15s
# 2000:	learn: 5234.8105057	test: 13655.0031071	best: 13654.2964373 (1997)	total: 14s	remaining: 2m 5s
# 3000:	learn: 3694.3663399	test: 13469.8325482	best: 13465.4674683 (2910)	total: 20.9s	remaining: 1m 58s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13465.46747
# bestIteration = 2910
#
# Shrink model to first 2911 iterations.
# 65
# Learning rate set to 0.009788
# 0:	learn: 33129.0749510	test: 32414.7223967	best: 32414.7223967 (0)	total: 25.4ms	remaining: 8m 27s
# 1000:	learn: 8277.8714817	test: 14474.0897809	best: 14473.4596156 (998)	total: 6.84s	remaining: 2m 9s
# 2000:	learn: 5316.4877605	test: 13894.6480362	best: 13892.8414405 (1975)	total: 13.6s	remaining: 2m 2s
# 3000:	learn: 3750.2904254	test: 13688.1606342	best: 13688.1606342 (3000)	total: 20.4s	remaining: 1m 55s
# 4000:	learn: 2796.6268254	test: 13587.4364222	best: 13587.0454248 (3965)	total: 27.3s	remaining: 1m 49s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13572.07171
# bestIteration = 4211
#
# Shrink model to first 4212 iterations.
# 64
# Learning rate set to 0.009788
# 0:	learn: 33133.6952270	test: 32433.6306263	best: 32433.6306263 (0)	total: 36.7ms	remaining: 12m 14s
# 1000:	learn: 8346.9142535	test: 14407.4795498	best: 14407.4795498 (1000)	total: 6.79s	remaining: 2m 8s
# 2000:	learn: 5310.3129886	test: 13801.6427324	best: 13801.6427324 (2000)	total: 13.6s	remaining: 2m 2s
# 3000:	learn: 3726.9798322	test: 13614.4130022	best: 13613.6858953 (2997)	total: 20.4s	remaining: 1m 55s
# 4000:	learn: 2836.0530731	test: 13516.3112843	best: 13516.3112843 (4000)	total: 27.1s	remaining: 1m 48s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13482.26759
# bestIteration = 4825
#
# Shrink model to first 4826 iterations.
# 63
# Learning rate set to 0.009788
# 0:	learn: 33117.8521427	test: 32393.8704835	best: 32393.8704835 (0)	total: 25.9ms	remaining: 8m 37s
# 1000:	learn: 8258.6483424	test: 14481.1633392	best: 14481.1633392 (1000)	total: 6.85s	remaining: 2m 10s
# 2000:	learn: 5253.6899901	test: 13767.8106733	best: 13767.4442769 (1999)	total: 13.7s	remaining: 2m 3s
# 3000:	learn: 3765.1350115	test: 13616.0512504	best: 13615.4094024 (2971)	total: 20.5s	remaining: 1m 56s
# 4000:	learn: 2811.3241168	test: 13526.0613327	best: 13526.0613327 (4000)	total: 27.3s	remaining: 1m 49s
# 5000:	learn: 2171.9703280	test: 13471.8240673	best: 13471.8240673 (5000)	total: 34.1s	remaining: 1m 42s
# 6000:	learn: 1721.0758407	test: 13430.5405758	best: 13429.5307862 (5982)	total: 40.9s	remaining: 1m 35s
# 7000:	learn: 1399.5444384	test: 13410.9651143	best: 13410.6304761 (6916)	total: 47.8s	remaining: 1m 28s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13410.63048
# bestIteration = 6916
#
# Shrink model to first 6917 iterations.
# 62
# Learning rate set to 0.009788
# 0:	learn: 33119.8458259	test: 32408.6834095	best: 32408.6834095 (0)	total: 39.1ms	remaining: 13m 2s
# 1000:	learn: 8234.3961695	test: 14324.9865314	best: 14324.9865314 (1000)	total: 6.75s	remaining: 2m 8s
# 2000:	learn: 5220.6293922	test: 13644.3321593	best: 13644.3321593 (2000)	total: 13.5s	remaining: 2m 1s
# 3000:	learn: 3781.1488741	test: 13478.3113348	best: 13477.8809161 (2991)	total: 20.3s	remaining: 1m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13419.99089
# bestIteration = 3472
#
# Shrink model to first 3473 iterations.
# 61
# Learning rate set to 0.009788
# 0:	learn: 33119.6176326	test: 32375.4374696	best: 32375.4374696 (0)	total: 26.9ms	remaining: 8m 58s
# 1000:	learn: 8359.0547309	test: 14209.4253438	best: 14209.4253438 (1000)	total: 6.81s	remaining: 2m 9s
# 2000:	learn: 5300.0700812	test: 13640.7799976	best: 13640.7570434 (1999)	total: 13.6s	remaining: 2m 2s
# 3000:	learn: 3801.8153329	test: 13445.1957372	best: 13444.2465527 (2979)	total: 20.3s	remaining: 1m 55s
# 4000:	learn: 2868.6115445	test: 13397.5472941	best: 13397.5472941 (4000)	total: 27.1s	remaining: 1m 48s
# 5000:	learn: 2201.5412406	test: 13348.8174812	best: 13348.6678710 (4999)	total: 34s	remaining: 1m 41s
# 6000:	learn: 1729.1431334	test: 13314.0203251	best: 13314.0203251 (6000)	total: 40.9s	remaining: 1m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13291.74147
# bestIteration = 6810
#
# Shrink model to first 6811 iterations.
# 60
# Learning rate set to 0.009788
# 0:	learn: 33117.9473446	test: 32414.7266838	best: 32414.7266838 (0)	total: 29.6ms	remaining: 9m 52s
# 1000:	learn: 8231.0937665	test: 14336.9726614	best: 14336.9726614 (1000)	total: 6.62s	remaining: 2m 5s
# 2000:	learn: 5319.4102561	test: 13781.7646551	best: 13781.7646551 (2000)	total: 13.2s	remaining: 1m 58s
# 3000:	learn: 3828.9499602	test: 13519.2087445	best: 13518.5794426 (2992)	total: 19.8s	remaining: 1m 52s
# 4000:	learn: 2871.9915576	test: 13445.7942777	best: 13445.7825398 (3992)	total: 26.5s	remaining: 1m 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13395.29745
# bestIteration = 4773
#
# Shrink model to first 4774 iterations.
# 59
# Learning rate set to 0.009788
# 0:	learn: 33137.2131974	test: 32423.4350086	best: 32423.4350086 (0)	total: 38.3ms	remaining: 12m 45s
# 1000:	learn: 8290.6595517	test: 14289.3489579	best: 14288.9244506 (999)	total: 6.68s	remaining: 2m 6s
# 2000:	learn: 5302.1378314	test: 13716.0098418	best: 13716.0098418 (2000)	total: 13.3s	remaining: 1m 59s
# 3000:	learn: 3752.6717875	test: 13491.0209192	best: 13490.9743391 (2999)	total: 20s	remaining: 1m 53s
# 4000:	learn: 2818.3207061	test: 13425.8243363	best: 13424.9563688 (3979)	total: 26.7s	remaining: 1m 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13423.32048
# bestIteration = 4049
#
# Shrink model to first 4050 iterations.
# 58
# Learning rate set to 0.009788
# 0:	learn: 33115.7544388	test: 32409.2941687	best: 32409.2941687 (0)	total: 35.2ms	remaining: 11m 43s
# 1000:	learn: 8234.7981924	test: 14504.7633812	best: 14504.7633812 (1000)	total: 6.59s	remaining: 2m 5s
# 2000:	learn: 5368.5900652	test: 14006.7821427	best: 14006.0900966 (1992)	total: 13.1s	remaining: 1m 58s
# 3000:	learn: 3762.7416102	test: 13807.1605830	best: 13806.0286779 (2980)	total: 20.3s	remaining: 1m 55s
# 4000:	learn: 2848.4516860	test: 13732.9889643	best: 13732.3592575 (3986)	total: 27.6s	remaining: 1m 50s
# 5000:	learn: 2164.1660600	test: 13669.5284645	best: 13669.5284645 (5000)	total: 34.2s	remaining: 1m 42s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13663.73581
# bestIteration = 5357
#
# Shrink model to first 5358 iterations.
# 57
# Learning rate set to 0.009788
# 0:	learn: 33103.2442628	test: 32361.4521248	best: 32361.4521248 (0)	total: 21.6ms	remaining: 7m 12s
# 1000:	learn: 8260.9603470	test: 14350.0101955	best: 14347.7555027 (998)	total: 6.34s	remaining: 2m
# 2000:	learn: 5232.7143221	test: 13721.2059797	best: 13720.6909841 (1997)	total: 12.6s	remaining: 1m 53s
# 3000:	learn: 3736.2853597	test: 13549.8197103	best: 13549.8197103 (3000)	total: 19s	remaining: 1m 47s
# 4000:	learn: 2803.7255475	test: 13482.4276588	best: 13482.4276588 (4000)	total: 25.3s	remaining: 1m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13455.33841
# bestIteration = 4629
#
# Shrink model to first 4630 iterations.
# 56
# Learning rate set to 0.009788
# 0:	learn: 33133.1156410	test: 32424.8877726	best: 32424.8877726 (0)	total: 35.2ms	remaining: 11m 43s
# 1000:	learn: 8307.5923434	test: 14304.6769927	best: 14304.5511564 (999)	total: 6.36s	remaining: 2m
# 2000:	learn: 5292.6004235	test: 13749.0756080	best: 13747.6962913 (1996)	total: 12.9s	remaining: 1m 55s
# 3000:	learn: 3828.2173416	test: 13587.0239865	best: 13587.0239865 (3000)	total: 19.2s	remaining: 1m 48s
# 4000:	learn: 2829.3160561	test: 13516.0802368	best: 13516.0802368 (4000)	total: 25.7s	remaining: 1m 42s
# 5000:	learn: 2164.5323063	test: 13486.2222444	best: 13485.0217288 (4974)	total: 32.1s	remaining: 1m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13485.02173
# bestIteration = 4974
#
# Shrink model to first 4975 iterations.
# 55
# Learning rate set to 0.009788
# 0:	learn: 33121.5040142	test: 32371.6214254	best: 32371.6214254 (0)	total: 32.7ms	remaining: 10m 53s
# 1000:	learn: 8160.2689410	test: 14308.9924616	best: 14308.5851247 (998)	total: 6.25s	remaining: 1m 58s
# 2000:	learn: 5176.4885121	test: 13766.9659573	best: 13766.3604366 (1995)	total: 12.4s	remaining: 1m 51s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13622.03669
# bestIteration = 2609
#
# Shrink model to first 2610 iterations.
# 54
# Learning rate set to 0.009788
# 0:	learn: 33131.3622716	test: 32428.7556167	best: 32428.7556167 (0)	total: 12.4ms	remaining: 4m 8s
# 1000:	learn: 8297.9246839	test: 14388.9493150	best: 14388.9493150 (1000)	total: 6.27s	remaining: 1m 59s
# 2000:	learn: 5428.2424260	test: 13904.2339173	best: 13903.3683962 (1998)	total: 12.5s	remaining: 1m 52s
# 3000:	learn: 3761.1567733	test: 13676.6675234	best: 13676.4318858 (2996)	total: 18.8s	remaining: 1m 46s
# 4000:	learn: 2769.2017749	test: 13600.7769302	best: 13600.2022656 (3988)	total: 28s	remaining: 1m 51s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13578.48328
# bestIteration = 4520
#
# Shrink model to first 4521 iterations.
# 53
# Learning rate set to 0.009788
# 0:	learn: 33121.0583620	test: 32403.5283451	best: 32403.5283451 (0)	total: 10.3ms	remaining: 3m 26s
# 1000:	learn: 8310.0430550	test: 14355.5085801	best: 14355.0549157 (999)	total: 6.63s	remaining: 2m 5s
# 2000:	learn: 5334.3210078	test: 13797.8796782	best: 13797.8796782 (2000)	total: 13.2s	remaining: 1m 59s
# 3000:	learn: 3730.2405464	test: 13610.8108078	best: 13608.6613223 (2947)	total: 19.8s	remaining: 1m 52s
# 4000:	learn: 2762.0323815	test: 13519.6612229	best: 13518.3442772 (3988)	total: 26.7s	remaining: 1m 46s
# 5000:	learn: 2121.9907308	test: 13475.2088036	best: 13473.9862892 (4988)	total: 33.4s	remaining: 1m 40s
# 6000:	learn: 1677.7218007	test: 13440.7730122	best: 13440.7317299 (5999)	total: 39.7s	remaining: 1m 32s
# 7000:	learn: 1349.7917031	test: 13414.9897921	best: 13414.8770014 (6995)	total: 46s	remaining: 1m 25s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13413.22473
# bestIteration = 7157
#
# Shrink model to first 7158 iterations.
# 52
# Learning rate set to 0.009788
# 0:	learn: 33114.8757165	test: 32365.2997732	best: 32365.2997732 (0)	total: 32.8ms	remaining: 10m 56s
# 1000:	learn: 8159.2993651	test: 14342.3001205	best: 14340.3954467 (994)	total: 6.3s	remaining: 1m 59s
# 2000:	learn: 5371.7615969	test: 13830.7766310	best: 13830.7766310 (2000)	total: 12.5s	remaining: 1m 52s
# 3000:	learn: 3880.3617936	test: 13628.7885564	best: 13627.6812041 (2956)	total: 18.7s	remaining: 1m 45s
# 4000:	learn: 2872.7914874	test: 13561.1958927	best: 13560.9304389 (3986)	total: 24.9s	remaining: 1m 39s
# 5000:	learn: 2196.1446026	test: 13485.3764797	best: 13485.2807014 (4995)	total: 31.1s	remaining: 1m 33s
# 6000:	learn: 1724.0424759	test: 13452.2948145	best: 13451.7615642 (5974)	total: 37.4s	remaining: 1m 27s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13445.46446
# bestIteration = 6367
#
# Shrink model to first 6368 iterations.
# 51
# Learning rate set to 0.009788
# 0:	learn: 33113.8692349	test: 32389.0873500	best: 32389.0873500 (0)	total: 23.5ms	remaining: 7m 50s
# 1000:	learn: 8270.5232275	test: 14247.9127032	best: 14247.0657786 (998)	total: 6.19s	remaining: 1m 57s
# 2000:	learn: 5407.6204977	test: 13692.4945783	best: 13692.4630551 (1999)	total: 12.3s	remaining: 1m 50s
# 3000:	learn: 3865.9883099	test: 13449.6076186	best: 13448.6897008 (2997)	total: 18.4s	remaining: 1m 44s
# 4000:	learn: 2881.1802963	test: 13307.5511112	best: 13307.4394948 (3998)	total: 24.5s	remaining: 1m 38s
# 5000:	learn: 2223.1625426	test: 13262.7253206	best: 13262.7253206 (5000)	total: 30.7s	remaining: 1m 32s
# 6000:	learn: 1765.8255678	test: 13224.0698512	best: 13224.0698512 (6000)	total: 37s	remaining: 1m 26s
# 7000:	learn: 1417.5819715	test: 13201.5206248	best: 13201.4060552 (6996)	total: 43.1s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13189.55067
# bestIteration = 7657
#
# Shrink model to first 7658 iterations.
# 50
# Learning rate set to 0.009788
# 0:	learn: 33115.1541261	test: 32375.2596860	best: 32375.2596860 (0)	total: 15.2ms	remaining: 5m 3s
# 1000:	learn: 8213.8076136	test: 14227.5930064	best: 14227.2702783 (998)	total: 6.05s	remaining: 1m 54s
# 2000:	learn: 5352.1720336	test: 13761.7926936	best: 13761.6783463 (1984)	total: 12.2s	remaining: 1m 49s
# 3000:	learn: 3713.7805207	test: 13528.3887328	best: 13528.3887328 (3000)	total: 18.6s	remaining: 1m 45s
# 4000:	learn: 2799.7752328	test: 13395.5731276	best: 13394.9049220 (3994)	total: 24.7s	remaining: 1m 38s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13369.51508
# bestIteration = 4480
#
# Shrink model to first 4481 iterations.
# 49
# Learning rate set to 0.009788
# 0:	learn: 33098.4604135	test: 32389.3499349	best: 32389.3499349 (0)	total: 9.31ms	remaining: 3m 6s
# 1000:	learn: 8196.7093492	test: 14536.4150634	best: 14536.4150634 (1000)	total: 5.86s	remaining: 1m 51s
# 2000:	learn: 5337.2638495	test: 14051.8078210	best: 14051.8078210 (2000)	total: 11.8s	remaining: 1m 45s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13903.82926
# bestIteration = 2527
#
# Shrink model to first 2528 iterations.
# 48
# Learning rate set to 0.009788
# 0:	learn: 33133.4324094	test: 32406.0935877	best: 32406.0935877 (0)	total: 10ms	remaining: 3m 20s
# 1000:	learn: 8260.3099155	test: 14401.2547089	best: 14400.4811649 (992)	total: 5.88s	remaining: 1m 51s
# 2000:	learn: 5412.0156766	test: 13886.0130068	best: 13885.4728328 (1996)	total: 11.7s	remaining: 1m 45s
# 3000:	learn: 3887.8771557	test: 13672.4511611	best: 13672.3993040 (2994)	total: 17.4s	remaining: 1m 38s
# 4000:	learn: 2932.0407237	test: 13571.6207623	best: 13569.3470330 (3964)	total: 23.5s	remaining: 1m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13542.34605
# bestIteration = 4335
#
# Shrink model to first 4336 iterations.
# 47
# Learning rate set to 0.009788
# 0:	learn: 33124.1943800	test: 32421.4289282	best: 32421.4289282 (0)	total: 10ms	remaining: 3m 20s
# 1000:	learn: 8329.2092632	test: 14301.1850318	best: 14299.2884260 (989)	total: 6.14s	remaining: 1m 56s
# 2000:	learn: 5422.8023734	test: 13769.9640609	best: 13767.8142160 (1963)	total: 11.9s	remaining: 1m 46s
# 3000:	learn: 3829.3981019	test: 13505.9770360	best: 13505.5575246 (2997)	total: 17.6s	remaining: 1m 39s
# 4000:	learn: 2856.6568567	test: 13426.9145539	best: 13425.8805708 (3952)	total: 23.4s	remaining: 1m 33s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13405.63715
# bestIteration = 4367
#
# Shrink model to first 4368 iterations.
# 46
# Learning rate set to 0.009788
# 0:	learn: 33121.9038405	test: 32397.5385077	best: 32397.5385077 (0)	total: 9.49ms	remaining: 3m 9s
# 1000:	learn: 8294.1783202	test: 14545.2992370	best: 14545.2992370 (1000)	total: 5.63s	remaining: 1m 46s
# 2000:	learn: 5262.0309903	test: 13943.3907020	best: 13943.3907020 (2000)	total: 11.3s	remaining: 1m 41s
# 3000:	learn: 3833.2507880	test: 13769.7452295	best: 13769.7452295 (3000)	total: 17s	remaining: 1m 36s
# 4000:	learn: 2858.2743925	test: 13693.8057392	best: 13693.1966189 (3996)	total: 22.8s	remaining: 1m 31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13666.09222
# bestIteration = 4572
#
# Shrink model to first 4573 iterations.
# 45
# Learning rate set to 0.009788
# 0:	learn: 33139.1407398	test: 32398.8614661	best: 32398.8614661 (0)	total: 8.5ms	remaining: 2m 49s
# 1000:	learn: 8299.2259407	test: 14164.0934953	best: 14164.0934953 (1000)	total: 5.54s	remaining: 1m 45s
# 2000:	learn: 5385.5384462	test: 13679.5564035	best: 13679.5564035 (2000)	total: 11s	remaining: 1m 38s
# 3000:	learn: 3779.9573739	test: 13479.3118244	best: 13479.3118244 (3000)	total: 16.5s	remaining: 1m 33s
# 4000:	learn: 2817.4549988	test: 13374.3280310	best: 13374.3280310 (4000)	total: 22.1s	remaining: 1m 28s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13344.4649
# bestIteration = 4578
#
# Shrink model to first 4579 iterations.
# 44
# Learning rate set to 0.009788
# 0:	learn: 33107.9325507	test: 32387.3830371	best: 32387.3830371 (0)	total: 13ms	remaining: 4m 19s
# 1000:	learn: 8270.6043560	test: 14436.5188843	best: 14436.5188843 (1000)	total: 5.48s	remaining: 1m 44s
# 2000:	learn: 5262.0207930	test: 13910.4584341	best: 13907.6771449 (1985)	total: 11.1s	remaining: 1m 39s
# 3000:	learn: 3797.0088590	test: 13687.5810140	best: 13687.1802573 (2996)	total: 16.6s	remaining: 1m 33s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13629.47184
# bestIteration = 3601
#
# Shrink model to first 3602 iterations.
# 43
# Learning rate set to 0.009788
# 0:	learn: 33132.1524888	test: 32427.7473302	best: 32427.7473302 (0)	total: 10.2ms	remaining: 3m 24s
# 1000:	learn: 8209.9264614	test: 14356.5151768	best: 14356.5151768 (1000)	total: 5.31s	remaining: 1m 40s
# 2000:	learn: 5168.6085325	test: 13778.3371377	best: 13778.3371377 (2000)	total: 10.7s	remaining: 1m 36s
# 3000:	learn: 3797.6258371	test: 13577.0685803	best: 13575.1392632 (2994)	total: 17.4s	remaining: 1m 38s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13575.13926
# bestIteration = 2994
#
# Shrink model to first 2995 iterations.
# 42
# Learning rate set to 0.009788
# 0:	learn: 33118.0713129	test: 32407.9451662	best: 32407.9451662 (0)	total: 30.9ms	remaining: 10m 18s
# 1000:	learn: 8247.6118135	test: 14425.8393342	best: 14425.8393342 (1000)	total: 5.35s	remaining: 1m 41s
# 2000:	learn: 5315.2104680	test: 13842.8920327	best: 13837.9007735 (1993)	total: 10.6s	remaining: 1m 35s
# 3000:	learn: 3798.4929671	test: 13696.7090577	best: 13696.6926839 (2999)	total: 15.9s	remaining: 1m 30s
# 4000:	learn: 2782.0691822	test: 13624.9567891	best: 13624.8189402 (3996)	total: 21.3s	remaining: 1m 24s
# 5000:	learn: 2137.7260053	test: 13582.6140028	best: 13582.5360274 (4999)	total: 26.6s	remaining: 1m 19s
# 6000:	learn: 1703.4113500	test: 13547.7340382	best: 13547.7340382 (6000)	total: 32s	remaining: 1m 14s
# 7000:	learn: 1380.5867387	test: 13525.5916569	best: 13525.5916569 (7000)	total: 37.4s	remaining: 1m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13522.90416
# bestIteration = 7215
#
# Shrink model to first 7216 iterations.
# 41
# Learning rate set to 0.009788
# 0:	learn: 33103.6059574	test: 32393.0079583	best: 32393.0079583 (0)	total: 18ms	remaining: 5m 59s
# 1000:	learn: 8330.8522174	test: 14216.8135760	best: 14216.8135760 (1000)	total: 5.25s	remaining: 1m 39s
# 2000:	learn: 5467.3940328	test: 13684.8155570	best: 13670.3373303 (1961)	total: 10.5s	remaining: 1m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13670.33733
# bestIteration = 1961
#
# Shrink model to first 1962 iterations.
# 40
# Learning rate set to 0.009788
# 0:	learn: 33137.5277093	test: 32407.8849861	best: 32407.8849861 (0)	total: 10.9ms	remaining: 3m 37s
# 1000:	learn: 8372.8464922	test: 14297.8353476	best: 14297.5217111 (999)	total: 5.66s	remaining: 1m 47s
# 2000:	learn: 5472.6683330	test: 13723.5556908	best: 13723.5011232 (1998)	total: 12.4s	remaining: 1m 51s
# 3000:	learn: 3858.5182903	test: 13473.2159460	best: 13473.2159460 (3000)	total: 18.2s	remaining: 1m 42s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13457.74597
# bestIteration = 3186
#
# Shrink model to first 3187 iterations.
# 39
# Learning rate set to 0.009788
# 0:	learn: 33123.5102869	test: 32373.0587367	best: 32373.0587367 (0)	total: 36.8ms	remaining: 12m 16s
# 1000:	learn: 8336.4823682	test: 14387.2688031	best: 14387.2688031 (1000)	total: 6.05s	remaining: 1m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13891.19717
# bestIteration = 1820
#
# Shrink model to first 1821 iterations.
# 38
# Learning rate set to 0.009788
# 0:	learn: 33117.6900621	test: 32385.9339716	best: 32385.9339716 (0)	total: 19.7ms	remaining: 6m 33s
# 1000:	learn: 8269.4668246	test: 14359.9037670	best: 14359.9037670 (1000)	total: 5.57s	remaining: 1m 45s
# 2000:	learn: 5361.2236416	test: 13952.2011247	best: 13949.8549768 (1999)	total: 12.1s	remaining: 1m 48s
# 3000:	learn: 3794.5536213	test: 13757.0346607	best: 13755.5238352 (2991)	total: 17.8s	remaining: 1m 41s
# 4000:	learn: 2815.0265069	test: 13643.4405616	best: 13643.2284735 (3999)	total: 24.7s	remaining: 1m 38s
# 5000:	learn: 2199.7681891	test: 13587.9910457	best: 13587.7839254 (4997)	total: 30.8s	remaining: 1m 32s
# 6000:	learn: 1743.0150014	test: 13554.5472145	best: 13552.9840830 (5926)	total: 36.8s	remaining: 1m 25s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13552.98408
# bestIteration = 5926
#
# Shrink model to first 5927 iterations.
# 37
# Learning rate set to 0.009788
# 0:	learn: 33122.5950809	test: 32378.5151538	best: 32378.5151538 (0)	total: 22.4ms	remaining: 7m 27s
# 1000:	learn: 8344.9239195	test: 14434.4454641	best: 14434.4454641 (1000)	total: 5.75s	remaining: 1m 49s
# 2000:	learn: 5436.0678394	test: 13914.1466929	best: 13914.1466929 (2000)	total: 11.1s	remaining: 1m 39s
# 3000:	learn: 3872.7625997	test: 13707.3686439	best: 13705.5900139 (2995)	total: 15.9s	remaining: 1m 30s
# 4000:	learn: 2810.7149011	test: 13593.2735853	best: 13591.6758190 (3989)	total: 20.8s	remaining: 1m 23s
# 5000:	learn: 2176.8522780	test: 13540.6485908	best: 13540.6485908 (5000)	total: 25.7s	remaining: 1m 17s
# 6000:	learn: 1710.7287457	test: 13505.0180541	best: 13504.8546697 (5987)	total: 30.6s	remaining: 1m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13502.57237
# bestIteration = 6224
#
# Shrink model to first 6225 iterations.
# 36
# Learning rate set to 0.009788
# 0:	learn: 33117.6099655	test: 32408.9570118	best: 32408.9570118 (0)	total: 27.6ms	remaining: 9m 12s
# 1000:	learn: 8248.7577944	test: 14328.1659349	best: 14328.1659349 (1000)	total: 4.67s	remaining: 1m 28s
# 2000:	learn: 5356.8941501	test: 13875.1662178	best: 13874.9192059 (1988)	total: 9.3s	remaining: 1m 23s
# 3000:	learn: 3779.0754720	test: 13708.0117278	best: 13708.0117278 (3000)	total: 14s	remaining: 1m 19s
# 4000:	learn: 2797.3505318	test: 13619.9155381	best: 13619.7656364 (3993)	total: 18.7s	remaining: 1m 14s
# 5000:	learn: 2161.3144021	test: 13552.7007152	best: 13552.5794908 (4999)	total: 23.4s	remaining: 1m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13539.20264
# bestIteration = 5422
#
# Shrink model to first 5423 iterations.
# 35
# Learning rate set to 0.009788
# 0:	learn: 33140.8172646	test: 32417.0643659	best: 32417.0643659 (0)	total: 34.2ms	remaining: 11m 24s
# 1000:	learn: 8240.6202813	test: 14227.5920371	best: 14227.4042635 (999)	total: 4.81s	remaining: 1m 31s
# 2000:	learn: 5387.2857121	test: 13618.0122692	best: 13617.5101413 (1999)	total: 9.51s	remaining: 1m 25s
# 3000:	learn: 3942.3912039	test: 13440.7345735	best: 13440.3103551 (2998)	total: 14.1s	remaining: 1m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13425.7149
# bestIteration = 3411
#
# Shrink model to first 3412 iterations.
# 34
# Learning rate set to 0.009788
# 0:	learn: 33125.5051912	test: 32420.5224383	best: 32420.5224383 (0)	total: 18.8ms	remaining: 6m 15s
# 1000:	learn: 8311.6706489	test: 14397.9638018	best: 14396.0036471 (994)	total: 4.43s	remaining: 1m 24s
# 2000:	learn: 5358.8667009	test: 13830.3718900	best: 13830.3718900 (2000)	total: 8.92s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13730.58519
# bestIteration = 2466
#
# Shrink model to first 2467 iterations.
# 33
# Learning rate set to 0.009788
# 0:	learn: 33105.7707332	test: 32396.1274131	best: 32396.1274131 (0)	total: 12.4ms	remaining: 4m 8s
# 1000:	learn: 8328.4316001	test: 14523.5033117	best: 14523.5033117 (1000)	total: 4.35s	remaining: 1m 22s
# 2000:	learn: 5469.7897707	test: 13981.5162462	best: 13981.4389357 (1995)	total: 8.64s	remaining: 1m 17s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13928.12949
# bestIteration = 2313
#
# Shrink model to first 2314 iterations.
# 32
# Learning rate set to 0.009788
# 0:	learn: 33126.3587766	test: 32421.5474377	best: 32421.5474377 (0)	total: 27.2ms	remaining: 9m 4s
# 1000:	learn: 8380.3529439	test: 14295.7637502	best: 14295.2942451 (999)	total: 4.26s	remaining: 1m 20s
# 2000:	learn: 5441.8193412	test: 13838.5384662	best: 13837.1495042 (1999)	total: 8.49s	remaining: 1m 16s
# 3000:	learn: 3849.2442367	test: 13653.7708484	best: 13652.8899317 (2984)	total: 12.8s	remaining: 1m 12s
# 4000:	learn: 2839.0779326	test: 13574.4134220	best: 13574.0529543 (3998)	total: 17.1s	remaining: 1m 8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13548.16058
# bestIteration = 4514
#
# Shrink model to first 4515 iterations.
# 31
# Learning rate set to 0.009788
# 0:	learn: 33106.5860663	test: 32385.0227681	best: 32385.0227681 (0)	total: 15.1ms	remaining: 5m 2s
# 1000:	learn: 8454.6969245	test: 14140.9488402	best: 14140.9488402 (1000)	total: 4.17s	remaining: 1m 19s
# 2000:	learn: 5610.6937329	test: 13672.5601979	best: 13670.6401442 (1999)	total: 8.24s	remaining: 1m 14s
# 3000:	learn: 3922.6908674	test: 13477.0038294	best: 13474.2334773 (2919)	total: 12.3s	remaining: 1m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13474.23348
# bestIteration = 2919
#
# Shrink model to first 2920 iterations.
# 30
# Learning rate set to 0.009788
# 0:	learn: 33119.7755292	test: 32388.7654444	best: 32388.7654444 (0)	total: 36.8ms	remaining: 12m 15s
# 1000:	learn: 8411.0096125	test: 14170.6657158	best: 14170.6657158 (1000)	total: 4.08s	remaining: 1m 17s
# 2000:	learn: 5581.1776715	test: 13593.6647952	best: 13592.8032573 (1996)	total: 8.09s	remaining: 1m 12s
# 3000:	learn: 4034.1087293	test: 13418.0879070	best: 13417.7989197 (2998)	total: 12.2s	remaining: 1m 9s
# 4000:	learn: 2966.3870472	test: 13269.9347195	best: 13269.9347195 (4000)	total: 16.3s	remaining: 1m 5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13242.38494
# bestIteration = 4763
#
# Shrink model to first 4764 iterations.
# 29
# Learning rate set to 0.009788
# 0:	learn: 33118.1363877	test: 32402.3232467	best: 32402.3232467 (0)	total: 17.1ms	remaining: 5m 41s
# 1000:	learn: 8407.7158746	test: 14299.7957148	best: 14299.7957148 (1000)	total: 3.95s	remaining: 1m 14s
# 2000:	learn: 5526.1329329	test: 13766.5231796	best: 13766.5231796 (2000)	total: 7.81s	remaining: 1m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13752.68266
# bestIteration = 2065
#
# Shrink model to first 2066 iterations.
# 28
# Learning rate set to 0.009788
# 0:	learn: 33124.1550480	test: 32422.9514144	best: 32422.9514144 (0)	total: 31.4ms	remaining: 10m 27s
# 1000:	learn: 8367.1180094	test: 14136.7750561	best: 14135.3936484 (998)	total: 3.8s	remaining: 1m 12s
# 2000:	learn: 5459.2824306	test: 13584.5922636	best: 13584.5922636 (2000)	total: 7.53s	remaining: 1m 7s
# 3000:	learn: 3907.6844391	test: 13374.6408959	best: 13372.9673464 (2996)	total: 11.3s	remaining: 1m 4s
# 4000:	learn: 2902.8704600	test: 13269.4773950	best: 13268.5989955 (3972)	total: 15.1s	remaining: 1m
# 5000:	learn: 2283.5995501	test: 13209.0288820	best: 13208.8858994 (4965)	total: 18.9s	remaining: 56.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13197.14788
# bestIteration = 5268
#
# Shrink model to first 5269 iterations.
# 27
# Learning rate set to 0.009788
# 0:	learn: 33108.3548518	test: 32389.7042144	best: 32389.7042144 (0)	total: 11ms	remaining: 3m 39s
# 1000:	learn: 8434.6989755	test: 14431.8851277	best: 14429.9429867 (999)	total: 3.64s	remaining: 1m 9s
# 2000:	learn: 5665.2768634	test: 13932.7974224	best: 13932.7974224 (2000)	total: 7.23s	remaining: 1m 5s
# 3000:	learn: 3968.2094390	test: 13712.1650086	best: 13712.1650086 (3000)	total: 10.8s	remaining: 1m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13597.6221
# bestIteration = 3899
#
# Shrink model to first 3900 iterations.
# 26
# Learning rate set to 0.009788
# 0:	learn: 33106.8102682	test: 32400.7748498	best: 32400.7748498 (0)	total: 12.9ms	remaining: 4m 18s
# 1000:	learn: 8494.6706541	test: 14426.5500655	best: 14426.0042286 (998)	total: 3.59s	remaining: 1m 8s
# 2000:	learn: 5633.6689524	test: 13821.5063574	best: 13819.4884841 (1987)	total: 7.09s	remaining: 1m 3s
# 3000:	learn: 4001.8402452	test: 13624.7286704	best: 13624.1851787 (2982)	total: 10.6s	remaining: 1m
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13550.25874
# bestIteration = 3765
#
# Shrink model to first 3766 iterations.
# 25
# Learning rate set to 0.009788
# 0:	learn: 33103.0124444	test: 32389.8463059	best: 32389.8463059 (0)	total: 10.9ms	remaining: 3m 38s
# 1000:	learn: 8483.3276756	test: 14223.4393535	best: 14222.2958867 (997)	total: 3.51s	remaining: 1m 6s
# 2000:	learn: 5945.5104391	test: 13759.5175318	best: 13759.5065227 (1999)	total: 6.95s	remaining: 1m 2s
# 3000:	learn: 4187.2726499	test: 13495.5264496	best: 13495.2202428 (2999)	total: 10.4s	remaining: 59.1s
# 4000:	learn: 3120.0588895	test: 13418.2525954	best: 13418.2525954 (4000)	total: 14s	remaining: 55.8s
# 5000:	learn: 2439.2994965	test: 13354.5572111	best: 13354.2042840 (4993)	total: 17.4s	remaining: 52.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13344.1486
# bestIteration = 5319
#
# Shrink model to first 5320 iterations.
# 24
# Learning rate set to 0.009788
# 0:	learn: 33126.7613465	test: 32413.0034203	best: 32413.0034203 (0)	total: 18.2ms	remaining: 6m 4s
# 1000:	learn: 8334.4256015	test: 14233.6936277	best: 14233.6936277 (1000)	total: 3.37s	remaining: 1m 3s
# 2000:	learn: 5751.4362010	test: 13648.2660871	best: 13648.2660871 (2000)	total: 6.8s	remaining: 1m 1s
# 3000:	learn: 4155.1551681	test: 13448.5667609	best: 13448.5667609 (3000)	total: 10.3s	remaining: 58.4s
# 4000:	learn: 3177.8940771	test: 13351.9356311	best: 13351.9149070 (3998)	total: 13.7s	remaining: 54.7s
# 5000:	learn: 2538.5958667	test: 13273.3515257	best: 13273.3309382 (4998)	total: 17.1s	remaining: 51.3s
# 6000:	learn: 2065.1480658	test: 13226.3535143	best: 13226.1838688 (5995)	total: 20.5s	remaining: 47.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13224.95288
# bestIteration = 6021
#
# Shrink model to first 6022 iterations.
# 23
# Learning rate set to 0.009788
# 0:	learn: 33102.1028945	test: 32400.9302575	best: 32400.9302575 (0)	total: 30.9ms	remaining: 10m 18s
# 1000:	learn: 8443.5193355	test: 14154.9171636	best: 14154.9171636 (1000)	total: 3.36s	remaining: 1m 3s
# 2000:	learn: 5633.1140468	test: 13576.6857544	best: 13576.6857544 (2000)	total: 6.72s	remaining: 1m
# 3000:	learn: 4149.2637096	test: 13363.0505173	best: 13362.6139007 (2998)	total: 10.1s	remaining: 57.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13272.72409
# bestIteration = 3514
#
# Shrink model to first 3515 iterations.
# 22
# Learning rate set to 0.009788
# 0:	learn: 33109.1633465	test: 32408.6253603	best: 32408.6253603 (0)	total: 30.1ms	remaining: 10m 1s
# 1000:	learn: 8429.1461504	test: 14211.0132064	best: 14209.3780867 (993)	total: 3.3s	remaining: 1m 2s
# 2000:	learn: 5832.9879701	test: 13539.8653639	best: 13539.8653639 (2000)	total: 6.53s	remaining: 58.7s
# 3000:	learn: 4139.1507915	test: 13310.6088870	best: 13310.5988813 (2999)	total: 9.83s	remaining: 55.7s
# 4000:	learn: 3157.3222985	test: 13178.9971927	best: 13177.8933946 (3976)	total: 13.1s	remaining: 52.6s
# 5000:	learn: 2474.6809520	test: 13094.4539925	best: 13094.1676428 (4999)	total: 16.5s	remaining: 49.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13044.881
# bestIteration = 5773
#
# Shrink model to first 5774 iterations.
# 21
# Learning rate set to 0.009788
# 0:	learn: 33120.3872810	test: 32384.2151892	best: 32384.2151892 (0)	total: 35.6ms	remaining: 11m 51s
# 1000:	learn: 8550.1454814	test: 14147.2557083	best: 14146.1197279 (996)	total: 3.27s	remaining: 1m 2s
# 2000:	learn: 5738.7044949	test: 13412.6211892	best: 13412.6211892 (2000)	total: 6.77s	remaining: 1m
# 3000:	learn: 4095.7532945	test: 13220.5653376	best: 13220.0837534 (2992)	total: 10.3s	remaining: 58.3s
# 4000:	learn: 3156.7015400	test: 13114.5235660	best: 13114.5116176 (3997)	total: 13.8s	remaining: 55.4s
# 5000:	learn: 2517.4687145	test: 13031.4366306	best: 13031.0770171 (4993)	total: 17.2s	remaining: 51.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13019.81715
# bestIteration = 5271
#
# Shrink model to first 5272 iterations.
# 20
# Learning rate set to 0.009788
# 0:	learn: 33104.9737099	test: 32410.9985801	best: 32410.9985801 (0)	total: 18.4ms	remaining: 6m 8s
# 1000:	learn: 8447.6489821	test: 14136.2329873	best: 14134.2300962 (996)	total: 3.03s	remaining: 57.6s
# 2000:	learn: 5907.0855275	test: 13657.0574978	best: 13656.2012122 (1990)	total: 6.04s	remaining: 54.3s
# 3000:	learn: 4355.2014650	test: 13539.2285998	best: 13539.2285998 (3000)	total: 9.12s	remaining: 51.6s
# 4000:	learn: 3412.8645124	test: 13449.2695566	best: 13449.2695566 (4000)	total: 12.2s	remaining: 48.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13440.34308
# bestIteration = 4138
#
# Shrink model to first 4139 iterations.
# 19
# Learning rate set to 0.009788
# 0:	learn: 33122.0190644	test: 32420.2090962	best: 32420.2090962 (0)	total: 7.63ms	remaining: 2m 32s
# 1000:	learn: 8478.5176431	test: 14442.6695602	best: 14442.6695602 (1000)	total: 2.94s	remaining: 55.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 14216.63798
# bestIteration = 1273
#
# Shrink model to first 1274 iterations.
# 18
# Learning rate set to 0.009788
# 0:	learn: 33132.9472646	test: 32421.1475148	best: 32421.1475148 (0)	total: 16.2ms	remaining: 5m 24s
# 1000:	learn: 8417.6666064	test: 14209.8399533	best: 14209.8399533 (1000)	total: 2.88s	remaining: 54.7s
# 2000:	learn: 5893.8949848	test: 13596.1510311	best: 13596.1510311 (2000)	total: 5.73s	remaining: 51.5s
# 3000:	learn: 4366.2742763	test: 13366.3807947	best: 13366.3807947 (3000)	total: 8.55s	remaining: 48.4s
# 4000:	learn: 3341.3333371	test: 13244.6217432	best: 13244.2941442 (3996)	total: 11.4s	remaining: 45.5s
# 5000:	learn: 2667.8391591	test: 13178.1744923	best: 13175.3522972 (4961)	total: 14.3s	remaining: 42.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13175.3523
# bestIteration = 4961
#
# Shrink model to first 4962 iterations.
# 17
# Learning rate set to 0.009788
# 0:	learn: 33106.4021925	test: 32399.7311022	best: 32399.7311022 (0)	total: 13.2ms	remaining: 4m 24s
# 1000:	learn: 8542.1901972	test: 14081.1825540	best: 14077.5287612 (995)	total: 2.82s	remaining: 53.6s
# 2000:	learn: 6148.9658895	test: 13503.8668327	best: 13503.8668327 (2000)	total: 5.59s	remaining: 50.3s
# 3000:	learn: 4355.9659617	test: 13295.7931761	best: 13295.2866808 (2954)	total: 8.4s	remaining: 47.6s
# 4000:	learn: 3355.3488427	test: 13186.3068964	best: 13186.3068964 (4000)	total: 11.3s	remaining: 45.1s
# 5000:	learn: 2649.5657530	test: 13116.7671260	best: 13116.7671260 (5000)	total: 14.1s	remaining: 42.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13098.60212
# bestIteration = 5326
#
# Shrink model to first 5327 iterations.
# 16
# Learning rate set to 0.009788
# 0:	learn: 33115.4012494	test: 32374.6286257	best: 32374.6286257 (0)	total: 4.98ms	remaining: 1m 39s
# 1000:	learn: 8598.1894000	test: 13986.2286777	best: 13986.0149559 (999)	total: 2.68s	remaining: 50.9s
# 2000:	learn: 6042.9605564	test: 13498.3946115	best: 13497.5317066 (1998)	total: 5.35s	remaining: 48.2s
# 3000:	learn: 4467.5540497	test: 13232.5287478	best: 13232.5287478 (3000)	total: 8.06s	remaining: 45.6s
# 4000:	learn: 3525.6107904	test: 13055.5887385	best: 13055.5887385 (4000)	total: 10.7s	remaining: 42.9s
# 5000:	learn: 2856.9886319	test: 12955.9279804	best: 12955.7685909 (4998)	total: 13.4s	remaining: 40.1s
# 6000:	learn: 2351.8282035	test: 12907.5566057	best: 12907.5566057 (6000)	total: 16s	remaining: 37.4s
# 7000:	learn: 1948.3050888	test: 12868.2008875	best: 12867.7964750 (6996)	total: 18.7s	remaining: 34.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12866.83902
# bestIteration = 7038
#
# Shrink model to first 7039 iterations.
# 15
# Learning rate set to 0.009788
# 0:	learn: 33119.4961771	test: 32407.0175185	best: 32407.0175185 (0)	total: 4.37ms	remaining: 1m 27s
# 1000:	learn: 8541.2868243	test: 14356.9097572	best: 14356.9097572 (1000)	total: 2.63s	remaining: 49.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13987.46061
# bestIteration = 1724
#
# Shrink model to first 1725 iterations.
# 14
# Learning rate set to 0.009788
# 0:	learn: 33099.8893331	test: 32374.4104196	best: 32374.4104196 (0)	total: 29ms	remaining: 9m 39s
# 1000:	learn: 8556.6796497	test: 14450.1693312	best: 14450.1693312 (1000)	total: 2.64s	remaining: 50.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 14141.74277
# bestIteration = 1785
#
# Shrink model to first 1786 iterations.
# 13
# Learning rate set to 0.009788
# 0:	learn: 33108.5253361	test: 32405.5849689	best: 32405.5849689 (0)	total: 15.9ms	remaining: 5m 17s
# 1000:	learn: 8624.9245166	test: 14423.3373215	best: 14422.1352890 (996)	total: 2.6s	remaining: 49.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13999.4684
# bestIteration = 1872
#
# Shrink model to first 1873 iterations.
# 12
# Learning rate set to 0.009788
# 0:	learn: 33120.4022507	test: 32408.6381846	best: 32408.6381846 (0)	total: 4ms	remaining: 1m 20s
# 1000:	learn: 8688.4044889	test: 14094.2957011	best: 14094.2957011 (1000)	total: 2.42s	remaining: 46s
# 2000:	learn: 6426.9834772	test: 13716.9127060	best: 13709.6246212 (1934)	total: 4.83s	remaining: 43.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13709.62462
# bestIteration = 1934
#
# Shrink model to first 1935 iterations.
# 11
# Learning rate set to 0.009788
# 0:	learn: 33122.6018613	test: 32383.8610454	best: 32383.8610454 (0)	total: 8.16ms	remaining: 2m 43s
# 1000:	learn: 8675.6597395	test: 14391.1810203	best: 14391.1810203 (1000)	total: 2.49s	remaining: 47.3s
# 2000:	learn: 6458.2562643	test: 13970.9765145	best: 13960.0134388 (1918)	total: 4.97s	remaining: 44.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13960.01344
# bestIteration = 1918
#
# Shrink model to first 1919 iterations.
# 10
# Learning rate set to 0.009788
# 0:	learn: 33126.8726850	test: 32413.6258884	best: 32413.6258884 (0)	total: 11.4ms	remaining: 3m 47s
# 1000:	learn: 8680.9138123	test: 14577.0471020	best: 14573.8339159 (991)	total: 2.41s	remaining: 45.7s
# 2000:	learn: 6502.2871000	test: 14123.5822565	best: 14123.1052318 (1998)	total: 4.76s	remaining: 42.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13983.04027
# bestIteration = 2606
#
# Shrink model to first 2607 iterations.
# 9
# Learning rate set to 0.009788
# 0:	learn: 33101.5522588	test: 32376.3345582	best: 32376.3345582 (0)	total: 2.72ms	remaining: 54.5s
# 1000:	learn: 8712.5624696	test: 14665.1348841	best: 14664.9026661 (999)	total: 2.38s	remaining: 45.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 14618.92515
# bestIteration = 1128
#
# Shrink model to first 1129 iterations.
# 8
# Learning rate set to 0.009788
# 0:	learn: 33104.5028745	test: 32376.9026644	best: 32376.9026644 (0)	total: 17.2ms	remaining: 5m 43s
# 1000:	learn: 9219.1457517	test: 14779.6342764	best: 14773.7006977 (995)	total: 2.35s	remaining: 44.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 14746.41111
# bestIteration = 1072
#
# Shrink model to first 1073 iterations.
# 7
# Learning rate set to 0.009788
# 0:	learn: 33095.0760893	test: 32378.4826625	best: 32378.4826625 (0)	total: 2.61ms	remaining: 52.3s
# 1000:	learn: 9790.2177973	test: 15221.8091848	best: 15221.0561733 (999)	total: 2.35s	remaining: 44.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 15056.63589
# bestIteration = 1346
#
# Shrink model to first 1347 iterations.
# 6
# Learning rate set to 0.009788
# 0:	learn: 33098.2729339	test: 32409.1051768	best: 32409.1051768 (0)	total: 2.62ms	remaining: 52.3s
# 1000:	learn: 9871.3945715	test: 15066.0214068	best: 15054.0091179 (969)	total: 2.33s	remaining: 44.2s
# 2000:	learn: 7721.7743176	test: 14545.2778486	best: 14545.2778486 (2000)	total: 4.66s	remaining: 41.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 14442.88402
# bestIteration = 2655
#
# Shrink model to first 2656 iterations.
# 5
# Learning rate set to 0.009788
# 0:	learn: 33103.5906747	test: 32404.2828446	best: 32404.2828446 (0)	total: 2.61ms	remaining: 52.1s
# 1000:	learn: 10147.3679249	test: 15340.2224175	best: 15340.2184483 (999)	total: 2.32s	remaining: 44s
# 2000:	learn: 7958.6011793	test: 14783.0387745	best: 14783.0387745 (2000)	total: 4.64s	remaining: 41.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 14705.36938
# bestIteration = 2311
#
# Shrink model to first 2312 iterations.
# 4
# Learning rate set to 0.009788
# 0:	learn: 33108.3793657	test: 32370.1390897	best: 32370.1390897 (0)	total: 2.53ms	remaining: 50.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 17370.87769
# bestIteration = 515
#
# Shrink model to first 516 iterations.
# 3
# Learning rate set to 0.009788
# 0:	learn: 33108.0584409	test: 32366.2185751	best: 32366.2185751 (0)	total: 2.57ms	remaining: 51.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 18275.75931
# bestIteration = 582
#
# Shrink model to first 583 iterations.
# 2
# Learning rate set to 0.009788
# 0:	learn: 33104.3179879	test: 32401.4927486	best: 32401.4927486 (0)	total: 2.44ms	remaining: 48.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 18280.12324
# bestIteration = 666
#
# Shrink model to first 667 iterations.

# %%
# train, test 분할
col_dict, X, y = Xy_split(hitter)

# 변수의 순위도출
model = LinearRegression()
selector = RFE(model, n_features_to_select = 1, step = 1)
selector = selector.fit(X, y)

# 데이터프레임으로 생성
hitter_regression = pd.DataFrame({'변수명':list(col_dict.keys()),
                                   '실제변수명':list(col_dict.values()),
                                   'regression순위':list(selector.ranking_)})

# %% [markdown]
# #### 2. 투수

# %%
# train, test 분할
col_dict, X, y = Xy_split(pitcher)

# 변수의 순위도출
model = RandomForestRegressor(random_state = 42)
selector = RFE(model, n_features_to_select = 1, step = 1)
selector = selector.fit(X, y)

# 데이터프레임으로 생성
pitcher_rf = pd.DataFrame({'변수명':list(col_dict.keys()),
                  '실제변수명':list(col_dict.values()),
                  'rf순위':list(selector.ranking_)})

# %%
# train, test 분할
col_dict, X, y = Xy_split(pitcher)
X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

X = X.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y = y.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

col_dict_origin = col_dict.copy()

# RFE 적용
lgb_params = {"objective" : "rmse",
             "verbosity" : -1}

remove_cols = []

while True:

    # lgbm 모델링
    lgb_dtrain = lgb.Dataset(data = X, label = y) 
    lgb_dvalid = lgb.Dataset(data = X_test, label = y_test) 

    lgb_model = lgb.train(lgb_params, lgb_dtrain, 20000, valid_sets=[lgb_dvalid], early_stopping_rounds=100, verbose_eval=1000)

    # 가장 낮은 변수들 중 1개 삭제
    remove_col = [col for col, importance in zip(list(col_dict.keys()), lgb_model.feature_importance()) if importance == min(lgb_model.feature_importance())][-1]
    remove_cols.append(remove_col)
    X.drop(remove_col, axis=1, inplace=True)
    X_test.drop(remove_col, axis=1, inplace=True)
    del col_dict[remove_col]
    
    # while문 종료조건
    if X.shape[1] == 1:
        remove_cols.append(X.columns[0])
        break

# 데이터프레임으로 생성
pitcher_lgbm = pd.DataFrame({'변수명':remove_cols,
                            '실제변수명':[col_dict_origin[key] for key in remove_cols],
                            'lgbm순위':[i for i in range(len(col_dict_origin), 0, -1)]})
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14155.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [87]	valid_0's rmse: 13877.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [98]	valid_0's rmse: 13862.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	valid_0's rmse: 13895.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	valid_0's rmse: 13895.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [81]	valid_0's rmse: 13828.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [99]	valid_0's rmse: 13897.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [133]	valid_0's rmse: 13828.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [69]	valid_0's rmse: 14072.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [132]	valid_0's rmse: 13887.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [83]	valid_0's rmse: 13968.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [72]	valid_0's rmse: 14079.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [108]	valid_0's rmse: 13956.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [91]	valid_0's rmse: 14000.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [83]	valid_0's rmse: 13947.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [73]	valid_0's rmse: 13956.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [31]	valid_0's rmse: 13742.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's rmse: 13679.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [46]	valid_0's rmse: 13829.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [30]	valid_0's rmse: 13967
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [29]	valid_0's rmse: 13784.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [75]	valid_0's rmse: 13787.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [30]	valid_0's rmse: 14033.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [67]	valid_0's rmse: 13903.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [35]	valid_0's rmse: 13805.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [52]	valid_0's rmse: 13823.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [38]	valid_0's rmse: 13870.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [60]	valid_0's rmse: 13819.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [69]	valid_0's rmse: 13404.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [69]	valid_0's rmse: 13689.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [67]	valid_0's rmse: 13638.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [92]	valid_0's rmse: 13737.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [74]	valid_0's rmse: 13905.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [58]	valid_0's rmse: 13770.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [65]	valid_0's rmse: 13862.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 13510.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [89]	valid_0's rmse: 13644.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [81]	valid_0's rmse: 13690.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [80]	valid_0's rmse: 13744.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [67]	valid_0's rmse: 13657.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [70]	valid_0's rmse: 13700.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [81]	valid_0's rmse: 13435.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [71]	valid_0's rmse: 13876.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [52]	valid_0's rmse: 14014.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [67]	valid_0's rmse: 13820.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [80]	valid_0's rmse: 13762
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [90]	valid_0's rmse: 14065.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [99]	valid_0's rmse: 14390.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [70]	valid_0's rmse: 14586
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [58]	valid_0's rmse: 14687.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [63]	valid_0's rmse: 14519.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [61]	valid_0's rmse: 14456.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 14441.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [71]	valid_0's rmse: 14695.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [84]	valid_0's rmse: 14446.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [64]	valid_0's rmse: 14863.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [61]	valid_0's rmse: 14621.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [53]	valid_0's rmse: 14536.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [72]	valid_0's rmse: 14575.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 15015.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [57]	valid_0's rmse: 14842.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [395]	valid_0's rmse: 14881.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [72]	valid_0's rmse: 14282.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [128]	valid_0's rmse: 14481.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	valid_0's rmse: 14900.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [31]	valid_0's rmse: 14868.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [31]	valid_0's rmse: 15332.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	valid_0's rmse: 15221.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [369]	valid_0's rmse: 14570.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [36]	valid_0's rmse: 16470.1

# %%
# train, test 분할
col_dict, X, y = Xy_split(pitcher)
X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

X = X.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y = y.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

col_dict_origin = col_dict.copy()

# RFE 적용
xgb_final_param = {
          "objective" : 'reg:squarederror',
          "random_state" : 42,
          "verbosity" : 0
          }

remove_cols = []

while True:
    
    print(X.shape[1])

    # xgb 모델링
    xgb_dtrain = xgb.DMatrix(data = X, label = y) 
    xgb_dvalid = xgb.DMatrix(data = X_test, label = y_test) 

    xgb_model = xgb.train(params = xgb_final_param, dtrain = xgb_dtrain, num_boost_round = 20000, early_stopping_rounds = 100, verbose_eval = 1000, evals=[(xgb_dtrain, 'train'), (xgb_dvalid,'eval')])

    # 가장 낮은 변수들 중 1개 삭제
    remove_col = sorted(xgb_model.get_score().items(),  key = lambda item: item[1])[0][0]
    remove_cols.append(remove_col)
    X.drop(remove_col, axis=1, inplace=True)
    X_test.drop(remove_col, axis=1, inplace=True)
    del col_dict[remove_col]
    
    # while문 종료조건
    if X.shape[1] == 1:
        remove_cols.append(X.columns[0])
        break

# 데이터프레임으로 생성
pitcher_xgb = pd.DataFrame({'변수명':remove_cols,
                            '실제변수명':[col_dict_origin[key] for key in remove_cols],
                            'xgb순위':[i for i in range(len(col_dict_origin), 0, -1)]})
# Out:
# 80
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [109]	train-rmse:285.52805	eval-rmse:15078.06543
# 79
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [109]	train-rmse:275.94363	eval-rmse:15052.00879
# 78
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [109]	train-rmse:264.18320	eval-rmse:15084.03711
# 77
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [109]	train-rmse:260.17914	eval-rmse:15064.01660
# 76
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [109]	train-rmse:297.44650	eval-rmse:15059.33301
# 75
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [109]	train-rmse:286.38422	eval-rmse:15070.94043
# 74
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [109]	train-rmse:286.39770	eval-rmse:15070.93750
# 73
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [109]	train-rmse:247.07932	eval-rmse:15124.81445
# 72
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [109]	train-rmse:284.32089	eval-rmse:15124.25879
# 71
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [108]	train-rmse:282.48743	eval-rmse:15142.96973
# 70
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [108]	train-rmse:302.07208	eval-rmse:15222.34863
# 69
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [131]	train-rmse:159.42950	eval-rmse:15043.57812
# 68
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [171]	train-rmse:80.36897	eval-rmse:15032.11426
# 67
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [145]	train-rmse:142.24034	eval-rmse:14962.92773
# 66
# [0]	train-rmse:19822.49023	eval-rmse:22013.53125
# [125]	train-rmse:200.70528	eval-rmse:15092.99316
# 65
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [115]	train-rmse:244.00323	eval-rmse:14990.33496
# 64
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [124]	train-rmse:219.26195	eval-rmse:14864.13379
# 63
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [118]	train-rmse:239.85030	eval-rmse:14884.02930
# 62
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [123]	train-rmse:211.30550	eval-rmse:14870.44336
# 61
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [108]	train-rmse:263.09537	eval-rmse:14667.59473
# 60
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [113]	train-rmse:269.99969	eval-rmse:14510.39648
# 59
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [118]	train-rmse:239.15581	eval-rmse:14446.30566
# 58
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [110]	train-rmse:261.96808	eval-rmse:14575.82519
# 57
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [111]	train-rmse:255.04231	eval-rmse:14540.71973
# 56
# [0]	train-rmse:19824.54492	eval-rmse:22030.39844
# [166]	train-rmse:83.38899	eval-rmse:14356.93457
# 55
# [0]	train-rmse:19861.71680	eval-rmse:22172.60938
# [198]	train-rmse:58.76455	eval-rmse:14611.17188
# 54
# [0]	train-rmse:19861.71680	eval-rmse:22172.60938
# [114]	train-rmse:233.56340	eval-rmse:14664.66113
# 53
# [0]	train-rmse:19861.71680	eval-rmse:22172.60938
# [265]	train-rmse:13.76256	eval-rmse:14597.57422
# 52
# [0]	train-rmse:19861.71680	eval-rmse:22172.60938
# [110]	train-rmse:265.30856	eval-rmse:14662.92676
# 51
# [0]	train-rmse:19860.43555	eval-rmse:22267.79492
# [168]	train-rmse:96.55991	eval-rmse:14579.04394
# 50
# [0]	train-rmse:19860.43555	eval-rmse:22267.79492
# [109]	train-rmse:266.92966	eval-rmse:14640.24414
# 49
# [0]	train-rmse:19860.43555	eval-rmse:22267.79492
# [107]	train-rmse:262.38123	eval-rmse:15564.12891
# 48
# [0]	train-rmse:19860.43555	eval-rmse:22267.79492
# [110]	train-rmse:290.27594	eval-rmse:15246.78027
# 47
# [0]	train-rmse:19860.43555	eval-rmse:22267.79492
# [110]	train-rmse:260.74615	eval-rmse:15486.74316
# 46
# [0]	train-rmse:19860.43555	eval-rmse:22267.79492
# [113]	train-rmse:226.74397	eval-rmse:15423.86328
# 45
# [0]	train-rmse:19860.43555	eval-rmse:22267.79492
# [219]	train-rmse:39.24824	eval-rmse:15408.49609
# 44
# [0]	train-rmse:19860.43555	eval-rmse:22267.79492
# [299]	train-rmse:9.49097	eval-rmse:14561.25977
# 43
# [0]	train-rmse:19860.43555	eval-rmse:22291.57227
# [109]	train-rmse:239.67364	eval-rmse:13464.91894
# 42
# [0]	train-rmse:19860.43555	eval-rmse:22291.57227
# [115]	train-rmse:236.11142	eval-rmse:13366.79394
# 41
# [0]	train-rmse:19860.17383	eval-rmse:22291.57227
# [121]	train-rmse:209.97569	eval-rmse:13091.51465
# 40
# [0]	train-rmse:19860.17383	eval-rmse:22291.57227
# [120]	train-rmse:228.06924	eval-rmse:13336.29785
# 39
# [0]	train-rmse:19860.17383	eval-rmse:22291.57227
# [217]	train-rmse:34.52875	eval-rmse:13097.05859
# 38
# [0]	train-rmse:19860.17383	eval-rmse:22291.57227
# [122]	train-rmse:212.31952	eval-rmse:13289.36328
# 37
# [0]	train-rmse:19860.17383	eval-rmse:22291.57227
# [193]	train-rmse:72.65132	eval-rmse:13356.29394
# 36
# [0]	train-rmse:19860.17383	eval-rmse:22291.57227
# [248]	train-rmse:26.13914	eval-rmse:13439.31445
# 35
# [0]	train-rmse:19865.00586	eval-rmse:22285.89844
# [143]	train-rmse:165.40508	eval-rmse:14188.12012
# 34
# [0]	train-rmse:19865.00586	eval-rmse:22285.89844
# [112]	train-rmse:262.98492	eval-rmse:13746.22461
# 33
# [0]	train-rmse:19868.56641	eval-rmse:22370.08594
# [108]	train-rmse:309.38925	eval-rmse:13579.20117
# 32
# [0]	train-rmse:19868.56641	eval-rmse:22370.08594
# [109]	train-rmse:299.69681	eval-rmse:13606.84961
# 31
# [0]	train-rmse:19881.82617	eval-rmse:22652.58008
# [127]	train-rmse:258.42660	eval-rmse:14684.01465
# 30
# [0]	train-rmse:19886.31836	eval-rmse:22450.25000
# [129]	train-rmse:197.65302	eval-rmse:14519.16016
# 29
# [0]	train-rmse:19892.47266	eval-rmse:22106.89453
# [125]	train-rmse:244.44052	eval-rmse:13856.22070
# 28
# [0]	train-rmse:19914.69727	eval-rmse:23280.10742
# [122]	train-rmse:249.46910	eval-rmse:15827.28320
# 27
# [0]	train-rmse:19914.69727	eval-rmse:23280.10742
# [180]	train-rmse:86.93633	eval-rmse:16070.27051
# 26
# [0]	train-rmse:19914.69727	eval-rmse:23280.10742
# [118]	train-rmse:303.92789	eval-rmse:15772.86621
# 25
# [0]	train-rmse:19914.69727	eval-rmse:23280.10742
# [127]	train-rmse:200.55183	eval-rmse:15254.19531
# 24
# [0]	train-rmse:19914.69727	eval-rmse:23280.10742
# [128]	train-rmse:214.42246	eval-rmse:16024.56152
# 23
# [0]	train-rmse:19878.65039	eval-rmse:23408.92188
# [122]	train-rmse:272.80298	eval-rmse:15985.37793
# 22
# [0]	train-rmse:19878.65039	eval-rmse:23408.92188
# [129]	train-rmse:250.33600	eval-rmse:16189.62500
# 21
# [0]	train-rmse:19878.65039	eval-rmse:23408.92188
# [123]	train-rmse:276.70056	eval-rmse:16237.66016
# 20
# [0]	train-rmse:19922.96289	eval-rmse:23685.36523
# [117]	train-rmse:289.98520	eval-rmse:17197.26562
# 19
# [0]	train-rmse:19923.12891	eval-rmse:22841.10742
# [112]	train-rmse:362.17209	eval-rmse:14529.50098
# 18
# [0]	train-rmse:19923.12891	eval-rmse:22841.10742
# [110]	train-rmse:344.62720	eval-rmse:15073.25879
# 17
# [0]	train-rmse:19923.12891	eval-rmse:22841.10742
# [115]	train-rmse:337.78415	eval-rmse:14607.69238
# 16
# [0]	train-rmse:19934.24023	eval-rmse:22789.99414
# [121]	train-rmse:311.50623	eval-rmse:14251.67676
# 15
# [0]	train-rmse:19974.94531	eval-rmse:23112.83594
# [107]	train-rmse:454.39618	eval-rmse:15341.86035
# 14
# [0]	train-rmse:19976.45703	eval-rmse:23118.38867
# [154]	train-rmse:255.91235	eval-rmse:15155.89160
# 13
# [0]	train-rmse:20017.92188	eval-rmse:22775.17383
# [106]	train-rmse:585.34369	eval-rmse:15857.53223
# 12
# [0]	train-rmse:20001.52148	eval-rmse:22895.18164
# [105]	train-rmse:608.89221	eval-rmse:16403.06445
# 11
# [0]	train-rmse:20010.52539	eval-rmse:22965.11133
# [107]	train-rmse:519.97742	eval-rmse:16071.43848
# 10
# [0]	train-rmse:20012.81250	eval-rmse:22952.99805
# [118]	train-rmse:536.19330	eval-rmse:15616.32715
# 9
# [0]	train-rmse:20082.58789	eval-rmse:23015.22461
# [122]	train-rmse:513.59210	eval-rmse:15007.06738
# 8
# [0]	train-rmse:20082.30664	eval-rmse:22877.75391
# [105]	train-rmse:713.43103	eval-rmse:15227.35254
# 7
# [0]	train-rmse:20083.56641	eval-rmse:22850.57031
# [107]	train-rmse:821.47308	eval-rmse:15266.45410
# 6
# [0]	train-rmse:20085.33984	eval-rmse:22852.15625
# [111]	train-rmse:792.91028	eval-rmse:15243.71289
# 5
# [0]	train-rmse:20281.65039	eval-rmse:23246.40625
# [105]	train-rmse:998.62543	eval-rmse:17378.58594
# 4
# [0]	train-rmse:20318.73633	eval-rmse:22844.24805
# [103]	train-rmse:1537.65918	eval-rmse:17413.98633
# 3
# [0]	train-rmse:20627.26367	eval-rmse:23679.16797
# [106]	train-rmse:2180.00122	eval-rmse:19715.94336
# 2
# [0]	train-rmse:21534.36523	eval-rmse:24493.03711
# [106]	train-rmse:3550.39502	eval-rmse:21594.73828

# %%
# train, test 분할
col_dict, X, y = Xy_split(pitcher)
X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

X = X.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y = y.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

col_dict_origin = col_dict.copy()

# RFE 적용
remove_cols = []

while True:
    
    print(X.shape[1])

    # cb 모델링
    cat_cols = []
    cb_dtrain = Pool(data=X, label=y, cat_features=cat_cols)
    cb_dvalid = Pool(data=X_test, label=y_test, cat_features=cat_cols)

    cb_model = CatBoostRegressor(iterations=20000, eval_metric='RMSE', loss_function='RMSE', verbose = 0)
    cb_model.fit(cb_dtrain, eval_set=cb_dvalid, early_stopping_rounds=100, verbose_eval=1000, use_best_model=True)
    
    # 가장 낮은 변수들 중 1개 삭제
    remove_col = [col for col, importance in zip(list(col_dict.keys()), cb_model.feature_importances_) if importance == min(cb_model.feature_importances_)][-1]
    remove_cols.append(remove_col)
    X.drop(remove_col, axis=1, inplace=True)
    X_test.drop(remove_col, axis=1, inplace=True)
    del col_dict[remove_col]
    
    # while문 종료조건
    if X.shape[1] == 1:
        remove_cols.append(X.columns[0])
        break

# 데이터프레임으로 생성
pitcher_cb = pd.DataFrame({'변수명':remove_cols,
                            '실제변수명':[col_dict_origin[key] for key in remove_cols],
                            'cb순위':[i for i in range(len(col_dict_origin), 0, -1)]})
# Out:
# 80
# Learning rate set to 0.009508
# 0:	learn: 23571.9276317	test: 25562.8093113	best: 25562.8093113 (0)	total: 11.5ms	remaining: 3m 49s
# 1000:	learn: 6012.0475898	test: 12300.1169826	best: 12300.1169826 (1000)	total: 6.57s	remaining: 2m 4s
# 2000:	learn: 3878.6744319	test: 12039.8890787	best: 12038.0696409 (1977)	total: 12.8s	remaining: 1m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11996.6898
# bestIteration = 2618
#
# Shrink model to first 2619 iterations.
# 79
# Learning rate set to 0.009508
# 0:	learn: 23563.5305629	test: 25525.9988497	best: 25525.9988497 (0)	total: 9.79ms	remaining: 3m 15s
# 1000:	learn: 6000.1740169	test: 12336.3241135	best: 12335.8910386 (999)	total: 6.25s	remaining: 1m 58s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12089.89134
# bestIteration = 1491
#
# Shrink model to first 1492 iterations.
# 78
# Learning rate set to 0.009508
# 0:	learn: 23574.5241304	test: 25564.8189973	best: 25564.8189973 (0)	total: 7.99ms	remaining: 2m 39s
# 1000:	learn: 5974.7377237	test: 12355.2935706	best: 12354.5450976 (995)	total: 6.11s	remaining: 1m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12177.09675
# bestIteration = 1401
#
# Shrink model to first 1402 iterations.
# 77
# Learning rate set to 0.009508
# 0:	learn: 23582.3726417	test: 25574.7325825	best: 25574.7325825 (0)	total: 9.87ms	remaining: 3m 17s
# 1000:	learn: 6030.0226764	test: 12584.9222700	best: 12584.9222700 (1000)	total: 6.14s	remaining: 1m 56s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12374.6497
# bestIteration = 1746
#
# Shrink model to first 1747 iterations.
# 76
# Learning rate set to 0.009508
# 0:	learn: 23562.6073858	test: 25560.6407782	best: 25560.6407782 (0)	total: 9.29ms	remaining: 3m 5s
# 1000:	learn: 6004.1070370	test: 12491.2852288	best: 12491.2852288 (1000)	total: 6.09s	remaining: 1m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12253.66299
# bestIteration = 1573
#
# Shrink model to first 1574 iterations.
# 75
# Learning rate set to 0.009508
# 0:	learn: 23564.8452360	test: 25558.7144553	best: 25558.7144553 (0)	total: 9.78ms	remaining: 3m 15s
# 1000:	learn: 6000.7469676	test: 12389.9909795	best: 12389.9909795 (1000)	total: 6.09s	remaining: 1m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12229.31214
# bestIteration = 1441
#
# Shrink model to first 1442 iterations.
# 74
# Learning rate set to 0.009508
# 0:	learn: 23570.4221450	test: 25553.1039597	best: 25553.1039597 (0)	total: 10.6ms	remaining: 3m 31s
# 1000:	learn: 5983.1345748	test: 12266.7485116	best: 12266.7485116 (1000)	total: 6.11s	remaining: 1m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12101.55776
# bestIteration = 1404
#
# Shrink model to first 1405 iterations.
# 73
# Learning rate set to 0.009508
# 0:	learn: 23572.3338670	test: 25559.8583291	best: 25559.8583291 (0)	total: 8.64ms	remaining: 2m 52s
# 1000:	learn: 5948.9446192	test: 12339.9493084	best: 12339.9493084 (1000)	total: 6.09s	remaining: 1m 55s
# 2000:	learn: 3830.8733538	test: 12084.2264338	best: 12083.1134416 (1991)	total: 12.1s	remaining: 1m 48s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12056.63367
# bestIteration = 2208
#
# Shrink model to first 2209 iterations.
# 72
# Learning rate set to 0.009508
# 0:	learn: 23569.9037873	test: 25542.8746739	best: 25542.8746739 (0)	total: 9.55ms	remaining: 3m 11s
# 1000:	learn: 5982.4480782	test: 12285.1422312	best: 12283.9337302 (997)	total: 6.03s	remaining: 1m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12072.18888
# bestIteration = 1365
#
# Shrink model to first 1366 iterations.
# 71
# Learning rate set to 0.009508
# 0:	learn: 23573.1371726	test: 25554.7383561	best: 25554.7383561 (0)	total: 10.8ms	remaining: 3m 36s
# 1000:	learn: 5963.7092020	test: 12434.6547368	best: 12433.0004000 (998)	total: 6.15s	remaining: 1m 56s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12256.90211
# bestIteration = 1436
#
# Shrink model to first 1437 iterations.
# 70
# Learning rate set to 0.009508
# 0:	learn: 23566.4097494	test: 25565.1983160	best: 25565.1983160 (0)	total: 9.42ms	remaining: 3m 8s
# 1000:	learn: 5933.9045277	test: 12269.7402060	best: 12269.7402060 (1000)	total: 6.1s	remaining: 1m 55s
# 2000:	learn: 3763.3247526	test: 12024.6053491	best: 12020.5325233 (1913)	total: 12.2s	remaining: 1m 49s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11929.8587
# bestIteration = 2810
#
# Shrink model to first 2811 iterations.
# 69
# Learning rate set to 0.009508
# 0:	learn: 23566.3011970	test: 25541.3594008	best: 25541.3594008 (0)	total: 10.2ms	remaining: 3m 23s
# 1000:	learn: 6065.9975323	test: 12245.2514759	best: 12245.2514759 (1000)	total: 6.02s	remaining: 1m 54s
# 2000:	learn: 3772.8027810	test: 11920.6426567	best: 11917.6604783 (1956)	total: 12.1s	remaining: 1m 48s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11917.66048
# bestIteration = 1956
#
# Shrink model to first 1957 iterations.
# 68
# Learning rate set to 0.009508
# 0:	learn: 23574.9786121	test: 25573.0721903	best: 25573.0721903 (0)	total: 11.3ms	remaining: 3m 45s
# 1000:	learn: 5975.2255541	test: 12395.7717659	best: 12395.5118536 (999)	total: 6.06s	remaining: 1m 55s
# 2000:	learn: 3866.1434706	test: 12128.9928748	best: 12128.9928748 (2000)	total: 12.1s	remaining: 1m 48s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12089.42502
# bestIteration = 2399
#
# Shrink model to first 2400 iterations.
# 67
# Learning rate set to 0.009508
# 0:	learn: 23557.2361451	test: 25546.4775337	best: 25546.4775337 (0)	total: 10.3ms	remaining: 3m 25s
# 1000:	learn: 5941.9147727	test: 12438.1963414	best: 12436.8419277 (995)	total: 6.01s	remaining: 1m 54s
# 2000:	learn: 3741.0259288	test: 12127.9863102	best: 12127.0430817 (1999)	total: 12s	remaining: 1m 47s
# 3000:	learn: 2631.5987789	test: 12065.8530695	best: 12064.8039836 (2983)	total: 17.9s	remaining: 1m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12061.30403
# bestIteration = 3126
#
# Shrink model to first 3127 iterations.
# 66
# Learning rate set to 0.009508
# 0:	learn: 23574.9730428	test: 25552.7164464	best: 25552.7164464 (0)	total: 11.1ms	remaining: 3m 42s
# 1000:	learn: 5921.1150625	test: 12387.1743024	best: 12384.3473470 (996)	total: 6.03s	remaining: 1m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12132.35803
# bestIteration = 1716
#
# Shrink model to first 1717 iterations.
# 65
# Learning rate set to 0.009508
# 0:	learn: 23568.1196483	test: 25556.0986999	best: 25556.0986999 (0)	total: 10ms	remaining: 3m 20s
# 1000:	learn: 5998.7961783	test: 12340.6415405	best: 12340.6415405 (1000)	total: 6s	remaining: 1m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12110.68941
# bestIteration = 1410
#
# Shrink model to first 1411 iterations.
# 64
# Learning rate set to 0.009508
# 0:	learn: 23581.0545321	test: 25569.5723527	best: 25569.5723527 (0)	total: 11ms	remaining: 3m 40s
# 1000:	learn: 5964.2926175	test: 12432.1541144	best: 12432.1541144 (1000)	total: 5.92s	remaining: 1m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12192.45111
# bestIteration = 1681
#
# Shrink model to first 1682 iterations.
# 63
# Learning rate set to 0.009508
# 0:	learn: 23568.2526750	test: 25554.4813563	best: 25554.4813563 (0)	total: 7.69ms	remaining: 2m 33s
# 1000:	learn: 6045.2575793	test: 12414.7179368	best: 12414.7179368 (1000)	total: 5.94s	remaining: 1m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12202.02476
# bestIteration = 1698
#
# Shrink model to first 1699 iterations.
# 62
# Learning rate set to 0.009508
# 0:	learn: 23574.9364846	test: 25543.2402584	best: 25543.2402584 (0)	total: 10.2ms	remaining: 3m 23s
# 1000:	learn: 5914.0833546	test: 12466.2761217	best: 12466.2761217 (1000)	total: 6.77s	remaining: 2m 8s
# 2000:	learn: 3720.6421667	test: 12199.2309153	best: 12198.6069864 (1999)	total: 13.4s	remaining: 2m
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12147.43333
# bestIteration = 2669
#
# Shrink model to first 2670 iterations.
# 61
# Learning rate set to 0.009508
# 0:	learn: 23569.8640357	test: 25584.5031172	best: 25584.5031172 (0)	total: 7.34ms	remaining: 2m 26s
# 1000:	learn: 5927.4911796	test: 12351.4484732	best: 12350.9361415 (999)	total: 5.95s	remaining: 1m 52s
# 2000:	learn: 3734.6708434	test: 12074.5431616	best: 12074.5431616 (2000)	total: 11.7s	remaining: 1m 45s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12012.65297
# bestIteration = 2472
#
# Shrink model to first 2473 iterations.
# 60
# Learning rate set to 0.009508
# 0:	learn: 23573.9067544	test: 25551.4881442	best: 25551.4881442 (0)	total: 10.2ms	remaining: 3m 23s
# 1000:	learn: 5942.7626160	test: 12251.6100127	best: 12251.6100127 (1000)	total: 5.79s	remaining: 1m 49s
# 2000:	learn: 3786.9247917	test: 11992.6363464	best: 11991.1368006 (1943)	total: 11.5s	remaining: 1m 43s
# 3000:	learn: 2685.5299443	test: 11923.3863775	best: 11918.2891956 (2905)	total: 17.2s	remaining: 1m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11918.2892
# bestIteration = 2905
#
# Shrink model to first 2906 iterations.
# 59
# Learning rate set to 0.009508
# 0:	learn: 23573.2659852	test: 25562.4439295	best: 25562.4439295 (0)	total: 10.8ms	remaining: 3m 36s
# 1000:	learn: 5962.6779816	test: 12226.9074975	best: 12226.9074975 (1000)	total: 5.7s	remaining: 1m 48s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12071.23441
# bestIteration = 1480
#
# Shrink model to first 1481 iterations.
# 58
# Learning rate set to 0.009508
# 0:	learn: 23571.3665573	test: 25584.1363526	best: 25584.1363526 (0)	total: 9.18ms	remaining: 3m 3s
# 1000:	learn: 5938.0400098	test: 12391.9544497	best: 12391.9178478 (995)	total: 5.67s	remaining: 1m 47s
# 2000:	learn: 3746.8277991	test: 12010.8396823	best: 12010.8396823 (2000)	total: 11.2s	remaining: 1m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11997.46831
# bestIteration = 2222
#
# Shrink model to first 2223 iterations.
# 57
# Learning rate set to 0.009508
# 0:	learn: 23573.4540520	test: 25561.5981269	best: 25561.5981269 (0)	total: 9.08ms	remaining: 3m 1s
# 1000:	learn: 5972.0586783	test: 12265.4716494	best: 12265.4716494 (1000)	total: 5.6s	remaining: 1m 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12021.89805
# bestIteration = 1487
#
# Shrink model to first 1488 iterations.
# 56
# Learning rate set to 0.009508
# 0:	learn: 23569.3240710	test: 25553.5279613	best: 25553.5279613 (0)	total: 9.44ms	remaining: 3m 8s
# 1000:	learn: 5929.6112534	test: 12476.7013592	best: 12476.4173670 (999)	total: 5.63s	remaining: 1m 46s
# 2000:	learn: 3782.4354839	test: 12187.3058286	best: 12186.8577149 (1991)	total: 11.1s	remaining: 1m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12179.6645
# bestIteration = 2073
#
# Shrink model to first 2074 iterations.
# 55
# Learning rate set to 0.009508
# 0:	learn: 23577.3285806	test: 25547.7335907	best: 25547.7335907 (0)	total: 8.86ms	remaining: 2m 57s
# 1000:	learn: 5909.1248593	test: 12327.1541256	best: 12326.6274043 (997)	total: 5.52s	remaining: 1m 44s
# 2000:	learn: 3790.6542924	test: 12049.2675100	best: 12049.2675100 (2000)	total: 11s	remaining: 1m 38s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11978.56175
# bestIteration = 2796
#
# Shrink model to first 2797 iterations.
# 54
# Learning rate set to 0.009508
# 0:	learn: 23554.9951445	test: 25558.3535683	best: 25558.3535683 (0)	total: 9.26ms	remaining: 3m 5s
# 1000:	learn: 5946.3082119	test: 12380.6441487	best: 12380.6441487 (1000)	total: 5.45s	remaining: 1m 43s
# 2000:	learn: 3818.7909451	test: 12128.2162772	best: 12128.2162772 (2000)	total: 10.8s	remaining: 1m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12064.61056
# bestIteration = 2710
#
# Shrink model to first 2711 iterations.
# 53
# Learning rate set to 0.009508
# 0:	learn: 23554.0460335	test: 25543.3264072	best: 25543.3264072 (0)	total: 9.25ms	remaining: 3m 5s
# 1000:	learn: 5989.7765445	test: 12235.0338372	best: 12235.0338372 (1000)	total: 5.31s	remaining: 1m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11987.38065
# bestIteration = 1620
#
# Shrink model to first 1621 iterations.
# 52
# Learning rate set to 0.009508
# 0:	learn: 23561.5142056	test: 25540.5968488	best: 25540.5968488 (0)	total: 9.29ms	remaining: 3m 5s
# 1000:	learn: 5905.1720811	test: 12378.8286460	best: 12378.8286460 (1000)	total: 5.14s	remaining: 1m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12196.9565
# bestIteration = 1467
#
# Shrink model to first 1468 iterations.
# 51
# Learning rate set to 0.009508
# 0:	learn: 23565.4288762	test: 25543.6219278	best: 25543.6219278 (0)	total: 8.73ms	remaining: 2m 54s
# 1000:	learn: 5951.3766166	test: 12320.1306893	best: 12320.1306893 (1000)	total: 5.15s	remaining: 1m 37s
# 2000:	learn: 3815.1516519	test: 12007.2703365	best: 12006.5518026 (1997)	total: 10.2s	remaining: 1m 32s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11973.32282
# bestIteration = 2169
#
# Shrink model to first 2170 iterations.
# 50
# Learning rate set to 0.009508
# 0:	learn: 23562.7659887	test: 25550.4714256	best: 25550.4714256 (0)	total: 7.53ms	remaining: 2m 30s
# 1000:	learn: 5967.8431307	test: 12288.2231095	best: 12288.2231095 (1000)	total: 5.14s	remaining: 1m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12023.12959
# bestIteration = 1750
#
# Shrink model to first 1751 iterations.
# 49
# Learning rate set to 0.009508
# 0:	learn: 23569.4057894	test: 25556.7753091	best: 25556.7753091 (0)	total: 9.36ms	remaining: 3m 7s
# 1000:	learn: 6003.3205516	test: 12126.5004147	best: 12126.5004147 (1000)	total: 5.09s	remaining: 1m 36s
# 2000:	learn: 3850.1880511	test: 11824.3117419	best: 11816.8743909 (1929)	total: 10.1s	remaining: 1m 31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11816.87439
# bestIteration = 1929
#
# Shrink model to first 1930 iterations.
# 48
# Learning rate set to 0.009508
# 0:	learn: 23566.9470951	test: 25553.2139253	best: 25553.2139253 (0)	total: 7.4ms	remaining: 2m 27s
# 1000:	learn: 5878.1480023	test: 12502.3159828	best: 12502.3159828 (1000)	total: 5.05s	remaining: 1m 35s
# 2000:	learn: 3687.4208597	test: 12238.6039490	best: 12238.4953887 (1999)	total: 10.1s	remaining: 1m 30s
# 3000:	learn: 2614.8397132	test: 12163.9740600	best: 12162.8945113 (2922)	total: 15.1s	remaining: 1m 25s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12151.43496
# bestIteration = 3270
#
# Shrink model to first 3271 iterations.
# 47
# Learning rate set to 0.009508
# 0:	learn: 23565.7412734	test: 25553.0387229	best: 25553.0387229 (0)	total: 9.97ms	remaining: 3m 19s
# 1000:	learn: 5961.6656645	test: 12346.4768950	best: 12346.4768950 (1000)	total: 5.06s	remaining: 1m 35s
# 2000:	learn: 3694.5814561	test: 12082.8470064	best: 12082.5607400 (1997)	total: 10.1s	remaining: 1m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12031.20308
# bestIteration = 2712
#
# Shrink model to first 2713 iterations.
# 46
# Learning rate set to 0.009508
# 0:	learn: 23566.6986958	test: 25558.3817839	best: 25558.3817839 (0)	total: 6.89ms	remaining: 2m 17s
# 1000:	learn: 5867.4241010	test: 12278.5031239	best: 12278.5031239 (1000)	total: 5.02s	remaining: 1m 35s
# 2000:	learn: 3726.3081033	test: 12044.2430262	best: 12042.5879620 (1994)	total: 9.95s	remaining: 1m 29s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12014.82859
# bestIteration = 2379
#
# Shrink model to first 2380 iterations.
# 45
# Learning rate set to 0.009508
# 0:	learn: 23567.8251225	test: 25550.4521606	best: 25550.4521606 (0)	total: 9.79ms	remaining: 3m 15s
# 1000:	learn: 5994.1787563	test: 12206.2349907	best: 12206.2349907 (1000)	total: 4.9s	remaining: 1m 33s
# 2000:	learn: 3757.6964808	test: 11863.7929579	best: 11862.9240551 (1984)	total: 9.77s	remaining: 1m 27s
# 3000:	learn: 2666.2958553	test: 11758.9566384	best: 11757.8328405 (2920)	total: 14.6s	remaining: 1m 22s
# 4000:	learn: 1984.9650018	test: 11717.6627250	best: 11717.3091054 (3930)	total: 19.5s	remaining: 1m 17s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11717.30911
# bestIteration = 3930
#
# Shrink model to first 3931 iterations.
# 44
# Learning rate set to 0.009508
# 0:	learn: 23572.0327248	test: 25573.3689454	best: 25573.3689454 (0)	total: 6.96ms	remaining: 2m 19s
# 1000:	learn: 5915.5147317	test: 12257.1707896	best: 12257.1707896 (1000)	total: 4.88s	remaining: 1m 32s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12092.94078
# bestIteration = 1431
#
# Shrink model to first 1432 iterations.
# 43
# Learning rate set to 0.009508
# 0:	learn: 23559.0889448	test: 25527.7598544	best: 25527.7598544 (0)	total: 8.41ms	remaining: 2m 48s
# 1000:	learn: 5949.0875450	test: 12114.8847297	best: 12114.6954867 (998)	total: 4.75s	remaining: 1m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11924.99787
# bestIteration = 1519
#
# Shrink model to first 1520 iterations.
# 42
# Learning rate set to 0.009508
# 0:	learn: 23567.9512573	test: 25538.9516728	best: 25538.9516728 (0)	total: 8.23ms	remaining: 2m 44s
# 1000:	learn: 5998.1911420	test: 12299.7098770	best: 12299.7098770 (1000)	total: 4.73s	remaining: 1m 29s
# 2000:	learn: 3732.7368504	test: 12006.5081011	best: 12006.4135354 (1999)	total: 9.43s	remaining: 1m 24s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11944.16322
# bestIteration = 2832
#
# Shrink model to first 2833 iterations.
# 41
# Learning rate set to 0.009508
# 0:	learn: 23555.1860716	test: 25549.3116106	best: 25549.3116106 (0)	total: 7.14ms	remaining: 2m 22s
# 1000:	learn: 5883.8213769	test: 12288.7038302	best: 12288.7038302 (1000)	total: 4.74s	remaining: 1m 30s
# 2000:	learn: 3786.7987166	test: 12057.5172471	best: 12055.9880531 (1984)	total: 9.37s	remaining: 1m 24s
# 3000:	learn: 2632.1520758	test: 11994.1781420	best: 11993.8713071 (2991)	total: 14.4s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11982.66673
# bestIteration = 3212
#
# Shrink model to first 3213 iterations.
# 40
# Learning rate set to 0.009508
# 0:	learn: 23579.5525510	test: 25570.2898514	best: 25570.2898514 (0)	total: 9.45ms	remaining: 3m 8s
# 1000:	learn: 5938.8116221	test: 12274.0915189	best: 12274.0915189 (1000)	total: 5.16s	remaining: 1m 37s
# 2000:	learn: 3734.8203119	test: 11973.6278904	best: 11973.0168613 (1997)	total: 10.3s	remaining: 1m 32s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11967.33017
# bestIteration = 2056
#
# Shrink model to first 2057 iterations.
# 39
# Learning rate set to 0.009508
# 0:	learn: 23566.1298541	test: 25545.1534729	best: 25545.1534729 (0)	total: 6.84ms	remaining: 2m 16s
# 1000:	learn: 5933.7233208	test: 12281.7969650	best: 12281.7969650 (1000)	total: 4.66s	remaining: 1m 28s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12127.41456
# bestIteration = 1326
#
# Shrink model to first 1327 iterations.
# 38
# Learning rate set to 0.009508
# 0:	learn: 23565.9827791	test: 25524.6067172	best: 25524.6067172 (0)	total: 7.98ms	remaining: 2m 39s
# 1000:	learn: 5934.1846857	test: 12343.1447148	best: 12342.6366329 (999)	total: 4.62s	remaining: 1m 27s
# 2000:	learn: 3775.8609232	test: 12113.6540345	best: 12113.6540345 (2000)	total: 9.15s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12059.71829
# bestIteration = 2593
#
# Shrink model to first 2594 iterations.
# 37
# Learning rate set to 0.009508
# 0:	learn: 23582.0989748	test: 25571.4777599	best: 25571.4777599 (0)	total: 8.18ms	remaining: 2m 43s
# 1000:	learn: 5969.1571884	test: 12261.1142847	best: 12261.1142847 (1000)	total: 4.44s	remaining: 1m 24s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11990.17761
# bestIteration = 1760
#
# Shrink model to first 1761 iterations.
# 36
# Learning rate set to 0.009508
# 0:	learn: 23569.0276070	test: 25566.1620488	best: 25566.1620488 (0)	total: 7.98ms	remaining: 2m 39s
# 1000:	learn: 6026.3682890	test: 12265.0988527	best: 12264.7847251 (999)	total: 4.44s	remaining: 1m 24s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12052.95713
# bestIteration = 1783
#
# Shrink model to first 1784 iterations.
# 35
# Learning rate set to 0.009508
# 0:	learn: 23580.6239244	test: 25568.2827477	best: 25568.2827477 (0)	total: 9.53ms	remaining: 3m 10s
# 1000:	learn: 5915.8266436	test: 12054.3725039	best: 12054.3725039 (1000)	total: 4.28s	remaining: 1m 21s
# 2000:	learn: 3800.5913087	test: 11806.3034380	best: 11806.3034380 (2000)	total: 8.5s	remaining: 1m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11721.94498
# bestIteration = 2773
#
# Shrink model to first 2774 iterations.
# 34
# Learning rate set to 0.009508
# 0:	learn: 23563.4862463	test: 25552.8393691	best: 25552.8393691 (0)	total: 9.4ms	remaining: 3m 7s
# 1000:	learn: 6010.2078751	test: 12230.0537229	best: 12229.6139152 (999)	total: 4.07s	remaining: 1m 17s
# 2000:	learn: 3825.6954943	test: 11981.9430169	best: 11981.9430169 (2000)	total: 8.16s	remaining: 1m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11892.29197
# bestIteration = 2514
#
# Shrink model to first 2515 iterations.
# 33
# Learning rate set to 0.009508
# 0:	learn: 23566.1169924	test: 25550.4031377	best: 25550.4031377 (0)	total: 8.32ms	remaining: 2m 46s
# 1000:	learn: 5944.2757146	test: 12131.8249863	best: 12131.5893103 (999)	total: 4.39s	remaining: 1m 23s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11945.7362
# bestIteration = 1389
#
# Shrink model to first 1390 iterations.
# 32
# Learning rate set to 0.009508
# 0:	learn: 23573.1430827	test: 25558.4118075	best: 25558.4118075 (0)	total: 8.24ms	remaining: 2m 44s
# 1000:	learn: 6007.6557185	test: 12057.7128923	best: 12057.7128923 (1000)	total: 4.04s	remaining: 1m 16s
# 2000:	learn: 3821.1999956	test: 11768.6302083	best: 11768.6302083 (2000)	total: 8.03s	remaining: 1m 12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11716.61451
# bestIteration = 2357
#
# Shrink model to first 2358 iterations.
# 31
# Learning rate set to 0.009508
# 0:	learn: 23574.4822765	test: 25562.5467526	best: 25562.5467526 (0)	total: 8.22ms	remaining: 2m 44s
# 1000:	learn: 6012.2234658	test: 12126.9455821	best: 12126.6719474 (996)	total: 3.95s	remaining: 1m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11961.43197
# bestIteration = 1552
#
# Shrink model to first 1553 iterations.
# 30
# Learning rate set to 0.009508
# 0:	learn: 23560.2972215	test: 25553.0200787	best: 25553.0200787 (0)	total: 6.03ms	remaining: 2m
# 1000:	learn: 6081.3400192	test: 12129.1293225	best: 12129.1293225 (1000)	total: 3.77s	remaining: 1m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11974.21246
# bestIteration = 1388
#
# Shrink model to first 1389 iterations.
# 29
# Learning rate set to 0.009508
# 0:	learn: 23586.7637871	test: 25551.1962783	best: 25551.1962783 (0)	total: 5.75ms	remaining: 1m 55s
# 1000:	learn: 6042.8445322	test: 12184.9719837	best: 12184.4827715 (999)	total: 3.75s	remaining: 1m 11s
# 2000:	learn: 3863.8920524	test: 11933.8699708	best: 11932.9178837 (1991)	total: 7.46s	remaining: 1m 7s
# 3000:	learn: 2783.7687978	test: 11824.0452512	best: 11824.0299092 (2998)	total: 11.2s	remaining: 1m 3s
# 4000:	learn: 2104.2394251	test: 11775.8167900	best: 11775.8167900 (4000)	total: 14.9s	remaining: 59.6s
# 5000:	learn: 1663.3187964	test: 11747.7681335	best: 11747.7681335 (5000)	total: 18.7s	remaining: 56s
# 6000:	learn: 1358.8835979	test: 11725.0205868	best: 11724.9312074 (5995)	total: 22.4s	remaining: 52.3s
# 7000:	learn: 1143.8090802	test: 11713.8881638	best: 11713.8881638 (7000)	total: 26.2s	remaining: 48.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11712.40921
# bestIteration = 7044
#
# Shrink model to first 7045 iterations.
# 28
# Learning rate set to 0.009508
# 0:	learn: 23553.3472125	test: 25544.8420048	best: 25544.8420048 (0)	total: 5.98ms	remaining: 1m 59s
# 1000:	learn: 5977.0811975	test: 12143.2592539	best: 12142.1071616 (996)	total: 3.62s	remaining: 1m 8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12011.60948
# bestIteration = 1334
#
# Shrink model to first 1335 iterations.
# 27
# Learning rate set to 0.009508
# 0:	learn: 23542.8609791	test: 25532.9497456	best: 25532.9497456 (0)	total: 5.47ms	remaining: 1m 49s
# 1000:	learn: 6054.7221611	test: 12079.3665082	best: 12079.3665082 (1000)	total: 3.53s	remaining: 1m 7s
# 2000:	learn: 3824.0824936	test: 11843.5664139	best: 11843.5664139 (2000)	total: 7.04s	remaining: 1m 3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11825.9516
# bestIteration = 2187
#
# Shrink model to first 2188 iterations.
# 26
# Learning rate set to 0.009508
# 0:	learn: 23560.6574989	test: 25513.1198753	best: 25513.1198753 (0)	total: 5.65ms	remaining: 1m 53s
# 1000:	learn: 6076.5195772	test: 12175.3433073	best: 12175.3433073 (1000)	total: 3.41s	remaining: 1m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12004.38667
# bestIteration = 1539
#
# Shrink model to first 1540 iterations.
# 25
# Learning rate set to 0.009508
# 0:	learn: 23561.5916233	test: 25532.6995059	best: 25532.6995059 (0)	total: 4.98ms	remaining: 1m 39s
# 1000:	learn: 6161.0250266	test: 12099.2157354	best: 12099.0686062 (998)	total: 3.81s	remaining: 1m 12s
# 2000:	learn: 3868.6195268	test: 11824.5618161	best: 11821.6849891 (1968)	total: 7.36s	remaining: 1m 6s
# 3000:	learn: 2778.5727453	test: 11672.8697992	best: 11672.1955358 (2995)	total: 10.8s	remaining: 1m 1s
# 4000:	learn: 2104.9761565	test: 11592.5786216	best: 11591.9120440 (3990)	total: 14.2s	remaining: 56.6s
# 5000:	learn: 1676.1304501	test: 11541.9839138	best: 11541.9383617 (4999)	total: 17.5s	remaining: 52.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11523.72867
# bestIteration = 5748
#
# Shrink model to first 5749 iterations.
# 24
# Learning rate set to 0.009508
# 0:	learn: 23557.6316350	test: 25553.8496906	best: 25553.8496906 (0)	total: 7.12ms	remaining: 2m 22s
# 1000:	learn: 6112.1461054	test: 12420.6438830	best: 12420.6438830 (1000)	total: 3.4s	remaining: 1m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12307.14885
# bestIteration = 1236
#
# Shrink model to first 1237 iterations.
# 23
# Learning rate set to 0.009508
# 0:	learn: 23574.2248126	test: 25547.5080652	best: 25547.5080652 (0)	total: 6.68ms	remaining: 2m 13s
# 1000:	learn: 6201.8800860	test: 12117.7565689	best: 12117.7565689 (1000)	total: 3.33s	remaining: 1m 3s
# 2000:	learn: 3949.3031366	test: 11897.2295373	best: 11897.2295373 (2000)	total: 6.64s	remaining: 59.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11819.85111
# bestIteration = 2499
#
# Shrink model to first 2500 iterations.
# 22
# Learning rate set to 0.009508
# 0:	learn: 23570.6738659	test: 25556.7079132	best: 25556.7079132 (0)	total: 7.07ms	remaining: 2m 21s
# 1000:	learn: 5833.2683270	test: 11933.3561540	best: 11932.2544730 (998)	total: 3.33s	remaining: 1m 3s
# 2000:	learn: 3784.8609189	test: 11745.2776569	best: 11742.8656423 (1987)	total: 6.63s	remaining: 59.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11667.27424
# bestIteration = 2639
#
# Shrink model to first 2640 iterations.
# 21
# Learning rate set to 0.009508
# 0:	learn: 23579.3893853	test: 25575.0228558	best: 25575.0228558 (0)	total: 5.34ms	remaining: 1m 46s
# 1000:	learn: 5852.7266861	test: 12059.4707915	best: 12058.5690069 (998)	total: 3.26s	remaining: 1m 1s
# 2000:	learn: 3692.5552932	test: 11766.7739242	best: 11766.5809760 (1980)	total: 6.51s	remaining: 58.6s
# 3000:	learn: 2719.2048967	test: 11686.2672518	best: 11685.5270230 (2997)	total: 9.74s	remaining: 55.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11675.86591
# bestIteration = 3073
#
# Shrink model to first 3074 iterations.
# 20
# Learning rate set to 0.009508
# 0:	learn: 23557.7350437	test: 25548.7097006	best: 25548.7097006 (0)	total: 7.37ms	remaining: 2m 27s
# 1000:	learn: 5685.5606346	test: 11936.0262497	best: 11934.2414559 (999)	total: 3.24s	remaining: 1m 1s
# 2000:	learn: 3684.8435648	test: 11591.1734826	best: 11591.1734826 (2000)	total: 6.43s	remaining: 57.9s
# 3000:	learn: 2653.1291415	test: 11411.5429116	best: 11411.1487141 (2999)	total: 9.65s	remaining: 54.7s
# 4000:	learn: 2025.7407215	test: 11338.9811759	best: 11338.4748524 (3997)	total: 12.9s	remaining: 51.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11332.14383
# bestIteration = 4207
#
# Shrink model to first 4208 iterations.
# 19
# Learning rate set to 0.009508
# 0:	learn: 23571.1846956	test: 25544.5613035	best: 25544.5613035 (0)	total: 7.16ms	remaining: 2m 23s
# 1000:	learn: 5706.3889092	test: 12070.4464897	best: 12070.4464897 (1000)	total: 3.06s	remaining: 58.1s
# 2000:	learn: 3668.3000483	test: 11679.2754695	best: 11678.9811097 (1998)	total: 6.07s	remaining: 54.6s
# 3000:	learn: 2696.7251369	test: 11512.2756980	best: 11511.6599816 (2996)	total: 9.06s	remaining: 51.3s
# 4000:	learn: 2125.1654122	test: 11429.1894120	best: 11429.1894120 (4000)	total: 12.1s	remaining: 48.3s
# 5000:	learn: 1725.2548345	test: 11393.0400992	best: 11392.6055671 (4978)	total: 15.1s	remaining: 45.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11381.45287
# bestIteration = 5467
#
# Shrink model to first 5468 iterations.
# 18
# Learning rate set to 0.009508
# 0:	learn: 23562.3000544	test: 25553.1059839	best: 25553.1059839 (0)	total: 5.4ms	remaining: 1m 47s
# 1000:	learn: 5722.3085171	test: 12117.1344036	best: 12117.1344036 (1000)	total: 2.87s	remaining: 54.4s
# 2000:	learn: 3694.5124532	test: 11771.9257033	best: 11771.9257033 (2000)	total: 5.66s	remaining: 50.9s
# 3000:	learn: 2741.8541016	test: 11646.2851543	best: 11646.2342653 (2999)	total: 8.5s	remaining: 48.1s
# 4000:	learn: 2142.6735556	test: 11578.6138097	best: 11578.3316535 (3990)	total: 11.3s	remaining: 45.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11568.48549
# bestIteration = 4305
#
# Shrink model to first 4306 iterations.
# 17
# Learning rate set to 0.009508
# 0:	learn: 23572.4187088	test: 25547.6048702	best: 25547.6048702 (0)	total: 4.63ms	remaining: 1m 32s
# 1000:	learn: 5702.1613306	test: 11937.6769735	best: 11937.1785057 (999)	total: 2.82s	remaining: 53.5s
# 2000:	learn: 3758.8481669	test: 11614.4769485	best: 11613.0286143 (1995)	total: 5.55s	remaining: 49.9s
# 3000:	learn: 2816.4068550	test: 11455.7346726	best: 11455.5428065 (2998)	total: 8.29s	remaining: 47s
# 4000:	learn: 2222.7423094	test: 11369.0541461	best: 11369.0229335 (3997)	total: 11s	remaining: 44.2s
# 5000:	learn: 1825.7069215	test: 11334.6822026	best: 11334.3066746 (4998)	total: 13.8s	remaining: 41.4s
# 6000:	learn: 1539.5033562	test: 11294.6774659	best: 11294.4028448 (5998)	total: 16.5s	remaining: 38.6s
# 7000:	learn: 1316.4569198	test: 11275.8864645	best: 11275.8792276 (6979)	total: 19.3s	remaining: 35.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11275.4971
# bestIteration = 7005
#
# Shrink model to first 7006 iterations.
# 16
# Learning rate set to 0.009508
# 0:	learn: 23564.5278213	test: 25553.1807185	best: 25553.1807185 (0)	total: 4.81ms	remaining: 1m 36s
# 1000:	learn: 5755.6128162	test: 12008.6167676	best: 12008.6167676 (1000)	total: 2.74s	remaining: 52s
# 2000:	learn: 3781.7062256	test: 11571.3729066	best: 11570.9033247 (1996)	total: 5.46s	remaining: 49.2s
# 3000:	learn: 2860.0793745	test: 11400.7554242	best: 11399.8942680 (2998)	total: 8.13s	remaining: 46.1s
# 4000:	learn: 2304.4800089	test: 11347.2385755	best: 11346.6190341 (3952)	total: 10.8s	remaining: 43.2s
# 5000:	learn: 1887.8258976	test: 11308.5111916	best: 11308.5111916 (5000)	total: 13.5s	remaining: 40.5s
# 6000:	learn: 1599.6127364	test: 11281.3758868	best: 11280.9464079 (5990)	total: 16.2s	remaining: 37.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11276.89503
# bestIteration = 6340
#
# Shrink model to first 6341 iterations.
# 15
# Learning rate set to 0.009508
# 0:	learn: 23554.5059852	test: 25540.5480383	best: 25540.5480383 (0)	total: 5.44ms	remaining: 1m 48s
# 1000:	learn: 5925.2022093	test: 12155.2215773	best: 12155.2215773 (1000)	total: 3.02s	remaining: 57.3s
# 2000:	learn: 4030.6956223	test: 11948.6042201	best: 11948.1222312 (1998)	total: 6.07s	remaining: 54.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11857.79364
# bestIteration = 2652
#
# Shrink model to first 2653 iterations.
# 14
# Learning rate set to 0.009508
# 0:	learn: 23558.5827021	test: 25523.7568698	best: 25523.7568698 (0)	total: 3.22ms	remaining: 1m 4s
# 1000:	learn: 5885.6367769	test: 12128.6479775	best: 12128.6479775 (1000)	total: 3s	remaining: 57s
# 2000:	learn: 4063.3703110	test: 11836.7253450	best: 11836.2960531 (1999)	total: 5.78s	remaining: 52s
# 3000:	learn: 3063.5767628	test: 11670.1488299	best: 11670.1488299 (3000)	total: 8.49s	remaining: 48.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11644.25694
# bestIteration = 3301
#
# Shrink model to first 3302 iterations.
# 13
# Learning rate set to 0.009508
# 0:	learn: 23567.5136116	test: 25555.4546176	best: 25555.4546176 (0)	total: 4.09ms	remaining: 1m 21s
# 1000:	learn: 5902.5321294	test: 12084.2382200	best: 12084.2114187 (998)	total: 2.64s	remaining: 50.2s
# 2000:	learn: 3944.4625660	test: 11763.7645809	best: 11761.9154373 (1991)	total: 5.21s	remaining: 46.9s
# 3000:	learn: 3005.0158513	test: 11672.2643470	best: 11672.2643470 (3000)	total: 7.79s	remaining: 44.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11594.84923
# bestIteration = 3845
#
# Shrink model to first 3846 iterations.
# 12
# Learning rate set to 0.009508
# 0:	learn: 23569.7118973	test: 25556.7354947	best: 25556.7354947 (0)	total: 4.13ms	remaining: 1m 22s
# 1000:	learn: 5937.6141981	test: 12216.5970179	best: 12216.5970179 (1000)	total: 2.5s	remaining: 47.5s
# 2000:	learn: 3890.4827946	test: 11840.7488307	best: 11840.4059069 (1998)	total: 4.98s	remaining: 44.8s
# 3000:	learn: 2992.0819379	test: 11688.0039312	best: 11687.2485081 (2964)	total: 7.48s	remaining: 42.4s
# 4000:	learn: 2408.2353316	test: 11623.8294486	best: 11622.7492696 (3992)	total: 9.96s	remaining: 39.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11593.92222
# bestIteration = 4889
#
# Shrink model to first 4890 iterations.
# 11
# Learning rate set to 0.009508
# 0:	learn: 23560.0207595	test: 25531.4307811	best: 25531.4307811 (0)	total: 3.8ms	remaining: 1m 15s
# 1000:	learn: 6027.8402966	test: 12289.8806722	best: 12289.4719701 (992)	total: 2.48s	remaining: 47.1s
# 2000:	learn: 4092.0535939	test: 12004.8364370	best: 12004.8364370 (2000)	total: 4.91s	remaining: 44.2s
# 3000:	learn: 3127.8297084	test: 11844.1927997	best: 11843.7971711 (2996)	total: 7.34s	remaining: 41.6s
# 4000:	learn: 2469.6052516	test: 11757.3811021	best: 11755.4597888 (3930)	total: 9.81s	remaining: 39.2s
# 5000:	learn: 2043.7048886	test: 11712.4435019	best: 11712.3251588 (4995)	total: 12.2s	remaining: 36.7s
# 6000:	learn: 1725.8645595	test: 11681.0561397	best: 11680.9365667 (5974)	total: 14.7s	remaining: 34.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11677.14071
# bestIteration = 6290
#
# Shrink model to first 6291 iterations.
# 10
# Learning rate set to 0.009508
# 0:	learn: 23571.1746273	test: 25561.0633804	best: 25561.0633804 (0)	total: 3.72ms	remaining: 1m 14s
# 1000:	learn: 6037.1042478	test: 12136.7077263	best: 12136.7077263 (1000)	total: 2.42s	remaining: 45.8s
# 2000:	learn: 4120.7425623	test: 11796.7200722	best: 11796.4042666 (1963)	total: 4.81s	remaining: 43.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11780.38077
# bestIteration = 2116
#
# Shrink model to first 2117 iterations.
# 9
# Learning rate set to 0.009508
# 0:	learn: 23556.8256441	test: 25524.1126142	best: 25524.1126142 (0)	total: 4.66ms	remaining: 1m 33s
# 1000:	learn: 6160.7223528	test: 12610.1454191	best: 12610.1454191 (1000)	total: 2.36s	remaining: 44.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12447.26409
# bestIteration = 1619
#
# Shrink model to first 1620 iterations.
# 8
# Learning rate set to 0.009508
# 0:	learn: 23566.0198143	test: 25545.7214662	best: 25545.7214662 (0)	total: 3.69ms	remaining: 1m 13s
# 1000:	learn: 6396.3078826	test: 12514.6597989	best: 12514.6597989 (1000)	total: 2.32s	remaining: 44s
# 2000:	learn: 4517.4746718	test: 12192.9709252	best: 12189.7401265 (1962)	total: 4.61s	remaining: 41.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12189.74013
# bestIteration = 1962
#
# Shrink model to first 1963 iterations.
# 7
# Learning rate set to 0.009508
# 0:	learn: 23564.2711899	test: 25546.7668385	best: 25546.7668385 (0)	total: 4.62ms	remaining: 1m 32s
# 1000:	learn: 6887.0186611	test: 12743.4337209	best: 12743.4337209 (1000)	total: 2.32s	remaining: 44s
# 2000:	learn: 5040.1519506	test: 12305.1412839	best: 12304.3373135 (1995)	total: 4.61s	remaining: 41.5s
# 3000:	learn: 3875.8840307	test: 12076.9889983	best: 12076.8752502 (2999)	total: 6.94s	remaining: 39.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12060.75234
# bestIteration = 3240
#
# Shrink model to first 3241 iterations.
# 6
# Learning rate set to 0.009508
# 0:	learn: 23563.7342910	test: 25523.6183890	best: 25523.6183890 (0)	total: 2.45ms	remaining: 48.9s
# 1000:	learn: 7155.9768309	test: 12933.5048332	best: 12933.0939850 (997)	total: 2.27s	remaining: 43s
# 2000:	learn: 5201.1690345	test: 12719.7722965	best: 12717.1281924 (1980)	total: 4.49s	remaining: 40.4s
# 3000:	learn: 4174.6766723	test: 12580.1613713	best: 12577.0950683 (2961)	total: 6.72s	remaining: 38s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12577.09507
# bestIteration = 2961
#
# Shrink model to first 2962 iterations.
# 5
# Learning rate set to 0.009508
# 0:	learn: 23569.5197962	test: 25518.6142149	best: 25518.6142149 (0)	total: 4.09ms	remaining: 1m 21s
# 1000:	learn: 7546.7041575	test: 12715.7145125	best: 12714.3511036 (998)	total: 2.2s	remaining: 41.8s
# 2000:	learn: 5594.8057863	test: 11857.5603477	best: 11857.5603477 (2000)	total: 4.37s	remaining: 39.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11716.18964
# bestIteration = 2288
#
# Shrink model to first 2289 iterations.
# 4
# Learning rate set to 0.009508
# 0:	learn: 23562.2566385	test: 25545.0120734	best: 25545.0120734 (0)	total: 2.4ms	remaining: 47.9s
# 1000:	learn: 8668.6928675	test: 13266.2821755	best: 13266.2821755 (1000)	total: 2.17s	remaining: 41.2s
# 2000:	learn: 6661.0570358	test: 12485.7329186	best: 12485.5975701 (1998)	total: 4.31s	remaining: 38.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12378.45917
# bestIteration = 2321
#
# Shrink model to first 2322 iterations.
# 3
# Learning rate set to 0.009508
# 0:	learn: 23561.9447213	test: 25535.3259769	best: 25535.3259769 (0)	total: 2.4ms	remaining: 48s
# 1000:	learn: 10081.1124690	test: 15207.7907724	best: 15205.7076680 (994)	total: 2.14s	remaining: 40.7s
# 2000:	learn: 8280.4333927	test: 14707.9473251	best: 14707.2640816 (1998)	total: 4.3s	remaining: 38.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 14642.99439
# bestIteration = 2199
#
# Shrink model to first 2200 iterations.
# 2
# Learning rate set to 0.009508
# 0:	learn: 23566.2565427	test: 25527.9478387	best: 25527.9478387 (0)	total: 2.39ms	remaining: 47.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 16523.58974
# bestIteration = 481
#
# Shrink model to first 482 iterations.

# %%
# train, test 분할
col_dict, X, y = Xy_split(pitcher)

# 변수의 순위도출
model = LinearRegression()
selector = RFE(model, n_features_to_select = 1, step = 1)
selector = selector.fit(X, y)

# 데이터프레임으로 생성
pitcher_regression = pd.DataFrame({'변수명':list(col_dict.keys()),
                                   '실제변수명':list(col_dict.values()),
                                   'regression순위':list(selector.ranking_)})

# %% [markdown]
# # 데이터프레임 병합

# %%
hitter_final = pd.merge(hitter_rf, hitter_lgbm, on=['변수명','실제변수명'], how='left')
hitter_final = pd.merge(hitter_final, hitter_xgb, on=['변수명','실제변수명'], how='left')
hitter_final = pd.merge(hitter_final, hitter_cb, on=['변수명','실제변수명'], how='left')
hitter_final = pd.merge(hitter_final, hitter_regression, on=['변수명','실제변수명'], how='left')
hitter_final
# Out:
#            변수명        실제변수명  rf순위  lgbm순위  xgb순위  cb순위  regression순위
# 0    variable1         데뷔년도     5      11      3     5            53
# 1    variable2           연도     9      15     11     6            70
# 2    variable3           타율    10      30      4    32             9
# 3    variable4           경기    21      13      9    38            82
# 4    variable5           타석    61      42     13    46            42
# ..         ...          ...   ...     ...    ...   ...           ...
# 80  variable81  포지션(수비)_우익수    78      81     66    77            57
# 81  variable82  포지션(수비)_유격수    79      82     84    76            51
# 82  variable83  포지션(수비)_좌익수    74      83     73    71            36
# 83  variable84  포지션(수비)_중견수    67      84     71    73            23
# 84  variable85   포지션(수비)_포수    75      85     83    72            54
#
# [85 rows x 7 columns]

# %%
pitcher_final = pd.merge(pitcher_rf, pitcher_lgbm, on=['변수명','실제변수명'], how='left')
pitcher_final = pd.merge(pitcher_final, pitcher_xgb, on=['변수명','실제변수명'], how='left')
pitcher_final = pd.merge(pitcher_final, pitcher_cb, on=['변수명','실제변수명'], how='left')
pitcher_final = pd.merge(pitcher_final, pitcher_regression, on=['변수명','실제변수명'], how='left')
pitcher_final
# Out:
#            변수명             실제변수명  rf순위  lgbm순위  xgb순위  cb순위  regression순위
# 0    variable1              데뷔년도    15       3      4    12            32
# 1    variable2                연도    11      19      9    10            31
# 2    variable3             평균자책점    30      29      2    19            64
# 3    variable4                경기    37      39     10    37            27
# 4    variable5                승리    68      44     39    52            45
# ..         ...               ...   ...     ...    ...   ...           ...
# 75  variable76             팀명_롯데    46      59     60    40            18
# 76  variable77             팀명_삼성    42      71     70    45            17
# 77  variable78  팀명_우리/히어로즈/넥센/키움    78      79     69    75            13
# 78  variable79             팀명_한화    53      64     62    50            60
# 79  variable80             팀명_현대    77      80     80    80            24
#
# [80 rows x 7 columns]

# %%
hitter_final.to_csv('../변수중요도데이터/RFE_타자.csv', index=False, encoding='utf-8-sig')
pitcher_final.to_csv('../변수중요도데이터/RFE_투수.csv', index=False, encoding='utf-8-sig')
