# %% [markdown]
# # 패키지 불러오기

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import xgboost as xgb

from catboost import Pool, CatBoostRegressor
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler


n_splits = 5

# %% [markdown]
# # 모델 정의
#  1. Random Forest
#  2. Lightgbm
#  3. Xgboost
#  4. Catboost
#  5. Knn
#  6. Linear regression

# %%
def Xy_split(dataset):
    
    X = dataset.drop('연봉', axis=1)
    column_dict = {f'variable{idx+1}':col for idx, col in enumerate(X.columns)}
    X = X.rename(columns = {col:f'variable{idx+1}' for idx, col in enumerate(X.columns)})
    y = dataset['연봉']
    
    return column_dict, X, y

# %%
def rf_model(data_x, data_y):

    # rf 모델링
    performance = []
    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :]
        y_train = data_y[tr_idx]

        X_valid = data_x.iloc[val_idx, :]
        y_valid = data_y[val_idx]

        rf_model = RandomForestRegressor(random_state = 42)
        rf_model.fit(X_train, y_train)

        pred_valid = rf_model.predict(X_valid)
        rmse = mean_squared_error(y_valid, pred_valid, squared=False)
        performance.append(rmse)
        
    # rf 성능종합
    performance.append(np.mean(performance))

    output = pd.DataFrame({'rf':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %%
def lgbm_model(data_x, data_y):

    # lgbm 모델링
    lgb_params = {"objective" : "rmse",
                 "verbosity" : -1}

    lgb_models={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        print(f'\n\n ============================ {step} ============================')    

        X_train = data_x.iloc[tr_idx, :].values
        y_train = data_y[tr_idx].values

        X_valid = data_x.iloc[val_idx, :].values
        y_valid = data_y[val_idx].values

        lgb_dtrain = lgb.Dataset(data = X_train, label = y_train) 
        lgb_dvalid = lgb.Dataset(data = X_valid, label = y_valid) 

        lgb_model = lgb.train(lgb_params, lgb_dtrain, 20000, valid_sets=[lgb_dvalid], early_stopping_rounds=100, verbose_eval=1000)
        lgb_models[step] = lgb_model

        step += 1
        
    # lgbm 성능종합
    performance = [lgb_models[step].best_score['valid_0']['rmse'] for step in range(1,6)]
    performance.append(np.mean(performance))

    output = pd.DataFrame({'lgbm':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %%
def xgb_model(data_x, data_y):
    
    # xgb 모델링
    xgb_final_param = {
          "objective" : 'reg:squarederror',
          "random_state" : 42,
          "verbosity" : 0
          }

    xgb_models={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :].values
        y_train = data_y[tr_idx].values

        X_valid = data_x.iloc[val_idx, :].values
        y_valid = data_y[val_idx].values

        xgb_dtrain = xgb.DMatrix(data = X_train, label = y_train) 
        xgb_dvalid = xgb.DMatrix(data = X_valid, label = y_valid) 

        xgb_model = xgb.train(params = xgb_final_param, dtrain = xgb_dtrain, num_boost_round = 20000, early_stopping_rounds = 100, verbose_eval = 1000, evals=[(xgb_dtrain, 'train'), (xgb_dvalid,'eval')])
        xgb_models[step] = xgb_model

        step += 1
        
    # xgb 성능종합
    performance = [xgb_models[step].best_score for step in range(1,6)]
    performance.append(np.mean(performance))

    output = pd.DataFrame({'xgb':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %%
def cb_model(data_x, data_y):

    # cb 모델링
    cat_cols = []

    cb_models={}
    step = 1

    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :]
        y_train = data_y[tr_idx]

        X_valid = data_x.iloc[val_idx, :]
        y_valid = data_y[val_idx]

        cb_dtrain = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        cb_dvalid = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        cb_model = CatBoostRegressor(iterations=20000, eval_metric='RMSE', loss_function='RMSE', verbose = 0)

        cb_model.fit(cb_dtrain, eval_set=cb_dvalid, early_stopping_rounds=100, verbose_eval=1000, use_best_model=True)
        cb_models[step] = cb_model

        step += 1
        
    # cb 성능종합
    performance = [cb_models[step].best_score_['validation']['RMSE'] for step in range(1,6)]
    performance.append(np.mean(performance))

    output = pd.DataFrame({'cb':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %%
def knn_model(data_x, data_y):

    # knn 모델링
    performance = []
    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :]
        y_train = data_y[tr_idx]

        X_valid = data_x.iloc[val_idx, :]
        y_valid = data_y[val_idx]

        knn_model = KNeighborsRegressor()
        knn_model.fit(X_train, y_train)

        pred_valid = knn_model.predict(X_valid)
        rmse = mean_squared_error(y_valid, pred_valid, squared=False)
        performance.append(rmse)
        
    # knn 성능종합
    performance.append(np.mean(performance))

    output = pd.DataFrame({'knn':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %%
def regression_model(data_x, data_y):

    # regression 모델링
    performance = []
    cv = KFold(n_splits = n_splits, shuffle = True, random_state=42)

    for tr_idx, val_idx in cv.split(data_x):  

        X_train = data_x.iloc[tr_idx, :]
        y_train = data_y[tr_idx]

        X_valid = data_x.iloc[val_idx, :]
        y_valid = data_y[val_idx]

        regression_model = LinearRegression()
        regression_model.fit(X_train, y_train)

        pred_valid = regression_model.predict(X_valid)
        rmse = mean_squared_error(y_valid, pred_valid, squared=False)
        performance.append(rmse)
        
    # regression 성능종합
    performance.append(np.mean(performance))

    output = pd.DataFrame({'regression':performance}, index=['cv1','cv2','cv3','cv4','cv5','평균'])
    return output

# %% [markdown]
# # train, test분할 후 모델링

# %%
hitter = pd.read_csv('../선수데이터(전처리완료)/타자(모델링용).csv')
pitcher = pd.read_csv('../선수데이터(전처리완료)/투수(모델링용).csv')

# %% [markdown]
# #### 1. 타자

# %%
# train, test 분할
col_dict, X, y = Xy_split(hitter)
X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

X = X.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y = y.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
# 타자데이터 도출
hitter_performance = pd.concat([rf_model(X, y),
                                  lgbm_model(X, y),
                                  xgb_model(X, y),
                                  cb_model(X, y),
                                  knn_model(X, y),
                                  regression_model(X, y)], axis=1)
# Out:
#  ============================ 1 ============================
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's rmse: 18451.3
# [2000]	valid_0's rmse: 18420.8
# [3000]	valid_0's rmse: 18419.9
# Early stopping, best iteration is:
# [3318]	valid_0's rmse: 18419.9
#
#
#  ============================ 2 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [44]	valid_0's rmse: 14847
#
#
#  ============================ 3 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [12]	valid_0's rmse: 14796.4
#
#
#  ============================ 4 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [37]	valid_0's rmse: 11639.7
#
#
#  ============================ 5 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [115]	valid_0's rmse: 14675.5
# [0]	train-rmse:26942.34766	eval-rmse:31251.62695
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [52]	train-rmse:1003.94617	eval-rmse:19265.26367
#
# [0]	train-rmse:27199.75781	eval-rmse:30016.45312
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [7]	train-rmse:6376.16455	eval-rmse:14374.27637
#
# [0]	train-rmse:28645.83008	eval-rmse:22419.62305
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [7]	train-rmse:6449.81689	eval-rmse:12889.06641
#
# [0]	train-rmse:27734.21484	eval-rmse:28032.51172
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [9]	train-rmse:5253.46777	eval-rmse:13683.84766
#
# [0]	train-rmse:27089.64258	eval-rmse:30660.32422
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [23]	train-rmse:2494.42383	eval-rmse:16778.28906
#
# Learning rate set to 0.008468
# 0:	learn: 32394.7135347	test: 36053.8473815	best: 36053.8473815 (0)	total: 133ms	remaining: 44m 15s
# 1000:	learn: 7895.6758048	test: 18207.0227862	best: 18202.4992712 (994)	total: 7.8s	remaining: 2m 28s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 17979.34678
# bestIteration = 1379
#
# Shrink model to first 1380 iterations.
# Learning rate set to 0.008468
# 0:	learn: 32709.1773591	test: 34912.7818492	best: 34912.7818492 (0)	total: 8.36ms	remaining: 2m 47s
# 1000:	learn: 8044.1453962	test: 15238.1279712	best: 15238.1279712 (1000)	total: 7.35s	remaining: 2m 19s
# 2000:	learn: 5128.4991645	test: 14370.5911711	best: 14370.5911711 (2000)	total: 14.1s	remaining: 2m 6s
# 3000:	learn: 3546.9669493	test: 14222.2207040	best: 14220.0783906 (2934)	total: 20.6s	remaining: 1m 56s
# 4000:	learn: 2580.8579377	test: 14132.6288038	best: 14132.6288038 (4000)	total: 27.1s	remaining: 1m 48s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 14083.62958
# bestIteration = 4504
#
# Shrink model to first 4505 iterations.
# Learning rate set to 0.008469
# 0:	learn: 34817.2039859	test: 25577.0120363	best: 25577.0120363 (0)	total: 10.3ms	remaining: 3m 26s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13888.59345
# bestIteration = 731
#
# Shrink model to first 732 iterations.
# Learning rate set to 0.008469
# 0:	learn: 33273.7445078	test: 32788.9448666	best: 32788.9448666 (0)	total: 7.89ms	remaining: 2m 37s
# 1000:	learn: 8738.1580986	test: 12286.4479974	best: 12285.8910956 (999)	total: 6.68s	remaining: 2m 6s
# 2000:	learn: 5278.2051785	test: 11711.8972248	best: 11711.6364354 (1999)	total: 13.3s	remaining: 1m 59s
# 3000:	learn: 3683.5519072	test: 11568.3931839	best: 11568.3931839 (3000)	total: 19.9s	remaining: 1m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 11544.46573
# bestIteration = 3226
#
# Shrink model to first 3227 iterations.
# Learning rate set to 0.008469
# 0:	learn: 32567.2374159	test: 35492.5348445	best: 35492.5348445 (0)	total: 18.5ms	remaining: 6m 9s
# 1000:	learn: 8168.5217904	test: 15767.8397304	best: 15767.7809818 (999)	total: 7.16s	remaining: 2m 15s
# 2000:	learn: 5535.6717390	test: 15201.8900334	best: 15200.5055088 (1997)	total: 14.1s	remaining: 2m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 15195.40324
# bestIteration = 2048
#
# Shrink model to first 2049 iterations.

# %% [markdown]
# #### 2. 투수

# %%
# train, test 분할
col_dict, X, y = Xy_split(pitcher)
X, X_test, y, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 42)

X = X.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y = y.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
# 타자데이터 도출
pitcher_performance = pd.concat([rf_model(X, y),
                                  lgbm_model(X, y),
                                  xgb_model(X, y),
                                  cb_model(X, y),
                                  knn_model(X, y),
                                  regression_model(X, y)], axis=1)
# Out:
#  ============================ 1 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [110]	valid_0's rmse: 10824.2
#
#
#  ============================ 2 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [707]	valid_0's rmse: 12383.9
#
#
#  ============================ 3 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [629]	valid_0's rmse: 13816.2
#
#
#  ============================ 4 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [87]	valid_0's rmse: 12729.5
#
#
#  ============================ 5 ============================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [135]	valid_0's rmse: 9978.2
# [0]	train-rmse:20657.09961	eval-rmse:18609.31836
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [98]	train-rmse:277.40286	eval-rmse:11886.96582
#
# [0]	train-rmse:19289.38281	eval-rmse:25077.99219
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [98]	train-rmse:234.57732	eval-rmse:14428.16992
#
# [0]	train-rmse:19902.51172	eval-rmse:23098.14648
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [28]	train-rmse:1554.61865	eval-rmse:16302.74707
#
# [0]	train-rmse:19731.56836	eval-rmse:22028.75977
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [51]	train-rmse:860.36853	eval-rmse:10843.75781
#
# [0]	train-rmse:19835.16992	eval-rmse:22473.73047
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [22]	train-rmse:1741.33557	eval-rmse:12779.96680
#
# Learning rate set to 0.008178
# 0:	learn: 24683.6357360	test: 18535.8604295	best: 18535.8604295 (0)	total: 7.32ms	remaining: 2m 26s
# 1000:	learn: 6234.5787934	test: 10731.5274943	best: 10731.5274943 (1000)	total: 5.5s	remaining: 1m 44s
# 2000:	learn: 3926.9912720	test: 10378.5754252	best: 10378.2651069 (1993)	total: 11.3s	remaining: 1m 41s
# 3000:	learn: 2773.2086367	test: 10241.9953450	best: 10240.9218192 (2994)	total: 17.4s	remaining: 1m 38s
# 4000:	learn: 2093.4231542	test: 10207.5477599	best: 10206.7464843 (3918)	total: 23s	remaining: 1m 31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 10182.91037
# bestIteration = 4821
#
# Shrink model to first 4822 iterations.
# Learning rate set to 0.008178
# 0:	learn: 22850.9442068	test: 26386.7687237	best: 26386.7687237 (0)	total: 5.36ms	remaining: 1m 47s
# 1000:	learn: 6148.6096525	test: 14972.8361200	best: 14972.8361200 (1000)	total: 6.11s	remaining: 1m 55s
# 2000:	learn: 3814.0633083	test: 14376.9099924	best: 14376.9099924 (2000)	total: 11.9s	remaining: 1m 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 14336.11889
# bestIteration = 2226
#
# Shrink model to first 2227 iterations.
# Learning rate set to 0.008178
# 0:	learn: 23553.2334194	test: 23696.6587711	best: 23696.6587711 (0)	total: 5.96ms	remaining: 1m 59s
# 1000:	learn: 6076.3504554	test: 14538.2861124	best: 14534.2036357 (994)	total: 5.72s	remaining: 1m 48s
# 2000:	learn: 3864.3488260	test: 13996.8098063	best: 13996.8098063 (2000)	total: 11s	remaining: 1m 39s
# 3000:	learn: 2707.6047210	test: 13846.6075302	best: 13841.1009705 (2923)	total: 16.7s	remaining: 1m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 13841.10097
# bestIteration = 2923
#
# Shrink model to first 2924 iterations.
# Learning rate set to 0.008179
# 0:	learn: 23321.8551407	test: 24648.6460339	best: 24648.6460339 (0)	total: 5.45ms	remaining: 1m 49s
# 1000:	learn: 6517.8262065	test: 13148.3719476	best: 13148.3719476 (1000)	total: 7.62s	remaining: 2m 24s
# 2000:	learn: 4258.6337080	test: 12525.7279292	best: 12523.9827136 (1998)	total: 13.7s	remaining: 2m 3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 12480.15064
# bestIteration = 2154
#
# Shrink model to first 2155 iterations.
# Learning rate set to 0.008179
# 0:	learn: 23475.3826033	test: 24004.1290364	best: 24004.1290364 (0)	total: 6.5ms	remaining: 2m 10s
# 1000:	learn: 6251.9444553	test: 11052.2728698	best: 11052.2728698 (1000)	total: 7.56s	remaining: 2m 23s
# 2000:	learn: 3901.4690693	test: 10625.8914722	best: 10624.5048795 (1991)	total: 14.2s	remaining: 2m 7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 10582.91518
# bestIteration = 2669
#
# Shrink model to first 2670 iterations.

# %%
hitter_performance
# Out:
#                rf          lgbm           xgb            cb           knn  \
# cv1  19062.965001  18419.857842  19265.263672  17979.346783  24309.044907
# cv2  14948.659792  14847.011120  14374.276367  14083.629580  22245.811100
# cv3  14159.109251  14796.443613  12889.066406  13888.593452  16752.209503
# cv4  13561.716226  11639.662181  13683.847656  11544.465733  19936.459560
# cv5  15377.857431  14675.495329  16778.289063  15195.403243  23401.592839
# 평균   15422.061540  14875.694017  15398.148633  14538.287758  21329.023582
#
#        regression
# cv1  19683.116488
# cv2  20540.114117
# cv3  16956.557524
# cv4  18166.131027
# cv5  19412.053978
# 평균   18951.594627

# %%
pitcher_performance
# Out:
#                rf          lgbm           xgb            cb           knn  \
# cv1  11748.253558  10824.219858  11886.965820  10182.910374  14571.069385
# cv2  14634.478167  12383.870205  14428.169922  14336.118890  17939.294682
# cv3  14667.678986  13816.188361  16302.747070  13841.100970  18103.366336
# cv4  12756.476335  12729.498726  10843.757813  12480.150641  16845.421768
# cv5  12140.179929   9978.197740  12779.966797  10582.915176  14137.889689
# 평균   13189.413395  11946.394978  13248.321484  12284.639210  16319.408372
#
#        regression
# cv1  13862.119082
# cv2  18453.360137
# cv3  17635.620481
# cv4  17049.830481
# cv5  16305.818655
# 평균   16661.349767
